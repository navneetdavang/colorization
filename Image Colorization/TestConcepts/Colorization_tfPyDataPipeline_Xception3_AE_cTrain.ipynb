# %% [markdown]
# # Using the Xception Pretrained Model As Encoder in AE
# (changing the relu to the tanh)

# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 8.1 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.24.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.24.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.24.0

# %%
# !nvidia-smi
# Out:
# Tue Feb 15 05:23:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.xception import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                    # no of epochs to train  the model
latent_shape = (8,8,2048)            # shape of latent space / bottleneck from the XceptionNet
_lw = latent_shape[0]
_lh = latent_shape[1]
_lc = latent_shape[2]

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.Accuracy()
val_acc_metric = keras.metrics.Accuracy()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []


modelFileName = 'Ct_tfPyClass_xcept3_GCData_cTrain_100_500'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/' + modelFileName + '.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/' + modelFileName + '.csv'

# %% [markdown]
# #### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    
    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]
                
                w = image.shape[0]
                h = image.shape[1]
                isGrayScale = False
                for i in range(w):
                    for j in range(h):
                        
                        if r[i,j] == g[i,j] == b[i,j]:
                            isGrayScale = True
                        else:
                            isGrayScale = False
                            break
            else:
                isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])
        print(removedImages)
        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages], axis=0)

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                numpy.array 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                numpy.array
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    @staticmethod
    def fixup_shape(_l, _ab, w, h):

        '''
        Description : 
                Method to fix the shape of L and AB channels i.e X and Y
        Input :
                _l => L channel
                _ab => AB channel
                w => Width of the Image 
                h => Height of the Image
        Returns :
                tf.Tensor (shape => (w,h,1)), tf.Tensor (shape => (w,h,2))
        '''

        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, img_height, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Initializing the Pretrained XceptionNet Model

# %% [markdown]
# ##### Xception Net Configuration

# %%
xcept = Xception(include_top=False, input_shape=(256,256,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
xcept.trainable = False

# %%
xcept.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 127, 127, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 127, 127, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 127, 127, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 125, 125, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 125, 125, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 125, 125, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 125, 125, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 125, 125, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 125, 125, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 125, 125, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 125, 125, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 63, 63, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 63, 63, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 63, 63, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 63, 63, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 63, 63, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 63, 63, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 63, 63, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 63, 63, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 63, 63, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 63, 63, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 32, 32, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 32, 32, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 16, 16, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 8, 8, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 8, 8, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 8, 8, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 8, 8, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 8, 8, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 8, 8, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 8, 8, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 8, 8, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# #### Feature Extractor Class

# %%
class FeatureExtractor:
    '''
    Description : Class to Extract the Features from the given images
    '''

    # method to get the latent space from the Xception network
    @staticmethod
    def getLatentSpaceFromXceptionNet(_l, _ab):
        '''
        Description : 
                Method to get the Latent Space from the Xception network
        Input :
                _l => L channel
                _ab => AB channel
        Returns :
                numpy.array (Extracted Feature), 
                numpy.array (shape => (w, h, 2))

        '''

        # print(_l.shape)

        gray_img = _l[:,:,0]

        # reshaping adding 2 extra channel in the gray_img
        gray_img = gray2rgb(gray_img)

        # print('gray2rgb gray_img shape :', gray_img.shape)
        
        # adding extra 1 dim in gray_img to fit in the vggmodel
        gray_img = gray_img.reshape((1,) + gray_img.shape)

        # print('model fit gray_img shape :', gray_img.shape)

        # predicting the latent space
        _latent = xcept.predict(gray_img)

        # print('predicted Latent :', _latent.shape)
        # print('predicted Latent dtype:', _latent.dtype)
    
        _latent = _latent[0]

        # print('predicted Latent :', _latent.shape)
    
        return _latent, _ab

    # method to fixup the shape of the output of the latent space 
    @staticmethod
    def fixup_shape(_latent, _ab, w, h, lw, lh, lc):
        '''
        Description : 
                Method to fixup the shape of the output of the latent space 
        Input :
                _latent => Latent Space
                _ab => AB channel
                w => Width of the AB Channel
                h => Height of the AB Channel
                (lw, lh, lc) => Dimension of the Latent Space
        Returns :
                tf.Tensor (Extracted Feature | shape => (_lw, _lh, _lc)), 
                tf.Tensor (AB Channel | shape => (w, h, 2))

        '''
        _latent.set_shape([lw, lh, lc])
        _ab.set_shape([w,h,2])

        return _latent, _ab

# %% [markdown]
# #### Class to Map the Extracted Features

# %%
class FeatureExtractMapper:
    '''
    Description : Class to Map the Extracted Features to the Dataset
    '''

    # Method to get the Feature Extracted Dataset
    @staticmethod
    def getXYDataset(dataset, img_w, img_h, lw, lh, lc):
        '''
        Description : 
                Method to get the Feature Extracted Dataset
        Input :
                dataset => MapDatset (consist of the splited LAB image channel [L & AB])
                img_w => Width of the Image 
                img_h => Height of the Image
                (lw, lh, lc) => Shape of the Latent Space
        Returns :
                MapDataset shapes: ((lw, lh, lc), (img_w, img_h, 2)), types: (tf.float32, tf.float32)
        '''

        ds = dataset.map(lambda x, y : tf.py_function(FeatureExtractor.getLatentSpaceFromXceptionNet,
                                                     [x, y],
                                                     [tf.float32, tf.float32]))
        
        return ds.map(lambda x, y : FeatureExtractor.fixup_shape(x, y, img_w, img_h, lw, lh, lc))

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')

        _latent, _ab = FeatureExtractor.getLatentSpaceFromXceptionNet(_l, _ab)

        print(f'_fn_predLAB _latent Shape : {_latent.shape}')

        _latent = _latent.reshape((1,) + _latent.shape)
        print(f'_latent re-Shape : {_latent.shape}')

        _abPred = model.predict(_latent)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        print('_fn_imgPostProcess_w')
        w = _ab.shape[1]
        print('_fn_imgPostProcess_h')
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))
        print('ab shape :', _ab.shape)
        print('l shape :', _l.shape)
        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[:,:,0] 
        print('ok')
        result[:,:,1:] = _ab[0,:,:,:]
        print('not ok')

        result = result.astype('float32')
        # print(result)
        print(f'_fn_imgPost result shape : {result.shape}')

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        # result = tf.convert_to_tensor(result)
        # # print(result)

        # rgb = tfio.experimental.color.lab_to_rgb(result)
        # rgb = rgb.numpy()

        rgb = lab2rgb(result)

        # ########
        
        print(f'_fn_imgPost rgb shape : {rgb.shape}')
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 

        print(f'_fn_predRGB _l shape: {_l.shape}')
        print(f'_fn_predRGB predAB shape: {predAB.shape}')

        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8800

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 759 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 1259 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 2841 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 2911 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 3047 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 3808 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 4022 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 4369 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# Removing ## ID : 4398 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# Removing ## ID : 4544 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 6084 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# Removing ## ID : 6354 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 6587 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 6755 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 7362 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
train_lab_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
trainData
# Out:
# <MapDataset shapes: ((256, 256, 1), (256, 256, 2)), types: (tf.float32, tf.float32)>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Mapping the Features on datasets

# %% [markdown]
# ##### Getting the train Feature Dataset

# %%
trainFeatureData = FeatureExtractMapper.getXYDataset(trainData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the val Feature Dataset

# %%
valFeatureData = FeatureExtractMapper.getXYDataset(valData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the test Feature Dataset

# %%
testFeatureData = FeatureExtractMapper.getXYDataset(testData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %%
trainFeatureData = config_ds(trainFeatureData, batchSize)
testFeatureData = config_ds(testFeatureData, batchSize)
valFeatureData = config_ds(valFeatureData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape)

    # decoder

    # # l1
    # l1 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(input_L)

    # # l2
    # l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(l1)
    # l2_up = UpSampling2D(size=(2,2))(l2)

    # # l3
    # l3 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l2_up)
    # l3_up = UpSampling2D(size=(2,2))(l3)

    # # l4
    # l4 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l3_up)
    # l4_up = UpSampling2D(size=(2,2))(l4)

    # # l5
    # l5 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l4_up)
    # l5_up = UpSampling2D(size=(2,2))(l5)

    # # l6
    # l6 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l5_up)
    # l6_up = UpSampling2D(size=(2,2))(l6)

    # decoder

    # l9
    # l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(input_L)
    # l9_up = UpSampling2D((2,2))(l9)

    # # l10
    # l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l9_up)
    # l10_up = UpSampling2D((2,2))(l10)

    # # l11
    # l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l10_up)

    # # l12
    # l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l11)

    # # l13
    # l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l12)
    # l13_up = UpSampling2D((2,2))(l13)


    # deocder

    # l1
    l1 = Conv2DTranspose(filters=512, kernel_size=3, strides=(2,2), padding='same', activation='relu')(input_L)

    # l2
    l2 = Conv2DTranspose(filters=128, kernel_size=3, strides=(2,2), padding='same', activation='relu')(l1)

    # l3
    l3 = Conv2DTranspose(filters=64, kernel_size=3, strides=(2,2), padding='same', activation='relu')(l2)

    # l4
    l4 = Conv2DTranspose(filters=32, kernel_size=3, strides=(2,2), padding='same', activation='relu')(l3)
    
    # l5
    l5 = Conv2DTranspose(filters=2, kernel_size=3, strides=(2,2), padding='same', activation='tanh')(l4)

    return Model(inputs=input_L, outputs=l5)

# %%
model = autoEncoder(inputShape=latent_shape)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8, 8, 2048)]      0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 512)      9437696
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 128)      589952
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 64)       73792
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 128, 128, 32)     18464
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 256, 256, 2)      578
#  ranspose)
#
# =================================================================
# Total params: 10,120,482
# Trainable params: 10,120,482
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='RMSProp', loss='mse', metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer_fn.apply_gradients(zip(grads, model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value

# %%
@tf.function
def test_step(x, y):
    val_logits = model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
import time

epochs = 500
for epoch in range(epochs):
    print("\Epoch : %d / %d" % (epoch+1, epochs))
    start_time = time.time()

    # Iterate over the batches of the dataset.
    _loss = None
    for step, (x_batch_train, y_batch_train) in enumerate(trainFeatureData):
        loss_value = train_step(x_batch_train, y_batch_train)
        _loss = loss_value
        # # Log every 200 batches.
        # if step % 200 == 0:
        #     print(
        #         "Training loss (for one batch) at step %d: %.4f"
        #         % (step, float(loss_value))
        #     )
        #     print("Seen so far: %d samples" % ((step + 1) * batchSize))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in valFeatureData:
        test_step(x_batch_val, y_batch_val)

    val_acc = val_acc_metric.result()
    val_acc_metric.reset_states()
    print(f'Train Loss : {_loss} Train Acc : {train_acc} Val Acc : {float(val_acc)}')
    # print("Validation acc: %.4f" % (float(val_acc),))
    print("Time taken: %.2fs" % (time.time() - start_time))
# Out:
# \Epoch : 1 / 500
# Train Loss : 0.0011247206712141633 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 2.00s
# \Epoch : 2 / 500
# Train Loss : 0.0027120239101350307 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.26s
# \Epoch : 3 / 500
# Train Loss : 0.0014226601924747229 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.26s
# \Epoch : 4 / 500
# Train Loss : 0.0011082636192440987 Train Acc : 0.0 Val Acc : 7.629394644936838e-07
# Time taken: 0.26s
# \Epoch : 5 / 500
# Train Loss : 0.0008534715161658823 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 6 / 500
# Train Loss : 0.0006526996730826795 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.23s
# \Epoch : 7 / 500
# Train Loss : 0.0006048054783605039 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 8 / 500
# Train Loss : 0.0005369107821024954 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 9 / 500
# Train Loss : 0.0004732026718556881 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 10 / 500
# Train Loss : 0.0004535298212431371 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 11 / 500
# Train Loss : 0.0004258504486642778 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 12 / 500
# Train Loss : 0.00039918191032484174 Train Acc : 2.8610230629055877e-07 Val Acc : 7.629394644936838e-07
# Time taken: 0.24s
# \Epoch : 13 / 500
# Train Loss : 0.0003766199224628508 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 14 / 500
# Train Loss : 0.0003618171322159469 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.23s
# \Epoch : 15 / 500
# Train Loss : 0.00035166231100447476 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 16 / 500
# Train Loss : 0.0003439484862610698 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 17 / 500
# Train Loss : 0.00033689875272102654 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 18 / 500
# Train Loss : 0.00033080141292884946 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 19 / 500
# Train Loss : 0.00032681645825505257 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 20 / 500
# Train Loss : 0.00032242402085103095 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 21 / 500
# Train Loss : 0.00031920941546559334 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 22 / 500
# Train Loss : 0.00031630462035536766 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 23 / 500
# Train Loss : 0.00031396574922837317 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.23s
# \Epoch : 24 / 500
# Train Loss : 0.00031210220186039805 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.23s
# \Epoch : 25 / 500
# Train Loss : 0.00031028009834699333 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 26 / 500
# Train Loss : 0.0003089477540925145 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 27 / 500
# Train Loss : 0.0003072327235713601 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 28 / 500
# Train Loss : 0.00030569732189178467 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 29 / 500
# Train Loss : 0.00030484519083984196 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 30 / 500
# Train Loss : 0.00030497409170493484 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 31 / 500
# Train Loss : 0.0003034638939425349 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 32 / 500
# Train Loss : 0.00030277384212240577 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 33 / 500
# Train Loss : 0.00030941414297558367 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 34 / 500
# Train Loss : 0.00030763508402742445 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 35 / 500
# Train Loss : 0.00030830688774585724 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 36 / 500
# Train Loss : 0.0003777972306124866 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 37 / 500
# Train Loss : 0.000376991112716496 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 38 / 500
# Train Loss : 0.00039956136606633663 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 39 / 500
# Train Loss : 0.0008750528795644641 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 40 / 500
# Train Loss : 0.0008258831803686917 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 41 / 500
# Train Loss : 0.0005538059631362557 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 42 / 500
# Train Loss : 0.0005664333002641797 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 43 / 500
# Train Loss : 0.0006197940674610436 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 44 / 500
# Train Loss : 0.00047339440789073706 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 45 / 500
# Train Loss : 0.00043434201506897807 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 46 / 500
# Train Loss : 0.0004107711720280349 Train Acc : 2.8610230629055877e-07 Val Acc : 7.629394644936838e-07
# Time taken: 0.24s
# \Epoch : 47 / 500
# Train Loss : 0.0003999463515356183 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 48 / 500
# Train Loss : 0.0003792826319113374 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 49 / 500
# Train Loss : 0.0003769368049688637 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 50 / 500
# Train Loss : 0.00034963892539963126 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 51 / 500
# Train Loss : 0.0003372841456439346 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 52 / 500
# Train Loss : 0.0003261236706748605 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 53 / 500
# Train Loss : 0.0003180488711223006 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 54 / 500
# Train Loss : 0.0003198689082637429 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 55 / 500
# Train Loss : 0.00031351821962744 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 56 / 500
# Train Loss : 0.00030709189013578 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.34s
# \Epoch : 57 / 500
# Train Loss : 0.00030267826514318585 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 58 / 500
# Train Loss : 0.0003015059628523886 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 59 / 500
# Train Loss : 0.0003015699330717325 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 60 / 500
# Train Loss : 0.0002982135920319706 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 61 / 500
# Train Loss : 0.0003013497043866664 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 62 / 500
# Train Loss : 0.00030936230905354023 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 63 / 500
# Train Loss : 0.00030903794686309993 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 64 / 500
# Train Loss : 0.0003002312150783837 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 65 / 500
# Train Loss : 0.00030524900648742914 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 66 / 500
# Train Loss : 0.00031991995638236403 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 67 / 500
# Train Loss : 0.00030848957248963416 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 68 / 500
# Train Loss : 0.0003033339453395456 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 69 / 500
# Train Loss : 0.00033975226688198745 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 70 / 500
# Train Loss : 0.0003490337112452835 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 71 / 500
# Train Loss : 0.0003252048627473414 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 72 / 500
# Train Loss : 0.00039577719871886075 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 73 / 500
# Train Loss : 0.00045147028868086636 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 74 / 500
# Train Loss : 0.0003925204509869218 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 75 / 500
# Train Loss : 0.0004709218046627939 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 76 / 500
# Train Loss : 0.000638452940620482 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 77 / 500
# Train Loss : 0.0005436184001155198 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 78 / 500
# Train Loss : 0.00039951232611201704 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 79 / 500
# Train Loss : 0.00048035819781944156 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 80 / 500
# Train Loss : 0.0005957413814030588 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 81 / 500
# Train Loss : 0.0005171232623979449 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 82 / 500
# Train Loss : 0.0005129864439368248 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 83 / 500
# Train Loss : 0.0004880400956608355 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 84 / 500
# Train Loss : 0.00040293362690135837 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 85 / 500
# Train Loss : 0.0004106269625481218 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 86 / 500
# Train Loss : 0.0003993294667452574 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 87 / 500
# Train Loss : 0.0003733611956704408 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 88 / 500
# Train Loss : 0.0003487579233478755 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 89 / 500
# Train Loss : 0.0003416659019421786 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 90 / 500
# Train Loss : 0.00032462438684888184 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 91 / 500
# Train Loss : 0.00032898399513214827 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 92 / 500
# Train Loss : 0.0003181922365911305 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 93 / 500
# Train Loss : 0.00033082562731578946 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 94 / 500
# Train Loss : 0.00032341040787287056 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 95 / 500
# Train Loss : 0.0003125398070551455 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 96 / 500
# Train Loss : 0.00029340657056309283 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 97 / 500
# Train Loss : 0.00029092669137753546 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 98 / 500
# Train Loss : 0.00029026088304817677 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 99 / 500
# Train Loss : 0.0002874743950087577 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 100 / 500
# Train Loss : 0.00028328539337962866 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 101 / 500
# Train Loss : 0.0002808815042953938 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 102 / 500
# Train Loss : 0.00027725088875740767 Train Acc : 0.0 Val Acc : 7.629394644936838e-07
# Time taken: 0.24s
# \Epoch : 103 / 500
# Train Loss : 0.0002766748075373471 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 104 / 500
# Train Loss : 0.00027749192668125033 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 105 / 500
# Train Loss : 0.00028167449636384845 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 106 / 500
# Train Loss : 0.0002819924266077578 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 107 / 500
# Train Loss : 0.0002830391749739647 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 108 / 500
# Train Loss : 0.0002928373869508505 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 109 / 500
# Train Loss : 0.0003129831748083234 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 110 / 500
# Train Loss : 0.00030504376627504826 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 111 / 500
# Train Loss : 0.00030483657610602677 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 112 / 500
# Train Loss : 0.00036952923983335495 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 113 / 500
# Train Loss : 0.00039949145866557956 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 114 / 500
# Train Loss : 0.0003429609350860119 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 115 / 500
# Train Loss : 0.00033284249366261065 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 116 / 500
# Train Loss : 0.00043640058720484376 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 117 / 500
# Train Loss : 0.000593002769164741 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 118 / 500
# Train Loss : 0.0006213795277290046 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 119 / 500
# Train Loss : 0.0003524115600157529 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 120 / 500
# Train Loss : 0.000397712632548064 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 121 / 500
# Train Loss : 0.0004104909021407366 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 122 / 500
# Train Loss : 0.00038304959889501333 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 123 / 500
# Train Loss : 0.0004329850780777633 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 124 / 500
# Train Loss : 0.0004250748606864363 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 125 / 500
# Train Loss : 0.00033316054032184184 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 126 / 500
# Train Loss : 0.00031271553598344326 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 127 / 500
# Train Loss : 0.00032395729795098305 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 128 / 500
# Train Loss : 0.0003381871501915157 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 129 / 500
# Train Loss : 0.00031280488474294543 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 130 / 500
# Train Loss : 0.0003002964658662677 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 131 / 500
# Train Loss : 0.00032059423392638564 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 132 / 500
# Train Loss : 0.00033732003066688776 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 133 / 500
# Train Loss : 0.0002898650709539652 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 134 / 500
# Train Loss : 0.0002822456299327314 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 135 / 500
# Train Loss : 0.00032053288305178285 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 136 / 500
# Train Loss : 0.0003359789843671024 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 137 / 500
# Train Loss : 0.0002998940763063729 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 138 / 500
# Train Loss : 0.00029081007232889533 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 139 / 500
# Train Loss : 0.0003293886547908187 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 140 / 500
# Train Loss : 0.0003450574877206236 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 141 / 500
# Train Loss : 0.00028637773357331753 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 142 / 500
# Train Loss : 0.00027665309607982635 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 143 / 500
# Train Loss : 0.00031557708280161023 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 144 / 500
# Train Loss : 0.0003326990408822894 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 145 / 500
# Train Loss : 0.00029858428752049804 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 146 / 500
# Train Loss : 0.0002832381578627974 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 147 / 500
# Train Loss : 0.000332971423631534 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 148 / 500
# Train Loss : 0.00036561270826496184 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 149 / 500
# Train Loss : 0.00029951450414955616 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 150 / 500
# Train Loss : 0.0002771204453893006 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 151 / 500
# Train Loss : 0.00031707511516287923 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 152 / 500
# Train Loss : 0.000359910074621439 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 153 / 500
# Train Loss : 0.0003529053064994514 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 154 / 500
# Train Loss : 0.00029027057462371886 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 155 / 500
# Train Loss : 0.0003095483989454806 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 156 / 500
# Train Loss : 0.0003709428128786385 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 157 / 500
# Train Loss : 0.00036037940299138427 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 158 / 500
# Train Loss : 0.00032899080542847514 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 159 / 500
# Train Loss : 0.0002993679081555456 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 160 / 500
# Train Loss : 0.0003267578431405127 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 161 / 500
# Train Loss : 0.0004132130998186767 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 162 / 500
# Train Loss : 0.00044373777927830815 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 163 / 500
# Train Loss : 0.0003639703500084579 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 164 / 500
# Train Loss : 0.00034481051261536777 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 165 / 500
# Train Loss : 0.00033457751851528883 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 166 / 500
# Train Loss : 0.00036056735552847385 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 167 / 500
# Train Loss : 0.00035923332325182855 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 168 / 500
# Train Loss : 0.00036136253038421273 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 169 / 500
# Train Loss : 0.00033904469455592334 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 170 / 500
# Train Loss : 0.0003276631759945303 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 171 / 500
# Train Loss : 0.0003485377528704703 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 172 / 500
# Train Loss : 0.00039209905662573874 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 173 / 500
# Train Loss : 0.00040681747486814857 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 174 / 500
# Train Loss : 0.00032644683960825205 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 175 / 500
# Train Loss : 0.0003111821715719998 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 176 / 500
# Train Loss : 0.00031266643782146275 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 177 / 500
# Train Loss : 0.00032305126660503447 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 178 / 500
# Train Loss : 0.0003122759808320552 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 179 / 500
# Train Loss : 0.00030943332239985466 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 180 / 500
# Train Loss : 0.00029818105394952 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 181 / 500
# Train Loss : 0.0002884708228521049 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 182 / 500
# Train Loss : 0.0002696164301596582 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 183 / 500
# Train Loss : 0.0002683495986275375 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 184 / 500
# Train Loss : 0.00027548434445634484 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 185 / 500
# Train Loss : 0.00028505921363830566 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 186 / 500
# Train Loss : 0.00028101252974011004 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 187 / 500
# Train Loss : 0.0002699285978451371 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 188 / 500
# Train Loss : 0.00026240950683131814 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 189 / 500
# Train Loss : 0.00027477683033794165 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 190 / 500
# Train Loss : 0.0002871567849069834 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 191 / 500
# Train Loss : 0.0002890806063078344 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 192 / 500
# Train Loss : 0.00026752089615911245 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 193 / 500
# Train Loss : 0.00025387457571923733 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 194 / 500
# Train Loss : 0.00025455100694671273 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 195 / 500
# Train Loss : 0.00026082005933858454 Train Acc : 9.536743306171047e-08 Val Acc : 7.629394644936838e-07
# Time taken: 0.24s
# \Epoch : 196 / 500
# Train Loss : 0.0002581515582278371 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 197 / 500
# Train Loss : 0.0002503652940504253 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 198 / 500
# Train Loss : 0.00024539546575397253 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 199 / 500
# Train Loss : 0.0002532822254579514 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 200 / 500
# Train Loss : 0.00025605945847928524 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 201 / 500
# Train Loss : 0.0002466512378305197 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 202 / 500
# Train Loss : 0.00023701202007941902 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 203 / 500
# Train Loss : 0.00024007954925764352 Train Acc : 5.722046125811175e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 204 / 500
# Train Loss : 0.00024493661476299167 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 205 / 500
# Train Loss : 0.0002440292591927573 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 206 / 500
# Train Loss : 0.00024125688651110977 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 207 / 500
# Train Loss : 0.00023896215134300292 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 208 / 500
# Train Loss : 0.0002473913482390344 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 209 / 500
# Train Loss : 0.00027330854209139943 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 210 / 500
# Train Loss : 0.000249559961957857 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 211 / 500
# Train Loss : 0.0002421853569103405 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 212 / 500
# Train Loss : 0.0003286144929006696 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 213 / 500
# Train Loss : 0.0003181032952852547 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 214 / 500
# Train Loss : 0.00031758492696098983 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 215 / 500
# Train Loss : 0.00041829439578577876 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 216 / 500
# Train Loss : 0.00041190069168806076 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 217 / 500
# Train Loss : 0.0007033414440229535 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 218 / 500
# Train Loss : 0.0007887115934863687 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 219 / 500
# Train Loss : 0.0003644778043963015 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 220 / 500
# Train Loss : 0.0006701771635562181 Train Acc : 0.0 Val Acc : 7.629394644936838e-07
# Time taken: 0.25s
# \Epoch : 221 / 500
# Train Loss : 0.0007166778086684644 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 222 / 500
# Train Loss : 0.0005489722825586796 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 223 / 500
# Train Loss : 0.0007750227814540267 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 224 / 500
# Train Loss : 0.0007910843123681843 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 225 / 500
# Train Loss : 0.0004567523719742894 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 226 / 500
# Train Loss : 0.0004308508650865406 Train Acc : 0.0 Val Acc : 7.629394644936838e-07
# Time taken: 0.25s
# \Epoch : 227 / 500
# Train Loss : 0.00048750260611996055 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 228 / 500
# Train Loss : 0.0004870962875429541 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 229 / 500
# Train Loss : 0.00039199611637741327 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 230 / 500
# Train Loss : 0.0003474238910712302 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 231 / 500
# Train Loss : 0.00031350666540674865 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 232 / 500
# Train Loss : 0.0003053953987546265 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 233 / 500
# Train Loss : 0.0002963290025945753 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 234 / 500
# Train Loss : 0.0002865862916223705 Train Acc : 1.9073486612342094e-07 Val Acc : 7.629394644936838e-07
# Time taken: 0.25s
# \Epoch : 235 / 500
# Train Loss : 0.0002663007180672139 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 236 / 500
# Train Loss : 0.0002538200933486223 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.34s
# \Epoch : 237 / 500
# Train Loss : 0.00024686564574949443 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 238 / 500
# Train Loss : 0.00024475983809679747 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 239 / 500
# Train Loss : 0.00024516196572221816 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 240 / 500
# Train Loss : 0.00024305982515215874 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 241 / 500
# Train Loss : 0.00023638340644538403 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 242 / 500
# Train Loss : 0.00023083297128323466 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 243 / 500
# Train Loss : 0.00022988213459029794 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 244 / 500
# Train Loss : 0.00023200371651910245 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 245 / 500
# Train Loss : 0.0002324179804418236 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 246 / 500
# Train Loss : 0.00022901102784089744 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 247 / 500
# Train Loss : 0.00022469986288342625 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 248 / 500
# Train Loss : 0.000223899885895662 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 249 / 500
# Train Loss : 0.00022599464864470065 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 250 / 500
# Train Loss : 0.00022640240786131471 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 251 / 500
# Train Loss : 0.0002239018795080483 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 252 / 500
# Train Loss : 0.00022282148711383343 Train Acc : 5.722046125811175e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 253 / 500
# Train Loss : 0.0002248870732728392 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 254 / 500
# Train Loss : 0.00022606368293054402 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 255 / 500
# Train Loss : 0.00022320004063658416 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 256 / 500
# Train Loss : 0.00022159755462780595 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 257 / 500
# Train Loss : 0.00022491881099995226 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 258 / 500
# Train Loss : 0.000228708959184587 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 259 / 500
# Train Loss : 0.00022715338855050504 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 260 / 500
# Train Loss : 0.00023013641475699842 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 261 / 500
# Train Loss : 0.00023653468815609813 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 262 / 500
# Train Loss : 0.0002390471927355975 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 263 / 500
# Train Loss : 0.00023281827452592552 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 264 / 500
# Train Loss : 0.00024026920436881483 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 265 / 500
# Train Loss : 0.0002462250122334808 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 266 / 500
# Train Loss : 0.0002488712198100984 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 267 / 500
# Train Loss : 0.00024358159862458706 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 268 / 500
# Train Loss : 0.0002539980341680348 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 269 / 500
# Train Loss : 0.00024995015701279044 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 270 / 500
# Train Loss : 0.00025027827359735966 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 271 / 500
# Train Loss : 0.0002583604073151946 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 272 / 500
# Train Loss : 0.0002707132953219116 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 273 / 500
# Train Loss : 0.0002586581977084279 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 274 / 500
# Train Loss : 0.0002655704156495631 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 275 / 500
# Train Loss : 0.00024656913592480123 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 276 / 500
# Train Loss : 0.00023047788999974728 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 277 / 500
# Train Loss : 0.0002492806816007942 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 278 / 500
# Train Loss : 0.0002444715064484626 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 279 / 500
# Train Loss : 0.00023063768458086997 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 280 / 500
# Train Loss : 0.00026320660253986716 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 281 / 500
# Train Loss : 0.0002623514155857265 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 282 / 500
# Train Loss : 0.000237438507610932 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 283 / 500
# Train Loss : 0.000275007332675159 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 284 / 500
# Train Loss : 0.00029412913136184216 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 285 / 500
# Train Loss : 0.00027477811090648174 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 286 / 500
# Train Loss : 0.0003080449823755771 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 287 / 500
# Train Loss : 0.00033814687049016356 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 288 / 500
# Train Loss : 0.0002912358904723078 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 289 / 500
# Train Loss : 0.0003305425343569368 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 290 / 500
# Train Loss : 0.00047474296297878027 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 291 / 500
# Train Loss : 0.0004096479678992182 Train Acc : 5.722046125811175e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 292 / 500
# Train Loss : 0.0002676728763617575 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 293 / 500
# Train Loss : 0.0003413370286580175 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 294 / 500
# Train Loss : 0.00038616068195551634 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 295 / 500
# Train Loss : 0.00033753388561308384 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 296 / 500
# Train Loss : 0.00034071371192112565 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 297 / 500
# Train Loss : 0.00034025474451482296 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 298 / 500
# Train Loss : 0.00031315063824877143 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.26s
# \Epoch : 299 / 500
# Train Loss : 0.00028643273981288075 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 300 / 500
# Train Loss : 0.00028771255165338516 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 301 / 500
# Train Loss : 0.0003310019092168659 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.26s
# \Epoch : 302 / 500
# Train Loss : 0.00033889079350046813 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 303 / 500
# Train Loss : 0.0003216286131646484 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 304 / 500
# Train Loss : 0.00027807438164018095 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 305 / 500
# Train Loss : 0.0002725805388763547 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 306 / 500
# Train Loss : 0.00026286300271749496 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 307 / 500
# Train Loss : 0.0002534650848247111 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 308 / 500
# Train Loss : 0.00023944741406012326 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 309 / 500
# Train Loss : 0.00024233039584942162 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 310 / 500
# Train Loss : 0.00023750225955154747 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 311 / 500
# Train Loss : 0.0002270718978252262 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 312 / 500
# Train Loss : 0.00022389904188457876 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 313 / 500
# Train Loss : 0.00022903741046320647 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 314 / 500
# Train Loss : 0.0002250797115266323 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 315 / 500
# Train Loss : 0.00021463375014718622 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 316 / 500
# Train Loss : 0.00021805660799145699 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 317 / 500
# Train Loss : 0.00023273717670235783 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 318 / 500
# Train Loss : 0.0002294971200171858 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 319 / 500
# Train Loss : 0.00022441003238782287 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 320 / 500
# Train Loss : 0.00024293959722854197 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 321 / 500
# Train Loss : 0.00025548020494170487 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 322 / 500
# Train Loss : 0.00022506568348035216 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 323 / 500
# Train Loss : 0.0002214921551058069 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 324 / 500
# Train Loss : 0.00024609395768493414 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 325 / 500
# Train Loss : 0.00024935806868597865 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 326 / 500
# Train Loss : 0.0002277662424603477 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 327 / 500
# Train Loss : 0.00024270756694022566 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 328 / 500
# Train Loss : 0.00027026227326132357 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 329 / 500
# Train Loss : 0.00025810516672208905 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 330 / 500
# Train Loss : 0.00022762242588214576 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 331 / 500
# Train Loss : 0.00027330266311764717 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch :
Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 391 / 500
# Train Loss : 0.000204063777346164 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 392 / 500
# Train Loss : 0.00022670908947475255 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 393 / 500
# Train Loss : 0.00020967848831787705 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 394 / 500
# Train Loss : 0.00019986936240456998 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 395 / 500
# Train Loss : 0.00023930853058118373 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 396 / 500
# Train Loss : 0.0002657089498825371 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 397 / 500
# Train Loss : 0.00023123901337385178 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 398 / 500
# Train Loss : 0.00023367066751234233 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 399 / 500
# Train Loss : 0.00033219330362044275 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 400 / 500
# Train Loss : 0.0003268782456871122 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.34s
# \Epoch : 401 / 500
# Train Loss : 0.00023181652068160474 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.34s
# \Epoch : 402 / 500
# Train Loss : 0.0002687554806470871 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.37s
# \Epoch : 403 / 500
# Train Loss : 0.0003113087732344866 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.32s
# \Epoch : 404 / 500
# Train Loss : 0.00029783963691443205 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.29s
# \Epoch : 405 / 500
# Train Loss : 0.0002682759950403124 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 406 / 500
# Train Loss : 0.0002494034415576607 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 407 / 500
# Train Loss : 0.000252844940405339 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 408 / 500
# Train Loss : 0.0002603197644930333 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 409 / 500
# Train Loss : 0.00024961913004517555 Train Acc : 5.722046125811175e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 410 / 500
# Train Loss : 0.00025751328212209046 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 411 / 500
# Train Loss : 0.0002516117237973958 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 412 / 500
# Train Loss : 0.0002561971195973456 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 413 / 500
# Train Loss : 0.00024650210980325937 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 414 / 500
# Train Loss : 0.00024253554875031114 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 415 / 500
# Train Loss : 0.0002308907569386065 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 416 / 500
# Train Loss : 0.00023496750509366393 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 417 / 500
# Train Loss : 0.0002451288455631584 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 418 / 500
# Train Loss : 0.0002497685782145709 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 419 / 500
# Train Loss : 0.00024522177409380674 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 420 / 500
# Train Loss : 0.00021853312500752509 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 421 / 500
# Train Loss : 0.0002152284432668239 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 422 / 500
# Train Loss : 0.00022256432566791773 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 423 / 500
# Train Loss : 0.00023217301350086927 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 424 / 500
# Train Loss : 0.00022196440841071308 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 425 / 500
# Train Loss : 0.00020506320288404822 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 426 / 500
# Train Loss : 0.00019755256653297693 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 427 / 500
# Train Loss : 0.0002065766602754593 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 428 / 500
# Train Loss : 0.0002178383874706924 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 429 / 500
# Train Loss : 0.000212190774618648 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 430 / 500
# Train Loss : 0.00019835613784380257 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 431 / 500
# Train Loss : 0.00019177942886017263 Train Acc : 0.0 Val Acc : 7.629394644936838e-07
# Time taken: 0.25s
# \Epoch : 432 / 500
# Train Loss : 0.00019646526197902858 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 433 / 500
# Train Loss : 0.00020634577958844602 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 434 / 500
# Train Loss : 0.00020693799888249487 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 435 / 500
# Train Loss : 0.00020108468015678227 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 436 / 500
# Train Loss : 0.00018983683548867702 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.34s
# \Epoch : 437 / 500
# Train Loss : 0.00018978647131007165 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 438 / 500
# Train Loss : 0.00020009878790006042 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 439 / 500
# Train Loss : 0.0002062398416455835 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 440 / 500
# Train Loss : 0.000196571767446585 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 441 / 500
# Train Loss : 0.00018804198771249503 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 442 / 500
# Train Loss : 0.00019131034787278622 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 443 / 500
# Train Loss : 0.00019832875113934278 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 444 / 500
# Train Loss : 0.00019376975251361728 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 445 / 500
# Train Loss : 0.00019095290917903185 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 446 / 500
# Train Loss : 0.00019315836834721267 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 447 / 500
# Train Loss : 0.00019297291873954237 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 448 / 500
# Train Loss : 0.0002001694665523246 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 449 / 500
# Train Loss : 0.00020523213606793433 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 450 / 500
# Train Loss : 0.00019063659419771284 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 451 / 500
# Train Loss : 0.00019265912123955786 Train Acc : 5.722046125811175e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 452 / 500
# Train Loss : 0.00022210055612958968 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 453 / 500
# Train Loss : 0.00020755271543748677 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 454 / 500
# Train Loss : 0.00020031561143696308 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 455 / 500
# Train Loss : 0.00026256387354806066 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 456 / 500
# Train Loss : 0.00023992781643755734 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 457 / 500
# Train Loss : 0.00022904490469954908 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 458 / 500
# Train Loss : 0.00038273734389804304 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 459 / 500
# Train Loss : 0.000370668713003397 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 460 / 500
# Train Loss : 0.0002870692405849695 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 461 / 500
# Train Loss : 0.0005604734178632498 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 462 / 500
# Train Loss : 0.0006012577214278281 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 463 / 500
# Train Loss : 0.00027485910686664283 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 464 / 500
# Train Loss : 0.0003486574278213084 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 465 / 500
# Train Loss : 0.0004779946757480502 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 466 / 500
# Train Loss : 0.000445981917437166 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 467 / 500
# Train Loss : 0.00040079100290313363 Train Acc : 2.8610230629055877e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 468 / 500
# Train Loss : 0.0003027909551747143 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 469 / 500
# Train Loss : 0.0002988192136399448 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 470 / 500
# Train Loss : 0.0003316157090011984 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 471 / 500
# Train Loss : 0.000355479191057384 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 472 / 500
# Train Loss : 0.00035817758180201054 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.26s
# \Epoch : 473 / 500
# Train Loss : 0.00035344561911188066 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 474 / 500
# Train Loss : 0.000295616511721164 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 475 / 500
# Train Loss : 0.00027693939046002924 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 476 / 500
# Train Loss : 0.0002581578737590462 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 477 / 500
# Train Loss : 0.0002494889486115426 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 478 / 500
# Train Loss : 0.00023037151549942791 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 479 / 500
# Train Loss : 0.00022266068845055997 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 480 / 500
# Train Loss : 0.00020765390945598483 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 481 / 500
# Train Loss : 0.00019797205459326506 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 482 / 500
# Train Loss : 0.00019414442067500204 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 483 / 500
# Train Loss : 0.00019477913156151772 Train Acc : 4.76837158203125e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 484 / 500
# Train Loss : 0.00019286329916212708 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 485 / 500
# Train Loss : 0.00018956318672280759 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 486 / 500
# Train Loss : 0.0001877274626167491 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 487 / 500
# Train Loss : 0.00018469369388185441 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 488 / 500
# Train Loss : 0.00018428091425448656 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 489 / 500
# Train Loss : 0.00018573530542198569 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 490 / 500
# Train Loss : 0.00018638376786839217 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 491 / 500
# Train Loss : 0.00018285313853994012 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 492 / 500
# Train Loss : 0.00018031836953014135 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 493 / 500
# Train Loss : 0.00018102301692124456 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 494 / 500
# Train Loss : 0.0001795687130652368 Train Acc : 5.722046125811175e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 495 / 500
# Train Loss : 0.00017830869182944298 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 496 / 500
# Train Loss : 0.00018030230421572924 Train Acc : 0.0 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 497 / 500
# Train Loss : 0.00017865626432467252 Train Acc : 9.536743306171047e-08 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 498 / 500
# Train Loss : 0.00017477473011240363 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.24s
# \Epoch : 499 / 500
# Train Loss : 0.00018242988153360784 Train Acc : 1.9073486612342094e-07 Val Acc : 0.0
# Time taken: 0.25s
# \Epoch : 500 / 500
# Train Loss : 0.00018468417692929506 Train Acc : 3.814697322468419e-07 Val Acc : 0.0
# Time taken: 0.25s

# %%
# training the model
history = model.fit(trainFeatureData, validation_data=valFeatureData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 21s 3s/step - loss: 0.0497 - accuracy: 0.5121 - val_loss: 0.0100 - val_accuracy: 0.5907
# Epoch 2/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0125 - accuracy: 0.6534 - val_loss: 0.0097 - val_accuracy: 0.5976
# Epoch 3/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0120 - accuracy: 0.6677 - val_loss: 0.0098 - val_accuracy: 0.5952
# Epoch 4/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0118 - accuracy: 0.6691 - val_loss: 0.0100 - val_accuracy: 0.5938
# Epoch 5/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0116 - accuracy: 0.6692 - val_loss: 0.0103 - val_accuracy: 0.5936
# Epoch 6/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0114 - accuracy: 0.6689 - val_loss: 0.0108 - val_accuracy: 0.5937
# Epoch 7/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0113 - accuracy: 0.6695 - val_loss: 0.0120 - val_accuracy: 0.5932
# Epoch 8/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0114 - accuracy: 0.6699 - val_loss: 0.0106 - val_accuracy: 0.5941
# Epoch 9/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0110 - accuracy: 0.6702 - val_loss: 0.0122 - val_accuracy: 0.5941
# Epoch 10/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0108 - accuracy: 0.6712 - val_loss: 0.0152 - val_accuracy: 0.5958
# Epoch 11/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0111 - accuracy: 0.6712 - val_loss: 0.0110 - val_accuracy: 0.5945
# Epoch 12/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0105 - accuracy: 0.6715 - val_loss: 0.0147 - val_accuracy: 0.5943
# Epoch 13/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0105 - accuracy: 0.6720 - val_loss: 0.0135 - val_accuracy: 0.6006
# Epoch 14/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0099 - accuracy: 0.6756 - val_loss: 0.0174 - val_accuracy: 0.5984
# Epoch 15/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0105 - accuracy: 0.6701 - val_loss: 0.0139 - val_accuracy: 0.6095
# Epoch 16/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0096 - accuracy: 0.6800 - val_loss: 0.0166 - val_accuracy: 0.6046
# Epoch 17/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0094 - accuracy: 0.6751 - val_loss: 0.0101 - val_accuracy: 0.6148
# Epoch 18/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0108 - accuracy: 0.6810 - val_loss: 0.0103 - val_accuracy: 0.6009
# Epoch 19/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0099 - accuracy: 0.6765 - val_loss: 0.0113 - val_accuracy: 0.6245
# Epoch 20/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0090 - accuracy: 0.6891 - val_loss: 0.0122 - val_accuracy: 0.6278
# Epoch 21/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0086 - accuracy: 0.6975 - val_loss: 0.0090 - val_accuracy: 0.6146
# Epoch 22/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0109 - accuracy: 0.6755 - val_loss: 0.0099 - val_accuracy: 0.6241
# Epoch 23/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0093 - accuracy: 0.6893 - val_loss: 0.0095 - val_accuracy: 0.6217
# Epoch 24/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0085 - accuracy: 0.6969 - val_loss: 0.0105 - val_accuracy: 0.6301
# Epoch 25/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0081 - accuracy: 0.7049 - val_loss: 0.0088 - val_accuracy: 0.6077
# Epoch 26/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0093 - accuracy: 0.6827 - val_loss: 0.0139 - val_accuracy: 0.6282
# Epoch 27/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0084 - accuracy: 0.6909 - val_loss: 0.0084 - val_accuracy: 0.6262
# Epoch 28/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.
# Epoch 495/500
# 3/3 [==============================] - 0s 98ms/step - loss: 7.1802e-04 - accuracy: 0.8766 - val_loss: 0.0116 - val_accuracy: 0.6239
# Epoch 496/500
# 3/3 [==============================] - 0s 94ms/step - loss: 6.0477e-04 - accuracy: 0.8848 - val_loss: 0.0118 - val_accuracy: 0.6439
# Epoch 497/500
# 3/3 [==============================] - 0s 100ms/step - loss: 5.9680e-04 - accuracy: 0.8735 - val_loss: 0.0106 - val_accuracy: 0.6259
# Epoch 498/500
# 3/3 [==============================] - 0s 94ms/step - loss: 5.7917e-04 - accuracy: 0.8861 - val_loss: 0.0123 - val_accuracy: 0.6527
# Epoch 499/500
# 3/3 [==============================] - 0s 96ms/step - loss: 8.0759e-04 - accuracy: 0.8671 - val_loss: 0.0094 - val_accuracy: 0.6258
# Epoch 500/500
# 3/3 [==============================] - 0s 95ms/step - loss: 8.2722e-04 - accuracy: 0.8786 - val_loss: 0.0137 - val_accuracy: 0.6474
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Image Colorization/model-history/model/Ct_tfPyClass_xcept3_GCData_100_500.model/assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %%
newModel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8, 8, 2048)]      0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 512)      9437696
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 128)      589952
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 64)       73792
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 128, 128, 32)     18464
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 256, 256, 2)      578
#  ranspose)
#
# =================================================================
# Total params: 10,120,482
# Trainable params: 10,120,482
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/3555.jpg'
# fileName = '/content/test8.jpeg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(model, imgFile)
# Out:
# _fn_predLAB _l Shape : (256, 256, 1)
# _fn_predLAB _latent Shape : (8, 8, 2048)
# _latent re-Shape : (1, 8, 8, 2048)
# _fn_predRGB _l shape: (256, 256, 1)
# _fn_predRGB predAB shape: (1, 256, 256, 2)
# _fn_imgPostProcess_w
# _fn_imgPostProcess_h
# ab shape : (1, 256, 256, 2)
# l shape : (256, 256, 1)
# ok
# not ok
# _fn_imgPost result shape : (256, 256, 3)
# _fn_imgPost rgb shape : (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape)

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----

# %%
for x in test_ds:
    print(x)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1079.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/108.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1080.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1081.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1082.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1083.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1084.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1085.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1086.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1087.jpg', shape=(), dtype=string)
