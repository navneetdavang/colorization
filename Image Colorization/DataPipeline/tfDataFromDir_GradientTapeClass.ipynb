# %% [markdown]
# ### Setup Libs

# %%
# !pip install tensorflow-io
# Out:
# Requirement already satisfied: tensorflow-io in /usr/local/lib/python3.7/dist-packages (0.23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.23.1)

# %%
# !pip install tensorflow-gpu

# %%
# !nvidia-smi
# Out:
# Thu Jan 27 13:32:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Importing the Libs

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %% [markdown]
# ##### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
            else:
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]

                if r.all() == g.all() == b.all():
                    isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])

        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages])

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor 
        '''
        image = tf.io.read_file(filePath)
        image = tf.io.decode_jpeg(image)
        image = tf.image.resize(image, size=[img_width,img_height])
        image = tf.image.convert_image_dtype(image, tf.float32)
        image = image / 255.0           # normalizing the image
        return image 

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                tf.Tensor 
        '''
        labImage = tfio.experimental.color.rgb_to_lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape= [img_width,img_height,2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : ImageUtils.getRGBData(x, img_width, img_height))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : ImageUtils.getLABData(x))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, 2img_height56, 2)), types: (tf.float32, tf.float32)
        '''
        return labImg_ds.map(lambda x : ImageUtils.getXYData(x, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, img):

        '''
        Description :
                Method to takes RGB Image, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                img => RGB image (w * h * 3) (np.array)
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        # type conversion
        img = np.float32(img)
        # normalizing the img
        img /= 255

        # converting img to lab space using opencv
        # bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        # lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)

        # converting img to lab space using opencv
        lab = rgb2lab(img)
        print(lab.shape)

        # splitting the channels
        _l = []
        _l.append(lab[:,:,0] / 100)
        
        _l = np.array(_l)
        _l = _l.reshape(_l.shape + (1,))

        print(_l.shape)

        p_ab = model.predict(_l)
        print(p_ab.shape)   
        return np.array(_l), np.array(p_ab)

    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        w = _ab.shape[1]
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))

        # de normalizing the values
        _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[0,:,:,0] 
        result[:,:,1:] = _ab[0,:,:,:]


        result = result.astype('float32')
        # print(result)
        print(result.shape)

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        rgb = lab2rgb(result)
        
        print(rgb.shape)
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3) (np.array)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 
        print(_l.shape)
        print(predAB.shape)
        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8785

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 196 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 244 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 417 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 531 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 877 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 1216 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 2286 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 2911 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 3167 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# Removing ## ID : 4215 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# Removing ## ID : 4749 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 4766 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 6030 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 6246 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# Removing ## ID : 7319 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(500)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 500

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 400
# Test Size : 50
# Val Size : 50

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 400
# val_ds Size : 50
# test_ds Size : 50

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.numpy().shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(2):
    print('LAB Images Shape :', lab.numpy().shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.batch(32).take(1):
    print('L Shape : ',_l.shape)
    print('AB Shape : ',_ab.shape)
# Out:
# L Shape :  (32, 256, 256, 1)
# AB Shape :  (32, 256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.numpy().shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.numpy().shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.batch(32).take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (32, 256, 256, 1)
# AB Shape :  (32, 256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.numpy().shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.numpy().shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.batch(32).take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (32, 256, 256, 1)
# AB Shape :  (32, 256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                     # no of epochs to train  the model

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []

#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/tfGTClass_GCData_500_500.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/tfGTClass_GCData_500_500.csv'

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape)

    # encoder

    # l1 
    l1 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same',strides=2)(input_L)

    # l2
    l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(l1)
    
    # l3
    l3 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', strides=2)(l2)

    # l4
    l4 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(l3)

    # l5
    l5 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', strides=2)(l4)

    # l6
    l6 = Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same')(l5)

    # l7
    l7 = Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same')(l6)

    # l8
    l8 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(l7)


    # decoder

    # l9
    l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(l8)
    l9_up = UpSampling2D((2,2))(l9)

    # l10
    l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l9_up)
    l10_up = UpSampling2D((2,2))(l10)

    # l11
    l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l10_up)

    # l12
    l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l11)

    # l13
    l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l12)
    l13_up = UpSampling2D((2,2))(l13)

    return Model(inputs=input_L, outputs=l13_up)

# %%
model = autoEncoder()

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d_26 (Conv2D)          (None, 128, 128, 64)      640
#
#  conv2d_27 (Conv2D)          (None, 128, 128, 128)     73856
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 128)       147584
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 256)       295168
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 256)       590080
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 256)       1179904
#
#  conv2d_34 (Conv2D)          (None, 32, 32, 128)       295040
#
#  up_sampling2d_6 (UpSampling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 64)        73792
#
#  up_sampling2d_7 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_36 (Conv2D)          (None, 128, 128, 32)      18464
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 16)      4624
#
#  conv2d_38 (Conv2D)          (None, 128, 128, 2)       290
#
#  up_sampling2d_8 (UpSampling  (None, 256, 256, 2)      0
#  2D)
#
# =================================================================
# Total params: 6,219,410
# Trainable params: 6,219,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer=optimizer_fn, loss=loss_fn,metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
# training the model
history = model.fit(trainData, validation_data=valData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 13/13 [==============================] - 25s 1s/step - loss: 0.1017 - accuracy: 0.6393 - val_loss: 0.0141 - val_accuracy: 0.6330
# Epoch 2/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0125 - accuracy: 0.6644 - val_loss: 0.0139 - val_accuracy: 0.6317
# Epoch 3/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0124 - accuracy: 0.6652 - val_loss: 0.0139 - val_accuracy: 0.6343
# Epoch 4/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0122 - accuracy: 0.6707 - val_loss: 0.0138 - val_accuracy: 0.6386
# Epoch 5/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0121 - accuracy: 0.6761 - val_loss: 0.0137 - val_accuracy: 0.6386
# Epoch 6/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0120 - accuracy: 0.6762 - val_loss: 0.0137 - val_accuracy: 0.6386
# Epoch 7/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0120 - accuracy: 0.6763 - val_loss: 0.0137 - val_accuracy: 0.6388
# Epoch 8/500
# 13/13 [==============================] - 4s 316ms/step - loss: 0.0120 - accuracy: 0.6768 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 9/500
# 13/13 [==============================] - 4s 316ms/step - loss: 0.0120 - accuracy: 0.6797 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 10/500
# 13/13 [==============================] - 4s 319ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6407
# Epoch 11/500
# 13/13 [==============================] - 4s 318ms/step - loss: 0.0119 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 12/500
# 13/13 [==============================] - 4s 317ms/step - loss: 0.0119 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 13/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0119 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 14/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0119 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 15/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0119 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 16/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0118 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 17/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0118 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 18/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0118 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 19/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6793 - val_loss: 0.0137 - val_accuracy: 0.6401
# Epoch 20/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0118 - accuracy: 0.6797 - val_loss: 0.0137 - val_accuracy: 0.6396
# Epoch 21/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6797 - val_loss: 0.0137 - val_accuracy: 0.6380
# Epoch 22/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0118 - accuracy: 0.6791 - val_loss: 0.0137 - val_accuracy: 0.6353
# Epoch 23/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0118 - accuracy: 0.6794 - val_loss: 0.0136 - val_accuracy: 0.6371
# Epoch 24/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0118 - accuracy: 0.6790 - val_loss: 0.0137 - val_accuracy: 0.6332
# Epoch 25/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6779 - val_loss: 0.0138 - val_accuracy: 0.6350
# Epoch 26/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6789 - val_loss: 0.0137 - val_accuracy: 0.6336
# Epoch 27/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6788 - val_loss: 0.0138 - val_accuracy: 0.6308
# Epoch 28/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0117 - accuracy: 0.6781 - val_loss: 0.0137 - val_accuracy: 0.6318
# Epoch 29/500
# 13/13 [==============================] - 4s 317ms/step - loss: 0.0117 - accuracy: 0.6794 - val_loss: 0.0136 - val_accuracy: 0.6399
# Epoch 30/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0117 - accuracy: 0.6804 - val_loss: 0.0136 - val_accuracy: 0.6403
# Epoch 31/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0117 - accuracy: 0.6786 - val_loss: 0.0136 - val_accuracy: 0.6343
# Epoch 32/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0116 - accuracy: 0.6749 - val_loss: 0.0136 - val_accuracy: 0.6363
# Epoch 33/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0117 - accuracy: 0.6759 - val_loss: 0.0135 - val_accuracy: 0.6306
# Epoch 34/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0119 - accuracy: 0.6785 - val_loss: 0.0137 - val_accuracy: 0.6311
# Epoch 35/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6790 - val_loss: 0.0137 - val_accuracy: 0.6344
# Epoch 36/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0123 - accuracy: 0.6556 - val_loss: 0.0139 - val_accuracy: 0.6323
# Epoch 37/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6800 - val_loss: 0.0139 - val_accuracy: 0.6291
# Epoch 38/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6796 - val_loss: 0.0137 - val_accuracy: 0.6391
# Epoch 39/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6805 - val_loss: 0.0136 - val_accuracy: 0.6407
# Epoch 40/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6802 - val_loss: 0.0136 - val_accuracy: 0.6307
# Epoch 41/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0133 - accuracy: 0.6428 - val_loss: 0.0137 - val_accuracy: 0.6408
# Epoch 42/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0120 - accuracy: 0.6796 - val_loss: 0.0138 - val_accuracy: 0.6407
# Epoch 43/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0121 - accuracy: 0.6794 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 44/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6797 - val_loss: 0.0137 - val_accuracy: 0.6404
# Epoch 45/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0119 - accuracy: 0.6791 - val_loss: 0.0137 - val_accuracy: 0.6408
# Epoch 46/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0119 - accuracy: 0.6797 - val_loss: 0.0137 - val_accuracy: 0.6408
# Epoch 47/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0123 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6408
# Epoch 48/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0120 - accuracy: 0.6794 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 49/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0119 - accuracy: 0.6798 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 50/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0119 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 51/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0119 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6407
# Epoch 52/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0119 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6406
# Epoch 53/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0118 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6405
# Epoch 54/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0118 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6405
# Epoch 55/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0118 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6406
# Epoch 56/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0118 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6406
# Epoch 57/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0118 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6401
# Epoch 58/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0118 - accuracy: 0.6749 - val_loss: 0.0137 - val_accuracy: 0.6177
# Epoch 59/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6749 - val_loss: 0.0136 - val_accuracy: 0.6366
# Epoch 60/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6676 - val_loss: 0.0136 - val_accuracy: 0.6360
# Epoch 61/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6779 - val_loss: 0.0138 - val_accuracy: 0.6298
# Epoch 62/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6775 - val_loss: 0.0138 - val_accuracy: 0.6346
# Epoch 63/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6690 - val_loss: 0.0137 - val_accuracy: 0.6380
# Epoch 64/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6799 - val_loss: 0.0137 - val_accuracy: 0.6381
# Epoch 65/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6721 - val_loss: 0.0137 - val_accuracy: 0.6233
# Epoch 66/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6664 - val_loss: 0.0137 - val_accuracy: 0.6339
# Epoch 67/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6768 - val_loss: 0.0138 - val_accuracy: 0.6191
# Epoch 68/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6715 - val_loss: 0.0138 - val_accuracy: 0.6267
# Epoch 69/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0119 - accuracy: 0.6734 - val_loss: 0.0137 - val_accuracy: 0.6394
# Epoch 70/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0119 - accuracy: 0.6794 - val_loss: 0.0138 - val_accuracy: 0.6348
# Epoch 71/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0119 - accuracy: 0.6809 - val_loss: 0.0137 - val_accuracy: 0.6352
# Epoch 72/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0118 - accuracy: 0.6793 - val_loss: 0.0137 - val_accuracy: 0.6391
# Epoch 73/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0118 - accuracy: 0.6803 - val_loss: 0.0137 - val_accuracy: 0.6399
# Epoch 74/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0118 - accuracy: 0.6787 - val_loss: 0.0137 - val_accuracy: 0.6342
# Epoch 75/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0117 - accuracy: 0.6785 - val_loss: 0.0137 - val_accuracy: 0.6360
# Epoch 76/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6779 - val_loss: 0.0137 - val_accuracy: 0.6327
# Epoch 77/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0117 - accuracy: 0.6777 - val_loss: 0.0137 - val_accuracy: 0.6265
# Epoch 78/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6726 - val_loss: 0.0137 - val_accuracy: 0.6319
# Epoch 79/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0116 - accuracy: 0.6751 - val_loss: 0.0137 - val_accuracy: 0.6280
# Epoch 80/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0117 - accuracy: 0.6677 - val_loss: 0.0137 - val_accuracy: 0.6401
# Epoch 81/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0118 - accuracy: 0.6798 - val_loss: 0.0136 - val_accuracy: 0.6402
# Epoch 82/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0118 - accuracy: 0.6799 - val_loss: 0.0136 - val_accuracy: 0.6363
# Epoch 83/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6766 - val_loss: 0.0136 - val_accuracy: 0.6368
# Epoch 84/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6761 - val_loss: 0.0136 - val_accuracy: 0.6360
# Epoch 85/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0117 - accuracy: 0.6600 - val_loss: 0.0136 - val_accuracy: 0.6184
# Epoch 86/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0119 - accuracy: 0.6473 - val_loss: 0.0137 - val_accuracy: 0.6354
# Epoch 87/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6793 - val_loss: 0.0137 - val_accuracy: 0.6347
# Epoch 88/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6791 - val_loss: 0.0137 - val_accuracy: 0.6342
# Epoch 89/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0116 - accuracy: 0.6788 - val_loss: 0.0136 - val_accuracy: 0.6293
# Epoch 90/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0116 - accuracy: 0.6654 - val_loss: 0.0137 - val_accuracy: 0.6258
# Epoch 91/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0116 - accuracy: 0.6663 - val_loss: 0.0135 - val_accuracy: 0.6359
# Epoch 92/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0117 - accuracy: 0.6735 - val_loss: 0.0137 - val_accuracy: 0.6305
# Epoch 93/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0119 - accuracy: 0.6706 - val_loss: 0.0137 - val_accuracy: 0.6326
# Epoch 94/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6767 - val_loss: 0.0139 - val_accuracy: 0.6027
# Epoch 95/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0118 - accuracy: 0.6620 - val_loss: 0.0137 - val_accuracy: 0.6388
# Epoch 96/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0118 - accuracy: 0.6801 - val_loss: 0.0136 - val_accuracy: 0.6372
# Epoch 97/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6701 - val_loss: 0.0136 - val_accuracy: 0.6199
# Epoch 98/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0117 - accuracy: 0.6680 - val_loss: 0.0136 - val_accuracy: 0.6399
# Epoch 99/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0117 - accuracy: 0.6778 - val_loss: 0.0137 - val_accuracy: 0.6312
# Epoch 100/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0116 - accuracy: 0.6730 - val_loss: 0.0136 - val_accuracy: 0.6271
# Epoch 101/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0116 - accuracy: 0.6641 - val_loss: 0.0136 - val_accuracy: 0.6243
# Epoch 102/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0116 - accuracy: 0.6679 - val_loss: 0.0136 - val_accuracy: 0.6248
# Epoch 103/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0116 - accuracy: 0.6742 - val_loss: 0.0136 - val_accuracy: 0.6307
# Epoch 104/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0116 - accuracy: 0.6787 - val_loss: 0.0137 - val_accuracy: 0.6291
# Epoch 105/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0116 - accuracy: 0.6755 - val_loss: 0.0136 - val_accuracy: 0.6252
# Epoch 106/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0115 - accuracy: 0.6714 - val_loss: 0.0136 - val_accuracy: 0.6249
# Epoch 107/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0115 - accuracy: 0.6697 - val_loss: 0.0139 - val_accuracy: 0.6235
# Epoch 108/500
# 13/13 [==============================] - 4s 314ms/step - loss: 0.0115 - accuracy: 0.6615 - val_loss: 0.0138 - val_accuracy: 0.6192
# Epoch 109/500
# 13/13 [==============================] - 4s 316ms/step - loss: 0.0114 - accuracy: 0.6729 - val_loss: 0.0135 - val_accuracy: 0.6297
# Epoch 110/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0115 - accuracy: 0.6550 - val_loss: 0.0133 - val_accuracy: 0.6375
# Epoch 111/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0115 - accuracy: 0.6799 - val_loss: 0.0133 - val_accuracy: 0.6388
# Epoch 112/500
# 13/13 [==============================] - 4s 316ms/step - loss: 0.0114 - accuracy: 0.6758 - val_loss: 0.0133 - val_accuracy: 0.6342
# Epoch 113/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0116 - accuracy: 0.6780 - val_loss: 0.0134 - val_accuracy: 0.6086
# Epoch 114/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0115 - accuracy: 0.6696 - val_loss: 0.0138 - val_accuracy: 0.6258
# Epoch 115/500
# 13/13 [==============================] - 4s 316ms/step - loss: 0.0114 - accuracy: 0.6744 - val_loss: 0.0137 - val_accuracy: 0.6347
# Epoch 116/500
# 13/13 [==============================] - 4s 317ms/step - loss: 0.0113 - accuracy: 0.6771 - val_loss: 0.0136 - val_accuracy: 0.6259
# Epoch 117/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0113 - accuracy: 0.6681 - val_loss: 0.0145 - val_accuracy: 0.6233
# Epoch 118/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0114 - accuracy: 0.6764 - val_loss: 0.0149 - val_accuracy: 0.6212
# Epoch 119/500
# 13/13 [==============================] - 4s 317ms/step - loss: 0.0113 - accuracy: 0.6694 - val_loss: 0.0146 - val_accuracy: 0.6241
# Epoch 120/500
# 13/13 [==============================] - 4s 317ms/step - loss: 0.0116 - accuracy: 0.6631 - val_loss: 0.0157 - val_accuracy: 0.6261
# Epoch 121/500
# 13/13 [==============================] - 4s 318ms/step - loss: 0.0134 - accuracy: 0.6774 - val_loss: 0.0140 - val_accuracy: 0.6371
# Epoch 122/500
# 13/13 [==============================] - 4s 316ms/step - loss: 0.0120 - accuracy: 0.6803 - val_loss: 0.0135 - val_accuracy: 0.6448
# Epoch 123/500
# 13/13 [==============================] - 4s 315ms/step - loss: 0.0118 - accuracy: 0.6786 - val_loss: 0.0135 - val_accuracy: 0.6490
# Epoch 124/500
# 13/13 [==============================] - 4s 317ms/step - loss: 0.0116 - accuracy: 0.6843 - val_loss: 0.0133 - val_accuracy: 0.6452
# Epoch 125/500
# 13/13 [==============================] - 4s 318ms/step - loss: 0.0116 - accuracy: 0.6858 - val_loss: 0.0139 - val_accuracy: 0.6353
# Epoch 126/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0120 - accuracy: 0.6767 - val_loss: 0.0139 - val_accuracy: 0.6408
# Epoch 127/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 128/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 129/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 130/500
# 13/13 [==============================] - 4s 302ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 131/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 132/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6795 - val_loss: 0.0158 - val_accuracy: 0.6386
# Epoch 133/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0121 - accuracy: 0.6792 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 134/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 135/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 136/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 137/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 138/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 139/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 140/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 141/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 142/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 143/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 144/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 145/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 146/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 147/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 148/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 149/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 150/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 151/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 152/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 153/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 154/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 155/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 156/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 157/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 158/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 159/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 160/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 161/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 162/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 163/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 164/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 165/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 166/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 167/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 168/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 169/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 170/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 171/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 172/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 173/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 174/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 175/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 176/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 177/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 178/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 179/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 180/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 181/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 182/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 183/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 184/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 185/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 186/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 187/500
# 13/13 [==============================] - 4s 303ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 188/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 189/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 190/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 191/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 192/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 193/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 194/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 195/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 196/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 197/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 198/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 199/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 200/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 201/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 202/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 203/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 204/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 205/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 206/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 207/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 208/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 209/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 210/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 211/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 212/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 213/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 214/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 215/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 216/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 217/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 218/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 219/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 220/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 221/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 222/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 223/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 224/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 225/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 226/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 227/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 228/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 229/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 230/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 231/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 232/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 233/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 234/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 235/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 236/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 237/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 238/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 239/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 240/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 241/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 242/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 243/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 244/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 245/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 246/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 247/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 248/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 249/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 250/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 251/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 252/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 253/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 254/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 255/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 256/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 257/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 258/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 259/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 260/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 261/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 262/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 263/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 264/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 265/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 266/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 267/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 268/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 269/500
# 13/13 [==============================] - 4s 303ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 270/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 271/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 272/500
# 13/13 [==============================] - 4s 304ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 273/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 274/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 275/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 276/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 277/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 278/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 279/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 280/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 281/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 282/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 283/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 284/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 285/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 286/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 287/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 288/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 289/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 290/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 291/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 292/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 293/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 294/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 295/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 296/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 297/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 298/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 299/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 300/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 301/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 302/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 303/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 304/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 305/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 306/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 307/500
# 13/13 [==============================] - 4s 305ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 308/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 309/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 310/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 311/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 312/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 313/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 314/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 315/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 316/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 317/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 318/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 319/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 320/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 321/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 322/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 323/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0121 - accuracy: 0.6786 - val_loss: 0.0138 - val_accuracy: 0.6407
# Epoch 324/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0120 - accuracy: 0.6797 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 325/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 326/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 327/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 328/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 329/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 330/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 331/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 332/500
# ...
# Epoch 392/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 393/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 394/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 395/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 396/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 397/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 398/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 399/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 400/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 401/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 402/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 403/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 404/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 405/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 406/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 407/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 408/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 409/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 410/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 411/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 412/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 413/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 414/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 415/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 416/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 417/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 418/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 419/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 420/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 421/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 422/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 423/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 424/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 425/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 426/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 427/500
# 13/13 [==============================] - 4s 306ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 428/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 429/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 430/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 431/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 432/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 433/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 434/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 435/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 436/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 437/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 438/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 439/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 440/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 441/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 442/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 443/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 444/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 445/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 446/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 447/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 448/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 449/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 450/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 451/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 452/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 453/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 454/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 455/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 456/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 457/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 458/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 459/500
# 13/13 [==============================] - 4s 307ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 460/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 461/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 462/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 463/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 464/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 465/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 466/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 467/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 468/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 469/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 470/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 471/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 472/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 473/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 474/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 475/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 476/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 477/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 478/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 479/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 480/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 481/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 482/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 483/500
# 13/13 [==============================] - 4s 309ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 484/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 485/500
# 13/13 [==============================] - 4s 313ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 486/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 487/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 488/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 489/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 490/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 491/500
# 13/13 [==============================] - 4s 308ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 492/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 493/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 494/500
# 13/13 [==============================] - 4s 311ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 495/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 496/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 497/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 498/500
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 499/500
# 13/13 [==============================] - 4s 318ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# Epoch 500/500
# 13/13 [==============================] - 4s 312ms/step - loss: 0.0120 - accuracy: 0.6798 - val_loss: 0.0138 - val_accuracy: 0.6408
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Image Colorization/model-history/model/tfGTClass_GCData_500_500.model/assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %% [markdown]
# #### Predict

# %%
Ximg = imread('/content/gcImages/content/gc-dataset/train/100.jpg')

# %%
rgbResult = Colorizer().predictRGB(newModel, Ximg)
# Out:
# (256, 256, 3)
# (1, 256, 256, 1)
# (1, 256, 256, 2)
# (1, 256, 256, 1)
# (1, 256, 256, 2)
# (256, 256, 3)
# (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape )

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----

# %% [markdown]
# Time Pass

# %%
pts_in_hull = np.load('/content/pts_in_hull.npy')

# %%
pts_in_hull
# Out:
# array([[ -90,   50],
#        [ -90,   60],
#        [ -90,   70],
#        [ -90,   80],
#        [ -90,   90],
#        [ -80,   20],
#        [ -80,   30],
#        [ -80,   40],
#        [ -80,   50],
#        [ -80,   60],
#        [ -80,   70],
#        [ -80,   80],
#        [ -80,   90],
#        [ -70,    0],
#        [ -70,   10],
#        [ -70,   20],
#        [ -70,   30],
#        [ -70,   40],
#        [ -70,   50],
#        [ -70,   60],
#        [ -70,   70],
#        [ -70,   80],
#        [ -70,   90],
#        [ -60,  -20],
#        [ -60,  -10],
#        [ -60,    0],
#        [ -60,   10],
#        [ -60,   20],
#        [ -60,   30],
#        [ -60,   40],
#        [ -60,   50],
#        [ -60,   60],
#        [ -60,   70],
#        [ -60,   80],
#        [ -60,   90],
#        [ -50,  -30],
#        [ -50,  -20],
#        [ -50,  -10],
#        [ -50,    0],
#        [ -50,   10],
#        [ -50,   20],
#        [ -50,   30],
#        [ -50,   40],
#        [ -50,   50],
#        [ -50,   60],
#        [ -50,   70],
#        [ -50,   80],
#        [ -50,   90],
#        [ -50,  100],
#        [ -40,  -40],
#        [ -40,  -30],
#        [ -40,  -20],
#        [ -40,  -10],
#        [ -40,    0],
#        [ -40,   10],
#        [ -40,   20],
#        [ -40,   30],
#        [ -40,   40],
#        [ -40,   50],
#        [ -40,   60],
#        [ -40,   70],
#        [ -40,   80],
#        [ -40,   90],
#        [ -40,  100],
#        [ -30,  -50],
#        [ -30,  -40],
#        [ -30,  -30],
#        [ -30,  -20],
#        [ -30,  -10],
#        [ -30,    0],
#        [ -30,   10],
#        [ -30,   20],
#        [ -30,   30],
#        [ -30,   40],
#        [ -30,   50],
#        [ -30,   60],
#        [ -30,   70],
#        [ -30,   80],
#        [ -30,   90],
#        [ -30,  100],
#        [ -20,  -50],
#        [ -20,  -40],
#        [ -20,  -30],
#        [ -20,  -20],
#        [ -20,  -10],
#        [ -20,    0],
#        [ -20,   10],
#        [ -20,   20],
#        [ -20,   30],
#        [ -20,   40],
#        [ -20,   50],
#        [ -20,   60],
#        [ -20,   70],
#        [ -20,   80],
#        [ -20,   90],
#        [ -20,  100],
#        [ -10,  -60],
#        [ -10,  -50],
#        [ -10,  -40],
#        [ -10,  -30],
#        [ -10,  -20],
#        [ -10,  -10],
#        [ -10,    0],
#        [ -10,   10],
#        [ -10,   20],
#        [ -10,   30],
#        [ -10,   40],
#        [ -10,   50],
#        [ -10,   60],
#        [ -10,   70],
#        [ -10,   80],
#        [ -10,   90],
#        [ -10,  100],
#        [   0,  -70],
#        [   0,  -60],
#        [   0,  -50],
#        [   0,  -40],
#        [   0,  -30],
#        [   0,  -20],
#        [   0,  -10],
#        [   0,    0],
#        [   0,   10],
#        [   0,   20],
#        [   0,   30],
#        [   0,   40],
#        [   0,   50],
#        [   0,   60],
#        [   0,   70],
#        [   0,   80],
#        [   0,   90],
#        [   0,  100],
#        [  10,  -80],
#        [  10,  -70],
#        [  10,  -60],
#        [  10,  -50],
#        [  10,  -40],
#        [  10,  -30],
#        [  10,  -20],
#        [  10,  -10],
#        [  10,    0],
#        [  10,   10],
#        [  10,   20],
#        [  10,   30],
#        [  10,   40],
#        [  10,   50],
#        [  10,   60],
#        [  10,   70],
#        [  10,   80],
#        [  10,   90],
#        [  20,  -80],
#        [  20,  -70],
#        [  20,  -60],
#        [  20,  -50],
#        [  20,  -40],
#        [  20,  -30],
#        [  20,  -20],
#        [  20,  -10],
#        [  20,    0],
#        [  20,   10],
#        [  20,   20],
#        [  20,   30],
#        [  20,   40],
#        [  20,   50],
#        [  20,   60],
#        [  20,   70],
#        [  20,   80],
#        [  20,   90],
#        [  30,  -90],
#        [  30,  -80],
#        [  30,  -70],
#        [  30,  -60],
#        [  30,  -50],
#        [  30,  -40],
#        [  30,  -30],
#        [  30,  -20],
#        [  30,  -10],
#        [  30,    0],
#        [  30,   10],
#        [  30,   20],
#        [  30,   30],
#        [  30,   40],
#        [  30,   50],
#        [  30,   60],
#        [  30,   70],
#        [  30,   80],
#        [  30,   90],
#        [  40, -100],
#        [  40,  -90],
#        [  40,  -80],
#        [  40,  -70],
#        [  40,  -60],
#        [  40,  -50],
#        [  40,  -40],
#        [  40,  -30],
#        [  40,  -20],
#        [  40,  -10],
#        [  40,    0],
#        [  40,   10],
#        [  40,   20],
#        [  40,   30],
#        [  40,   40],
#        [  40,   50],
#        [  40,   60],
#        [  40,   70],
#        [  40,   80],
#        [  40,   90],
#        [  50, -100],
#        [  50,  -90],
#        [  50,  -80],
#        [  50,  -70],
#        [  50,  -60],
#        [  50,  -50],
#        [  50,  -40],
#        [  50,  -30],
#        [  50,  -20],
#        [  50,  -10],
#        [  50,    0],
#        [  50,   10],
#        [  50,   20],
#        [  50,   30],
#        [  50,   40],
#        [  50,   50],
#        [  50,   60],
#        [  50,   70],
#        [  50,   80],
#        [  60, -110],
#        [  60, -100],
#        [  60,  -90],
#        [  60,  -80],
#        [  60,  -70],
#        [  60,  -60],
#        [  60,  -50],
#        [  60,  -40],
#        [  60,  -30],
#        [  60,  -20],
#        [  60,  -10],
#        [  60,    0],
#        [  60,   10],
#        [  60,   20],
#        [  60,   30],
#        [  60,   40],
#        [  60,   50],
#        [  60,   60],
#        [  60,   70],
#        [  60,   80],
#        [  70, -110],
#        [  70, -100],
#        [  70,  -90],
#        [  70,  -80],
#        [  70,  -70],
#        [  70,  -60],
#        [  70,  -50],
#        [  70,  -40],
#        [  70,  -30],
#        [  70,  -20],
#        [  70,  -10],
#        [  70,    0],
#        [  70,   10],
#        [  70,   20],
#        [  70,   30],
#        [  70,   40],
#        [  70,   50],
#        [  70,   60],
#        [  70,   70],
#        [  70,   80],
#        [  80, -110],
#        [  80, -100],
#        [  80,  -90],
#        [  80,  -80],
#        [  80,  -70],
#        [  80,  -60],
#        [  80,  -50],
#        [  80,  -40],
#        [  80,  -30],
#        [  80,  -20],
#        [  80,  -10],
#        [  80,    0],
#        [  80,   10],
#        [  80,   20],
#        [  80,   30],
#        [  80,   40],
#        [  80,   50],
#        [  80,   60],
#        [  80,   70],
#        [  90, -110],
#        [  90, -100],
#        [  90,  -90],
#        [  90,  -80],
#        [  90,  -70],
#        [  90,  -60],
#        [  90,  -50],
#        [  90,  -40],
#        [  90,  -30],
#        [  90,  -20],
#        [  90,  -10],
#        [  90,    0],
#        [  90,   10],
#        [  90,   20],
#        [  90,   30],
#        [  90,   40],
#        [  90,   50],
#        [  90,   60],
#        [  90,   70],
#        [ 100,  -90],
#        [ 100,  -80],
#        [ 100,  -70],
#        [ 100,  -60],
#        [ 100,  -50],
#        [ 100,  -40],
#        [ 100,  -30],
#        [ 100,  -20],
#        [ 100,  -10],
#        [ 100,    0]])
