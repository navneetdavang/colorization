# %% [markdown]
# # Using the VGG16 (v2) Pretrained Model As Encoder in AE

# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 1.5 MB/s
# Collecting tensorflow-io-gcs-filesystem==0.24.0
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 35.0 MB/s
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow-io
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.23.1
#     Uninstalling tensorflow-io-gcs-filesystem-0.23.1:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.23.1
# Successfully installed tensorflow-io-0.24.0 tensorflow-io-gcs-filesystem-0.24.0

# %%
# !nvidia-smi
# Out:
# Sat Feb  5 09:53:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 224
img_h = 224

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                    # no of epochs to train  the model
latent_shape = (7,7,512)            # shape of latent space / bottleneck from the VGG
_lw = latent_shape[0]
_lh = latent_shape[1]
_lc = latent_shape[2]

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []


modelFileName = 'Ct_tfPyClass_2vgg16_GCData_100_500'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/' + modelFileName + '.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/' + modelFileName + '.csv'

# %% [markdown]
# ##### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    
    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]
                
                w = image.shape[0]
                h = image.shape[1]
                isGrayScale = False
                for i in range(w):
                    for j in range(h):
                        
                        if r[i,j] == g[i,j] == b[i,j]:
                            isGrayScale = True
                        else:
                            isGrayScale = False
                            break
            else:
                isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])
        print(removedImages)
        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages], axis=0)

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                numpy.array 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                numpy.array
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    @staticmethod
    def fixup_shape(_l, _ab, w, h):

        '''
        Description : 
                Method to fix the shape of L and AB channels i.e X and Y
        Input :
                _l => L channel
                _ab => AB channel
                w => Width of the Image 
                h => Height of the Image
        Returns :
                tf.Tensor (shape => (w,h,1)), tf.Tensor (shape => (w,h,2))
        '''

        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, img_height, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Initializing the Pretrained VGG16 Model

# %% [markdown]
# ##### VGG16 Configuration

# %%
vggModel = tf.keras.applications.vgg16.VGG16(include_top=False, input_shape=(img_w, img_h, 3))

# %%
vggModel.trainable = False

# %%
vggModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
for i, layer in enumerate(vggModel.layers[:19]):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_4 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 False
# 18 block5_pool False

# %%
# taking first 
vgg16 = Sequential()
# vgg16.add(vggModel.input)
for i, layer in enumerate(vggModel.layers):
    if i < 19:
        vgg16.add(layer)

# %%
# setting the retraining off
vgg16.trainable = False

# %%
vgg16.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# #### Feature Extractor Class

# %%
class FeatureExtractor:
    '''
    Description : Class to Extract the Features from the given images
    '''

    """
    staticmethod
    def getLatentSpaceFromVGG(_l, _ab):
        gray_img = gray2rgb(_l[:,:,0])
        print(gray_img.shape)
        gray_img = gray_img.reshape((1,) + gray_img.shape)
        print('Reshaped gray :', gray_img.shape)
        latentSpace = vgg16.predict(gray_img)
        # print(latentSpace)
        print('z',latentSpace.shape)
        # latentSpace = latentSpace.reshape(latent_shape)
        # print('x:',latentSpace[0].shape)
        return latentSpace[0], _ab

    # to fix the shape
    staticmethod
    def fixup_shape(_latentSpace, _ab, w, h, latentShape):

        '''
        Description : 
                Method to fix the shape of L and AB channels i.e X and Y
        Input :
                _latentSpace => Extracted Feature Latent Space 
                _ab => AB channel
                w => Width of the Image 
                h => Height of the Image
        Returns :
                tf.Tensor (shape => (_lw, _lh, _lc)), tf.Tensor (shape => (w, h, 2))
        '''
        _lw, _lh, _lc = latentShape
        print(_lw, _lh, _lc)
        print('fixup',_latentSpace)
        _latentSpace.set_shape([8, 8, 512])
        print('xx',_latentSpace.shape)
        _ab.set_shape([w, h, 2])
        return _latentSpace, _ab

    """

    # method to get the latent space from the vgg16 network
    @staticmethod
    def getLatentSpaceFromVGG(_l, _ab):
        '''
        Description : 
                Method to get the Latent Space from the VGG16 network
        Input :
                _l => L channel
                _ab => AB channel
        Returns :
                numpy.array (Extracted Feature), 
                numpy.array (shape => (w, h, 2))

        '''

        # print(_l.shape)

        gray_img = _l[:,:,0]

        # reshaping adding 2 extra channel in the gray_img
        gray_img = gray2rgb(gray_img)

        # print('gray2rgb gray_img shape :', gray_img.shape)
        
        # adding extra 1 dim in gray_img to fit in the vggmodel
        gray_img = gray_img.reshape((1,) + gray_img.shape)

        # print('model fit gray_img shape :', gray_img.shape)

        # predicting the latent space
        _latent = vgg16.predict(gray_img)

        # print('predicted Latent :', _latent.shape)
        # print('predicted Latent dtype:', _latent.dtype)
    
        _latent = _latent[0]

        # print('predicted Latent :', _latent.shape)
    
        return _latent, _ab

    # method to fixup the shape of the output of the latent space 
    @staticmethod
    def fixup_shape(_latent, _ab, w, h, lw, lh, lc):
        '''
        Description : 
                Method to fixup the shape of the output of the latent space 
        Input :
                _latent => Latent Space
                _ab => AB channel
                w => Width of the AB Channel
                h => Height of the AB Channel
                (lw, lh, lc) => Dimension of the Latent Space
        Returns :
                tf.Tensor (Extracted Feature | shape => (_lw, _lh, _lc)), 
                tf.Tensor (AB Channel | shape => (w, h, 2))

        '''
        _latent.set_shape([lw, lh, lc])
        _ab.set_shape([w,h,2])

        return _latent, _ab

# %% [markdown]
# #### Class to Map the Extracted Features

# %%
class FeatureExtractMapper:
    '''
    Description : Class to Map the Extracted Features to the Dataset
    '''

    # Method to get the Feature Extracted Dataset
    @staticmethod
    def getXYDataset(dataset, img_w, img_h, lw, lh, lc):
        '''
        Description : 
                Method to get the Feature Extracted Dataset
        Input :
                dataset => MapDatset (consist of the splited LAB image channel [L & AB])
                img_w => Width of the Image 
                img_h => Height of the Image
                (lw, lh, lc) => Shape of the Latent Space
        Returns :
                MapDataset shapes: ((lw, lh, lc), (img_w, img_h, 2)), types: (tf.float32, tf.float32)
        '''

        ds = dataset.map(lambda x, y : tf.py_function(FeatureExtractor.getLatentSpaceFromVGG,
                                                     [x, y],
                                                     [tf.float32, tf.float32]))
        
        return ds.map(lambda x, y : FeatureExtractor.fixup_shape(x, y, img_w, img_h, lw, lh, lc))

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')

        _latent, _ab = FeatureExtractor.getLatentSpaceFromVGG(_l, _ab)

        print(f'_fn_predLAB _latent Shape : {_latent.shape}')

        _latent = _latent.reshape((1,) + _latent.shape)
        print(f'_latent re-Shape : {_latent.shape}')

        _abPred = model.predict(_latent)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        print('_fn_imgPostProcess_w')
        w = _ab.shape[1]
        print('_fn_imgPostProcess_h')
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))
        print('ab shape :', _ab.shape)
        print('l shape :', _l.shape)
        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[:,:,0] 
        print('ok')
        result[:,:,1:] = _ab[0,:,:,:]
        print('not ok')

        result = result.astype('float32')
        # print(result)
        print(f'_fn_imgPost result shape : {result.shape}')

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        # result = tf.convert_to_tensor(result)
        # # print(result)

        # rgb = tfio.experimental.color.lab_to_rgb(result)
        # rgb = rgb.numpy()

        rgb = lab2rgb(result)

        # ########
        
        print(f'_fn_imgPost rgb shape : {rgb.shape}')
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 

        print(f'_fn_predRGB _l shape: {_l.shape}')
        print(f'_fn_predRGB predAB shape: {predAB.shape}')

        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8785

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 244 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 717 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 2504 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# Removing ## ID : 2608 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 3130 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# Removing ## ID : 3587 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 3860 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 4867 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 5392 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 5668 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# Removing ## ID : 5763 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 6022 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 6590 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 8452 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 8517 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
train_lab_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
trainData
# Out:
# <MapDataset shapes: ((256, 256, 1), (256, 256, 2)), types: (tf.float32, tf.float32)>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (224, 224, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (224, 224, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (224, 224, 1)
# AB Shape :  (224, 224, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (224, 224, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (224, 224, 3)
# LAB Images Shape : (224, 224, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (224, 224, 1)
# AB Shape :  (224, 224, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (224, 224, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (224, 224, 3)
# LAB Images Shape : (224, 224, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (224, 224, 1)
# AB Shape :  (224, 224, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Mapping the Features on datasets

# %% [markdown]
# ##### Getting the train Feature Dataset

# %%
trainFeatureData = FeatureExtractMapper.getXYDataset(trainData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the val Feature Dataset

# %%
valFeatureData = FeatureExtractMapper.getXYDataset(valData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the test Feature Dataset

# %%
testFeatureData = FeatureExtractMapper.getXYDataset(testData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)
trainFeatureData = config_ds(trainFeatureData, batchSize)
testFeatureData = config_ds(testFeatureData, batchSize)
valFeatureData = config_ds(valFeatureData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape)

    # decoder

    # l1
    l1 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(input_L)

    # l2
    l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(l1)
    l2_up = UpSampling2D(size=(2,2))(l2)

    # l3
    l3 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l2_up)
    l3_up = UpSampling2D(size=(2,2))(l3)

    # l4
    l4 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l3_up)
    l4_up = UpSampling2D(size=(2,2))(l4)

    # l5
    l5 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l4_up)
    l5_up = UpSampling2D(size=(2,2))(l5)

    # l6
    l6 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l5_up)
    l6_up = UpSampling2D(size=(2,2))(l6)

    # decoder

    # l9
    # l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(input_L)
    # l9_up = UpSampling2D((2,2))(l9)

    # # l10
    # l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l9_up)
    # l10_up = UpSampling2D((2,2))(l10)

    # # l11
    # l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l10_up)

    # # l12
    # l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l11)

    # # l13
    # l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l12)
    # l13_up = UpSampling2D((2,2))(l13)

    return Model(inputs=input_L, outputs=l6_up)

# %%
model = autoEncoder(inputShape=latent_shape)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 7, 7, 512)]       0
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 256)         1179904
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 128)         295040
#
#  up_sampling2d_3 (UpSampling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        73792
#
#  up_sampling2d_4 (UpSampling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        18464
#
#  up_sampling2d_5 (UpSampling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 16)        4624
#
#  up_sampling2d_6 (UpSampling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 112, 112, 2)       290
#
#  up_sampling2d_7 (UpSampling  (None, 224, 224, 2)      0
#  2D)
#
# =================================================================
# Total params: 1,572,114
# Trainable params: 1,572,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
# training the model
history = model.fit(trainFeatureData, validation_data=valFeatureData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 17s 5s/step - loss: 0.4399 - accuracy: 0.5065 - val_loss: 0.3266 - val_accuracy: 0.4971
# Epoch 2/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2292 - accuracy: 0.5009 - val_loss: 0.0236 - val_accuracy: 0.5102
# Epoch 3/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0225 - accuracy: 0.5395 - val_loss: 0.0195 - val_accuracy: 0.5656
# Epoch 4/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.
500
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0095 - accuracy: 0.6718 - val_loss: 0.0108 - val_accuracy: 0.5931
# Epoch 36/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0093 - accuracy: 0.6708 - val_loss: 0.0111 - val_accuracy: 0.5945
# Epoch 37/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0091 - accuracy: 0.6717 - val_loss: 0.0108 - val_accuracy: 0.5941
# Epoch 38/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0088 - accuracy: 0.6714 - val_loss: 0.0104 - val_accuracy: 0.5936
# Epoch 39/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0086 - accuracy: 0.6706 - val_loss: 0.0114 - val_accuracy: 0.5952
# Epoch 40/500
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0085 - accuracy: 0.6702 - val_loss: 0.0107 - val_accuracy: 0.5926
# Epoch 41/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0084 - accuracy: 0.6699 - val_loss: 0.0101 - val_accuracy: 0.5924
# Epoch 42/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0083 - accuracy: 0.6717 - val_loss: 0.0119 - val_accuracy: 0.5946
# Epoch 43/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0086 - accuracy: 0.6733 - val_loss: 0.0101 - val_accuracy: 0.5946
# Epoch 44/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0089 - accuracy: 0.6699 - val_loss: 0.0103 - val_accuracy: 0.6026
# Epoch 45/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0088 - accuracy: 0.6688 - val_loss: 0.0115 - val_accuracy: 0.5976
# Epoch 46/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0088 - accuracy: 0.6712 - val_loss: 0.0108 - val_accuracy: 0.5998
# Epoch 47/500
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0087 - accuracy: 0.6716 - val_loss: 0.0106 - val_accuracy: 0.6018
# Epoch 48/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0083 - accuracy: 0.6730 - val_loss: 0.0117 - val_accuracy: 0.5973
# Epoch 49/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0083 - accuracy: 0.6716 - val_loss: 0.0104 - val_accuracy: 0.6017
# Epoch 50/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0081 - accuracy: 0.6718 - val_loss: 0.0119 - val_accuracy: 0.5951
# Epoch 51/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0080 - accuracy: 0.6703 - val_loss: 0.0106 - val_accuracy: 0.5964
# Epoch 52/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0079 - accuracy: 0.6694 - val_loss: 0.0114 - val_accuracy: 0.5935
# Epoch 53/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0078 - accuracy: 0.6694 - val_loss: 0.0106 - val_accuracy: 0.5926
# Epoch 54/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0077 - accuracy: 0.6803 - val_loss: 0.0110 - val_accuracy: 0.6328
# Epoch 55/500
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0077 - accuracy: 0.7057 - val_loss: 0.0106 - val_accuracy: 0.6231
# Epoch 56/500
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0076 - accuracy: 0.6998 - val_loss: 0.0110 - val_accuracy: 0.6322
# Epoch 57/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0075 - accuracy: 0.7074 - val_loss: 0.0109 - val_accuracy: 0.6279
# Epoch 58/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0075 - accuracy: 0.7016 - val_loss: 0.0112 - val_accuracy: 0.6336
# Epoch 59/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0074 - accuracy: 0.7088 - val_loss: 0.0109 - val_accuracy: 0.6280
# Epoch 60/500
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0074 - accuracy: 0.7043 - val_loss: 0.0111 - val_accuracy: 0.6342
# Epoch 61/500
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0073 - accuracy: 0.7095 - val_loss: 0.0108 - val_accuracy: 0.6334
# Epoch 62/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0072 - accuracy: 0.7061 - val_loss: 0.0110 - val_accuracy: 0.6403
# Epoch 63/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0072 - accuracy: 0.7091 - val_loss: 0.0108 - val_accuracy: 0.6384
# Epoch 64/500
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0071 - accuracy: 0.7076 - val_loss: 0.0108 - val_accuracy: 0.6398
# Epoch 65/500
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0071 - accuracy: 0.7081 - val_loss: 0.0108 - val_accuracy: 0.6401
# Epoch 66/500
# 3/3 [==============================] - 0s 56ms/step - loss: 0.
500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0029 - accuracy: 0.7687 - val_loss: 0.0111 - val_accuracy: 0.6143
# Epoch 190/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - accuracy: 0.7673 - val_loss: 0.0110 - val_accuracy: 0.6167
# Epoch 191/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0029 - accuracy: 0.7696 - val_loss: 0.0111 - val_accuracy: 0.6092
# Epoch 192/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0029 - accuracy: 0.7633 - val_loss: 0.0112 - val_accuracy: 0.6120
# Epoch 193/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0029 - accuracy: 0.7684 - val_loss: 0.0110 - val_accuracy: 0.6093
# Epoch 194/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0028 - accuracy: 0.7663 - val_loss: 0.0111 - val_accuracy: 0.6088
# Epoch 195/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0028 - accuracy: 0.7657 - val_loss: 0.0113 - val_accuracy: 0.6061
# Epoch 196/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0028 - accuracy: 0.7660 - val_loss: 0.0111 - val_accuracy: 0.6087
# Epoch 197/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0028 - accuracy: 0.7693 - val_loss: 0.0110 - val_accuracy: 0.6037
# Epoch 198/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0028 - accuracy: 0.7634 - val_loss: 0.0114 - val_accuracy: 0.6063
# Epoch 199/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0028 - accuracy: 0.7662 - val_loss: 0.0111 - val_accuracy: 0.6051
# Epoch 200/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0028 - accuracy: 0.7689 - val_loss: 0.0109 - val_accuracy: 0.6034
# Epoch 201/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0029 - accuracy: 0.7632 - val_loss: 0.0115 - val_accuracy: 0.6017
# Epoch 202/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0029 - accuracy: 0.7621 - val_loss: 0.0112 - val_accuracy: 0.6025
# Epoch 203/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0028 - accuracy: 0.7655 - val_loss: 0.0109 - val_accuracy: 0.6028
# Epoch 204/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0029 - accuracy: 0.7639 - val_loss: 0.0116 - val_accuracy: 0.5980
# Epoch 205/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - accuracy: 0.7616 - val_loss: 0.0110 - val_accuracy: 0.6014
# Epoch 206/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0028 - accuracy: 0.7659 - val_loss: 0.0109 - val_accuracy: 0.6005
# Epoch 207/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0028 - accuracy: 0.7641 - val_loss: 0.0118 - val_accuracy: 0.6040
# Epoch 208/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0028 - accuracy: 0.7685 - val_loss: 0.0108 - val_accuracy: 0.5975
# Epoch 209/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0027 - accuracy: 0.7713 - val_loss: 0.0110 - val_accuracy: 0.5975
# Epoch 210/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0027 - accuracy: 0.7642 - val_loss: 0.0116 - val_accuracy: 0.6122
# Epoch 211/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0027 - accuracy: 0.7787 - val_loss: 0.0108 - val_accuracy: 0.5908
# Epoch 212/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0027 - accuracy: 0.7705 - val_loss: 0.0111 - val_accuracy: 0.6024
# Epoch 213/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0026 - accuracy: 0.7742 - val_loss: 0.0115 - val_accuracy: 0.6066
# Epoch 214/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0026 - accuracy: 0.7820 - val_loss: 0.0109 - val_accuracy: 0.5955
# Epoch 215/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0026 - accuracy: 0.7730 - val_loss: 0.0112 - val_accuracy: 0.6082
# Epoch 216/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0026 - accuracy: 0.7814 - val_loss: 0.0114 - val_accuracy: 0.6045
# Epoch 217/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0026 - accuracy: 0.7816 - val_loss: 0.0109 - val_accuracy: 0.6002
# Epoch 218/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0026 - accuracy: 0.7782 - val_loss: 0.0111 - val_accuracy: 0.6050
# Epoch 219/500
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0026 - accuracy: 0.7810 - val_loss: 0.0115 - val_accuracy: 0.6089
# Epoch 220/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.
500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - accuracy: 0.8340 - val_loss: 0.0108 - val_accuracy: 0.6055
# Epoch 395/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0019 - accuracy: 0.8207 - val_loss: 0.0112 - val_accuracy: 0.6253
# Epoch 396/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0019 - accuracy: 0.8303 - val_loss: 0.0109 - val_accuracy: 0.6153
# Epoch 397/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0019 - accuracy: 0.8310 - val_loss: 0.0108 - val_accuracy: 0.6100
# Epoch 398/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - accuracy: 0.8219 - val_loss: 0.0114 - val_accuracy: 0.6269
# Epoch 399/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0019 - accuracy: 0.8315 - val_loss: 0.0108 - val_accuracy: 0.6104
# Epoch 400/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - accuracy: 0.8265 - val_loss: 0.0107 - val_accuracy: 0.6145
# Epoch 401/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0019 - accuracy: 0.8245 - val_loss: 0.0115 - val_accuracy: 0.6257
# Epoch 402/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0019 - accuracy: 0.8320 - val_loss: 0.0107 - val_accuracy: 0.6046
# Epoch 403/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0019 - accuracy: 0.8198 - val_loss: 0.0107 - val_accuracy: 0.6223
# Epoch 404/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0020 - accuracy: 0.8282 - val_loss: 0.0115 - val_accuracy: 0.6224
# Epoch 405/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0020 - accuracy: 0.8296 - val_loss: 0.0106 - val_accuracy: 0.6030
# Epoch 406/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0020 - accuracy: 0.8137 - val_loss: 0.0109 - val_accuracy: 0.6245
# Epoch 407/500
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0020 - accuracy: 0.8312 - val_loss: 0.0114 - val_accuracy: 0.6184
# Epoch 408/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0020 - accuracy: 0.8287 - val_loss: 0.0106 - val_accuracy: 0.6078
# Epoch 409/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - accuracy: 0.8238 - val_loss: 0.0110 - val_accuracy: 0.6123
# Epoch 410/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0019 - accuracy: 0.8250 - val_loss: 0.0111 - val_accuracy: 0.6276
# Epoch 411/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0019 - accuracy: 0.8332 - val_loss: 0.0107 - val_accuracy: 0.6029
# Epoch 412/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0019 - accuracy: 0.8249 - val_loss: 0.0110 - val_accuracy: 0.6135
# Epoch 413/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - accuracy: 0.8231 - val_loss: 0.0110 - val_accuracy: 0.6261
# Epoch 414/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0019 - accuracy: 0.8368 - val_loss: 0.0107 - val_accuracy: 0.6024
# Epoch 415/500
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0019 - accuracy: 0.8232 - val_loss: 0.0111 - val_accuracy: 0.6230
# Epoch 416/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0019 - accuracy: 0.8304 - val_loss: 0.0108 - val_accuracy: 0.6162
# Epoch 417/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8339 - val_loss: 0.0108 - val_accuracy: 0.6112
# Epoch 418/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0018 - accuracy: 0.8264 - val_loss: 0.0112 - val_accuracy: 0.6245
# Epoch 419/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8336 - val_loss: 0.0107 - val_accuracy: 0.6089
# Epoch 420/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0018 - accuracy: 0.8287 - val_loss: 0.0109 - val_accuracy: 0.6168
# Epoch 421/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - accuracy: 0.8307 - val_loss: 0.0113 - val_accuracy: 0.6234
# Epoch 422/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8335 - val_loss: 0.0107 - val_accuracy: 0.6081
# Epoch 423/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0018 - accuracy: 0.8269 - val_loss: 0.0109 - val_accuracy: 0.6177
# Epoch 424/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - accuracy: 0.8315 - val_loss: 0.0114 - val_accuracy: 0.6229
# Epoch 425/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - accuracy: 0.8326 - val_loss: 0.0107 - val_accuracy: 0.6085
# Epoch 426/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0019 - accuracy: 0.8267 - val_loss: 0.0109 - val_accuracy: 0.6170
# Epoch 427/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - accuracy: 0.8314 - val_loss: 0.0113 - val_accuracy: 0.6223
# Epoch 428/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0018 - accuracy: 0.8332 - val_loss: 0.0107 - val_accuracy: 0.6074
# Epoch 429/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0019 - accuracy: 0.8275 - val_loss: 0.0111 - val_accuracy: 0.6167
# Epoch 430/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8311 - val_loss: 0.0111 - val_accuracy: 0.6228
# Epoch 431/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0018 - accuracy: 0.8354 - val_loss: 0.0107 - val_accuracy: 0.6029
# Epoch 432/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0018 - accuracy: 0.8266 - val_loss: 0.0112 - val_accuracy: 0.6176
# Epoch 433/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - accuracy: 0.8297 - val_loss: 0.0110 - val_accuracy: 0.6228
# Epoch 434/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0018 - accuracy: 0.8372 - val_loss: 0.0108 - val_accuracy: 0.5999
# Epoch 435/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8249 - val_loss: 0.0112 - val_accuracy: 0.6201
# Epoch 436/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0019 - accuracy: 0.8279 - val_loss: 0.0109 - val_accuracy: 0.6238
# Epoch 437/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0019 - accuracy: 0.8365 - val_loss: 0.0108 - val_accuracy: 0.5992
# Epoch 438/500
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0019 - accuracy: 0.8211 - val_loss: 0.0113 - val_accuracy: 0.6242
# Epoch 439/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - accuracy: 0.8269 - val_loss: 0.0106 - val_accuracy: 0.6184
# Epoch 440/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0019 - accuracy: 0.8333 - val_loss: 0.0109 - val_accuracy: 0.6032
# Epoch 441/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0019 - accuracy: 0.8189 - val_loss: 0.0114 - val_accuracy: 0.6278
# Epoch 442/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0020 - accuracy: 0.8278 - val_loss: 0.0104 - val_accuracy: 0.6023
# Epoch 443/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0019 - accuracy: 0.8238 - val_loss: 0.0112 - val_accuracy: 0.6133
# Epoch 444/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - accuracy: 0.8264 - val_loss: 0.0109 - val_accuracy: 0.6285
# Epoch 445/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0018 - accuracy: 0.8350 - val_loss: 0.0106 - val_accuracy: 0.6000
# Epoch 446/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0019 - accuracy: 0.8191 - val_loss: 0.0115 - val_accuracy: 0.6227
# Epoch 447/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0019 - accuracy: 0.8315 - val_loss: 0.0105 - val_accuracy: 0.6147
# Epoch 448/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0018 - accuracy: 0.8363 - val_loss: 0.0110 - val_accuracy: 0.6108
# Epoch 449/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0018 - accuracy: 0.8234 - val_loss: 0.0112 - val_accuracy: 0.6243
# Epoch 450/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0018 - accuracy: 0.8335 - val_loss: 0.0105 - val_accuracy: 0.6081
# Epoch 451/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0018 - accuracy: 0.8321 - val_loss: 0.0112 - val_accuracy: 0.6189
# Epoch 452/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0018 - accuracy: 0.8330 - val_loss: 0.0109 - val_accuracy: 0.6184
# Epoch 453/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0018 - accuracy: 0.8356 - val_loss: 0.0107 - val_accuracy: 0.6130
# Epoch 454/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - accuracy: 0.8331 - val_loss: 0.0112 - val_accuracy: 0.6218
# Epoch 455/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0017 - accuracy: 0.8381 - val_loss: 0.0108 - val_accuracy: 0.6125
# Epoch 456/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0017 - accuracy: 0.8339 - val_loss: 0.0109 - val_accuracy: 0.6196
# Epoch 457/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0017 - accuracy: 0.8353 - val_loss: 0.0111 - val_accuracy: 0.6201
# Epoch 458/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0018 - accuracy: 0.8393 - val_loss: 0.0109 - val_accuracy: 0.6081
# Epoch 459/500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0018 - accuracy: 0.8305 - val_loss: 0.0110 - val_accuracy: 0.6256
# Epoch 460/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8373 - val_loss: 0.0110 - val_accuracy: 0.6143
# Epoch 461/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0018 - accuracy: 0.8369 - val_loss: 0.0110 - val_accuracy: 0.6093
# Epoch 462/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0018 - accuracy: 0.8277 - val_loss: 0.0109 - val_accuracy: 0.6283
# Epoch 463/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0018 - accuracy: 0.8407 - val_loss: 0.0109 - val_accuracy: 0.6040
# Epoch 464/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0018 - accuracy: 0.8294 - val_loss: 0.0111 - val_accuracy: 0.6209
# Epoch 465/500
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0018 - accuracy: 0.8337 - val_loss: 0.0108 - val_accuracy: 0.6208
# Epoch 466/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0017 - accuracy: 0.8406 - val_loss: 0.0108 - val_accuracy: 0.6094
# Epoch 467/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0017 - accuracy: 0.8299 - val_loss: 0.0112 - val_accuracy: 0.6240
# Epoch 468/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0017 - accuracy: 0.8403 - val_loss: 0.0109 - val_accuracy: 0.6103
# Epoch 469/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0017 - accuracy: 0.8348 - val_loss: 0.0108 - val_accuracy: 0.6149
# Epoch 470/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0017 - accuracy: 0.8358 - val_loss: 0.0112 - val_accuracy: 0.6197
# Epoch 471/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0017 - accuracy: 0.8394 - val_loss: 0.0110 - val_accuracy: 0.6133
# Epoch 472/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0017 - accuracy: 0.8336 - val_loss: 0.0108 - val_accuracy: 0.6155
# Epoch 473/500
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0017 - accuracy: 0.8385 - val_loss: 0.0111 - val_accuracy: 0.6140
# Epoch 474/500
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0017 - accuracy: 0.8360 - val_loss: 0.0112 - val_accuracy: 0.6197
# Epoch 475/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0017 - accuracy: 0.8347 - val_loss: 0.0107 - val_accuracy: 0.6145
# Epoch 476/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0017 - accuracy: 0.8386 - val_loss: 0.0109 - val_accuracy: 0.6086
# Epoch 477/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0017 - accuracy: 0.8317 - val_loss: 0.0114 - val_accuracy: 0.6227
# Epoch 478/500
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0017 - accuracy: 0.8356 - val_loss: 0.0109 - val_accuracy: 0.6139
# Epoch 479/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0017 - accuracy: 0.8387 - val_loss: 0.0106 - val_accuracy: 0.6030
# Epoch 480/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0018 - accuracy: 0.8278 - val_loss: 0.0115 - val_accuracy: 0.6235
# Epoch 481/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8364 - val_loss: 0.0110 - val_accuracy: 0.6151
# Epoch 482/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0017 - accuracy: 0.8382 - val_loss: 0.0106 - val_accuracy: 0.6051
# Epoch 483/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0018 - accuracy: 0.8293 - val_loss: 0.0113 - val_accuracy: 0.6234
# Epoch 484/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0018 - accuracy: 0.8385 - val_loss: 0.0112 - val_accuracy: 0.6105
# Epoch 485/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0017 - accuracy: 0.8360 - val_loss: 0.0106 - val_accuracy: 0.6118
# Epoch 486/500
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0018 - accuracy: 0.8326 - val_loss: 0.0112 - val_accuracy: 0.6241
# Epoch 487/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8405 - val_loss: 0.0111 - val_accuracy: 0.6030
# Epoch 488/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - accuracy: 0.8313 - val_loss: 0.0107 - val_accuracy: 0.6183
# Epoch 489/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0018 - accuracy: 0.8359 - val_loss: 0.0113 - val_accuracy: 0.6219
# Epoch 490/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0017 - accuracy: 0.8403 - val_loss: 0.0109 - val_accuracy: 0.6026
# Epoch 491/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0017 - accuracy: 0.8294 - val_loss: 0.0107 - val_accuracy: 0.6186
# Epoch 492/500
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0018 - accuracy: 0.8402 - val_loss: 0.0115 - val_accuracy: 0.6171
# Epoch 493/500
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - accuracy: 0.8370 - val_loss: 0.0109 - val_accuracy: 0.6104
# Epoch 494/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0018 - accuracy: 0.8331 - val_loss: 0.0106 - val_accuracy: 0.6103
# Epoch 495/500
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0018 - accuracy: 0.8382 - val_loss: 0.0115 - val_accuracy: 0.6169
# Epoch 496/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0018 - accuracy: 0.8339 - val_loss: 0.0110 - val_accuracy: 0.6179
# Epoch 497/500
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0017 - accuracy: 0.8394 - val_loss: 0.0106 - val_accuracy: 0.5959
# Epoch 498/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0017 - accuracy: 0.8304 - val_loss: 0.0113 - val_accuracy: 0.6215
# Epoch 499/500
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0017 - accuracy: 0.8338 - val_loss: 0.0112 - val_accuracy: 0.6223
# Epoch 500/500
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0017 - accuracy: 0.8419 - val_loss: 0.0106 - val_accuracy: 0.5926
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Image Colorization/model-history/model/Ct_tfPyClass_2vgg16_GCData_100_500.model/assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %%
newModel.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 7, 7, 512)]       0
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 256)         1179904
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 128)         295040
#
#  up_sampling2d_3 (UpSampling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        73792
#
#  up_sampling2d_4 (UpSampling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        18464
#
#  up_sampling2d_5 (UpSampling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 16)        4624
#
#  up_sampling2d_6 (UpSampling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 112, 112, 2)       290
#
#  up_sampling2d_7 (UpSampling  (None, 224, 224, 2)      0
#  2D)
#
# =================================================================
# Total params: 1,572,114
# Trainable params: 1,572,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/2000.jpg'
# fileName = '/content/test10.jpeg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predLAB _l Shape : (224, 224, 1)
# _fn_predLAB _latent Shape : (7, 7, 512)
# _latent re-Shape : (1, 7, 7, 512)
# _fn_predRGB _l shape: (224, 224, 1)
# _fn_predRGB predAB shape: (1, 224, 224, 2)
# _fn_imgPostProcess_w
# _fn_imgPostProcess_h
# ab shape : (1, 224, 224, 2)
# l shape : (224, 224, 1)
# ok
# not ok
# _fn_imgPost result shape : (224, 224, 3)
# _fn_imgPost rgb shape : (224, 224, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape )

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----

# %%
result = resize(rgbResult[0] , (1200, 1920))
imshow(result)
