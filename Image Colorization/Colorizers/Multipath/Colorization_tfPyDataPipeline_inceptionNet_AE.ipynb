# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 2.1 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.24.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.24.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.24.0

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# ##### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
            else:
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]

                if r.all() == g.all() == b.all():
                    isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])

        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages])

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                tf.Tensor 
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    def fixup_shape(_l, _ab, w, h):
        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, 2img_height56, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')
        _l = _l.numpy()
        _l = _l.reshape((1,) + _l.shape)
        print(f'_fn_predLAB _l re-Shape : {_l.shape}')
        _abPred = model.predict(_l)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        w = _ab.shape[1]
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))

        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[0,:,:,0] 
        result[:,:,1:] = _ab[0,:,:,:]


        result = result.astype('float32')
        # print(result)
        print(result.shape)

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        result = tf.convert_to_tensor(result)
        # print(result)

        rgb = tfio.experimental.color.lab_to_rgb(result)
        rgb = rgb.numpy()

        # ########
        
        print(rgb.shape)
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 
        print(_l.shape)
        print(predAB.shape)
        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8785

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 0

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(80)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 80

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 64
# Test Size : 8
# Val Size : 8

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 64
# val_ds Size : 8
# test_ds Size : 8

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
train_lab_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
trainData
# Out:
# <MapDataset shapes: ((256, 256, 1), (256, 256, 2)), types: (tf.float32, tf.float32)>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### Initializing the InceptionResNetV2

# %%
inceptionNet = InceptionResNetV2(include_top=False, input_shape=(256,256,3))

# %%
inceptionNet.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_1888 (Conv2D)           (None, 127, 127, 32  864         ['input_19[0][0]']
#                                 )
#
#  batch_normalization_1827 (Batc  (None, 127, 127, 32  96         ['conv2d_1888[0][0]']
#  hNormalization)                )
#
#  activation_1827 (Activation)   (None, 127, 127, 32  0           ['batch_normalization_1827[0][0]'
#                                 )                                ]
#
#  conv2d_1889 (Conv2D)           (None, 125, 125, 32  9216        ['activation_1827[0][0]']
#                                 )
#
#  batch_normalization_1828 (Batc  (None, 125, 125, 32  96         ['conv2d_1889[0][0]']
#  hNormalization)                )
#
#  activation_1828 (Activation)   (None, 125, 125, 32  0           ['batch_normalization_1828[0][0]'
#                                 )                                ]
#
#  conv2d_1890 (Conv2D)           (None, 125, 125, 64  18432       ['activation_1828[0][0]']
#                                 )
#
#  batch_normalization_1829 (Batc  (None, 125, 125, 64  192        ['conv2d_1890[0][0]']
#  hNormalization)                )
#
#  activation_1829 (Activation)   (None, 125, 125, 64  0           ['batch_normalization_1829[0][0]'
#                                 )                                ]
#
#  max_pooling2d_36 (MaxPooling2D  (None, 62, 62, 64)  0           ['activation_1829[0][0]']
#  )
#
#  conv2d_1891 (Conv2D)           (None, 62, 62, 80)   5120        ['max_pooling2d_36[0][0]']
#
#  batch_normalization_1830 (Batc  (None, 62, 62, 80)  240         ['conv2d_1891[0][0]']
#  hNormalization)
#
#  activation_1830 (Activation)   (None, 62, 62, 80)   0           ['batch_normalization_1830[0][0]'
#                                                                  ]
#
#  conv2d_1892 (Conv2D)           (None, 60, 60, 192)  138240      ['activation_1830[0][0]']
#
#  batch_normalization_1831 (Batc  (None, 60, 60, 192)  576        ['conv2d_1892[0][0]']
#  hNormalization)
#
#  activation_1831 (Activation)   (None, 60, 60, 192)  0           ['batch_normalization_1831[0][0]'
#                                                                  ]
#
#  max_pooling2d_37 (MaxPooling2D  (None, 29, 29, 192)  0          ['activation_1831[0][0]']
#  )
#
#  conv2d_1896 (Conv2D)           (None, 29, 29, 64)   12288       ['max_pooling2d_37[0][0]']
#
#  batch_normalization_1835 (Batc  (None, 29, 29, 64)  192         ['conv2d_1896[0][0]']
#  hNormalization)
#
#  activation_1835 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1835[0][0]'
#                                                                  ]
#
#  conv2d_1894 (Conv2D)           (None, 29, 29, 48)   9216        ['max_pooling2d_37[0][0]']
#
#  conv2d_1897 (Conv2D)           (None, 29, 29, 96)   55296       ['activation_1835[0][0]']
#
#  batch_normalization_1833 (Batc  (None, 29, 29, 48)  144         ['conv2d_1894[0][0]']
#  hNormalization)
#
#  batch_normalization_1836 (Batc  (None, 29, 29, 96)  288         ['conv2d_1897[0][0]']
#  hNormalization)
#
#  activation_1833 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1833[0][0]'
#                                                                  ]
#
#  activation_1836 (Activation)   (None, 29, 29, 96)   0           ['batch_normalization_1836[0][0]'
#                                                                  ]
#
#  average_pooling2d_9 (AveragePo  (None, 29, 29, 192)  0          ['max_pooling2d_37[0][0]']
#  oling2D)
#
#  conv2d_1893 (Conv2D)           (None, 29, 29, 96)   18432       ['max_pooling2d_37[0][0]']
#
#  conv2d_1895 (Conv2D)           (None, 29, 29, 64)   76800       ['activation_1833[0][0]']
#
#  conv2d_1898 (Conv2D)           (None, 29, 29, 96)   82944       ['activation_1836[0][0]']
#
#  conv2d_1899 (Conv2D)           (None, 29, 29, 64)   12288       ['average_pooling2d_9[0][0]']
#
#  batch_normalization_1832 (Batc  (None, 29, 29, 96)  288         ['conv2d_1893[0][0]']
#  hNormalization)
#
#  batch_normalization_1834 (Batc  (None, 29, 29, 64)  192         ['conv2d_1895[0][0]']
#  hNormalization)
#
#  batch_normalization_1837 (Batc  (None, 29, 29, 96)  288         ['conv2d_1898[0][0]']
#  hNormalization)
#
#  batch_normalization_1838 (Batc  (None, 29, 29, 64)  192         ['conv2d_1899[0][0]']
#  hNormalization)
#
#  activation_1832 (Activation)   (None, 29, 29, 96)   0           ['batch_normalization_1832[0][0]'
#                                                                  ]
#
#  activation_1834 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1834[0][0]'
#                                                                  ]
#
#  activation_1837 (Activation)   (None, 29, 29, 96)   0           ['batch_normalization_1837[0][0]'
#                                                                  ]
#
#  activation_1838 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1838[0][0]'
#                                                                  ]
#
#  mixed_5b (Concatenate)         (None, 29, 29, 320)  0           ['activation_1832[0][0]',
#                                                                   'activation_1834[0][0]',
#                                                                   'activation_1837[0][0]',
#                                                                   'activation_1838[0][0]']
#
#  conv2d_1903 (Conv2D)           (None, 29, 29, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_1842 (Batc  (None, 29, 29, 32)  96          ['conv2d_1903[0][0]']
#  hNormalization)
#
#  activation_1842 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1842[0][0]'
#                                                                  ]
#
#  conv2d_1901 (Conv2D)           (None, 29, 29, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_1904 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1842[0][0]']
#
#  batch_normalization_1840 (Batc  (None, 29, 29, 32)  96          ['conv2d_1901[0][0]']
#  hNormalization)
#
#  batch_normalization_1843 (Batc  (None, 29, 29, 48)  144         ['conv2d_1904[0][0]']
#  hNormalization)
#
#  activation_1840 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1840[0][0]'
#                                                                  ]
#
#  activation_1843 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1843[0][0]'
#                                                                  ]
#
#  conv2d_1900 (Conv2D)           (None, 29, 29, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_1902 (Conv2D)           (None, 29, 29, 32)   9216        ['activation_1840[0][0]']
#
#  conv2d_1905 (Conv2D)           (None, 29, 29, 64)   27648       ['activation_1843[0][0]']
#
#  batch_normalization_1839 (Batc  (None, 29, 29, 32)  96          ['conv2d_1900[0][0]']
#  hNormalization)
#
#  batch_normalization_1841 (Batc  (None, 29, 29, 32)  96          ['conv2d_1902[0][0]']
#  hNormalization)
#
#  batch_normalization_1844 (Batc  (None, 29, 29, 64)  192         ['conv2d_1905[0][0]']
#  hNormalization)
#
#  activation_1839 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1839[0][0]'
#                                                                  ]
#
#  activation_1841 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1841[0][0]'
#                                                                  ]
#
#  activation_1844 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1844[0][0]'
#                                                                  ]
#
#  block35_1_mixed (Concatenate)  (None, 29, 29, 128)  0           ['activation_1839[0][0]',
#                                                                   'activation_1841[0][0]',
#                                                                   'activation_1844[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 29, 29, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 29, 29, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 29, 29, 320)  0           ['block35_1[0][0]']
#
#  conv2d_1909 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_1848 (Batc  (None, 29, 29, 32)  96          ['conv2d_1909[0][0]']
#  hNormalization)
#
#  activation_1848 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1848[0][0]'
#                                                                  ]
#
#  conv2d_1907 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_1910 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1848[0][0]']
#
#  batch_normalization_1846 (Batc  (None, 29, 29, 32)  96          ['conv2d_1907[0][0]']
#  hNormalization)
#
#  batch_normalization_1849 (Batc  (None, 29, 29, 48)  144         ['conv2d_1910[0][0]']
#  hNormalization)
#
#  activation_1846 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1846[0][0]'
#                                                                  ]
#
#  activation_1849 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1849[0][0]'
#                                                                  ]
#
#  conv2d_1906 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_1908 (Conv2D)           (None, 29, 29, 32)   9216        ['activation_1846[0][0]']
#
#  conv2d_1911 (Conv2D)           (None, 29, 29, 64)   27648       ['activation_1849[0][0]']
#
#  batch_normalization_1845 (Batc  (None, 29, 29, 32)  96          ['conv2d_1906[0][0]']
#  hNormalization)
#
#  batch_normalization_1847 (Batc  (None, 29, 29, 32)  96          ['conv2d_1908[0][0]']
#  hNormalization)
#
#  batch_normalization_1850 (Batc  (None, 29, 29, 64)  192         ['conv2d_1911[0][0]']
#  hNormalization)
#
#  activation_1845 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1845[0][0]'
#                                                                  ]
#
#  activation_1847 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1847[0][0]'
#                                                                  ]
#
#  activation_1850 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1850[0][0]'
#                                                                  ]
#
#  block35_2_mixed (Concatenate)  (None, 29, 29, 128)  0           ['activation_1845[0][0]',
#                                                                   'activation_1847[0][0]',
#                                                                   'activation_1850[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 29, 29, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 29, 29, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 29, 29, 320)  0           ['block35_2[0][0]']
#
#  conv2d_1915 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_1854 (Batc  (None, 29, 29, 32)  96          ['conv2d_1915[0][0]']
#  hNormalization)
#
#  activation_1854 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1854[0][0]'
#                                                                  ]
#
#  conv2d_1913 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_1916 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1854[0][0]']
#
#  batch_normalization_1852 (Batc  (None, 29, 29, 32)  96          ['conv2d_1913[0][0]']
#  hNormalization)
#
#  batch_normalization_1855 (Batc  (None, 29, 29, 48)  144         ['conv2d_1916[0][0]']
#  hNormalization)
#
#  activation_1852 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1852[0][0]'
#                                                                  ]
#
#  activation_1855 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1855[0][0]'
#                                                                  ]
#
#  conv2d_1912 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_1914 (Conv2D)           (None, 29, 29, 32)   9216        ['activation_1852[0][0]']
#
#  conv2d_1917 (Conv2D)           (None, 29, 29, 64)   27648       ['activation_1855[0][0]']
#
#  batch_normalization_1851 (Batc  (None, 29, 29, 32)  96          ['conv2d_1912[0][0]']
#  hNormalization)
#
#  batch_normalization_1853 (Batc  (None, 29, 29, 32)  96          ['conv2d_1914[0][0]']
#  hNormalization)
#
#  batch_normalization_1856 (Batc  (None, 29, 29, 64)  192         ['conv2d_1917[0][0]']
#  hNormalization)
#
#  activation_1851 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1851[0][0]'
#                                                                  ]
#
#  activation_1853 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1853[0][0]'
#                                                                  ]
#
#  activation_1856 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1856[0][0]'
#                                                                  ]
#
#  block35_3_mixed (Concatenate)  (None, 29, 29, 128)  0           ['activation_1851[0][0]',
#                                                                   'activation_1853[0][0]',
#                                                                   'activation_1856[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 29, 29, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 29, 29, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 29, 29, 320)  0           ['block35_3[0][0]']
#
#  conv2d_1921 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_1860 (Batc  (None, 29, 29, 32)  96          ['conv2d_1921[0][0]']
#  hNormalization)
#
#  activation_1860 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1860[0][0]'
#                                                                  ]
#
#  conv2d_1919 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_1922 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1860[0][0]']
#
#  batch_normalization_1858 (Batc  (None, 29, 29, 32)  96          ['conv2d_1919[0][0]']
#  hNormalization)
#
#  batch_normalization_1861 (Batc  (None, 29, 29, 48)  144         ['conv2d_1922[0][0]']
#  hNormalization)
#
#  activation_1858 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1858[0][0]'
#                                                                  ]
#
#  activation_1861 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1861[0][0]'
#                                                                  ]
#
#  conv2d_1918 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_1920 (Conv2D)           (None, 29, 29, 32)   9216        ['activation_1858[0][0]']
#
#  conv2d_1923 (Conv2D)           (None, 29, 29, 64)   27648       ['activation_1861[0][0]']
#
#  batch_normalization_1857 (Batc  (None, 29, 29, 32)  96          ['conv2d_1918[0][0]']
#  hNormalization)
#
#  batch_normalization_1859 (Batc  (None, 29, 29, 32)  96          ['conv2d_1920[0][0]']
#  hNormalization)
#
#  batch_normalization_1862 (Batc  (None, 29, 29, 64)  192         ['conv2d_1923[0][0]']
#  hNormalization)
#
#  activation_1857 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1857[0][0]'
#                                                                  ]
#
#  activation_1859 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1859[0][0]'
#                                                                  ]
#
#  activation_1862 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1862[0][0]'
#                                                                  ]
#
#  block35_4_mixed (Concatenate)  (None, 29, 29, 128)  0           ['activation_1857[0][0]',
#                                                                   'activation_1859[0][0]',
#                                                                   'activation_1862[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 29, 29, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 29, 29, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 29, 29, 320)  0           ['block35_4[0][0]']
#
#  conv2d_1927 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_1866 (Batc  (None, 29, 29, 32)  96          ['conv2d_1927[0][0]']
#  hNormalization)
#
#  activation_1866 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1866[0][0]'
#                                                                  ]
#
#  conv2d_1925 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_1928 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1866[0][0]']
#
#  batch_normalization_1864 (Batc  (None, 29, 29, 32)  96          ['conv2d_1925[0][0]']
#  hNormalization)
#
#  batch_normalization_1867 (Batc  (None, 29, 29, 48)  144         ['conv2d_1928[0][0]']
#  hNormalization)
#
#  activation_1864 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1864[0][0]'
#                                                                  ]
#
#  activation_1867 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1867[0][0]'
#                                                                  ]
#
#  conv2d_1924 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_1926 (Conv2D)           (None, 29, 29, 32)   9216        ['activation_1864[0][0]']
#
#  conv2d_1929 (Conv2D)           (None, 29, 29, 64)   27648       ['activation_1867[0][0]']
#
#  batch_normalization_1863 (Batc  (None, 29, 29, 32)  96          ['conv2d_1924[0][0]']
#  hNormalization)
#
#  batch_normalization_1865 (Batc  (None, 29, 29, 32)  96          ['conv2d_1926[0][0]']
#  hNormalization)
#
#  batch_normalization_1868 (Batc  (None, 29, 29, 64)  192         ['conv2d_1929[0][0]']
#  hNormalization)
#
#  activation_1863 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1863[0][0]'
#                                                                  ]
#
#  activation_1865 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1865[0][0]'
#                                                                  ]
#
#  activation_1868 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1868[0][0]'
#                                                                  ]
#
#  block35_5_mixed (Concatenate)  (None, 29, 29, 128)  0           ['activation_1863[0][0]',
#                                                                   'activation_1865[0][0]',
#                                                                   'activation_1868[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 29, 29, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 29, 29, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 29, 29, 320)  0           ['block35_5[0][0]']
#
#  conv2d_1933 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_1872 (Batc  (None, 29, 29, 32)  96          ['conv2d_1933[0][0]']
#  hNormalization)
#
#  activation_1872 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1872[0][0]'
#                                                                  ]
#
#  conv2d_1931 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_1934 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1872[0][0]']
#
#  batch_normalization_1870 (Batc  (None, 29, 29, 32)  96          ['conv2d_1931[0][0]']
#  hNormalization)
#
#  batch_normalization_1873 (Batc  (None, 29, 29, 48)  144         ['conv2d_1934[0][0]']
#  hNormalization)
#
#  activation_1870 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1870[0][0]'
#                                                                  ]
#
#  activation_1873 (Activation)   (None, 29, 29, 48)   0           ['batch_normalization_1873[0][0]'
#                                                                  ]
#
#  conv2d_1930 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_1932 (Conv2D)           (None, 29, 29, 32)   9216        ['activation_1870[0][0]']
#
#  conv2d_1935 (Conv2D)           (None, 29, 29, 64)   27648       ['activation_1873[0][0]']
#
#  batch_normalization_1869 (Batc  (None, 29, 29, 32)  96          ['conv2d_1930[0][0]']
#  hNormalization)
#
#  batch_normalization_1871 (Batc  (None, 29, 29, 32)  96          ['conv2d_1932[0][0]']
#  hNormalization)
#
#  batch_normalization_1874 (Batc  (None, 29, 29, 64)  192         ['conv2d_1935[0][0]']
#  hNormalization)
#
#  activation_1869 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1869[0][0]'
#                                                                  ]
#
#  activation_1871 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1871[0][0]'
#                                                                  ]
#
#  activation_1874 (Activation)   (None, 29, 29, 64)   0           ['batch_normalization_1874[0][0]'
#                                                                  ]
#
#  block35_6_mixed (Concatenate)  (None, 29, 29, 128)  0           ['activation_1869[0][0]',
#                                                                   'activation_1871[0][0]',
#                                                                   'activation_1874[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 29, 29, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 29, 29, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 29, 29, 320)  0           ['block35_6[0][0]']
#
#  conv2d_1939 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_1878 (Batc  (None, 29, 29, 32)  96          ['conv2d_1939[0][0]']
#  hNormalization)
#
#  activation_1878 (Activation)   (None, 29, 29, 32)   0           ['batch_normalization_1878[0][0]'
#                                                                  ]
#
#  conv2d_1937 (Conv2D)           (None, 29, 29, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_1940 (Conv2D)           (None, 29, 29, 48)   13824       ['activation_1878[0][0]']
# ...
#
#  conv2d_2075 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_2078 (Conv2D)           (None, 6, 6, 256)    172032      ['activation_2016[0][0]']
#
#  batch_normalization_2014 (Batc  (None, 6, 6, 192)   576         ['conv2d_2075[0][0]']
#  hNormalization)
#
#  batch_normalization_2017 (Batc  (None, 6, 6, 256)   768         ['conv2d_2078[0][0]']
#  hNormalization)
#
#  activation_2014 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2014[0][0]'
#                                                                  ]
#
#  activation_2017 (Activation)   (None, 6, 6, 256)    0           ['batch_normalization_2017[0][0]'
#                                                                  ]
#
#  block8_7_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_2014[0][0]',
#                                                                   'activation_2017[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 6, 6, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_2080 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_2019 (Batc  (None, 6, 6, 192)   576         ['conv2d_2080[0][0]']
#  hNormalization)
#
#  activation_2019 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2019[0][0]'
#                                                                  ]
#
#  conv2d_2081 (Conv2D)           (None, 6, 6, 224)    129024      ['activation_2019[0][0]']
#
#  batch_normalization_2020 (Batc  (None, 6, 6, 224)   672         ['conv2d_2081[0][0]']
#  hNormalization)
#
#  activation_2020 (Activation)   (None, 6, 6, 224)    0           ['batch_normalization_2020[0][0]'
#                                                                  ]
#
#  conv2d_2079 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_2082 (Conv2D)           (None, 6, 6, 256)    172032      ['activation_2020[0][0]']
#
#  batch_normalization_2018 (Batc  (None, 6, 6, 192)   576         ['conv2d_2079[0][0]']
#  hNormalization)
#
#  batch_normalization_2021 (Batc  (None, 6, 6, 256)   768         ['conv2d_2082[0][0]']
#  hNormalization)
#
#  activation_2018 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2018[0][0]'
#                                                                  ]
#
#  activation_2021 (Activation)   (None, 6, 6, 256)    0           ['batch_normalization_2021[0][0]'
#                                                                  ]
#
#  block8_8_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_2018[0][0]',
#                                                                   'activation_2021[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 6, 6, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_2084 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_2023 (Batc  (None, 6, 6, 192)   576         ['conv2d_2084[0][0]']
#  hNormalization)
#
#  activation_2023 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2023[0][0]'
#                                                                  ]
#
#  conv2d_2085 (Conv2D)           (None, 6, 6, 224)    129024      ['activation_2023[0][0]']
#
#  batch_normalization_2024 (Batc  (None, 6, 6, 224)   672         ['conv2d_2085[0][0]']
#  hNormalization)
#
#  activation_2024 (Activation)   (None, 6, 6, 224)    0           ['batch_normalization_2024[0][0]'
#                                                                  ]
#
#  conv2d_2083 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_2086 (Conv2D)           (None, 6, 6, 256)    172032      ['activation_2024[0][0]']
#
#  batch_normalization_2022 (Batc  (None, 6, 6, 192)   576         ['conv2d_2083[0][0]']
#  hNormalization)
#
#  batch_normalization_2025 (Batc  (None, 6, 6, 256)   768         ['conv2d_2086[0][0]']
#  hNormalization)
#
#  activation_2022 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2022[0][0]'
#                                                                  ]
#
#  activation_2025 (Activation)   (None, 6, 6, 256)    0           ['batch_normalization_2025[0][0]'
#                                                                  ]
#
#  block8_9_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_2022[0][0]',
#                                                                   'activation_2025[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 6, 6, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_2088 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_2027 (Batc  (None, 6, 6, 192)   576         ['conv2d_2088[0][0]']
#  hNormalization)
#
#  activation_2027 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2027[0][0]'
#                                                                  ]
#
#  conv2d_2089 (Conv2D)           (None, 6, 6, 224)    129024      ['activation_2027[0][0]']
#
#  batch_normalization_2028 (Batc  (None, 6, 6, 224)   672         ['conv2d_2089[0][0]']
#  hNormalization)
#
#  activation_2028 (Activation)   (None, 6, 6, 224)    0           ['batch_normalization_2028[0][0]'
#                                                                  ]
#
#  conv2d_2087 (Conv2D)           (None, 6, 6, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_2090 (Conv2D)           (None, 6, 6, 256)    172032      ['activation_2028[0][0]']
#
#  batch_normalization_2026 (Batc  (None, 6, 6, 192)   576         ['conv2d_2087[0][0]']
#  hNormalization)
#
#  batch_normalization_2029 (Batc  (None, 6, 6, 256)   768         ['conv2d_2090[0][0]']
#  hNormalization)
#
#  activation_2026 (Activation)   (None, 6, 6, 192)    0           ['batch_normalization_2026[0][0]'
#                                                                  ]
#
#  activation_2029 (Activation)   (None, 6, 6, 256)    0           ['batch_normalization_2029[0][0]'
#                                                                  ]
#
#  block8_10_mixed (Concatenate)  (None, 6, 6, 448)    0           ['activation_2026[0][0]',
#                                                                   'activation_2029[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 6, 6, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 6, 6, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 6, 6, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 6, 6, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 6, 6, 1536)   0           ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
inceptionNet.trainable = False

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (img_w,img_h,1)           # input shape of the nn
num_epochs = 500                     # no of epochs to train  the model

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []

filePath = 'CtfPy_tfGTClass_GCData_multi_inception_AE_80_500'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/' + filePath + '.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/' + filePath + '.csv'

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape, name='Encoder_Input')

    # encoder

    # l1 
    l1 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same', strides=2, name='E-Conv1')(input_L)

    # l2
    l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv2')(l1)
    
    # l3
    l3 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', strides=2, name='E-Conv3')(l2)

    # l4
    l4 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv4')(l3)

    # l5
    l5 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', strides=2, name='E-Conv5')(l4)

    # l6
    l6 = Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv6')(l5)

    # l7
    l7 = Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv7')(l6)

    # l8
    l8 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv8')(l7)


    # inceptionNet input processing

    glb_input_L = Conv2D(filters=3, kernel_size=(3,3), activation='relu', padding='same', strides=1)(input_L)

    inception_input_L = Reshape((256,256,3), name='Global_Feature_Net_Input_Layer')(glb_input_L)

    # # Predicting the Global Features
    features = inceptionNet(inception_input_L)

    # # Fusion Layers
    # fusion_output = RepeatVector(32 * 32) (features)
    # fusion_output = Reshape(([6, 6, 1526])) (features)
    fusion_output = concatenate([l8, features], axis=3)
    fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same', name='Fusion_Output')(fusion_output)

    # decoder

    # # l9
    # l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv1')(fusion_output)
    # l9_up = UpSampling2D((2,2), name='D-Conv1-up')(l9)

    # # l10
    # l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv2')(l9_up)
    # l10_up = UpSampling2D((2,2), name='D-Conv2-up')(l10)

    # # l11
    # l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv3')(l10_up)

    # # l12
    # l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv4')(l11)

    # # l13
    # l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same', name='D-Conv5')(l12)
    # l13_up = UpSampling2D((2,2), name='D-Conv5-up')(l13)

    return Model(inputs=input_L, outputs=fusion_output)

# %%
model = autoEncoder()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-473-26bbb2c82833> in <module>()
# ----> 1 model = autoEncoder()
#
# <ipython-input-472-b6261d893575> in autoEncoder(inputShape)
#      43     # fusion_output = RepeatVector(32 * 32) (features)
#      44     # fusion_output = Reshape(([6, 6, 1526])) (features)
# ---> 45     fusion_output = concatenate([l8, features], axis=3)
#      46     fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same', name='Fusion_Output')(fusion_output)
#      47
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/merge.py in concatenate(inputs, axis, **kwargs)
#     963       A tensor, the concatenation of the inputs alongside axis `axis`.
#     964   """
# --> 965   return Concatenate(axis=axis, **kwargs)(inputs)
#     966
#     967
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/merge.py in build(self, input_shape)
#     523             shape[axis] for shape in shape_set if shape[axis] is not None)
#     524         if len(unique_dims) > 1:
# --> 525           raise ValueError(err_msg)
#     526
#     527   def _merge_function(self, inputs):
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concatenation axis. Received: input_shape=[(None, 32, 32, 256), (None, 6, 6, 1536)]

# %%
model.summary()

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
# training the model
history = model.fit(trainData, validation_data=valData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-78d015721de5> in <module>()
#       1 # training the model
# ----> 2 history = model.fit(trainData, validation_data=valData, epochs=num_epochs)
#       3 model.save(model_path)          # saving the model
#       4
#       5 # convert the history.history dict to a pandas DataFrame:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 810, in train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 1204, in mean_squared_error
#         return backend.mean(tf.math.squared_difference(y_pred, y_true), axis=-1)
#
#     ValueError: Dimensions must be equal, but are 304 and 299 for '{{node mean_squared_error/SquaredDifference}} = SquaredDifference[T=DT_FLOAT](model_16/D-Conv5-up/resize/ResizeNearestNeighbor, IteratorGetNext:1)' with input shapes: [?,304,304,2], [?,299,299,2].

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/30.jpg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predLAB _l Shape : (256, 256, 1)
# _fn_predLAB _l re-Shape : (1, 256, 256, 1)
# (1, 256, 256, 1)
# (1, 256, 256, 2)
# (256, 256, 3)
# (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape )

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----
