# %% [markdown]
# # Using the AE along with Global Feature Extracted using InceptionResNetV2
# (ZipDataset Pipeline)

# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 1.3 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.24.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.24.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.24.0

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %%
def Colorize():
    embed_input = Input(shape=(1000,))
    #Encoder
    encoder_input = Input(shape=(256, 256, 1,))
    encoder_output = Conv2D(128, (3,3), activation='relu', padding='same',strides=1)(encoder_input)
    encoder_output = MaxPooling2D((2, 2), padding='same')(encoder_output)
    encoder_output = Conv2D(128, (4,4), activation='relu', padding='same')(encoder_output)
    encoder_output = Conv2D(128, (3,3), activation='relu', padding='same',strides=1)(encoder_output)
    encoder_output = MaxPooling2D((2, 2), padding='same')(encoder_output)
    encoder_output = Conv2D(256, (4,4), activation='relu', padding='same')(encoder_output)
    encoder_output = Conv2D(256, (3,3), activation='relu', padding='same',strides=1)(encoder_output)
    encoder_output = MaxPooling2D((2, 2), padding='same')(encoder_output)
    encoder_output = Conv2D(256, (4,4), activation='relu', padding='same')(encoder_output)
    encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)
    encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)
    
    #Fusion
    fusion_output = RepeatVector(32 * 32)(embed_input) 
    fusion_output = Reshape(([32, 32, 1000]))(fusion_output)
    fusion_output = concatenate([encoder_output, fusion_output], axis=3) 
    fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output)
    
    #Decoder
    decoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output)
    decoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)
    decoder_output = UpSampling2D((2, 2))(decoder_output)
    decoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(decoder_output)
    decoder_output = UpSampling2D((2, 2))(decoder_output)
    decoder_output = Conv2D(64, (4,4), activation='relu', padding='same')(decoder_output)
    decoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)
    decoder_output = Conv2D(32, (2,2), activation='relu', padding='same')(decoder_output)
    decoder_output = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output)
    decoder_output = UpSampling2D((2, 2))(decoder_output)

    encoder_output_2 = Conv2D(128, (3,3), activation='relu', padding='same',strides=1)(encoder_input)
    encoder_output_2 = MaxPooling2D((2, 2), padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(128, (4,4), activation='relu', padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(128, (3,3), activation='relu', padding='same',strides=1)(encoder_output_2)
    encoder_output_2 = MaxPooling2D((2, 2), padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(256, (4,4), activation='relu', padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(256, (3,3), activation='relu', padding='same',strides=1)(encoder_output_2)
    encoder_output_2 = MaxPooling2D((2, 2), padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(256, (4,4), activation='relu', padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output_2)
    encoder_output_2 = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output_2)
    
    #Fusion
    fusion_output_2 = Conv2D(512, (1, 1), activation='relu', padding='same')(encoder_output_2)
    
    #Decoder
    decoder_output_2 = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output_2)
    decoder_output_2 = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output_2)
    decoder_output_2 = UpSampling2D((2, 2))(decoder_output_2)
    decoder_output_2 = Conv2D(128, (3,3), activation='relu', padding='same')(decoder_output_2)
    decoder_output_2 = UpSampling2D((2, 2))(decoder_output_2)
    decoder_output_2 = Conv2D(64, (4,4), activation='relu', padding='same')(decoder_output_2)
    decoder_output_2 = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output_2)
    decoder_output_2 = Conv2D(32, (2,2), activation='relu', padding='same')(decoder_output_2)
    decoder_output_2 = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output_2)
    decoder_output_2 = UpSampling2D((2, 2))(decoder_output_2)

    encoder_input_3 = concatenate([decoder_output, decoder_output_2], axis=3)
    encoder_output_3 = Conv2D(128, (3,3), activation='relu', padding='same',strides=1)(encoder_input_3)
    encoder_output_3 = MaxPooling2D((2, 2), padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(128, (4,4), activation='relu', padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(128, (3,3), activation='relu', padding='same',strides=1)(encoder_output_3)
    encoder_output_3 = MaxPooling2D((2, 2), padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(256, (4,4), activation='relu', padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(256, (3,3), activation='relu', padding='same',strides=1)(encoder_output_3)
    encoder_output_3 = MaxPooling2D((2, 2), padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(256, (4,4), activation='relu', padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output_3)
    encoder_output_3 = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output_3)
    
    #Fusion
    fusion_output_3 = Conv2D(512, (1, 1), activation='relu', padding='same')(encoder_output_3)
    
    #Decoder
    decoder_output_3 = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output_3)
    decoder_output_3 = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output_3)
    decoder_output_3 = UpSampling2D((2, 2))(decoder_output_3)
    decoder_output_3 = Conv2D(128, (3,3), activation='relu', padding='same')(decoder_output_3)
    decoder_output_3 = UpSampling2D((2, 2))(decoder_output_3)
    decoder_output_3 = Conv2D(64, (4,4), activation='relu', padding='same')(decoder_output_3)
    decoder_output_3 = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output_3)
    decoder_output_3 = Conv2D(32, (2,2), activation='relu', padding='same')(decoder_output_3)
    decoder_output_3 = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output_3)
    decoder_output_3 = UpSampling2D((2, 2))(decoder_output_3)

    return Model(inputs=[encoder_input, embed_input], outputs=decoder_output_3)

# %%
x = Colorize()

# %%
x.summary()

# %%
tf.keras.utils.plot_model(
    x, show_shapes=True, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=False, dpi=64, show_layer_activations=True
)

# %%
# z = InceptionResNetV2(input_shape=(299,299,3), include_top=False, pooling='avg')

# %%
z.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_454 (Conv2D)            (None, 149, 149, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_406 (Batch  (None, 149, 149, 32  96         ['conv2d_454[0][0]']
#  Normalization)                 )
#
#  activation_406 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_406[0][0]']
#                                 )
#
#  conv2d_455 (Conv2D)            (None, 147, 147, 32  9216        ['activation_406[0][0]']
#                                 )
#
#  batch_normalization_407 (Batch  (None, 147, 147, 32  96         ['conv2d_455[0][0]']
#  Normalization)                 )
#
#  activation_407 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_407[0][0]']
#                                 )
#
#  conv2d_456 (Conv2D)            (None, 147, 147, 64  18432       ['activation_407[0][0]']
#                                 )
#
#  batch_normalization_408 (Batch  (None, 147, 147, 64  192        ['conv2d_456[0][0]']
#  Normalization)                 )
#
#  activation_408 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_408[0][0]']
#                                 )
#
#  max_pooling2d_17 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_408[0][0]']
#  )
#
#  conv2d_457 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_17[0][0]']
#
#  batch_normalization_409 (Batch  (None, 73, 73, 80)  240         ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_409 (Activation)    (None, 73, 73, 80)   0           ['batch_normalization_409[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_409[0][0]']
#
#  batch_normalization_410 (Batch  (None, 71, 71, 192)  576        ['conv2d_458[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 71, 71, 192)  0           ['batch_normalization_410[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_410[0][0]']
#  )
#
#  conv2d_462 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_18[0][0]']
#
#  batch_normalization_414 (Batch  (None, 35, 35, 64)  192         ['conv2d_462[0][0]']
#  Normalization)
#
#  activation_414 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_414[0][0]']
#
#  conv2d_460 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_18[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_414[0][0]']
#
#  batch_normalization_412 (Batch  (None, 35, 35, 48)  144         ['conv2d_460[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 35, 35, 96)  288         ['conv2d_463[0][0]']
#  Normalization)
#
#  activation_412 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_412[0][0]']
#
#  activation_415 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_415[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 192)  0          ['max_pooling2d_18[0][0]']
#  oling2D)
#
#  conv2d_459 (Conv2D)            (None, 35, 35, 96)   18432       ['max_pooling2d_18[0][0]']
#
#  conv2d_461 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_412[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_415[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 35, 35, 64)   12288       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_411 (Batch  (None, 35, 35, 96)  288         ['conv2d_459[0][0]']
#  Normalization)
#
#  batch_normalization_413 (Batch  (None, 35, 35, 64)  192         ['conv2d_461[0][0]']
#  Normalization)
#
#  batch_normalization_416 (Batch  (None, 35, 35, 96)  288         ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 35, 35, 64)  192         ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_411[0][0]']
#
#  activation_413 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_413[0][0]']
#
#  activation_416 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_416[0][0]']
#
#  activation_417 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_417[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_411[0][0]',
#                                                                   'activation_413[0][0]',
#                                                                   'activation_416[0][0]',
#                                                                   'activation_417[0][0]']
#
#  conv2d_469 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_421 (Batch  (None, 35, 35, 32)  96          ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_421[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_470 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_421[0][0]']
#
#  batch_normalization_419 (Batch  (None, 35, 35, 32)  96          ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 35, 35, 48)  144         ['conv2d_470[0][0]']
#  Normalization)
#
#  activation_419 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_419[0][0]']
#
#  activation_422 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_422[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_419[0][0]']
#
#  conv2d_471 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_422[0][0]']
#
#  batch_normalization_418 (Batch  (None, 35, 35, 32)  96          ['conv2d_466[0][0]']
#  Normalization)
#
#  batch_normalization_420 (Batch  (None, 35, 35, 32)  96          ['conv2d_468[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 35, 35, 64)  192         ['conv2d_471[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_418[0][0]']
#
#  activation_420 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_420[0][0]']
#
#  activation_423 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_423[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_418[0][0]',
#                                                                   'activation_420[0][0]',
#                                                                   'activation_423[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 35, 35, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['block35_1[0][0]']
#
#  conv2d_475 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_427 (Batch  (None, 35, 35, 32)  96          ['conv2d_475[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_427[0][0]']
#
#  conv2d_473 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_476 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_427[0][0]']
#
#  batch_normalization_425 (Batch  (None, 35, 35, 32)  96          ['conv2d_473[0][0]']
#  Normalization)
#
#  batch_normalization_428 (Batch  (None, 35, 35, 48)  144         ['conv2d_476[0][0]']
#  Normalization)
#
#  activation_425 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_425[0][0]']
#
#  activation_428 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_428[0][0]']
#
#  conv2d_472 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_474 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_425[0][0]']
#
#  conv2d_477 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_428[0][0]']
#
#  batch_normalization_424 (Batch  (None, 35, 35, 32)  96          ['conv2d_472[0][0]']
#  Normalization)
#
#  batch_normalization_426 (Batch  (None, 35, 35, 32)  96          ['conv2d_474[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 35, 35, 64)  192         ['conv2d_477[0][0]']
#  Normalization)
#
#  activation_424 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_424[0][0]']
#
#  activation_426 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_426[0][0]']
#
#  activation_429 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_429[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_424[0][0]',
#                                                                   'activation_426[0][0]',
#                                                                   'activation_429[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 35, 35, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['block35_2[0][0]']
#
#  conv2d_481 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_433 (Batch  (None, 35, 35, 32)  96          ['conv2d_481[0][0]']
#  Normalization)
#
#  activation_433 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_433[0][0]']
#
#  conv2d_479 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_482 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_433[0][0]']
#
#  batch_normalization_431 (Batch  (None, 35, 35, 32)  96          ['conv2d_479[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 35, 35, 48)  144         ['conv2d_482[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_431[0][0]']
#
#  activation_434 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_434[0][0]']
#
#  conv2d_478 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_480 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_431[0][0]']
#
#  conv2d_483 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_434[0][0]']
#
#  batch_normalization_430 (Batch  (None, 35, 35, 32)  96          ['conv2d_478[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 35, 35, 32)  96          ['conv2d_480[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 35, 35, 64)  192         ['conv2d_483[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_430[0][0]']
#
#  activation_432 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_432[0][0]']
#
#  activation_435 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_435[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_430[0][0]',
#                                                                   'activation_432[0][0]',
#                                                                   'activation_435[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 35, 35, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['block35_3[0][0]']
#
#  conv2d_487 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_439 (Batch  (None, 35, 35, 32)  96          ['conv2d_487[0][0]']
#  Normalization)
#
#  activation_439 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_439[0][0]']
#
#  conv2d_485 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_488 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_439[0][0]']
#
#  batch_normalization_437 (Batch  (None, 35, 35, 32)  96          ['conv2d_485[0][0]']
#  Normalization)
#
#  batch_normalization_440 (Batch  (None, 35, 35, 48)  144         ['conv2d_488[0][0]']
#  Normalization)
#
#  activation_437 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_437[0][0]']
#
#  activation_440 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_440[0][0]']
#
#  conv2d_484 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_486 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_437[0][0]']
#
#  conv2d_489 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_440[0][0]']
#
#  batch_normalization_436 (Batch  (None, 35, 35, 32)  96          ['conv2d_484[0][0]']
#  Normalization)
#
#  batch_normalization_438 (Batch  (None, 35, 35, 32)  96          ['conv2d_486[0][0]']
#  Normalization)
#
#  batch_normalization_441 (Batch  (None, 35, 35, 64)  192         ['conv2d_489[0][0]']
#  Normalization)
#
#  activation_436 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_436[0][0]']
#
#  activation_438 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_438[0][0]']
#
#  activation_441 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_441[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_436[0][0]',
#                                                                   'activation_438[0][0]',
#                                                                   'activation_441[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 35, 35, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['block35_4[0][0]']
#
#  conv2d_493 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_445 (Batch  (None, 35, 35, 32)  96          ['conv2d_493[0][0]']
#  Normalization)
#
#  activation_445 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_445[0][0]']
#
#  conv2d_491 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_494 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_445[0][0]']
#
#  batch_normalization_443 (Batch  (None, 35, 35, 32)  96          ['conv2d_491[0][0]']
#  Normalization)
#
#  batch_normalization_446 (Batch  (None, 35, 35, 48)  144         ['conv2d_494[0][0]']
#  Normalization)
#
#  activation_443 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_443[0][0]']
#
#  activation_446 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_446[0][0]']
#
#  conv2d_490 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_492 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_443[0][0]']
#
#  conv2d_495 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_446[0][0]']
#
#  batch_normalization_442 (Batch  (None, 35, 35, 32)  96          ['conv2d_490[0][0]']
#  Normalization)
#
#  batch_normalization_444 (Batch  (None, 35, 35, 32)  96          ['conv2d_492[0][0]']
#  Normalization)
#
#  batch_normalization_447 (Batch  (None, 35, 35, 64)  192         ['conv2d_495[0][0]']
#  Normalization)
#
#  activation_442 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_442[0][0]']
#
#  activation_444 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_444[0][0]']
#
#  activation_447 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_447[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_442[0][0]',
#                                                                   'activation_444[0][0]',
#                                                                   'activation_447[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 35, 35, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['block35_5[0][0]']
#
#  conv2d_499 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_451 (Batch  (None, 35, 35, 32)  96          ['conv2d_499[0][0]']
#  Normalization)
#
#  activation_451 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_451[0][0]']
#
#  conv2d_497 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_500 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_451[0][0]']
#
#  batch_normalization_449 (Batch  (None, 35, 35, 32)  96          ['conv2d_497[0][0]']
#  Normalization)
#
#  batch_normalization_452 (Batch  (None, 35, 35, 48)  144         ['conv2d_500[0][0]']
#  Normalization)
#
#  activation_449 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_449[0][0]']
#
#  activation_452 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_452[0][0]']
#
#  conv2d_496 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_498 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_449[0][0]']
#
#  conv2d_501 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_452[0][0]']
#
#  batch_normalization_448 (Batch  (None, 35, 35, 32)  96          ['conv2d_496[0][0]']
#  Normalization)
#
#  batch_normalization_450 (Batch  (None, 35, 35, 32)  96          ['conv2d_498[0][0]']
#  Normalization)
#
#  batch_normalization_453 (Batch  (None, 35, 35, 64)  192         ['conv2d_501[0][0]']
#  Normalization)
#
#  activation_448 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_448[0][0]']
#
#  activation_450 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_450[0][0]']
#
#  activation_453 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_453[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_448[0][0]',
#                                                                   'activation_450[0][0]',
#                                                                   'activation_453[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 35, 35, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['block35_6[0][0]']
#
#  conv2d_505 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_457 (Batch  (None, 35, 35, 32)  96          ['conv2d_505[0][0]']
#  Normalization)
#
#  activation_457 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_457[0][0]']
#
#  conv2d_503 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_506 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_457[0][0]']
#
#  batch_normalization_455 (Batch  (None, 35, 35, 32)  96          ['conv2d_503[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 35, 35, 48)  144         ['conv2d_506[0][0]']
#  Normalization)
#
#  activation_455 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_455[0][0]']
#
#  activation_458 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_458[0][0]']
#
#  conv2d_502 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_504 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_455[0][0]']
#
#  conv2d_507 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_458[0][0]']
#
#  batch_normalization_454 (Batch  (None, 35, 35, 32)  96          ['conv2d_502[0][0]']
#  Normalization)
#
#  batch_normalization_456 (Batch  (None, 35, 35, 32)  96          ['conv2d_504[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 35, 35, 64)  192         ['conv2d_507[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_454[0][0]']
#
#  activation_456 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_456[0][0]']
#
#  activation_459 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_459[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_454[0][0]',
#                                                                   'activation_456[0][0]',
#                                                                   'activation_459[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 35, 35, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['block35_7[0][0]']
#
#  conv2d_511 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_463 (Batch  (None, 35, 35, 32)  96          ['conv2d_511[0][0]']
# ...
#  batch_normalization_594 (Batch  (None, 8, 8, 192)   576         ['conv2d_642[0][0]']
#  Normalization)
#
#  activation_594 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_594[0][0]']
#
#  conv2d_643 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_594[0][0]']
#
#  batch_normalization_595 (Batch  (None, 8, 8, 224)   672         ['conv2d_643[0][0]']
#  Normalization)
#
#  activation_595 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_595[0][0]']
#
#  conv2d_641 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_644 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_595[0][0]']
#
#  batch_normalization_593 (Batch  (None, 8, 8, 192)   576         ['conv2d_641[0][0]']
#  Normalization)
#
#  batch_normalization_596 (Batch  (None, 8, 8, 256)   768         ['conv2d_644[0][0]']
#  Normalization)
#
#  activation_593 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_593[0][0]']
#
#  activation_596 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_596[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_593[0][0]',
#                                                                   'activation_596[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 8, 8, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_646 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_598 (Batch  (None, 8, 8, 192)   576         ['conv2d_646[0][0]']
#  Normalization)
#
#  activation_598 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_598[0][0]']
#
#  conv2d_647 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_598[0][0]']
#
#  batch_normalization_599 (Batch  (None, 8, 8, 224)   672         ['conv2d_647[0][0]']
#  Normalization)
#
#  activation_599 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_599[0][0]']
#
#  conv2d_645 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_648 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_599[0][0]']
#
#  batch_normalization_597 (Batch  (None, 8, 8, 192)   576         ['conv2d_645[0][0]']
#  Normalization)
#
#  batch_normalization_600 (Batch  (None, 8, 8, 256)   768         ['conv2d_648[0][0]']
#  Normalization)
#
#  activation_597 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_597[0][0]']
#
#  activation_600 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_600[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_597[0][0]',
#                                                                   'activation_600[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 8, 8, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_650 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_602 (Batch  (None, 8, 8, 192)   576         ['conv2d_650[0][0]']
#  Normalization)
#
#  activation_602 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_602[0][0]']
#
#  conv2d_651 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_602[0][0]']
#
#  batch_normalization_603 (Batch  (None, 8, 8, 224)   672         ['conv2d_651[0][0]']
#  Normalization)
#
#  activation_603 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_603[0][0]']
#
#  conv2d_649 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_652 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_603[0][0]']
#
#  batch_normalization_601 (Batch  (None, 8, 8, 192)   576         ['conv2d_649[0][0]']
#  Normalization)
#
#  batch_normalization_604 (Batch  (None, 8, 8, 256)   768         ['conv2d_652[0][0]']
#  Normalization)
#
#  activation_601 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_601[0][0]']
#
#  activation_604 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_604[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_601[0][0]',
#                                                                   'activation_604[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 8, 8, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_654 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_606 (Batch  (None, 8, 8, 192)   576         ['conv2d_654[0][0]']
#  Normalization)
#
#  activation_606 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_606[0][0]']
#
#  conv2d_655 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_606[0][0]']
#
#  batch_normalization_607 (Batch  (None, 8, 8, 224)   672         ['conv2d_655[0][0]']
#  Normalization)
#
#  activation_607 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_607[0][0]']
#
#  conv2d_653 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_656 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_607[0][0]']
#
#  batch_normalization_605 (Batch  (None, 8, 8, 192)   576         ['conv2d_653[0][0]']
#  Normalization)
#
#  batch_normalization_608 (Batch  (None, 8, 8, 256)   768         ['conv2d_656[0][0]']
#  Normalization)
#
#  activation_605 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_605[0][0]']
#
#  activation_608 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_608[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_605[0][0]',
#                                                                   'activation_608[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 8, 8, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  obalAveragePooling2D)
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 300                    # no of epochs to train  the model

global_feature_w = 299
global_feature_h = 299
global_feature_input_shape = [global_feature_w, global_feature_h, 3]

global_feature_output_shape = [1000,]

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []


modelFileName = 'MultiPath_AE3_100_300'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/' + modelFileName + '.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/' + modelFileName + '.csv'

# %% [markdown]
# ##### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Initializing the Pretrained InceptionResNetV2 Model

# %% [markdown]
# ##### InceptionResNetV2 Configuration

# %%
inceptionNet = InceptionResNetV2(include_top=True)

# %%
inceptionNet.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_205 (Conv2D)            (None, 149, 149, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_203 (Batch  (None, 149, 149, 32  96         ['conv2d_205[0][0]']
#  Normalization)                 )
#
#  activation_203 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_203[0][0]']
#                                 )
#
#  conv2d_206 (Conv2D)            (None, 147, 147, 32  9216        ['activation_203[0][0]']
#                                 )
#
#  batch_normalization_204 (Batch  (None, 147, 147, 32  96         ['conv2d_206[0][0]']
#  Normalization)                 )
#
#  activation_204 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_204[0][0]']
#                                 )
#
#  conv2d_207 (Conv2D)            (None, 147, 147, 64  18432       ['activation_204[0][0]']
#                                 )
#
#  batch_normalization_205 (Batch  (None, 147, 147, 64  192        ['conv2d_207[0][0]']
#  Normalization)                 )
#
#  activation_205 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_205[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 73, 73, 64)  0           ['activation_205[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 73, 73, 80)  240         ['conv2d_208[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 73, 73, 80)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 71, 71, 192)  576        ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 71, 71, 192)  0           ['batch_normalization_207[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_207[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 35, 35, 64)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 35, 35, 48)  144         ['conv2d_211[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 35, 35, 96)  288         ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_210 (Conv2D)            (None, 35, 35, 96)   18432       ['max_pooling2d_5[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_209[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_212[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 35, 35, 64)   12288       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 35, 35, 96)  288         ['conv2d_210[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 35, 35, 64)  192         ['conv2d_212[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 35, 35, 96)  288         ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 35, 35, 64)  192         ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 35, 35, 32)  96          ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_218[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 35, 35, 32)  96          ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 35, 35, 48)  144         ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_219[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_216[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 35, 35, 32)  96          ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 35, 35, 32)  96          ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 35, 35, 64)  192         ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 35, 35, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['block35_1[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 35, 35, 32)  96          ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_224[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 35, 35, 32)  96          ['conv2d_224[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 35, 35, 48)  144         ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_225[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_222[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 35, 35, 32)  96          ['conv2d_223[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 35, 35, 32)  96          ['conv2d_225[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 35, 35, 64)  192         ['conv2d_228[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 35, 35, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['block35_2[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 35, 35, 32)  96          ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_230[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 35, 35, 32)  96          ['conv2d_230[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 35, 35, 48)  144         ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_231[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_228[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 35, 35, 32)  96          ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 35, 35, 32)  96          ['conv2d_231[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 35, 35, 64)  192         ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 35, 35, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['block35_3[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 35, 35, 32)  96          ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_236[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 35, 35, 32)  96          ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 35, 35, 48)  144         ['conv2d_239[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_237[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_234[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 35, 35, 32)  96          ['conv2d_235[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 35, 35, 32)  96          ['conv2d_237[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 35, 35, 64)  192         ['conv2d_240[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 35, 35, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['block35_4[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 35, 35, 32)  96          ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_242[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 35, 35, 32)  96          ['conv2d_242[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 35, 35, 48)  144         ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_243[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_240[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 35, 35, 32)  96          ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 35, 35, 32)  96          ['conv2d_243[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 35, 35, 64)  192         ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 35, 35, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['block35_5[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 35, 35, 32)  96          ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_248[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 35, 35, 32)  96          ['conv2d_248[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 35, 35, 48)  144         ['conv2d_251[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_249[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_246[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 35, 35, 32)  96          ['conv2d_247[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 35, 35, 32)  96          ['conv2d_249[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 35, 35, 64)  192         ['conv2d_252[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 35, 35, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['block35_6[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 35, 35, 32)  96          ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_254[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 35, 35, 32)  96          ['conv2d_254[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 35, 35, 48)  144         ['conv2d_257[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_255[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_252[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 35, 35, 32)  96          ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 35, 35, 32)  96          ['conv2d_255[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 35, 35, 64)  192         ['conv2d_258[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 35, 35, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['block35_7[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_260 (Batch  (None, 35, 35, 32)  96          ['conv2d_262[0][0]']
#  Normalization)
#
# ...
#
#  activation_391 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_391[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_391[0][0]']
#
#  batch_normalization_392 (Batch  (None, 8, 8, 224)   672         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_392 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_392[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_392[0][0]']
#
#  batch_normalization_390 (Batch  (None, 8, 8, 192)   576         ['conv2d_392[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 8, 8, 256)   768         ['conv2d_395[0][0]']
#  Normalization)
#
#  activation_390 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_393[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_390[0][0]',
#                                                                   'activation_393[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 8, 8, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_395 (Batch  (None, 8, 8, 192)   576         ['conv2d_397[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_395[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_395[0][0]']
#
#  batch_normalization_396 (Batch  (None, 8, 8, 224)   672         ['conv2d_398[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_396[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_396[0][0]']
#
#  batch_normalization_394 (Batch  (None, 8, 8, 192)   576         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 8, 8, 256)   768         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_394 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_397[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 8, 8, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_399 (Batch  (None, 8, 8, 192)   576         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_399[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 8, 8, 224)   672         ['conv2d_402[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_400[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 8, 8, 192)   576         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 8, 8, 256)   768         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 8, 8, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 8, 8, 192)   576         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_403[0][0]']
#
#  conv2d_406 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 8, 8, 224)   672         ['conv2d_406[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_404[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 8, 8, 192)   576         ['conv2d_404[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 8, 8, 256)   768         ['conv2d_407[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 8, 8, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         1537000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 55,873,736
# Trainable params: 55,813,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    
    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]
                
                w = image.shape[0]
                h = image.shape[1]
                isGrayScale = False
                for i in range(w):
                    for j in range(h):
                        
                        if r[i,j] == g[i,j] == b[i,j]:
                            isGrayScale = True
                        else:
                            isGrayScale = False
                            break
            else:
                isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])
        print(removedImages)
        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages], axis=0)

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                numpy.array 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                numpy.array
        '''
        labImage = rgb2lab(image)
        return labImage

    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    @staticmethod
    def fixup_shape(_l, _ab, w, h):

        '''
        Description : 
                Method to fix the shape of L and AB channels i.e X and Y
        Input :
                _l => L channel
                _ab => AB channel
                w => Width of the Image 
                h => Height of the Image
        Returns :
                tf.Tensor (shape => (w,h,1)), tf.Tensor (shape => (w,h,2))
        '''

        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

    # Method tp get the L and the feature data
    def getXData(labImage, img_width, img_height):
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])

        # extracting the features
        gray_img = labImage[:,:,0]
        gray_img = gray2rgb(gray_img)

        # resizing the image
        gray_img = resize(gray_img, output_shape=(global_feature_w, global_feature_h))
        gray_img = gray_img.reshape((1,)+gray_img.shape)

        # predicting the features
        features = inceptionNet.predict(gray_img)
        _feature = tf.reshape(features[0], shape=global_feature_output_shape)
        return _l, _feature

    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getYData(labImage, img_width, img_height):
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _ab


    # to fix the shape
    @staticmethod
    def fixup_shape(_l, _ab, w, h):
        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab


    # to fix the shape of X data
    @staticmethod
    def fixup_shape_Xdata(_l, _feature, w, h):
        _l.set_shape([w, h, 1])
        _feature.set_shape([global_feature_output_shape[0]])
        return _l, _feature


    # to fix the shape Y data
    @staticmethod
    def fixup_shape_Ydata(_ab, w, h):
        _ab.set_shape([w, h, 2])
        return _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, img_height, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

        # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

    # Method to split the LAB Image into L and FeaturesDataste
    @staticmethod
    def getXDataset(labImg_ds, img_width, img_height):

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape_Xdata(x, y, img_width, img_height))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getYDataset(labImg_ds, img_width, img_height):

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32]))

        return ds.map(lambda x : ImageUtils.fixup_shape_Ydata(x, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _feature = ImageUtils.getXData(labImage, img_w, img_h)

        _l = _l.reshape((1,) + _l.shape)
        _feature = _feature.reshape((1,) + _feature.shape)


        _abPred = model.predict([_l, _feature])
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        print('_fn_imgPostProcess_w')
        w = _ab.shape[1]
        print('_fn_imgPostProcess_h')
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))
        print('ab shape :', _ab.shape)
        print('l shape :', _l.shape)
        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[:,:,0] 
        print('ok')
        result[:,:,1:] = _ab[0,:,:,:]
        print('not ok')

        result = result.astype('float32')
        # print(result)
        print(f'_fn_imgPost result shape : {result.shape}')

        rgb = lab2rgb(result)

        # ########
        
        print(f'_fn_imgPost rgb shape : {rgb.shape}')
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 

        print(f'_fn_predRGB _l shape: {_l.shape}')
        print(f'_fn_predRGB predAB shape: {predAB.shape}')

        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8785

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 1015 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 1585 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 1897 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 2137 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# Removing ## ID : 2839 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 3249 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 3601 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 4076 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 4525 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 5058 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 5319 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# Removing ## ID : 6257 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 6378 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 6440 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# Removing ## ID : 7958 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Mapping the dataset to get the global features as well using InceptionResNetV2

# %% [markdown]
# ##### Function to get the train (X, Y) ZipDataset

# %%
def getZipDataset(ds, w, h):
    _X = DatasetMapper.getXDataset(ds, w, h)
    _Y = DatasetMapper.getYDataset(ds, w, h)
    _data = tf.data.Dataset.zip((_X, _Y))
    return _data

# %% [markdown]
# ##### Getting the train Feature Dataset

# %%
trainFeatureData = getZipDataset(train_lab_ds, img_w, img_h)

# %% [markdown]
# ##### Getting the val Feature Dataset

# %%
valFeatureData = getZipDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# ##### Getting the test Feature Dataset

# %%
testFeatureData = getZipDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 20

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %%
trainFeatureData = config_ds(trainFeatureData, batchSize)
testFeatureData = config_ds(testFeatureData, batchSize)
valFeatureData = config_ds(valFeatureData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = tf.keras.layers.Input(shape = inputShape, name='Encoder_Input')

    # embed input layer
    embed_input_L = tf.keras.layers.Input(shape = (global_feature_output_shape[0]), name='Embed_Input_L')

    # encoder

    # l1 
    l1 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same', strides=2, name='E-Conv1')(input_L)

    # l2
    l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv2')(l1)
    
    # l3
    l3 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', strides=2, name='E-Conv3')(l2)

    # l4
    l4 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv4')(l3)

    # l5
    l5 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', strides=2, name='E-Conv5')(l4)

    # l6
    l6 = Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv6')(l5)

    # l7
    l7 = Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv7')(l6)

    # l8
    l8 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', name='E-Conv8')(l7)


    # fusion 
    fusion_output = RepeatVector(32 * 32)(embed_input_L)
    fusion_output = Reshape(([32, 32, 1000])) (fusion_output)
    fusion_output = concatenate([l8, fusion_output], axis=3)
    fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output)


    # decoder

    # l9
    l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv1')(fusion_output)
    l9_up = UpSampling2D((2,2), name='D-Conv1-up')(l9)

    # l10
    l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv2')(l9_up)
    l10_up = UpSampling2D((2,2), name='D-Conv2-up')(l10)

    # l11
    l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv3')(l10_up)

    # l12
    l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same', name='D-Conv4')(l11)

    # l13
    l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same', name='D-Conv5')(l12)
    l13_up = UpSampling2D((2,2), name='D-Conv5-up')(l13)

    return Model(inputs=[input_L, embed_input_L], outputs=l13_up)

# %%
model = autoEncoder()

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Encoder_Input (InputLayer)     [(None, 256, 256, 1  0           []
#                                 )]
#
#  E-Conv1 (Conv2D)               (None, 128, 128, 64  640         ['Encoder_Input[0][0]']
#                                 )
#
#  E-Conv2 (Conv2D)               (None, 128, 128, 12  73856       ['E-Conv1[0][0]']
#                                 8)
#
#  E-Conv3 (Conv2D)               (None, 64, 64, 128)  147584      ['E-Conv2[0][0]']
#
#  E-Conv4 (Conv2D)               (None, 64, 64, 256)  295168      ['E-Conv3[0][0]']
#
#  E-Conv5 (Conv2D)               (None, 32, 32, 256)  590080      ['E-Conv4[0][0]']
#
#  E-Conv6 (Conv2D)               (None, 32, 32, 512)  1180160     ['E-Conv5[0][0]']
#
#  Embed_Input_L (InputLayer)     [(None, 1000)]       0           []
#
#  E-Conv7 (Conv2D)               (None, 32, 32, 512)  2359808     ['E-Conv6[0][0]']
#
#  repeat_vector_1 (RepeatVector)  (None, 1024, 1000)  0           ['Embed_Input_L[0][0]']
#
#  E-Conv8 (Conv2D)               (None, 32, 32, 256)  1179904     ['E-Conv7[0][0]']
#
#  reshape_1 (Reshape)            (None, 32, 32, 1000  0           ['repeat_vector_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 1256  0           ['E-Conv8[0][0]',
#                                 )                                 'reshape_1[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 32, 32, 256)  321792      ['concatenate_1[0][0]']
#
#  D-Conv1 (Conv2D)               (None, 32, 32, 128)  295040      ['conv2d_204[0][0]']
#
#  D-Conv1-up (UpSampling2D)      (None, 64, 64, 128)  0           ['D-Conv1[0][0]']
#
#  D-Conv2 (Conv2D)               (None, 64, 64, 64)   73792       ['D-Conv1-up[0][0]']
#
#  D-Conv2-up (UpSampling2D)      (None, 128, 128, 64  0           ['D-Conv2[0][0]']
#                                 )
#
#  D-Conv3 (Conv2D)               (None, 128, 128, 32  18464       ['D-Conv2-up[0][0]']
#                                 )
#
#  D-Conv4 (Conv2D)               (None, 128, 128, 16  4624        ['D-Conv3[0][0]']
#                                 )
#
#  D-Conv5 (Conv2D)               (None, 128, 128, 2)  290         ['D-Conv4[0][0]']
#
#  D-Conv5-up (UpSampling2D)      (None, 256, 256, 2)  0           ['D-Conv5[0][0]']
#
# ==================================================================================================
# Total params: 6,541,202
# Trainable params: 6,541,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, show_shapes=True, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=False, dpi=64, show_layer_activations=True
)

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
# os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
# training the model
history = model.fit(trainFeatureData, validation_data=valFeatureData, epochs=2)
# model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
# hist_df = pd.DataFrame(history.history) 
# with open(history_path, mode='w') as f:
#     hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/2
# 3/3 [==============================] - 185s 50s/step - loss: 0.1523 - accuracy: 0.5931 - val_loss: 0.0098 - val_accuracy: 0.4084
# Epoch 2/2
# 3/3 [==============================] - 100s 31s/step - loss: 0.0137 - accuracy: 0.3690 - val_loss: 0.0095 - val_accuracy: 0.5880
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model('/content/drive/MyDrive/Image Colorization/model-history/model/Test_Xception5_datasetZip.model')

# %%
newModel.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Encoder_Input (InputLayer)     [(None, 256, 256, 1  0           []
#                                 )]
#
#  E-Conv1 (Conv2D)               (None, 128, 128, 64  640         ['Encoder_Input[0][0]']
#                                 )
#
#  E-Conv2 (Conv2D)               (None, 128, 128, 12  73856       ['E-Conv1[0][0]']
#                                 8)
#
#  E-Conv3 (Conv2D)               (None, 64, 64, 128)  147584      ['E-Conv2[0][0]']
#
#  E-Conv4 (Conv2D)               (None, 64, 64, 256)  295168      ['E-Conv3[0][0]']
#
#  E-Conv5 (Conv2D)               (None, 32, 32, 256)  590080      ['E-Conv4[0][0]']
#
#  E-Conv6 (Conv2D)               (None, 32, 32, 512)  1180160     ['E-Conv5[0][0]']
#
#  Embed_Input_L (InputLayer)     [(None, 1000)]       0           []
#
#  E-Conv7 (Conv2D)               (None, 32, 32, 512)  2359808     ['E-Conv6[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 1024, 1000)   0           ['Embed_Input_L[0][0]']
#
#  E-Conv8 (Conv2D)               (None, 32, 32, 256)  1179904     ['E-Conv7[0][0]']
#
#  reshape (Reshape)              (None, 32, 32, 1000  0           ['repeat_vector[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 32, 32, 1256  0           ['E-Conv8[0][0]',
#                                 )                                 'reshape[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 32, 32, 256)  321792      ['concatenate[0][0]']
#
#  D-Conv1 (Conv2D)               (None, 32, 32, 128)  295040      ['conv2d_203[0][0]']
#
#  D-Conv1-up (UpSampling2D)      (None, 64, 64, 128)  0           ['D-Conv1[0][0]']
#
#  D-Conv2 (Conv2D)               (None, 64, 64, 64)   73792       ['D-Conv1-up[0][0]']
#
#  D-Conv2-up (UpSampling2D)      (None, 128, 128, 64  0           ['D-Conv2[0][0]']
#                                 )
#
#  D-Conv3 (Conv2D)               (None, 128, 128, 32  18464       ['D-Conv2-up[0][0]']
#                                 )
#
#  D-Conv4 (Conv2D)               (None, 128, 128, 16  4624        ['D-Conv3[0][0]']
#                                 )
#
#  D-Conv5 (Conv2D)               (None, 128, 128, 2)  290         ['D-Conv4[0][0]']
#
#  D-Conv5-up (UpSampling2D)      (None, 256, 256, 2)  0           ['D-Conv5[0][0]']
#
# ==================================================================================================
# Total params: 6,541,202
# Trainable params: 6,541,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/500.jpg'
# fileName = '/content/test6.jpeg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predRGB _l shape: (1, 256, 256, 1)
# _fn_predRGB predAB shape: (1, 256, 256, 2)
# _fn_imgPostProcess_w
# _fn_imgPostProcess_h
# ab shape : (1, 256, 256, 2)
# l shape : (1, 256, 256, 1)
# ok
# not ok
# _fn_imgPost result shape : (256, 256, 3)
# _fn_imgPost rgb shape : (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape)

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----
