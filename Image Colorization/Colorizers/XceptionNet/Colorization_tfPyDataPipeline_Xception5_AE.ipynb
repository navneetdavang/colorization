# %% [markdown]
# # Using the Xception Pretrained Model As Encoder in AE
# (Xeption3 extension : removing the normalization - Stat - Fail)

# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 2.5 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.24.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.24.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.24.0

# %%
# !nvidia-smi
# Out:
# Sat Feb 12 14:13:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.xception import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                    # no of epochs to train  the model
latent_shape = (8,8,2048)            # shape of latent space / bottleneck from the XceptionNet
_lw = latent_shape[0]
_lh = latent_shape[1]
_lc = latent_shape[2]

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []


modelFileName = 'Ct_tfPyClass_xcept5_GCData_100_500'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/' + modelFileName + '.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/' + modelFileName + '.csv'

# %% [markdown]
# #### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    
    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]
                
                w = image.shape[0]
                h = image.shape[1]
                isGrayScale = False
                for i in range(w):
                    for j in range(h):
                        
                        if r[i,j] == g[i,j] == b[i,j]:
                            isGrayScale = True
                        else:
                            isGrayScale = False
                            break
            else:
                isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])
        print(removedImages)
        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages], axis=0)

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                numpy.array 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                numpy.array
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    @staticmethod
    def fixup_shape(_l, _ab, w, h):

        '''
        Description : 
                Method to fix the shape of L and AB channels i.e X and Y
        Input :
                _l => L channel
                _ab => AB channel
                w => Width of the Image 
                h => Height of the Image
        Returns :
                tf.Tensor (shape => (w,h,1)), tf.Tensor (shape => (w,h,2))
        '''

        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, img_height, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Initializing the Pretrained XceptionNet Model

# %% [markdown]
# ##### Xception Net Configuration

# %%
xcept = Xception(include_top=False, input_shape=(256,256,3))

# %%
xcept.trainable = False

# %%
xcept.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 127, 127, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 127, 127, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 127, 127, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 125, 125, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 125, 125, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 125, 125, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 125, 125, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 125, 125, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 125, 125, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 125, 125, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 125, 125, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 63, 63, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 63, 63, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 63, 63, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 63, 63, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 63, 63, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 63, 63, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 63, 63, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 63, 63, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 63, 63, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 63, 63, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 32, 32, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 32, 32, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 16, 16, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 8, 8, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 8, 8, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 8, 8, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 8, 8, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 8, 8, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 8, 8, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 8, 8, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 8, 8, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# #### Feature Extractor Class

# %%
class FeatureExtractor:
    '''
    Description : Class to Extract the Features from the given images
    '''

    # method to get the latent space from the Xception network
    @staticmethod
    def getLatentSpaceFromXceptionNet(_l, _ab):
        '''
        Description : 
                Method to get the Latent Space from the Xception network
        Input :
                _l => L channel
                _ab => AB channel
        Returns :
                numpy.array (Extracted Feature), 
                numpy.array (shape => (w, h, 2))

        '''

        # print(_l.shape)

        gray_img = _l[:,:,0]

        # reshaping adding 2 extra channel in the gray_img
        gray_img = gray2rgb(gray_img)

        # print('gray2rgb gray_img shape :', gray_img.shape)
        
        # adding extra 1 dim in gray_img to fit in the vggmodel
        gray_img = gray_img.reshape((1,) + gray_img.shape)

        # print('model fit gray_img shape :', gray_img.shape)

        # predicting the latent space
        _latent = xcept.predict(gray_img)

        # print('predicted Latent :', _latent.shape)
        # print('predicted Latent dtype:', _latent.dtype)
    
        _latent = _latent[0]

        # print('predicted Latent :', _latent.shape)
    
        return _latent, _ab

    # method to fixup the shape of the output of the latent space 
    @staticmethod
    def fixup_shape(_latent, _ab, w, h, lw, lh, lc):
        '''
        Description : 
                Method to fixup the shape of the output of the latent space 
        Input :
                _latent => Latent Space
                _ab => AB channel
                w => Width of the AB Channel
                h => Height of the AB Channel
                (lw, lh, lc) => Dimension of the Latent Space
        Returns :
                tf.Tensor (Extracted Feature | shape => (_lw, _lh, _lc)), 
                tf.Tensor (AB Channel | shape => (w, h, 2))

        '''
        _latent.set_shape([lw, lh, lc])
        _ab.set_shape([w,h,2])

        return _latent, _ab

# %% [markdown]
# #### Class to Map the Extracted Features

# %%
class FeatureExtractMapper:
    '''
    Description : Class to Map the Extracted Features to the Dataset
    '''

    # Method to get the Feature Extracted Dataset
    @staticmethod
    def getXYDataset(dataset, img_w, img_h, lw, lh, lc):
        '''
        Description : 
                Method to get the Feature Extracted Dataset
        Input :
                dataset => MapDatset (consist of the splited LAB image channel [L & AB])
                img_w => Width of the Image 
                img_h => Height of the Image
                (lw, lh, lc) => Shape of the Latent Space
        Returns :
                MapDataset shapes: ((lw, lh, lc), (img_w, img_h, 2)), types: (tf.float32, tf.float32)
        '''

        ds = dataset.map(lambda x, y : tf.py_function(FeatureExtractor.getLatentSpaceFromXceptionNet,
                                                     [x, y],
                                                     [tf.float32, tf.float32]))
        
        return ds.map(lambda x, y : FeatureExtractor.fixup_shape(x, y, img_w, img_h, lw, lh, lc))

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')

        _latent, _ab = FeatureExtractor.getLatentSpaceFromXceptionNet(_l, _ab)

        print(f'_fn_predLAB _latent Shape : {_latent.shape}')

        _latent = _latent.reshape((1,) + _latent.shape)
        print(f'_latent re-Shape : {_latent.shape}')

        _abPred = model.predict(_latent)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        print('_fn_imgPostProcess_w')
        w = _ab.shape[1]
        print('_fn_imgPostProcess_h')
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))
        print('ab shape :', _ab.shape)
        print('l shape :', _l.shape)
        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[:,:,0] 
        print('ok')
        result[:,:,1:] = _ab[0,:,:,:]
        print('not ok')

        result = result.astype('float32')
        # print(result)
        print(f'_fn_imgPost result shape : {result.shape}')

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        # result = tf.convert_to_tensor(result)
        # # print(result)

        # rgb = tfio.experimental.color.lab_to_rgb(result)
        # rgb = rgb.numpy()

        rgb = lab2rgb(result)

        # ########
        
        print(f'_fn_imgPost rgb shape : {rgb.shape}')
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 

        print(f'_fn_predRGB _l shape: {_l.shape}')
        print(f'_fn_predRGB predAB shape: {predAB.shape}')

        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8800

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 759 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 1259 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 2841 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 2911 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 3047 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 3808 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 4022 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 4369 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# Removing ## ID : 4398 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# Removing ## ID : 4544 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 6084 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# Removing ## ID : 6354 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 6587 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 6755 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 7362 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
train_lab_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
trainData
# Out:
# <MapDataset shapes: ((256, 256, 1), (256, 256, 2)), types: (tf.float32, tf.float32)>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Mapping the Features on datasets

# %% [markdown]
# ##### Getting the train Feature Dataset

# %%
trainFeatureData = FeatureExtractMapper.getXYDataset(trainData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the val Feature Dataset

# %%
valFeatureData = FeatureExtractMapper.getXYDataset(valData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the test Feature Dataset

# %%
testFeatureData = FeatureExtractMapper.getXYDataset(testData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %%
trainFeatureData = config_ds(trainFeatureData, batchSize)
testFeatureData = config_ds(testFeatureData, batchSize)
valFeatureData = config_ds(valFeatureData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape)

    # decoder

    # # l1
    # l1 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(input_L)

    # # l2
    # l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(l1)
    # l2_up = UpSampling2D(size=(2,2))(l2)

    # # l3
    # l3 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l2_up)
    # l3_up = UpSampling2D(size=(2,2))(l3)

    # # l4
    # l4 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l3_up)
    # l4_up = UpSampling2D(size=(2,2))(l4)

    # # l5
    # l5 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l4_up)
    # l5_up = UpSampling2D(size=(2,2))(l5)

    # # l6
    # l6 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l5_up)
    # l6_up = UpSampling2D(size=(2,2))(l6)

    # decoder

    # l9
    # l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(input_L)
    # l9_up = UpSampling2D((2,2))(l9)

    # # l10
    # l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l9_up)
    # l10_up = UpSampling2D((2,2))(l10)

    # # l11
    # l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l10_up)

    # # l12
    # l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l11)

    # # l13
    # l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l12)
    # l13_up = UpSampling2D((2,2))(l13)


    # deocder

    # l1
    l1 = Conv2DTranspose(filters=512, kernel_size=3, strides=(2,2), padding='same', activation='relu')(input_L)

    # l2
    l2 = Conv2DTranspose(filters=128, kernel_size=3, strides=(2,2), padding='same', activation='relu')(l1)

    # l3
    l3 = Conv2DTranspose(filters=64, kernel_size=3, strides=(2,2), padding='same', activation='relu')(l2)

    # l4
    l4 = Conv2DTranspose(filters=32, kernel_size=3, strides=(2,2), padding='same', activation='relu')(l3)
    
    # l5
    l5 = Conv2DTranspose(filters=2, kernel_size=3, strides=(2,2), padding='same', activation='tanh')(l4)

    return Model(inputs=input_L, outputs=l5)

# %%
model = autoEncoder(inputShape=latent_shape)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 8, 8, 2048)]      0
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 16, 512)      9437696
#  ranspose)
#
#  conv2d_transpose_6 (Conv2DT  (None, 32, 32, 128)      589952
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 64, 64, 64)       73792
#  ranspose)
#
#  conv2d_transpose_8 (Conv2DT  (None, 128, 128, 32)     18464
#  ranspose)
#
#  conv2d_transpose_9 (Conv2DT  (None, 256, 256, 2)      578
#  ranspose)
#
# =================================================================
# Total params: 10,120,482
# Trainable params: 10,120,482
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='RMSProp', loss='mse', metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
# training the model
history = model.fit(trainFeatureData, validation_data=valFeatureData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 3s 270ms/step - loss: 0.0274 - accuracy: 0.6875 - val_loss: 0.0316 - val_accuracy: 0.5042
# Epoch 2/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0240 - accuracy: 0.4851 - val_loss: 0.0135 - val_accuracy: 0.4902
# Epoch 3/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0127 - accuracy: 0.6266 - val_loss: 0.0258 - val_accuracy: 0.6058
# Epoch 4/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0148 - accuracy: 0.5565 - val_loss: 0.0131 - val_accuracy: 0.5368
# Epoch 5/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0079 - accuracy: 0.6844 - val_loss: 0.0127 - val_accuracy: 0.5776
# Epoch 6/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0062 - accuracy: 0.7105 - val_loss: 0.0144 - val_accuracy: 0.6011
# Epoch 7/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0068 - accuracy: 0.7096 - val_loss: 0.0120 - val_accuracy: 0.4498
# Epoch 8/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0100 - accuracy: 0.6510 - val_loss: 0.0228 - val_accuracy: 0.6148
# Epoch 9/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0094 - accuracy: 0.5847 - val_loss: 0.0141 - val_accuracy: 0.5906
# Epoch 10/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0049 - accuracy: 0.7478 - val_loss: 0.0150 - val_accuracy: 0.6007
# Epoch 11/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0037 - accuracy: 0.7686 - val_loss: 0.0109 - val_accuracy: 0.5156
# Epoch 12/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0100 - accuracy: 0.6678 - val_loss: 0.0114 - val_accuracy: 0.5189
# Epoch 13/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0072 - accuracy: 0.6814 - val_loss: 0.0117 - val_accuracy: 0.4570
# Epoch 14/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0057 - accuracy: 0.6868 - val_loss: 0.0206 - val_accuracy: 0.6257
# Epoch 15/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0070 - accuracy: 0.6413 - val_loss: 0.0113 - val_accuracy: 0.5763
# Epoch 16/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0037 - accuracy: 0.7691 - val_loss: 0.0186 - val_accuracy: 0.6091
# Epoch 17/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0057 - accuracy: 0.7135 - val_loss: 0.0108 - val_accuracy: 0.5256
# Epoch 18/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0041 - accuracy: 0.7514 - val_loss: 0.0172 - val_accuracy: 0.6192
# Epoch 19/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0041 - accuracy: 0.6856 - val_loss: 0.0093 - val_accuracy: 0.4824
# Epoch 20/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0040 - accuracy: 0.7230 - val_loss: 0.0174 - val_accuracy: 0.6152
# Epoch 21/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0037 - accuracy: 0.7023 - val_loss: 0.0100 - val_accuracy: 0.5393
# Epoch 22/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0042 - accuracy: 0.7555 - val_loss: 0.0174 - val_accuracy: 0.6034
# Epoch 23/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0037 - accuracy: 0.7694 - val_loss: 0.0102 - val_accuracy: 0.5476
# Epoch 24/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0040 - accuracy: 0.7751 - val_loss: 0.0147 - val_accuracy: 0.5852
# Epoch 25/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0030 - accuracy: 0.7990 - val_loss: 0.0109 - val_accuracy: 0.4909
# Epoch 26/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0048 - accuracy: 0.7186 - val_loss: 0.0180 - val_accuracy: 0.6045
# Epoch 27/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0037 - accuracy: 0.7422 - val_loss: 0.0103 - val_accuracy: 0.4539
# Epoch 28/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0034 - accuracy: 0.6986 - val_loss: 0.0174 - val_accuracy: 0.6212
# Epoch 29/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0040 - accuracy: 0.6534 - val_loss: 0.0113 - val_accuracy: 0.5587
# Epoch 30/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0030 - accuracy: 0.7705 - val_loss: 0.0142 - val_accuracy: 0.5965
# Epoch 31/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0027 - accuracy: 0.7973 - val_loss: 0.0097 - val_accuracy: 0.4745
# Epoch 32/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0044 - accuracy: 0.7329 - val_loss: 0.0166 - val_accuracy: 0.5846
# Epoch 33/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0036 - accuracy: 0.8091 - val_loss: 0.0136 - val_accuracy: 0.5951
# Epoch 34/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0034 - accuracy: 0.7876 - val_loss: 0.0094 - val_accuracy: 0.5476
# Epoch 35/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0042 - accuracy: 0.7428 - val_loss: 0.0193 - val_accuracy: 0.6021
# Epoch 36/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0047 - accuracy: 0.6599 - val_loss: 0.0104 - val_accuracy: 0.4997
# Epoch 37/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0032 - accuracy: 0.7622 - val_loss: 0.0118 - val_accuracy: 0.5709
# Epoch 38/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0020 - accuracy: 0.8185 - val_loss: 0.0098 - val_accuracy: 0.4439
# Epoch 39/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0032 - accuracy: 0.7250 - val_loss: 0.0139 - val_accuracy: 0.5947
# Epoch 40/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0026 - accuracy: 0.7961 - val_loss: 0.0093 - val_accuracy: 0.5119
# Epoch 41/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0027 - accuracy: 0.7810 - val_loss: 0.0162 - val_accuracy: 0.6148
# Epoch 42/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0031 - accuracy: 0.6955 - val_loss: 0.0103 - val_accuracy: 0.5387
# Epoch 43/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0024 - accuracy: 0.7779 - val_loss: 0.0164 - val_accuracy: 0.6230
# Epoch 44/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0027 - accuracy: 0.7188 - val_loss: 0.0115 - val_accuracy: 0.5307
# Epoch 45/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0022 - accuracy: 0.7839 - val_loss: 0.0126 - val_accuracy: 0.6039
# Epoch 46/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0019 - accuracy: 0.8021 - val_loss: 0.0107 - val_accuracy: 0.4196
# Epoch 47/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0044 - accuracy: 0.6988 - val_loss: 0.0153 - val_accuracy: 0.6234
# Epoch 48/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0031 - accuracy: 0.7399 - val_loss: 0.0097 - val_accuracy: 0.5663
# Epoch 49/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0026 - accuracy: 0.8163 - val_loss: 0.0155 - val_accuracy: 0.6056
# Epoch 50/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0030 - accuracy: 0.8204 - val_loss: 0.0113 - val_accuracy: 0.5371
# Epoch 51/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0027 - accuracy: 0.7965 - val_loss: 0.0153 - val_accuracy: 0.6070
# Epoch 52/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0027 - accuracy: 0.7287 - val_loss: 0.0093 - val_accuracy: 0.4993
# Epoch 53/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0023 - accuracy: 0.7686 - val_loss: 0.0147 - val_accuracy: 0.6216
# Epoch 54/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0019 - accuracy: 0.7557 - val_loss: 0.0103 - val_accuracy: 0.5070
# Epoch 55/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0024 - accuracy: 0.7637 - val_loss: 0.0163 - val_accuracy: 0.6214
# Epoch 56/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0023 - accuracy: 0.7302 - val_loss: 0.0110 - val_accuracy: 0.5394
# Epoch 57/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0027 - accuracy: 0.8046 - val_loss: 0.0123 - val_accuracy: 0.5992
# Epoch 58/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0027 - accuracy: 0.8211 - val_loss: 0.0096 - val_accuracy: 0.5562
# Epoch 59/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0027 - accuracy: 0.8126 - val_loss: 0.0149 - val_accuracy: 0.6007
# Epoch 60/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0029 - accuracy: 0.8173 - val_loss: 0.0102 - val_accuracy: 0.4991
# Epoch 61/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0025 - accuracy: 0.7663 - val_loss: 0.0171 - val_accuracy: 0.6206
# Epoch 62/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0030 - accuracy: 0.7099 - val_loss: 0.0100 - val_accuracy: 0.5545
# Epoch 63/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0017 - accuracy: 0.8222 - val_loss: 0.0137 - val_accuracy: 0.6091
# Epoch 64/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0015 - accuracy: 0.8046 - val_loss: 0.0097 - val_accuracy: 0.4739
# Epoch 65/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0025 - accuracy: 0.7520 - val_loss: 0.0167 - val_accuracy: 0.6288
# Epoch 66/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0024 - accuracy: 0.7278 - val_loss: 0.0104 - val_accuracy: 0.5626
# Epoch 67/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0026 - accuracy: 0.8191 - val_loss: 0.0120 - val_accuracy: 0.6040
# Epoch 68/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0020 - accuracy: 0.8343 - val_loss: 0.0106 - val_accuracy: 0.5766
# Epoch 69/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0022 - accuracy: 0.8286 - val_loss: 0.0135 - val_accuracy: 0.5828
# Epoch 70/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0028 - accuracy: 0.8300 - val_loss: 0.0102 - val_accuracy: 0.5273
# Epoch 71/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0022 - accuracy: 0.7981 - val_loss: 0.0183 - val_accuracy: 0.6268
# Epoch 72/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0032 - accuracy: 0.6957 - val_loss: 0.0109 - val_accuracy: 0.5726
# Epoch 73/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0017 - accuracy: 0.8220 - val_loss: 0.0122 - val_accuracy: 0.5895
# Epoch 74/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0014 - accuracy: 0.8410 - val_loss: 0.0097 - val_accuracy: 0.5016
# Epoch 75/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0023 - accuracy: 0.7887 - val_loss: 0.0145 - val_accuracy: 0.6103
# Epoch 76/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0022 - accuracy: 0.7941 - val_loss: 0.0090 - val_accuracy: 0.4944
# Epoch 77/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0022 - accuracy: 0.7701 - val_loss: 0.0163 - val_accuracy: 0.6309
# Epoch 78/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0024 - accuracy: 0.7373 - val_loss: 0.0110 - val_accuracy: 0.5439
# Epoch 79/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0017 - accuracy: 0.8048 - val_loss: 0.0142 - val_accuracy: 0.6328
# Epoch 80/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0019 - accuracy: 0.7834 - val_loss: 0.0097 - val_accuracy: 0.5512
# Epoch 81/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0018 - accuracy: 0.8162 - val_loss: 0.0123 - val_accuracy: 0.6128
# Epoch 82/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0015 - accuracy: 0.8384 - val_loss: 0.0130 - val_accuracy: 0.5981
# Epoch 83/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0024 - accuracy: 0.8238 - val_loss: 0.0099 - val_accuracy: 0.4596
# Epoch 84/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0034 - accuracy: 0.7557 - val_loss: 0.0155 - val_accuracy: 0.6279
# Epoch 85/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0022 - accuracy: 0.7743 - val_loss: 0.0106 - val_accuracy: 0.5996
# Epoch 86/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0015 - accuracy: 0.8405 - val_loss: 0.0141 - val_accuracy: 0.6276
# Epoch 87/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0014 - accuracy: 0.8248 - val_loss: 0.0089 - val_accuracy: 0.5193
# Epoch 88/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0021 - accuracy: 0.7874 - val_loss: 0.0152 - val_accuracy: 0.6285
# Epoch 89/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0018 - accuracy: 0.7875 - val_loss: 0.0101 - val_accuracy: 0.5462
# Epoch 90/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0020 - accuracy: 0.8215 - val_loss: 0.0132 - val_accuracy: 0.6054
# Epoch 91/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0019 - accuracy: 0.8410 - val_loss: 0.0101 - val_accuracy: 0.6080
# Epoch 92/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0019 - accuracy: 0.8390 - val_loss: 0.0121 - val_accuracy: 0.5928
# Epoch 93/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0017 - accuracy: 0.8451 - val_loss: 0.0107 - val_accuracy: 0.5732
# Epoch 94/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0016 - accuracy: 0.8381 - val_loss: 0.0148 - val_accuracy: 0.6309
# Epoch 95/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0023 - accuracy: 0.7394 - val_loss: 0.0091 - val_accuracy: 0.4987
# Epoch 96/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0024 - accuracy: 0.7690 - val_loss: 0.0161 - val_accuracy: 0.6325
# Epoch 97/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0019 - accuracy: 0.7801 - val_loss: 0.0108 - val_accuracy: 0.5627
# Epoch 98/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0015 - accuracy: 0.8260 - val_loss: 0.0125 - val_accuracy: 0.6220
# Epoch 99/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0014 - accuracy: 0.8452 - val_loss: 0.0097 - val_accuracy: 0.5036
# Epoch 100/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0026 - accuracy: 0.7901 - val_loss: 0.0120 - val_accuracy: 0.6122
# Epoch 101/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0014 - accuracy: 0.8371 - val_loss: 0.0098 - val_accuracy: 0.5680
# Epoch 102/500
# 3/3 [==============================] - 0s 150ms/step - loss: 0.0014 - accuracy: 0.8416 - val_loss: 0.0145 - val_accuracy: 0.6136
# Epoch 103/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0020 - accuracy: 0.8324 - val_loss: 0.0096 - val_accuracy: 0.5298
# Epoch 104/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0019 - accuracy: 0.7984 - val_loss: 0.0159 - val_accuracy: 0.6331
# Epoch 105/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0021 - accuracy: 0.7590 - val_loss: 0.0107 - val_accuracy: 0.5344
# Epoch 106/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0017 - accuracy: 0.8041 - val_loss: 0.0132 - val_accuracy: 0.6327
# Epoch 107/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0014 - accuracy: 0.8187 - val_loss: 0.0092 - val_accuracy: 0.5408
# Epoch 108/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0018 - accuracy: 0.8115 - val_loss: 0.0132 - val_accuracy: 0.6344
# Epoch 109/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0015 - accuracy: 0.8208 - val_loss: 0.0106 - val_accuracy: 0.5847
# Epoch 110/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0013 - accuracy: 0.8478 - val_loss: 0.0103 - val_accuracy: 0.5949
# Epoch 111/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0023 - accuracy: 0.8396 - val_loss: 0.0135 - val_accuracy: 0.6346
# Epoch 112/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0022 - accuracy: 0.7840 - val_loss: 0.0092 - val_accuracy: 0.5046
# Epoch 113/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0022 - accuracy: 0.7872 - val_loss: 0.0140 - val_accuracy: 0.6218
# Epoch 114/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0018 - accuracy: 0.8267 - val_loss: 0.0104 - val_accuracy: 0.5662
# Epoch 115/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0015 - accuracy: 0.8329 - val_loss: 0.0138 - val_accuracy: 0.6269
# Epoch 116/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0014 - accuracy: 0.8339 - val_loss: 0.0092 - val_accuracy: 0.5318
# Epoch 117/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0015 - accuracy: 0.8177 - val_loss: 0.0134 - val_accuracy: 0.6324
# Epoch 118/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0017 - accuracy: 0.8294 - val_loss: 0.0124 - val_accuracy: 0.5926
# Epoch 119/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0032 - accuracy: 0.8134 - val_loss: 0.0143 - val_accuracy: 0.6255
# Epoch 120/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0018 - accuracy: 0.8004 - val_loss: 0.0093 - val_accuracy: 0.5731
# Epoch 121/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0016 - accuracy: 0.8372 - val_loss: 0.0139 - val_accuracy: 0.6323
# Epoch 122/500
# 3/3 [==============================] - 0s 150ms/step - loss: 0.0015 - accuracy: 0.8368 - val_loss: 0.0099 - val_accuracy: 0.5123
# Epoch 123/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0018 - accuracy: 0.7952 - val_loss: 0.0137 - val_accuracy: 0.6287
# Epoch 124/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013 - accuracy: 0.8231 - val_loss: 0.0096 - val_accuracy: 0.5494
# Epoch 125/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0015 - accuracy: 0.8299 - val_loss: 0.0132 - val_accuracy: 0.6318
# Epoch 126/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0013 - accuracy: 0.8313 - val_loss: 0.0086 - val_accuracy: 0.5629
# Epoch 127/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0019 - accuracy: 0.8365 - val_loss: 0.0124 - val_accuracy: 0.6184
# Epoch 128/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0015 - accuracy: 0.8544 - val_loss: 0.0107 - val_accuracy: 0.6004
# Epoch 129/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0015 - accuracy: 0.8515 - val_loss: 0.0114 - val_accuracy: 0.6069
# Epoch 130/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0012 - accuracy: 0.8565 - val_loss: 0.0101 - val_accuracy: 0.5715
# Epoch 131/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0014 - accuracy: 0.8470 - val_loss: 0.0160 - val_accuracy: 0.6373
# Epoch 132/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0022 - accuracy: 0.7579 - val_loss: 0.0099 - val_accuracy: 0.5260
# Epoch 133/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0020 - accuracy: 0.7901 - val_loss: 0.0138 - val_accuracy: 0.6271
# Epoch 134/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8320 - val_loss: 0.0094 - val_accuracy: 0.5508
# Epoch 135/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0016 - accuracy: 0.8183 - val_loss: 0.0135 - val_accuracy: 0.6338
# Epoch 136/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0016 - accuracy: 0.7952 - val_loss: 0.0097 - val_accuracy: 0.5380
# Epoch 137/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0016 - accuracy: 0.8139 - val_loss: 0.0139 - val_accuracy: 0.6315
# Epoch 138/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0015 - accuracy: 0.8346 - val_loss: 0.0089 - val_accuracy: 0.5662
# Epoch 139/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0022 - accuracy: 0.8338 - val_loss: 0.0118 - val_accuracy: 0.6232
# Epoch 140/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0013 - accuracy: 0.8525 - val_loss: 0.0103 - val_accuracy: 0.6032
# Epoch 141/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8604 - val_loss: 0.0122 - val_accuracy: 0.6083
# Epoch 142/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0014 - accuracy: 0.8606 - val_loss: 0.0095 - val_accuracy: 0.5492
# Epoch 143/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0017 - accuracy: 0.8365 - val_loss: 0.0142 - val_accuracy: 0.6343
# Epoch 144/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0017 - accuracy: 0.7832 - val_loss: 0.0093 - val_accuracy: 0.5264
# Epoch 145/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0015 - accuracy: 0.8140 - val_loss: 0.0135 - val_accuracy: 0.6398
# Epoch 146/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0013 - accuracy: 0.8235 - val_loss: 0.0109 - val_accuracy: 0.5900
# Epoch 147/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0013 - accuracy: 0.8515 - val_loss: 0.0123 - val_accuracy: 0.6196
# Epoch 148/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0014 - accuracy: 0.8529 - val_loss: 0.0116 - val_accuracy: 0.6170
# Epoch 149/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0016 - accuracy: 0.8357 - val_loss: 0.0092 - val_accuracy: 0.5215
# Epoch 150/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0021 - accuracy: 0.8079 - val_loss: 0.0142 - val_accuracy: 0.6275
# Epoch 151/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0016 - accuracy: 0.8326 - val_loss: 0.0092 - val_accuracy: 0.5786
# Epoch 152/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0014 - accuracy: 0.8420 - val_loss: 0.0136 - val_accuracy: 0.6308
# Epoch 153/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0012 - accuracy: 0.8315 - val_loss: 0.0093 - val_accuracy: 0.5573
# Epoch 154/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0013 - accuracy: 0.8271 - val_loss: 0.0134 - val_accuracy: 0.6385
# Epoch 155/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013 - accuracy: 0.8100 - val_loss: 0.0098 - val_accuracy: 0.5579
# Epoch 156/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0013 - accuracy: 0.8282 - val_loss: 0.0135 - val_accuracy: 0.6411
# Epoch 157/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0012 - accuracy: 0.8256 - val_loss: 0.0087 - val_accuracy: 0.5672
# Epoch 158/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0017 - accuracy: 0.8338 - val_loss: 0.0129 - val_accuracy: 0.6273
# Epoch 159/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0016 - accuracy: 0.8493 - val_loss: 0.0101 - val_accuracy: 0.5818
# Epoch 160/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0018 - accuracy: 0.8440 - val_loss: 0.0119 - val_accuracy: 0.6196
# Epoch 161/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0014 - accuracy: 0.8626 - val_loss: 0.0102 - val_accuracy: 0.6021
# Epoch 162/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0011 - accuracy: 0.8569 - val_loss: 0.0130 - val_accuracy: 0.6267
# Epoch 163/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0012 - accuracy: 0.8276 - val_loss: 0.0089 - val_accuracy: 0.5354
# Epoch 164/500
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0016 - accuracy: 0.8063 - val_loss: 0.0137 - val_accuracy: 0.6418
# Epoch 165/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0013 - accuracy: 0.8102 - val_loss: 0.0100 - val_accuracy: 0.5715
# Epoch 166/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0014 - accuracy: 0.8314 - val_loss: 0.0135 - val_accuracy: 0.6264
# Epoch 167/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0014 - accuracy: 0.8496 - val_loss: 0.0090 - val_accuracy: 0.5928
# Epoch 168/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0018 - accuracy: 0.8508 - val_loss: 0.0109 - val_accuracy: 0.6249
# Epoch 169/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0012 - accuracy: 0.8545 - val_loss: 0.0102 - val_accuracy: 0.5924
# Epoch 170/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0010 - accuracy: 0.8642 - val_loss: 0.0122 - val_accuracy: 0.6073
# Epoch 171/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0013 - accuracy: 0.8624 - val_loss: 0.0101 - val_accuracy: 0.5739
# Epoch 172/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013 - accuracy: 0.8510 - val_loss: 0.0146 - val_accuracy: 0.6392
# Epoch 173/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0019 - accuracy: 0.7755 - val_loss: 0.0093 - val_accuracy: 0.5310
# Epoch 174/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0016 - accuracy: 0.8155 - val_loss: 0.0126 - val_accuracy: 0.6333
# Epoch 175/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0010 - accuracy: 0.8459 - val_loss: 0.0094 - val_accuracy: 0.5874
# Epoch 176/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8456 - val_loss: 0.0125 - val_accuracy: 0.6325
# Epoch 177/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8398 - val_loss: 0.0099 - val_accuracy: 0.5888
# Epoch 178/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0012 - accuracy: 0.8528 - val_loss: 0.0107 - val_accuracy: 0.6165
# Epoch 179/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013 - accuracy: 0.8627 - val_loss: 0.0128 - val_accuracy: 0.6395
# Epoch 180/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0019 - accuracy: 0.8118 - val_loss: 0.0086 - val_accuracy: 0.5295
# Epoch 181/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0017 - accuracy: 0.8156 - val_loss: 0.0135 - val_accuracy: 0.6326
# Epoch 182/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0013 - accuracy: 0.8561 - val_loss: 0.0097 - val_accuracy: 0.6032
# Epoch 183/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0012 - accuracy: 0.8622 - val_loss: 0.0123 - val_accuracy: 0.6244
# Epoch 184/500
# 3/3 [==============================] - 0s 156ms/step - loss: 9.5646e-04 - accuracy: 0.8605 - val_loss: 0.0090 - val_accuracy: 0.5712
# Epoch 185/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0012 - accuracy: 0.8407 - val_loss: 0.0127 - val_accuracy: 0.6382
# Epoch 186/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0012 - accuracy: 0.8238 - val_loss: 0.0091 - val_accuracy: 0.5454
# Epoch 187/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0013 - accuracy: 0.8307 - val_loss: 0.0138 - val_accuracy: 0.6332
# Epoch 188/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8209 - val_loss: 0.0098 - val_accuracy: 0.5733
# Epoch 189/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0013 - accuracy: 0.8373 - val_loss: 0.0125 - val_accuracy: 0.6318
# Epoch 190/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0016 - accuracy: 0.8401 - val_loss: 0.0109 - val_accuracy: 0.6163
# Epoch 191/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0012 - accuracy: 0.8548 - val_loss: 0.0094 - val_accuracy: 0.5676
# Epoch 192/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0014 - accuracy: 0.8442 - val_loss: 0.0138 - val_accuracy: 0.6310
# Epoch 193/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0018 - accuracy: 0.8275 - val_loss: 0.0092 - val_accuracy: 0.5443
# Epoch 194/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0014 - accuracy: 0.8348 - val_loss: 0.0123 - val_accuracy: 0.6256
# Epoch 195/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.7738e-04 - accuracy: 0.8557 - val_loss: 0.0095 - val_accuracy: 0.6002
# Epoch 196/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8619 - val_loss: 0.0126 - val_accuracy: 0.6240
# Epoch 197/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0011 - accuracy: 0.8583 - val_loss: 0.0089 - val_accuracy: 0.5858
# Epoch 198/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0014 - accuracy: 0.8506 - val_loss: 0.0116 - val_accuracy: 0.6159
# Epoch 199/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0011 - accuracy: 0.8670 - val_loss: 0.0108 - val_accuracy: 0.6119
# Epoch 200/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0013 - accuracy: 0.8584 - val_loss: 0.0111 - val_accuracy: 0.6059
# Epoch 201/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0012 - accuracy: 0.8648 - val_loss: 0.0115 - val_accuracy: 0.6346
# Epoch 202/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0010 - accuracy: 0.8454 - val_loss: 0.0091 - val_accuracy: 0.5582
# Epoch 203/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0015 - accuracy: 0.8226 - val_loss: 0.0155 - val_accuracy: 0.6331
# Epoch 204/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0018 - accuracy: 0.7923 - val_loss: 0.0095 - val_accuracy: 0.5757
# Epoch 205/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013 - accuracy: 0.8506 - val_loss: 0.0118 - val_accuracy: 0.6288
# Epoch 206/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8606 - val_loss: 0.0093 - val_accuracy: 0.5967
# Epoch 207/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8663 - val_loss: 0.0117 - val_accuracy: 0.6251
# Epoch 208/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8666 - val_loss: 0.0092 - val_accuracy: 0.5818
# Epoch 209/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0013 - accuracy: 0.8562 - val_loss: 0.0120 - val_accuracy: 0.6299
# Epoch 210/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0011 - accuracy: 0.8529 - val_loss: 0.0090 - val_accuracy: 0.5686
# Epoch 211/500
# 3/3 [==============================] - 0s 164ms/step - loss: 0.0012 - accuracy: 0.8420 - val_loss: 0.0137 - val_accuracy: 0.6478
# Epoch 212/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0014 - accuracy: 0.8110 - val_loss: 0.0100 - val_accuracy: 0.5786
# Epoch 213/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0011 - accuracy: 0.8500 - val_loss: 0.0113 - val_accuracy: 0.6298
# Epoch 214/500
# 3/3 [==============================] - 0s 157ms/step - loss: 9.0083e-04 - accuracy: 0.8492 - val_loss: 0.0098 - val_accuracy: 0.5784
# Epoch 215/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0010 - accuracy: 0.8525 - val_loss: 0.0139 - val_accuracy: 0.6290
# Epoch 216/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0016 - accuracy: 0.8180 - val_loss: 0.0095 - val_accuracy: 0.5657
# Epoch 217/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0021 - accuracy: 0.8382 - val_loss: 0.0109 - val_accuracy: 0.6313
# Epoch 218/500
# 3/3 [==============================] - 0s 160ms/step - loss: 9.4092e-04 - accuracy: 0.8613 - val_loss: 0.0095 - val_accuracy: 0.6150
# Epoch 219/500
# 3/3 [==============================] - 0s 164ms/step - loss: 8.2751e-04 - accuracy: 0.8690 - val_loss: 0.0120 - val_accuracy: 0.6251
# Epoch 220/500
# 3/3 [==============================] - 0s 157ms/step - loss: 9.2228e-04 - accuracy: 0.8616 - val_loss: 0.0093 - val_accuracy: 0.5618
# Epoch 221/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8308 - val_loss: 0.0136 - val_accuracy: 0.6387
# Epoch 222/500
# 3/3 [==============================] - 0s 152ms/step - loss: 0.0012 - accuracy: 0.8235 - val_loss: 0.0096 - val_accuracy: 0.5752
# Epoch 223/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0012 - accuracy: 0.8490 - val_loss: 0.0125 - val_accuracy: 0.6319
# Epoch 224/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0011 - accuracy: 0.8561 - val_loss: 0.0092 - val_accuracy: 0.5926
# Epoch 225/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0016 - accuracy: 0.8576 - val_loss: 0.0106 - val_accuracy: 0.6238
# Epoch 226/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.7414e-04 - accuracy: 0.8646 - val_loss: 0.0098 - val_accuracy: 0.6085
# Epoch 227/500
# 3/3 [==============================] - 0s 157ms/step - loss: 8.5354e-04 - accuracy: 0.8728 - val_loss: 0.0123 - val_accuracy: 0.6320
# Epoch 228/500
# 3/3 [==============================] - 0s 166ms/step - loss: 0.0012 - accuracy: 0.8603 - val_loss: 0.0096 - val_accuracy: 0.5476
# Epoch 229/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0014 - accuracy: 0.8368 - val_loss: 0.0133 - val_accuracy: 0.6299
# Epoch 230/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0012 - accuracy: 0.8208 - val_loss: 0.0094 - val_accuracy: 0.5812
# Epoch 231/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0011 - accuracy: 0.8534 - val_loss: 0.0126 - val_accuracy: 0.6302
# Epoch 232/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8516 - val_loss: 0.0101 - val_accuracy: 0.6123
# Epoch 233/500
# 3/3 [==============================] - 1s 167ms/step - loss: 9.8894e-04 - accuracy: 0.8657 - val_loss: 0.0110 - val_accuracy: 0.6291
# Epoch 234/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0011 - accuracy: 0.8655 - val_loss: 0.0115 - val_accuracy: 0.6330
# Epoch 235/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0013 - accuracy: 0.8438 - val_loss: 0.0093 - val_accuracy: 0.5442
# Epoch 236/500
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0016 - accuracy: 0.8227 - val_loss: 0.0133 - val_accuracy: 0.6377
# Epoch 237/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0012 - accuracy: 0.8548 - val_loss: 0.0097 - val_accuracy: 0.6066
# Epoch 238/500
# 3/3 [==============================] - 0s 155ms/step - loss: 9.4505e-04 - accuracy: 0.8662 - val_loss: 0.0125 - val_accuracy: 0.6270
# Epoch 239/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.2936e-04 - accuracy: 0.8635 - val_loss: 0.0093 - val_accuracy: 0.5844
# Epoch 240/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0010 - accuracy: 0.8538 - val_loss: 0.0126 - val_accuracy: 0.6362
# Epoch 241/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0010 - accuracy: 0.8316 - val_loss: 0.0092 - val_accuracy: 0.5684
# Epoch 242/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0012 - accuracy: 0.8397 - val_loss: 0.0120 - val_accuracy: 0.6405
# Epoch 243/500
# 3/3 [==============================] - 0s 154ms/step - loss: 0.0010 - accuracy: 0.8386 - val_loss: 0.0091 - val_accuracy: 0.5783
# Epoch 244/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0011 - accuracy: 0.8497 - val_loss: 0.0128 - val_accuracy: 0.6280
# Epoch 245/500
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0013 - accuracy: 0.8145 - val_loss: 0.0099 - val_accuracy: 0.5683
# Epoch 246/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0014 - accuracy: 0.8487 - val_loss: 0.0116 - val_accuracy: 0.6301
# Epoch 247/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0014 - accuracy: 0.8635 - val_loss: 0.0115 - val_accuracy: 0.6372
# Epoch 248/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0012 - accuracy: 0.8511 - val_loss: 0.0089 - val_accuracy: 0.5893
# Epoch 249/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8593 - val_loss: 0.0122 - val_accuracy: 0.6304
# Epoch 250/500
# 3/3 [==============================] - 0s 162ms/step - loss: 9.6957e-04 - accuracy: 0.8668 - val_loss: 0.0091 - val_accuracy: 0.5870
# Epoch 251/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0011 - accuracy: 0.8631 - val_loss: 0.0121 - val_accuracy: 0.6336
# Epoch 252/500
# 3/3 [==============================] - 0s 156ms/step - loss: 9.1314e-04 - accuracy: 0.8622 - val_loss: 0.0095 - val_accuracy: 0.5867
# Epoch 253/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0010 - accuracy: 0.8653 - val_loss: 0.0118 - val_accuracy: 0.6396
# Epoch 254/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0011 - accuracy: 0.8534 - val_loss: 0.0096 - val_accuracy: 0.6040
# Epoch 255/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0012 - accuracy: 0.8684 - val_loss: 0.0114 - val_accuracy: 0.6063
# Epoch 256/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.9877e-04 - accuracy: 0.8710 - val_loss: 0.0104 - val_accuracy: 0.6280
# Epoch 257/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.1107e-04 - accuracy: 0.8670 - val_loss: 0.0110 - val_accuracy: 0.6113
# Epoch 258/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0010 - accuracy: 0.8682 - val_loss: 0.0105 - val_accuracy: 0.6057
# Epoch 259/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.9752e-04 - accuracy: 0.8713 - val_loss: 0.0117 - val_accuracy: 0.6316
# Epoch 260/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0011 - accuracy: 0.8325 - val_loss: 0.0086 - val_accuracy: 0.5327
# Epoch 261/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0016 - accuracy: 0.8089 - val_loss: 0.0134 - val_accuracy: 0.6413
# Epoch 262/500
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0011 - accuracy: 0.8355 - val_loss: 0.0096 - val_accuracy: 0.6074
# Epoch 263/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.6945e-04 - accuracy: 0.8681 - val_loss: 0.0119 - val_accuracy: 0.6302
# Epoch 264/500
# 3/3 [==============================] - 0s 155ms/step - loss: 8.3359e-04 - accuracy: 0.8604 - val_loss: 0.0098 - val_accuracy: 0.5913
# Epoch 265/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.6540e-04 - accuracy: 0.8567 - val_loss: 0.0121 - val_accuracy: 0.6413
# Epoch 266/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0010 - accuracy: 0.8586 - val_loss: 0.0098 - val_accuracy: 0.5911
# Epoch 267/500
# 3/3 [==============================] - 0s 160ms/step - loss: 9.2013e-04 - accuracy: 0.8655 - val_loss: 0.0115 - val_accuracy: 0.6337
# Epoch 268/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.2374e-04 - accuracy: 0.8662 - val_loss: 0.0093 - val_accuracy: 0.5756
# Epoch 269/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0011 - accuracy: 0.8495 - val_loss: 0.0145 - val_accuracy: 0.6312
# Epoch 270/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0021 - accuracy: 0.7988 - val_loss: 0.0090 - val_accuracy: 0.5727
# Epoch 271/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0016 - accuracy: 0.8506 - val_loss: 0.0110 - val_accuracy: 0.6290
# Epoch 272/500
# 3/3 [==============================] - 0s 157ms/step - loss: 7.9461e-04 - accuracy: 0.8723 - val_loss: 0.0092 - val_accuracy: 0.6005
# Epoch 273/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.0470e-04 - accuracy: 0.8706 - val_loss: 0.0111 - val_accuracy: 0.6238
# Epoch 274/500
# 3/3 [==============================] - 0s 159ms/step - loss: 7.9115e-04 - accuracy: 0.8750 - val_loss: 0.0095 - val_accuracy: 0.5887
# Epoch 275/500
# 3/3 [==============================] - 0s 162ms/step - loss: 8.9836e-04 - accuracy: 0.8653 - val_loss: 0.0127 - val_accuracy: 0.6311
# Epoch 276/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0011 - accuracy: 0.8471 - val_loss: 0.0087 - val_accuracy: 0.5859
# Epoch 277/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0010 - accuracy: 0.8593 - val_loss: 0.0126 - val_accuracy: 0.6279
# Epoch 278/500
# 3/3 [==============================] - 0s 160ms/step - loss: 9.1291e-04 - accuracy: 0.8472 - val_loss: 0.0094 - val_accuracy: 0.5826
# Epoch 279/500
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0010 - accuracy: 0.8474 - val_loss: 0.0126 - val_accuracy: 0.6466
# Epoch 280/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0012 - accuracy: 0.8270 - val_loss: 0.0101 - val_accuracy: 0.6015
# Epoch 281/500
# 3/3 [==============================] - 0s 165ms/step - loss: 8.7375e-04 - accuracy: 0.8701 - val_loss: 0.0102 - val_accuracy: 0.6136
# Epoch 282/500
# 3/3 [==============================] - 0s 160ms/step - loss: 9.3373e-04 - accuracy: 0.8740 - val_loss: 0.0120 - val_accuracy: 0.6314
# Epoch 283/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0014 - accuracy: 0.8480 - val_loss: 0.0090 - val_accuracy: 0.5678
# Epoch 284/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0013 - accuracy: 0.8496 - val_loss: 0.0119 - val_accuracy: 0.6280
# Epoch 285/500
# 3/3 [==============================] - 0s 159ms/step - loss: 8.8172e-04 - accuracy: 0.8675 - val_loss: 0.0092 - val_accuracy: 0.6105
# Epoch 286/500
# 3/3 [==============================] - 0s 159ms/step - loss: 8.2229e-04 - accuracy: 0.8736 - val_loss: 0.0121 - val_accuracy: 0.6289
# Epoch 287/500
# 3/3 [==============================] - 0s 159ms/step - loss: 8.2776e-04 - accuracy: 0.8657 - val_loss: 0.0092 - val_accuracy: 0.5908
# Epoch 288/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0010 - accuracy: 0.8574 - val_loss: 0.0125 - val_accuracy: 0.6291
# Epoch 289/500
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0010 - accuracy: 0.8610 - val_loss: 0.0090 - val_accuracy: 0.6125
# Epoch 290/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0011 - accuracy: 0.8679 - val_loss: 0.0111 - val_accuracy: 0.6150
# Epoch 291/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0011 - accuracy: 0.8683 - val_loss: 0.0108 - val_accuracy: 0.6187
# Epoch 292/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0011 - accuracy: 0.8665 - val_loss: 0.0106 - val_accuracy: 0.6225
# Epoch 293/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.2621e-04 - accuracy: 0.8744 - val_loss: 0.0109 - val_accuracy: 0.6258
# Epoch 294/500
# 3/3 [==============================] - 0s 156ms/step - loss: 7.6405e-04 - accuracy: 0.8716 - val_loss: 0.0095 - val_accuracy: 0.6005
# Epoch 295/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.1248e-04 - accuracy: 0.8621 - val_loss: 0.0142 - val_accuracy: 0.6337
# Epoch 296/500
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0015 - accuracy: 0.7978 - val_loss: 0.0098 - val_accuracy: 0.5725
# Epoch 297/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0013 - accuracy: 0.8438 - val_loss: 0.0122 - val_accuracy: 0.6347
# Epoch 298/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.7217e-04 - accuracy: 0.8713 - val_loss: 0.0089 - val_accuracy: 0.6084
# Epoch 299/500
# 3/3 [==============================] - 0s 156ms/step - loss: 9.7443e-04 - accuracy: 0.8746 - val_loss: 0.0111 - val_accuracy: 0.6187
# Epoch 300/500
# 3/3 [==============================] - 0s 157ms/step - loss: 8.2256e-04 - accuracy: 0.8771 - val_loss: 0.0095 - val_accuracy: 0.6111
# Epoch 301/500
# 3/3 [==============================] - 0s 157ms/step - loss: 8.9004e-04 - accuracy: 0.8727 - val_loss: 0.0113 - val_accuracy: 0.6238
# Epoch 302/500
# 3/3 [==============================] - 0s 162ms/step - loss: 9.6537e-04 - accuracy: 0.8696 - val_loss: 0.0090 - val_accuracy: 0.5969
# Epoch 303/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.6925e-04 - accuracy: 0.8669 - val_loss: 0.0132 - val_accuracy: 0.6320
# Epoch 304/500
# 3/3 [==============================] - 0s 164ms/step - loss: 0.0011 - accuracy: 0.8421 - val_loss: 0.0088 - val_accuracy: 0.5752
# Epoch 305/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0010 - accuracy: 0.8503 - val_loss: 0.0124 - val_accuracy: 0.6324
# Epoch 306/500
# 3/3 [==============================] - 1s 169ms/step - loss: 9.6566e-04 - accuracy: 0.8402 - val_loss: 0.0099 - val_accuracy: 0.5988
# Epoch 307/500
# 3/3 [==============================] - 0s 159ms/step - loss: 8.8301e-04 - accuracy: 0.8660 - val_loss: 0.0113 - val_accuracy: 0.6426
# Epoch 308/500
# 3/3 [==============================] - 0s 159ms/step - loss: 8.2658e-04 - accuracy: 0.8680 - val_loss: 0.0101 - val_accuracy: 0.6145
# Epoch 309/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.3087e-04 - accuracy: 0.8714 - val_loss: 0.0107 - val_accuracy: 0.6156
# Epoch 310/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0014 - accuracy: 0.8591 - val_loss: 0.0126 - val_accuracy: 0.6362
# Epoch 311/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0012 - accuracy: 0.8381 - val_loss: 0.0085 - val_accuracy: 0.5920
# Epoch 312/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.7136e-04 - accuracy: 0.8631 - val_loss: 0.0123 - val_accuracy: 0.6336
# Epoch 313/500
# 3/3 [==============================] - 0s 162ms/step - loss: 9.3175e-04 - accuracy: 0.8714 - val_loss: 0.0094 - val_accuracy: 0.6075
# Epoch 314/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.2119e-04 - accuracy: 0.8755 - val_loss: 0.0122 - val_accuracy: 0.6215
# Epoch 315/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.2434e-04 - accuracy: 0.8677 - val_loss: 0.0092 - val_accuracy: 0.5891
# Epoch 316/500
# 3/3 [==============================] - 0s 162ms/step - loss: 9.6697e-04 - accuracy: 0.8639 - val_loss: 0.0114 - val_accuracy: 0.6294
# Epoch 317/500
# 3/3 [==============================] - 0s 152ms/step - loss: 9.0878e-04 - accuracy: 0.8654 - val_loss: 0.0097 - val_accuracy: 0.6165
# Epoch 318/500
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0011 - accuracy: 0.8728 - val_loss: 0.0106 - val_accuracy: 0.6122
# Epoch 319/500
# 3/3 [==============================] - 0s 164ms/step - loss: 8.5539e-04 - accuracy: 0.8750 - val_loss: 0.0104 - val_accuracy: 0.6344
# Epoch 320/500
# 3/3 [==============================] - 0s 160ms/step - loss: 7.7284e-04 - accuracy: 0.8699 - val_loss: 0.0097 - val_accuracy: 0.5990
# Epoch 321/500
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0010 - accuracy: 0.8574 - val_loss: 0.0146 - val_accuracy: 0.6382
# Epoch 322/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0014 - accuracy: 0.8087 - val_loss: 0.0097 - val_accuracy: 0.5666
# Epoch 323/500
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0012 - accuracy: 0.8405 - val_loss: 0.0117 - val_accuracy: 0.6307
# Epoch 324/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.1294e-04 - accuracy: 0.8691 - val_loss: 0.0089 - val_accuracy: 0.6018
# Epoch 325/500
# 3/3 [==============================] - 0s 163ms/step - loss: 8.1624e-04 - accuracy: 0.8777 - val_loss: 0.0113 - val_accuracy: 0.6246
# Epoch 326/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.0330e-04 - accuracy: 0.8760 - val_loss: 0.0094 - val_accuracy: 0.6098
# Epoch 327/500
# 3/3 [==============================] - 0s 162ms/step - loss: 9.2894e-04 - accuracy: 0.8758 - val_loss: 0.0114 - val_accuracy: 0.6266
# Epoch 328/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.9791e-04 - accuracy: 0.8657 - val_loss: 0.0091 - val_accuracy: 0.5995
# Epoch 329/500
# 3/3 [==============================] - 0s 158ms/step - loss: 8.3467e-04 - accuracy: 0.8706 - val_loss: 0.0127 - val_accuracy: 0.6351
# Epoch 330/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0010 - accuracy: 0.8457 - val_loss: 0.0091 - val_accuracy: 0.5835
# Epoch 331/500
# 3/3 [==============================] - 1s 168ms/step - loss: 9.8128e-04 - accuracy: 0.8558 - val_loss: 0.0129 - val_accuracy: 0.6354
# Epoch 332/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.1912e-04 - accuracy: 0.8537 - val_loss: 0.0098 - val_accuracy: 0.5959
# Epoch 333/500
# 3/3 [==============================] - 0s 157ms/step - loss: 8.3993e-04 - accuracy: 0.8693 - val_loss: 0.0113 - val_accuracy: 0.6429
# Epoch 334/500
# 3/3 [==============================] - 0s 157ms/step - loss: 7.5023e-04 - accuracy: 0.8647 - val_loss: 0.0095 - val_accuracy: 0.5906
# Epoch 335/500
# ...
# Epoch 394/500
# 3/3 [==============================] - 0s 158ms/step - loss: 8.3065e-04 - accuracy: 0.8657 - val_loss: 0.0089 - val_accuracy: 0.5888
# Epoch 395/500
# 3/3 [==============================] - 0s 158ms/step - loss: 8.5990e-04 - accuracy: 0.8635 - val_loss: 0.0127 - val_accuracy: 0.6435
# Epoch 396/500
# 3/3 [==============================] - 0s 161ms/step - loss: 9.2303e-04 - accuracy: 0.8453 - val_loss: 0.0092 - val_accuracy: 0.5898
# Epoch 397/500
# 3/3 [==============================] - 0s 162ms/step - loss: 8.1283e-04 - accuracy: 0.8706 - val_loss: 0.0113 - val_accuracy: 0.6476
# Epoch 398/500
# 3/3 [==============================] - 1s 166ms/step - loss: 7.4991e-04 - accuracy: 0.8670 - val_loss: 0.0100 - val_accuracy: 0.6127
# Epoch 399/500
# 3/3 [==============================] - 0s 162ms/step - loss: 7.2162e-04 - accuracy: 0.8751 - val_loss: 0.0104 - val_accuracy: 0.6344
# Epoch 400/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.4123e-04 - accuracy: 0.8753 - val_loss: 0.0111 - val_accuracy: 0.6297
# Epoch 401/500
# 3/3 [==============================] - 0s 158ms/step - loss: 0.0011 - accuracy: 0.8485 - val_loss: 0.0092 - val_accuracy: 0.5835
# Epoch 402/500
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0012 - accuracy: 0.8433 - val_loss: 0.0123 - val_accuracy: 0.6361
# Epoch 403/500
# 3/3 [==============================] - 0s 164ms/step - loss: 9.1559e-04 - accuracy: 0.8740 - val_loss: 0.0089 - val_accuracy: 0.6015
# Epoch 404/500
# 3/3 [==============================] - 0s 156ms/step - loss: 7.8269e-04 - accuracy: 0.8743 - val_loss: 0.0115 - val_accuracy: 0.6312
# Epoch 405/500
# 3/3 [==============================] - 0s 163ms/step - loss: 6.3926e-04 - accuracy: 0.8738 - val_loss: 0.0093 - val_accuracy: 0.6074
# Epoch 406/500
# 3/3 [==============================] - 0s 156ms/step - loss: 6.7335e-04 - accuracy: 0.8781 - val_loss: 0.0114 - val_accuracy: 0.6426
# Epoch 407/500
# 3/3 [==============================] - 0s 157ms/step - loss: 7.3566e-04 - accuracy: 0.8577 - val_loss: 0.0089 - val_accuracy: 0.5850
# Epoch 408/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.7554e-04 - accuracy: 0.8575 - val_loss: 0.0122 - val_accuracy: 0.6465
# Epoch 409/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.9398e-04 - accuracy: 0.8459 - val_loss: 0.0098 - val_accuracy: 0.6048
# Epoch 410/500
# 3/3 [==============================] - 0s 165ms/step - loss: 8.0183e-04 - accuracy: 0.8698 - val_loss: 0.0110 - val_accuracy: 0.6326
# Epoch 411/500
# 3/3 [==============================] - 0s 157ms/step - loss: 8.3174e-04 - accuracy: 0.8741 - val_loss: 0.0109 - val_accuracy: 0.6349
# Epoch 412/500
# 3/3 [==============================] - 0s 164ms/step - loss: 0.0010 - accuracy: 0.8660 - val_loss: 0.0093 - val_accuracy: 0.5860
# Epoch 413/500
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0010 - accuracy: 0.8594 - val_loss: 0.0121 - val_accuracy: 0.6297
# Epoch 414/500
# 3/3 [==============================] - 1s 169ms/step - loss: 8.3142e-04 - accuracy: 0.8694 - val_loss: 0.0089 - val_accuracy: 0.5995
# Epoch 415/500
# 3/3 [==============================] - 1s 178ms/step - loss: 7.2953e-04 - accuracy: 0.8769 - val_loss: 0.0117 - val_accuracy: 0.6409
# Epoch 416/500
# 3/3 [==============================] - 0s 155ms/step - loss: 7.0000e-04 - accuracy: 0.8707 - val_loss: 0.0090 - val_accuracy: 0.6117
# Epoch 417/500
# 3/3 [==============================] - 0s 156ms/step - loss: 7.1514e-04 - accuracy: 0.8807 - val_loss: 0.0115 - val_accuracy: 0.6384
# Epoch 418/500
# 3/3 [==============================] - 0s 164ms/step - loss: 7.6635e-04 - accuracy: 0.8757 - val_loss: 0.0090 - val_accuracy: 0.6281
# Epoch 419/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.9336e-04 - accuracy: 0.8783 - val_loss: 0.0107 - val_accuracy: 0.6133
# Epoch 420/500
# 3/3 [==============================] - 0s 163ms/step - loss: 7.3852e-04 - accuracy: 0.8783 - val_loss: 0.0101 - val_accuracy: 0.6271
# Epoch 421/500
# 3/3 [==============================] - 0s 159ms/step - loss: 6.3696e-04 - accuracy: 0.8835 - val_loss: 0.0111 - val_accuracy: 0.6296
# Epoch 422/500
# 3/3 [==============================] - 0s 155ms/step - loss: 8.3643e-04 - accuracy: 0.8682 - val_loss: 0.0107 - val_accuracy: 0.6078
# Epoch 423/500
# 3/3 [==============================] - 0s 157ms/step - loss: 9.8547e-04 - accuracy: 0.8672 - val_loss: 0.0126 - val_accuracy: 0.6349
# Epoch 424/500
# 3/3 [==============================] - 1s 175ms/step - loss: 0.0010 - accuracy: 0.8384 - val_loss: 0.0087 - val_accuracy: 0.5841
# Epoch 425/500
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0010 - accuracy: 0.8531 - val_loss: 0.0116 - val_accuracy: 0.6416
# Epoch 426/500
# 3/3 [==============================] - 0s 162ms/step - loss: 6.7549e-04 - accuracy: 0.8711 - val_loss: 0.0096 - val_accuracy: 0.6124
# Epoch 427/500
# 3/3 [==============================] - 1s 164ms/step - loss: 6.6946e-04 - accuracy: 0.8773 - val_loss: 0.0114 - val_accuracy: 0.6401
# Epoch 428/500
# 3/3 [==============================] - 0s 156ms/step - loss: 6.9509e-04 - accuracy: 0.8646 - val_loss: 0.0092 - val_accuracy: 0.5924
# Epoch 429/500
# 3/3 [==============================] - 1s 166ms/step - loss: 7.9757e-04 - accuracy: 0.8611 - val_loss: 0.0114 - val_accuracy: 0.6450
# Epoch 430/500
# 3/3 [==============================] - 0s 163ms/step - loss: 7.1510e-04 - accuracy: 0.8600 - val_loss: 0.0092 - val_accuracy: 0.5947
# Epoch 431/500
# 3/3 [==============================] - 0s 166ms/step - loss: 7.3872e-04 - accuracy: 0.8674 - val_loss: 0.0120 - val_accuracy: 0.6364
# Epoch 432/500
# 3/3 [==============================] - 0s 158ms/step - loss: 8.9206e-04 - accuracy: 0.8666 - val_loss: 0.0089 - val_accuracy: 0.6020
# Epoch 433/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0013 - accuracy: 0.8664 - val_loss: 0.0112 - val_accuracy: 0.6275
# Epoch 434/500
# 3/3 [==============================] - 0s 166ms/step - loss: 7.3131e-04 - accuracy: 0.8742 - val_loss: 0.0095 - val_accuracy: 0.6204
# Epoch 435/500
# 3/3 [==============================] - 0s 159ms/step - loss: 5.8235e-04 - accuracy: 0.8860 - val_loss: 0.0112 - val_accuracy: 0.6347
# Epoch 436/500
# 3/3 [==============================] - 0s 159ms/step - loss: 5.9162e-04 - accuracy: 0.8786 - val_loss: 0.0094 - val_accuracy: 0.5882
# Epoch 437/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.0234e-04 - accuracy: 0.8605 - val_loss: 0.0127 - val_accuracy: 0.6350
# Epoch 438/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.6145e-04 - accuracy: 0.8314 - val_loss: 0.0088 - val_accuracy: 0.5775
# Epoch 439/500
# 3/3 [==============================] - 0s 160ms/step - loss: 9.2479e-04 - accuracy: 0.8640 - val_loss: 0.0118 - val_accuracy: 0.6323
# Epoch 440/500
# 3/3 [==============================] - 0s 159ms/step - loss: 7.4671e-04 - accuracy: 0.8764 - val_loss: 0.0095 - val_accuracy: 0.6210
# Epoch 441/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.9587e-04 - accuracy: 0.8777 - val_loss: 0.0108 - val_accuracy: 0.6322
# Epoch 442/500
# 3/3 [==============================] - 0s 162ms/step - loss: 7.9159e-04 - accuracy: 0.8758 - val_loss: 0.0094 - val_accuracy: 0.6228
# Epoch 443/500
# 3/3 [==============================] - 1s 168ms/step - loss: 6.6680e-04 - accuracy: 0.8819 - val_loss: 0.0113 - val_accuracy: 0.6252
# Epoch 444/500
# 3/3 [==============================] - 0s 161ms/step - loss: 7.8240e-04 - accuracy: 0.8811 - val_loss: 0.0089 - val_accuracy: 0.6051
# Epoch 445/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.0813e-04 - accuracy: 0.8728 - val_loss: 0.0122 - val_accuracy: 0.6302
# Epoch 446/500
# 3/3 [==============================] - 0s 160ms/step - loss: 8.0656e-04 - accuracy: 0.8549 - val_loss: 0.0089 - val_accuracy: 0.5860
# Epoch 447/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.1916e-04 - accuracy: 0.8606 - val_loss: 0.0119 - val_accuracy: 0.6459
# Epoch 448/500
# 3/3 [==============================] - 0s 164ms/step - loss: 7.7564e-04 - accuracy: 0.8592 - val_loss: 0.0097 - val_accuracy: 0.6071
# Epoch 449/500
# 3/3 [==============================] - 0s 161ms/step - loss: 6.8317e-04 - accuracy: 0.8786 - val_loss: 0.0113 - val_accuracy: 0.6385
# Epoch 450/500
# 3/3 [==============================] - 0s 159ms/step - loss: 7.1745e-04 - accuracy: 0.8802 - val_loss: 0.0104 - val_accuracy: 0.6301
# Epoch 451/500
# 3/3 [==============================] - 0s 157ms/step - loss: 8.2707e-04 - accuracy: 0.8731 - val_loss: 0.0104 - val_accuracy: 0.6052
# Epoch 452/500
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0010 - accuracy: 0.8639 - val_loss: 0.0119 - val_accuracy: 0.6343
# Epoch 453/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.5788e-04 - accuracy: 0.8573 - val_loss: 0.0085 - val_accuracy: 0.5969
# Epoch 454/500
# 3/3 [==============================] - 1s 169ms/step - loss: 8.1370e-04 - accuracy: 0.8714 - val_loss: 0.0118 - val_accuracy: 0.6366
# Epoch 455/500
# 3/3 [==============================] - 0s 158ms/step - loss: 6.8018e-04 - accuracy: 0.8778 - val_loss: 0.0095 - val_accuracy: 0.6195
# Epoch 456/500
# 3/3 [==============================] - 0s 156ms/step - loss: 6.5079e-04 - accuracy: 0.8860 - val_loss: 0.0112 - val_accuracy: 0.6318
# Epoch 457/500
# 3/3 [==============================] - 0s 163ms/step - loss: 6.6985e-04 - accuracy: 0.8811 - val_loss: 0.0092 - val_accuracy: 0.6260
# Epoch 458/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.3118e-04 - accuracy: 0.8818 - val_loss: 0.0113 - val_accuracy: 0.6196
# Epoch 459/500
# 3/3 [==============================] - 0s 162ms/step - loss: 7.5621e-04 - accuracy: 0.8792 - val_loss: 0.0094 - val_accuracy: 0.6181
# Epoch 460/500
# 3/3 [==============================] - 0s 156ms/step - loss: 7.1016e-04 - accuracy: 0.8798 - val_loss: 0.0117 - val_accuracy: 0.6373
# Epoch 461/500
# 3/3 [==============================] - 0s 156ms/step - loss: 8.3796e-04 - accuracy: 0.8525 - val_loss: 0.0087 - val_accuracy: 0.5769
# Epoch 462/500
# 3/3 [==============================] - 0s 162ms/step - loss: 9.4936e-04 - accuracy: 0.8502 - val_loss: 0.0127 - val_accuracy: 0.6374
# Epoch 463/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.6516e-04 - accuracy: 0.8535 - val_loss: 0.0096 - val_accuracy: 0.5974
# Epoch 464/500
# 3/3 [==============================] - 1s 162ms/step - loss: 7.1128e-04 - accuracy: 0.8750 - val_loss: 0.0110 - val_accuracy: 0.6377
# Epoch 465/500
# 3/3 [==============================] - 0s 156ms/step - loss: 6.3511e-04 - accuracy: 0.8811 - val_loss: 0.0101 - val_accuracy: 0.6183
# Epoch 466/500
# 3/3 [==============================] - 0s 163ms/step - loss: 6.7357e-04 - accuracy: 0.8803 - val_loss: 0.0104 - val_accuracy: 0.6260
# Epoch 467/500
# 3/3 [==============================] - 0s 159ms/step - loss: 8.4147e-04 - accuracy: 0.8842 - val_loss: 0.0113 - val_accuracy: 0.6340
# Epoch 468/500
# 3/3 [==============================] - 0s 157ms/step - loss: 9.0617e-04 - accuracy: 0.8591 - val_loss: 0.0091 - val_accuracy: 0.5778
# Epoch 469/500
# 3/3 [==============================] - 1s 167ms/step - loss: 9.2364e-04 - accuracy: 0.8602 - val_loss: 0.0120 - val_accuracy: 0.6450
# Epoch 470/500
# 3/3 [==============================] - 0s 159ms/step - loss: 7.9276e-04 - accuracy: 0.8740 - val_loss: 0.0089 - val_accuracy: 0.6078
# Epoch 471/500
# 3/3 [==============================] - 0s 164ms/step - loss: 6.9467e-04 - accuracy: 0.8791 - val_loss: 0.0115 - val_accuracy: 0.6245
# Epoch 472/500
# 3/3 [==============================] - 0s 160ms/step - loss: 6.2640e-04 - accuracy: 0.8746 - val_loss: 0.0094 - val_accuracy: 0.6027
# Epoch 473/500
# 3/3 [==============================] - 0s 162ms/step - loss: 6.9996e-04 - accuracy: 0.8732 - val_loss: 0.0116 - val_accuracy: 0.6344
# Epoch 474/500
# 3/3 [==============================] - 0s 158ms/step - loss: 7.6411e-04 - accuracy: 0.8552 - val_loss: 0.0088 - val_accuracy: 0.5983
# Epoch 475/500
# 3/3 [==============================] - 0s 161ms/step - loss: 8.3316e-04 - accuracy: 0.8740 - val_loss: 0.0113 - val_accuracy: 0.6327
# Epoch 476/500
# 3/3 [==============================] - 0s 162ms/step - loss: 8.4075e-04 - accuracy: 0.8823 - val_loss: 0.0102 - val_accuracy: 0.6328
# Epoch 477/500
# 3/3 [==============================] - 0s 158ms/step - loss: 9.1322e-04 - accuracy: 0.8771 - val_loss: 0.0104 - val_accuracy: 0.6153
# Epoch 478/500
# 3/3 [==============================] - 0s 159ms/step - loss: 6.7638e-04 - accuracy: 0.8799 - val_loss: 0.0112 - val_accuracy: 0.6301
# Epoch 479/500
# 3/3 [==============================] - 0s 158ms/step - loss: 5.5717e-04 - accuracy: 0.8832 - val_loss: 0.0095 - val_accuracy: 0.6148
# Epoch 480/500
# 3/3 [==============================] - 1s 165ms/step - loss: 6.8966e-04 - accuracy: 0.8736 - val_loss: 0.0129 - val_accuracy: 0.6454
# Epoch 481/500
# 3/3 [==============================] - 1s 173ms/step - loss: 9.8537e-04 - accuracy: 0.8298 - val_loss: 0.0088 - val_accuracy: 0.5808
# Epoch 482/500
# 3/3 [==============================] - 0s 159ms/step - loss: 9.2272e-04 - accuracy: 0.8569 - val_loss: 0.0112 - val_accuracy: 0.6391
# Epoch 483/500
# 3/3 [==============================] - 0s 167ms/step - loss: 6.7713e-04 - accuracy: 0.8801 - val_loss: 0.0093 - val_accuracy: 0.6187
# Epoch 484/500
# 3/3 [==============================] - 1s 163ms/step - loss: 7.3459e-04 - accuracy: 0.8851 - val_loss: 0.0108 - val_accuracy: 0.6212
# Epoch 485/500
# 3/3 [==============================] - 0s 157ms/step - loss: 7.1226e-04 - accuracy: 0.8810 - val_loss: 0.0093 - val_accuracy: 0.6179
# Epoch 486/500
# 3/3 [==============================] - 0s 163ms/step - loss: 7.0165e-04 - accuracy: 0.8832 - val_loss: 0.0115 - val_accuracy: 0.6237
# Epoch 487/500
# 3/3 [==============================] - 0s 165ms/step - loss: 7.5189e-04 - accuracy: 0.8763 - val_loss: 0.0090 - val_accuracy: 0.5925
# Epoch 488/500
# 3/3 [==============================] - 0s 164ms/step - loss: 8.0039e-04 - accuracy: 0.8703 - val_loss: 0.0121 - val_accuracy: 0.6410
# Epoch 489/500
# 3/3 [==============================] - 0s 160ms/step - loss: 7.7478e-04 - accuracy: 0.8558 - val_loss: 0.0090 - val_accuracy: 0.5949
# Epoch 490/500
# 3/3 [==============================] - 0s 161ms/step - loss: 7.3424e-04 - accuracy: 0.8677 - val_loss: 0.0117 - val_accuracy: 0.6306
# Epoch 491/500
# 3/3 [==============================] - 0s 157ms/step - loss: 7.5032e-04 - accuracy: 0.8613 - val_loss: 0.0100 - val_accuracy: 0.6094
# Epoch 492/500
# 3/3 [==============================] - 0s 167ms/step - loss: 7.1213e-04 - accuracy: 0.8721 - val_loss: 0.0106 - val_accuracy: 0.6312
# Epoch 493/500
# 3/3 [==============================] - 0s 161ms/step - loss: 6.8401e-04 - accuracy: 0.8805 - val_loss: 0.0102 - val_accuracy: 0.6256
# Epoch 494/500
# 3/3 [==============================] - 0s 157ms/step - loss: 7.2021e-04 - accuracy: 0.8784 - val_loss: 0.0097 - val_accuracy: 0.5951
# Epoch 495/500
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0010 - accuracy: 0.8587 - val_loss: 0.0121 - val_accuracy: 0.6383
# Epoch 496/500
# 3/3 [==============================] - 1s 167ms/step - loss: 8.8492e-04 - accuracy: 0.8560 - val_loss: 0.0087 - val_accuracy: 0.6049
# Epoch 497/500
# 3/3 [==============================] - 0s 164ms/step - loss: 6.7987e-04 - accuracy: 0.8797 - val_loss: 0.0115 - val_accuracy: 0.6291
# Epoch 498/500
# 3/3 [==============================] - 0s 162ms/step - loss: 6.4137e-04 - accuracy: 0.8799 - val_loss: 0.0092 - val_accuracy: 0.6156
# Epoch 499/500
# 3/3 [==============================] - 0s 158ms/step - loss: 6.4646e-04 - accuracy: 0.8860 - val_loss: 0.0117 - val_accuracy: 0.6267
# Epoch 500/500
# 3/3 [==============================] - 0s 158ms/step - loss: 6.7636e-04 - accuracy: 0.8793 - val_loss: 0.0091 - val_accuracy: 0.6117
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Image Colorization/model-history/model/Ct_tfPyClass_xcept5_GCData_100_500.model/assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %%
newModel.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 8, 8, 2048)]      0
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 16, 512)      9437696
#  ranspose)
#
#  conv2d_transpose_6 (Conv2DT  (None, 32, 32, 128)      589952
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 64, 64, 64)       73792
#  ranspose)
#
#  conv2d_transpose_8 (Conv2DT  (None, 128, 128, 32)     18464
#  ranspose)
#
#  conv2d_transpose_9 (Conv2DT  (None, 256, 256, 2)      578
#  ranspose)
#
# =================================================================
# Total params: 10,120,482
# Trainable params: 10,120,482
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/4123.jpg'
# fileName = '/content/test8.jpeg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predLAB _l Shape : (256, 256, 1)
# _fn_predLAB _latent Shape : (8, 8, 2048)
# _latent re-Shape : (1, 8, 8, 2048)
# _fn_predRGB _l shape: (256, 256, 1)
# _fn_predRGB predAB shape: (1, 256, 256, 2)
# _fn_imgPostProcess_w
# _fn_imgPostProcess_h
# ab shape : (1, 256, 256, 2)
# l shape : (256, 256, 1)
# ok
# not ok
# _fn_imgPost result shape : (256, 256, 3)
# _fn_imgPost rgb shape : (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape)

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----
