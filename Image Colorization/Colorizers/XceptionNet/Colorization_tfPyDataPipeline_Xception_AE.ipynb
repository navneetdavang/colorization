# %% [markdown]
# # Using the Xception Pretrained Model As Encoder in AE
# (Using Xception Net As Encoder)

# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 1.7 MB/s
# Collecting tensorflow-io-gcs-filesystem==0.24.0
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 39.4 MB/s
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow-io
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.23.1
#     Uninstalling tensorflow-io-gcs-filesystem-0.23.1:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.23.1
# Successfully installed tensorflow-io-0.24.0 tensorflow-io-gcs-filesystem-0.24.0

# %%
# !nvidia-smi
# Out:
# Tue Feb  8 11:11:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.xception import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                    # no of epochs to train  the model
latent_shape = (8,8,2048)            # shape of latent space / bottleneck from the XceptionNet
_lw = latent_shape[0]
_lh = latent_shape[1]
_lc = latent_shape[2]

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []


modelFileName = 'Ct_tfPyClass_xcept_GCData_100_500'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/' + modelFileName + '.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/history/' + modelFileName + '.csv'

# %% [markdown]
# #### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    
    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]
                
                w = image.shape[0]
                h = image.shape[1]
                isGrayScale = False
                for i in range(w):
                    for j in range(h):
                        
                        if r[i,j] == g[i,j] == b[i,j]:
                            isGrayScale = True
                        else:
                            isGrayScale = False
                            break
            else:
                isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])
        print(removedImages)
        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages], axis=0)

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                numpy.array 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                numpy.array
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    @staticmethod
    def fixup_shape(_l, _ab, w, h):

        '''
        Description : 
                Method to fix the shape of L and AB channels i.e X and Y
        Input :
                _l => L channel
                _ab => AB channel
                w => Width of the Image 
                h => Height of the Image
        Returns :
                tf.Tensor (shape => (w,h,1)), tf.Tensor (shape => (w,h,2))
        '''

        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, img_height, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Initializing the Pretrained XceptionNet Model

# %% [markdown]
# ##### Xception Net Configuration

# %%
xcept = Xception(include_top=False, input_shape=(256,256,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
xcept.trainable = False

# %%
xcept.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 127, 127, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 127, 127, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 127, 127, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 125, 125, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 125, 125, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 125, 125, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 125, 125, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 125, 125, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 125, 125, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 125, 125, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 125, 125, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 63, 63, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 63, 63, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 63, 63, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 63, 63, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 63, 63, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 63, 63, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 63, 63, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 63, 63, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 63, 63, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 63, 63, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 32, 32, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 32, 32, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 16, 16, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 8, 8, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 8, 8, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 8, 8, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 8, 8, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 8, 8, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 8, 8, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 8, 8, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 8, 8, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# #### Feature Extractor Class

# %%
class FeatureExtractor:
    '''
    Description : Class to Extract the Features from the given images
    '''

    # method to get the latent space from the Xception network
    @staticmethod
    def getLatentSpaceFromXceptionNet(_l, _ab):
        '''
        Description : 
                Method to get the Latent Space from the Xception network
        Input :
                _l => L channel
                _ab => AB channel
        Returns :
                numpy.array (Extracted Feature), 
                numpy.array (shape => (w, h, 2))

        '''

        # print(_l.shape)

        gray_img = _l[:,:,0]

        # reshaping adding 2 extra channel in the gray_img
        gray_img = gray2rgb(gray_img)

        # print('gray2rgb gray_img shape :', gray_img.shape)
        
        # adding extra 1 dim in gray_img to fit in the vggmodel
        gray_img = gray_img.reshape((1,) + gray_img.shape)

        # print('model fit gray_img shape :', gray_img.shape)

        # predicting the latent space
        _latent = xcept.predict(gray_img)

        # print('predicted Latent :', _latent.shape)
        # print('predicted Latent dtype:', _latent.dtype)
    
        _latent = _latent[0]

        # print('predicted Latent :', _latent.shape)
    
        return _latent, _ab

    # method to fixup the shape of the output of the latent space 
    @staticmethod
    def fixup_shape(_latent, _ab, w, h, lw, lh, lc):
        '''
        Description : 
                Method to fixup the shape of the output of the latent space 
        Input :
                _latent => Latent Space
                _ab => AB channel
                w => Width of the AB Channel
                h => Height of the AB Channel
                (lw, lh, lc) => Dimension of the Latent Space
        Returns :
                tf.Tensor (Extracted Feature | shape => (_lw, _lh, _lc)), 
                tf.Tensor (AB Channel | shape => (w, h, 2))

        '''
        _latent.set_shape([lw, lh, lc])
        _ab.set_shape([w,h,2])

        return _latent, _ab

# %% [markdown]
# #### Class to Map the Extracted Features

# %%
class FeatureExtractMapper:
    '''
    Description : Class to Map the Extracted Features to the Dataset
    '''

    # Method to get the Feature Extracted Dataset
    @staticmethod
    def getXYDataset(dataset, img_w, img_h, lw, lh, lc):
        '''
        Description : 
                Method to get the Feature Extracted Dataset
        Input :
                dataset => MapDatset (consist of the splited LAB image channel [L & AB])
                img_w => Width of the Image 
                img_h => Height of the Image
                (lw, lh, lc) => Shape of the Latent Space
        Returns :
                MapDataset shapes: ((lw, lh, lc), (img_w, img_h, 2)), types: (tf.float32, tf.float32)
        '''

        ds = dataset.map(lambda x, y : tf.py_function(FeatureExtractor.getLatentSpaceFromXceptionNet,
                                                     [x, y],
                                                     [tf.float32, tf.float32]))
        
        return ds.map(lambda x, y : FeatureExtractor.fixup_shape(x, y, img_w, img_h, lw, lh, lc))

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')

        _latent, _ab = FeatureExtractor.getLatentSpaceFromXceptionNet(_l, _ab)

        print(f'_fn_predLAB _latent Shape : {_latent.shape}')

        _latent = _latent.reshape((1,) + _latent.shape)
        print(f'_latent re-Shape : {_latent.shape}')

        _abPred = model.predict(_latent)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        print('_fn_imgPostProcess_w')
        w = _ab.shape[1]
        print('_fn_imgPostProcess_h')
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))
        print('ab shape :', _ab.shape)
        print('l shape :', _l.shape)
        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[:,:,0] 
        print('ok')
        result[:,:,1:] = _ab[0,:,:,:]
        print('not ok')

        result = result.astype('float32')
        # print(result)
        print(f'_fn_imgPost result shape : {result.shape}')

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        # result = tf.convert_to_tensor(result)
        # # print(result)

        # rgb = tfio.experimental.color.lab_to_rgb(result)
        # rgb = rgb.numpy()

        rgb = lab2rgb(result)

        # ########
        
        print(f'_fn_imgPost rgb shape : {rgb.shape}')
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 

        print(f'_fn_predRGB _l shape: {_l.shape}')
        print(f'_fn_predRGB predAB shape: {predAB.shape}')

        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8800

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 5 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 686 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 991 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# Removing ## ID : 1763 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 1885 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 3369 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 3829 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 4243 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 4812 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 5018 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 5282 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# Removing ## ID : 5342 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# Removing ## ID : 5956 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 6807 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 8727 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
train_lab_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
trainData
# Out:
# <MapDataset shapes: ((256, 256, 1), (256, 256, 2)), types: (tf.float32, tf.float32)>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Mapping the Features on datasets

# %% [markdown]
# ##### Getting the train Feature Dataset

# %%
trainFeatureData = FeatureExtractMapper.getXYDataset(trainData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the val Feature Dataset

# %%
valFeatureData = FeatureExtractMapper.getXYDataset(valData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# ##### Getting the test Feature Dataset

# %%
testFeatureData = FeatureExtractMapper.getXYDataset(testData, img_w, img_h, _lw, _lh, _lc)

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %%
trainFeatureData = config_ds(trainFeatureData, batchSize)
testFeatureData = config_ds(testFeatureData, batchSize)
valFeatureData = config_ds(valFeatureData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape)

    # decoder

    # l1
    l1 = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(input_L)

    # l2
    l2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(l1)
    l2_up = UpSampling2D(size=(2,2))(l2)

    # l3
    l3 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l2_up)
    l3_up = UpSampling2D(size=(2,2))(l3)

    # l4
    l4 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l3_up)
    l4_up = UpSampling2D(size=(2,2))(l4)

    # l5
    l5 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l4_up)
    l5_up = UpSampling2D(size=(2,2))(l5)

    # l6
    l6 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l5_up)
    l6_up = UpSampling2D(size=(2,2))(l6)

    # decoder

    # l9
    # l9 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(input_L)
    # l9_up = UpSampling2D((2,2))(l9)

    # # l10
    # l10 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(l9_up)
    # l10_up = UpSampling2D((2,2))(l10)

    # # l11
    # l11 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l10_up)

    # # l12
    # l12 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l11)

    # # l13
    # l13 = Conv2D(filters=2, kernel_size=(3,3), activation='tanh', padding='same')(l12)
    # l13_up = UpSampling2D((2,2))(l13)

    return Model(inputs=input_L, outputs=l6_up)

# %%
model = autoEncoder(inputShape=latent_shape)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8, 8, 2048)]      0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         4718848
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         295040
#
#  up_sampling2d (UpSampling2D  (None, 16, 16, 128)      0
#  )
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 64)        73792
#
#  up_sampling2d_1 (UpSampling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        18464
#
#  up_sampling2d_2 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 16)        4624
#
#  up_sampling2d_3 (UpSampling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 2)       290
#
#  up_sampling2d_4 (UpSampling  (None, 256, 256, 2)      0
#  2D)
#
# =================================================================
# Total params: 5,111,058
# Trainable params: 5,111,058
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
# training the model
history = model.fit(trainFeatureData, validation_data=valFeatureData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 25s 5s/step - loss: 0.4426 - accuracy: 0.4873 - val_loss: 0.7311 - val_accuracy: 0.4203
# Epoch 2/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.6275 - accuracy: 0.4583 - val_loss: 0.7535 - val_accuracy: 0.5787
# Epoch 3/500
# 3/3 [==============================] - 0s 71ms/step - loss: 0.5691 - accuracy: 0.5633 - val_loss: 0.5913 - val_accuracy: 0.4221
# Epoch 4/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.4868 - accuracy: 0.4540 - val_loss: 0.6405 - val_accuracy: 0.5824
# Epoch 5/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.5051 - accuracy: 0.6578 - val_loss: 0.3718 - val_accuracy: 0.5613
# Epoch 6/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.2821 - accuracy: 0.4785 - val_loss: 0.2403 - val_accuracy: 0.4904
# Epoch 7/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1586 - accuracy: 0.5480 - val_loss: 0.0601 - val_accuracy: 0.5236
# Epoch 8/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0358 - accuracy: 0.5398 - val_loss: 0.0162 - val_accuracy: 0.5802
# Epoch 9/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0185 - accuracy: 0.6325 - val_loss: 0.0115 - val_accuracy: 0.5747
# Epoch 10/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0146 - accuracy: 0.6444 - val_loss: 0.0098 - val_accuracy: 0.5846
# Epoch 11/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0128 - accuracy: 0.6532 - val_loss: 0.0096 - val_accuracy: 0.5862
# Epoch 12/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0126 - accuracy: 0.6575 - val_loss: 0.0097 - val_accuracy: 0.5909
# Epoch 13/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0124 - accuracy: 0.6624 - val_loss: 0.0096 - val_accuracy: 0.5930
# Epoch 14/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0123 - accuracy: 0.6654 - val_loss: 0.0095 - val_accuracy: 0.5921
# Epoch 15/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0121 - accuracy: 0.6673 - val_loss: 0.0096 - val_accuracy: 0.5929
# Epoch 16/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0120 - accuracy: 0.6683 - val_loss: 0.0096 - val_accuracy: 0.5933
# Epoch 17/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0120 - accuracy: 0.6690 - val_loss: 0.0096 - val_accuracy: 0.5931
# Epoch 18/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0119 - accuracy: 0.6695 - val_loss: 0.0096 - val_accuracy: 0.5933
# Epoch 19/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0119 - accuracy: 0.6697 - val_loss: 0.0097 - val_accuracy: 0.5934
# Epoch 20/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0118 - accuracy: 0.6699 - val_loss: 0.0097 - val_accuracy: 0.5935
# Epoch 21/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0117 - accuracy: 0.6700 - val_loss: 0.0097 - val_accuracy: 0.5935
# Epoch 22/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0117 - accuracy: 0.6701 - val_loss: 0.0098 - val_accuracy: 0.5935
# Epoch 23/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0117 - accuracy: 0.6702 - val_loss: 0.0098 - val_accuracy: 0.5935
# Epoch 24/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0116 - accuracy: 0.6702 - val_loss: 0.0099 - val_accuracy: 0.5934
# Epoch 25/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0116 - accuracy: 0.6702 - val_loss: 0.0099 - val_accuracy: 0.5934
# Epoch 26/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0116 - accuracy: 0.6702 - val_loss: 0.0099 - val_accuracy: 0.5934
# Epoch 27/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0115 - accuracy: 0.6702 - val_loss: 0.0100 - val_accuracy: 0.5934
# Epoch 28/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0115 - accuracy: 0.6702 - val_loss: 0.0100 - val_accuracy: 0.5934
# Epoch 29/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0115 - accuracy: 0.6703 - val_loss: 0.0101 - val_accuracy: 0.5934
# Epoch 30/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0115 - accuracy: 0.6703 - val_loss: 0.0101 - val_accuracy: 0.5934
# Epoch 31/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0102 - val_accuracy: 0.5934
# Epoch 32/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0102 - val_accuracy: 0.5933
# Epoch 33/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0102 - val_accuracy: 0.5933
# Epoch 34/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0103 - val_accuracy: 0.5933
# Epoch 35/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0103 - val_accuracy: 0.5933
# Epoch 36/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0103 - val_accuracy: 0.5933
# Epoch 37/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0104 - val_accuracy: 0.5933
# Epoch 38/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0104 - val_accuracy: 0.5933
# Epoch 39/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0104 - val_accuracy: 0.5933
# Epoch 40/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0105 - val_accuracy: 0.5933
# Epoch 41/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0105 - val_accuracy: 0.5933
# Epoch 42/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0105 - val_accuracy: 0.5933
# Epoch 43/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0106 - val_accuracy: 0.5933
# Epoch 44/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0106 - val_accuracy: 0.5934
# Epoch 45/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0106 - val_accuracy: 0.5934
# Epoch 46/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0106 - val_accuracy: 0.5934
# Epoch 47/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5934
# Epoch 48/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5934
# Epoch 49/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5934
# Epoch 50/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0107 - val_accuracy: 0.5934
# Epoch 51/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0107 - val_accuracy: 0.5934
# Epoch 52/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0107 - val_accuracy: 0.5934
# Epoch 53/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 54/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 55/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 56/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 57/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 58/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 59/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 60/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 61/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 62/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 63/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 64/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 65/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 66/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 67/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 68/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 69/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 70/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5937
# Epoch 71/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5937
# Epoch 72/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5937
# Epoch 73/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0113 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5937
# Epoch 74/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0112 - accuracy: 0.6705 - val_loss: 0.0112 - val_accuracy: 0.5938
# Epoch 75/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0112 - val_accuracy: 0.5939
# Epoch 76/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0112 - accuracy: 0.6705 - val_loss: 0.0109 - val_accuracy: 0.5940
# Epoch 77/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0112 - accuracy: 0.6706 - val_loss: 0.0111 - val_accuracy: 0.5939
# Epoch 78/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0113 - accuracy: 0.6705 - val_loss: 0.0109 - val_accuracy: 0.5940
# Epoch 79/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0112 - accuracy: 0.6705 - val_loss: 0.0108 - val_accuracy: 0.5944
# Epoch 80/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0113 - accuracy: 0.6705 - val_loss: 0.0108 - val_accuracy: 0.5939
# Epoch 81/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5938
# Epoch 82/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5938
# Epoch 83/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5939
# Epoch 84/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5941
# Epoch 85/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0111 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5941
# Epoch 86/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0111 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5942
# Epoch 87/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0110 - accuracy: 0.6705 - val_loss: 0.0109 - val_accuracy: 0.5941
# Epoch 88/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0110 - accuracy: 0.6706 - val_loss: 0.0109 - val_accuracy: 0.5942
# Epoch 89/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0110 - accuracy: 0.6707 - val_loss: 0.0109 - val_accuracy: 0.5943
# Epoch 90/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0109 - accuracy: 0.6710 - val_loss: 0.0110 - val_accuracy: 0.5944
# Epoch 91/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0108 - accuracy: 0.6712 - val_loss: 0.0109 - val_accuracy: 0.5946
# Epoch 92/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0108 - accuracy: 0.6714 - val_loss: 0.0113 - val_accuracy: 0.5944
# Epoch 93/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0108 - accuracy: 0.6714 - val_loss: 0.0108 - val_accuracy: 0.5944
# Epoch 94/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0109 - accuracy: 0.6715 - val_loss: 0.0108 - val_accuracy: 0.5942
# Epoch 95/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0107 - accuracy: 0.6713 - val_loss: 0.0120 - val_accuracy: 0.5939
# Epoch 96/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0107 - accuracy: 0.6713 - val_loss: 0.0108 - val_accuracy: 0.5941
# Epoch 97/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0107 - accuracy: 0.6714 - val_loss: 0.0108 - val_accuracy: 0.5940
# Epoch 98/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0107 - accuracy: 0.6716 - val_loss: 0.0108 - val_accuracy: 0.5938
# Epoch 99/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0106 - accuracy: 0.6713 - val_loss: 0.0109 - val_accuracy: 0.5934
# Epoch 100/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0105 - accuracy: 0.6710 - val_loss: 0.0113 - val_accuracy: 0.5939
# Epoch 101/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0104 - accuracy: 0.6711 - val_loss: 0.0109 - val_accuracy: 0.5953
# Epoch 102/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0103 - accuracy: 0.6718 - val_loss: 0.0109 - val_accuracy: 0.5955
# Epoch 103/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0102 - accuracy: 0.6721 - val_loss: 0.0110 - val_accuracy: 0.5953
# Epoch 104/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0101 - accuracy: 0.6720 - val_loss: 0.0110 - val_accuracy: 0.5950
# Epoch 105/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0100 - accuracy: 0.6722 - val_loss: 0.0111 - val_accuracy: 0.5952
# Epoch 106/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0100 - accuracy: 0.6725 - val_loss: 0.0110 - val_accuracy: 0.5945
# Epoch 107/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0099 - accuracy: 0.6726 - val_loss: 0.0119 - val_accuracy: 0.5961
# Epoch 108/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0098 - accuracy: 0.6733 - val_loss: 0.0109 - val_accuracy: 0.5963
# Epoch 109/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0098 - accuracy: 0.6738 - val_loss: 0.0108 - val_accuracy: 0.5972
# Epoch 110/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0100 - accuracy: 0.6737 - val_loss: 0.0113 - val_accuracy: 0.5960
# Epoch 111/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0100 - accuracy: 0.6739 - val_loss: 0.0112 - val_accuracy: 0.5955
# Epoch 112/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0098 - accuracy: 0.6743 - val_loss: 0.0116 - val_accuracy: 0.5961
# Epoch 113/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0097 - accuracy: 0.6748 - val_loss: 0.0110 - val_accuracy: 0.5980
# Epoch 114/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0095 - accuracy: 0.6757 - val_loss: 0.0116 - val_accuracy: 0.5986
# Epoch 115/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0094 - accuracy: 0.6768 - val_loss: 0.0115 - val_accuracy: 0.6000
# Epoch 116/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0093 - accuracy: 0.6783 - val_loss: 0.0115 - val_accuracy: 0.6019
# Epoch 117/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0092 - accuracy: 0.6782 - val_loss: 0.0111 - val_accuracy: 0.6031
# Epoch 118/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0091 - accuracy: 0.6797 - val_loss: 0.0116 - val_accuracy: 0.6024
# Epoch 119/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0090 - accuracy: 0.6805 - val_loss: 0.0111 - val_accuracy: 0.6027
# Epoch 120/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0089 - accuracy: 0.6807 - val_loss: 0.0131 - val_accuracy: 0.6014
# Epoch 121/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0089 - accuracy: 0.6811 - val_loss: 0.0112 - val_accuracy: 0.5992
# Epoch 122/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0088 - accuracy: 0.6815 - val_loss: 0.0110 - val_accuracy: 0.6030
# Epoch 123/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0087 - accuracy: 0.6820 - val_loss: 0.0112 - val_accuracy: 0.6035
# Epoch 124/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0088 - accuracy: 0.6825 - val_loss: 0.0114 - val_accuracy: 0.6016
# Epoch 125/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0087 - accuracy: 0.6818 - val_loss: 0.0127 - val_accuracy: 0.5984
# Epoch 126/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0084 - accuracy: 0.6824 - val_loss: 0.0112 - val_accuracy: 0.6005
# Epoch 127/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0083 - accuracy: 0.6838 - val_loss: 0.0121 - val_accuracy: 0.6029
# Epoch 128/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0085 - accuracy: 0.6836 - val_loss: 0.0112 - val_accuracy: 0.6003
# Epoch 129/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0081 - accuracy: 0.6848 - val_loss: 0.0130 - val_accuracy: 0.6008
# Epoch 130/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0080 - accuracy: 0.6848 - val_loss: 0.0120 - val_accuracy: 0.5978
# Epoch 131/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0077 - accuracy: 0.6849 - val_loss: 0.0122 - val_accuracy: 0.5986
# Epoch 132/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0076 - accuracy: 0.6864 - val_loss: 0.0120 - val_accuracy: 0.5977
# Epoch 133/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0074 - accuracy: 0.6866 - val_loss: 0.0119 - val_accuracy: 0.5957
# Epoch 134/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0073 - accuracy: 0.6867 - val_loss: 0.0132 - val_accuracy: 0.5972
# Epoch 135/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0073 - accuracy: 0.6870 - val_loss: 0.0118 - val_accuracy: 0.5976
# Epoch 136/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0072 - accuracy: 0.6876 - val_loss: 0.0109 - val_accuracy: 0.5951
# Epoch 137/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0075 - accuracy: 0.6870 - val_loss: 0.0116 - val_accuracy: 0.6061
# Epoch 138/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0077 - accuracy: 0.6884 - val_loss: 0.0114 - val_accuracy: 0.5972
# Epoch 139/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0078 - accuracy: 0.6825 - val_loss: 0.0128 - val_accuracy: 0.5826
# Epoch 140/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0075 - accuracy: 0.6832 - val_loss: 0.0127 - val_accuracy: 0.5897
# Epoch 141/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0072 - accuracy: 0.6884 - val_loss: 0.0114 - val_accuracy: 0.5936
# Epoch 142/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0070 - accuracy: 0.6883 - val_loss: 0.0128 - val_accuracy: 0.5914
# Epoch 143/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0069 - accuracy: 0.6891 - val_loss: 0.0099 - val_accuracy: 0.6113
# Epoch 144/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0070 - accuracy: 0.6895 - val_loss: 0.0131 - val_accuracy: 0.5859
# Epoch 145/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0069 - accuracy: 0.6841 - val_loss: 0.0117 - val_accuracy: 0.5877
# Epoch 146/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0066 - accuracy: 0.6867 - val_loss: 0.0120 - val_accuracy: 0.5848
# Epoch 147/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0065 - accuracy: 0.6869 - val_loss: 0.0115 - val_accuracy: 0.5869
# Epoch 148/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0064 - accuracy: 0.6861 - val_loss: 0.0136 - val_accuracy: 0.5828
# Epoch 149/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0063 - accuracy: 0.6908 - val_loss: 0.0120 - val_accuracy: 0.5893
# Epoch 150/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0062 - accuracy: 0.6918 - val_loss: 0.0132 - val_accuracy: 0.5901
# Epoch 151/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0060 - accuracy: 0.6931 - val_loss: 0.0120 - val_accuracy: 0.5921
# Epoch 152/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0059 - accuracy: 0.6937 - val_loss: 0.0126 - val_accuracy: 0.5976
# Epoch 153/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0058 - accuracy: 0.6948 - val_loss: 0.0127 - val_accuracy: 0.5910
# Epoch 154/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0057 - accuracy: 0.6976 - val_loss: 0.0120 - val_accuracy: 0.5913
# Epoch 155/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0058 - accuracy: 0.6995 - val_loss: 0.0127 - val_accuracy: 0.5993
# Epoch 156/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0056 - accuracy: 0.7014 - val_loss: 0.0115 - val_accuracy: 0.6020
# Epoch 157/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0055 - accuracy: 0.7039 - val_loss: 0.0126 - val_accuracy: 0.5967
# Epoch 158/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0054 - accuracy: 0.7055 - val_loss: 0.0120 - val_accuracy: 0.6029
# Epoch 159/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0054 - accuracy: 0.7055 - val_loss: 0.0124 - val_accuracy: 0.6049
# Epoch 160/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0053 - accuracy: 0.7093 - val_loss: 0.0114 - val_accuracy: 0.6116
# Epoch 161/500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0053 - accuracy: 0.7121 - val_loss: 0.0124 - val_accuracy: 0.6113
# Epoch 162/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0051 - accuracy: 0.7141 - val_loss: 0.0112 - val_accuracy: 0.6114
# Epoch 163/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0052 - accuracy: 0.7136 - val_loss: 0.0125 - val_accuracy: 0.6045
# Epoch 164/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0051 - accuracy: 0.7152 - val_loss: 0.0111 - val_accuracy: 0.6228
# Epoch 165/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0052 - accuracy: 0.7156 - val_loss: 0.0114 - val_accuracy: 0.6116
# Epoch 166/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0050 - accuracy: 0.7140 - val_loss: 0.0122 - val_accuracy: 0.6122
# Epoch 167/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0051 - accuracy: 0.7141 - val_loss: 0.0105 - val_accuracy: 0.6321
# Epoch 168/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0050 - accuracy: 0.7153 - val_loss: 0.0131 - val_accuracy: 0.6047
# Epoch 169/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0052 - accuracy: 0.7146 - val_loss: 0.0105 - val_accuracy: 0.6244
# Epoch 170/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0051 - accuracy: 0.7157 - val_loss: 0.0123 - val_accuracy: 0.6117
# Epoch 171/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0051 - accuracy: 0.7112 - val_loss: 0.0114 - val_accuracy: 0.5926
# Epoch 172/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0050 - accuracy: 0.7092 - val_loss: 0.0135 - val_accuracy: 0.6299
# Epoch 173/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0051 - accuracy: 0.7215 - val_loss: 0.0103 - val_accuracy: 0.6086
# Epoch 174/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0050 - accuracy: 0.7180 - val_loss: 0.0134 - val_accuracy: 0.6198
# Epoch 175/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0049 - accuracy: 0.7172 - val_loss: 0.0104 - val_accuracy: 0.6210
# Epoch 176/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0048 - accuracy: 0.7206 - val_loss: 0.0127 - val_accuracy: 0.6090
# Epoch 177/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0047 - accuracy: 0.7188 - val_loss: 0.0111 - val_accuracy: 0.6212
# Epoch 178/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0047 - accuracy: 0.7206 - val_loss: 0.0126 - val_accuracy: 0.6221
# Epoch 179/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0045 - accuracy: 0.7253 - val_loss: 0.0108 - val_accuracy: 0.6241
# Epoch 180/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0045 - accuracy: 0.7278 - val_loss: 0.0119 - val_accuracy: 0.6286
# Epoch 181/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0044 - accuracy: 0.7304 - val_loss: 0.0113 - val_accuracy: 0.6249
# Epoch 182/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0044 - accuracy: 0.7314 - val_loss: 0.0119 - val_accuracy: 0.6247
# Epoch 183/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0043 - accuracy: 0.7332 - val_loss: 0.0117 - val_accuracy: 0.6201
# Epoch 184/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0043 - accuracy: 0.7341 - val_loss: 0.0118 - val_accuracy: 0.6284
# Epoch 185/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0042 - accuracy: 0.7358 - val_loss: 0.0117 - val_accuracy: 0.6247
# Epoch 186/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0042 - accuracy: 0.7359 - val_loss: 0.0118 - val_accuracy: 0.6286
# Epoch 187/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0041 - accuracy: 0.7383 - val_loss: 0.0116 - val_accuracy: 0.6252
# Epoch 188/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0041 - accuracy: 0.7389 - val_loss: 0.0121 - val_accuracy: 0.6254
# Epoch 189/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0041 - accuracy: 0.7396 - val_loss: 0.0116 - val_accuracy: 0.6270
# Epoch 190/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0040 - accuracy: 0.7409 - val_loss: 0.0120 - val_accuracy: 0.6241
# Epoch 191/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0040 - accuracy: 0.7417 - val_loss: 0.0121 - val_accuracy: 0.6237
# Epoch 192/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0040 - accuracy: 0.7423 - val_loss: 0.0114 - val_accuracy: 0.6254
# Epoch 193/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0040 - accuracy: 0.7434 - val_loss: 0.0127 - val_accuracy: 0.6241
# Epoch 194/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0040 - accuracy: 0.7440 - val_loss: 0.0117 - val_accuracy: 0.6259
# Epoch 195/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0039 - accuracy: 0.7452 - val_loss: 0.0114 - val_accuracy: 0.6245
# Epoch 196/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0040 - accuracy: 0.7455 - val_loss: 0.0132 - val_accuracy: 0.6230
# Epoch 197/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0040 - accuracy: 0.7449 - val_loss: 0.0109 - val_accuracy: 0.6259
# Epoch 198/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0040 - accuracy: 0.7453 - val_loss: 0.0124 - val_accuracy: 0.6185
# Epoch 199/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0039 - accuracy: 0.7464 - val_loss: 0.0115 - val_accuracy: 0.6264
# Epoch 200/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0040 - accuracy: 0.7445 - val_loss: 0.0117 - val_accuracy: 0.6223
# Epoch 201/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0040 - accuracy: 0.7447 - val_loss: 0.0125 - val_accuracy: 0.6212
# Epoch 202/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0039 - accuracy: 0.7472 - val_loss: 0.0119 - val_accuracy: 0.6241
# Epoch 203/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0039 - accuracy: 0.7481 - val_loss: 0.0119 - val_accuracy: 0.6244
# Epoch 204/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0038 - accuracy: 0.7485 - val_loss: 0.0118 - val_accuracy: 0.6178
# Epoch 205/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0037 - accuracy: 0.7489 - val_loss: 0.0118 - val_accuracy: 0.6315
# Epoch 206/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0037 - accuracy: 0.7526 - val_loss: 0.0120 - val_accuracy: 0.6169
# Epoch 207/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0036 - accuracy: 0.7498 - val_loss: 0.0126 - val_accuracy: 0.6219
# Epoch 208/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0036 - accuracy: 0.7512 - val_loss: 0.0114 - val_accuracy: 0.6236
# Epoch 209/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0036 - accuracy: 0.7522 - val_loss: 0.0123 - val_accuracy: 0.6275
# Epoch 210/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0036 - accuracy: 0.7550 - val_loss: 0.0121 - val_accuracy: 0.6206
# Epoch 211/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0036 - accuracy: 0.7517 - val_loss: 0.0117 - val_accuracy: 0.6170
# Epoch 212/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0036 - accuracy: 0.7554 - val_loss: 0.0130 - val_accuracy: 0.6199
# Epoch 213/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0036 - accuracy: 0.7551 - val_loss: 0.0114 - val_accuracy: 0.6211
# Epoch 214/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0036 - accuracy: 0.7584 - val_loss: 0.0123 - val_accuracy: 0.6118
# Epoch 215/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0036 - accuracy: 0.7539 - val_loss: 0.0119 - val_accuracy: 0.6303
# Epoch 216/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0036 - accuracy: 0.7546 - val_loss: 0.0119 - val_accuracy: 0.6142
# Epoch 217/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0036 - accuracy: 0.7508 - val_loss: 0.0127 - val_accuracy: 0.6087
# Epoch 218/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0035 - accuracy: 0.7541 - val_loss: 0.0115 - val_accuracy: 0.6257
# Epoch 219/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0036 - accuracy: 0.7511 - val_loss: 0.0119 - val_accuracy: 0.6200
# Epoch 220/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0037 - accuracy: 0.7555 - val_loss: 0.0132 - val_accuracy: 0.6028
# Epoch 221/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0038 - accuracy: 0.7405 - val_loss: 0.0116 - val_accuracy: 0.5980
# Epoch 222/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0038 - accuracy: 0.7480 - val_loss: 0.0128 - val_accuracy: 0.5968
# Epoch 223/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0038 - accuracy: 0.7482 - val_loss: 0.0116 - val_accuracy: 0.6116
# Epoch 224/500
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0038 - accuracy: 0.7419 - val_loss: 0.0137 - val_accuracy: 0.6142
# Epoch 225/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0037 - accuracy: 0.7489 - val_loss: 0.0121 - val_accuracy: 0.6058
# Epoch 226/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0035 - accuracy: 0.7519 - val_loss: 0.0124 - val_accuracy: 0.6204
# Epoch 227/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0035 - accuracy: 0.7588 - val_loss: 0.0113 - val_accuracy: 0.6258
# Epoch 228/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0034 - accuracy: 0.7578 - val_loss: 0.0127 - val_accuracy: 0.6208
# Epoch 229/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0035 - accuracy: 0.7585 - val_loss: 0.0117 - val_accuracy: 0.6150
# Epoch 230/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0034 - accuracy: 0.7568 - val_loss: 0.0117 - val_accuracy: 0.6188
# Epoch 231/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0033 - accuracy: 0.7590 - val_loss: 0.0131 - val_accuracy: 0.6191
# Epoch 232/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0032 - accuracy: 0.7623 - val_loss: 0.0113 - val_accuracy: 0.6213
# Epoch 233/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0032 - accuracy: 0.7628 - val_loss: 0.0128 - val_accuracy: 0.6198
# Epoch 234/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0032 - accuracy: 0.7658 - val_loss: 0.0116 - val_accuracy: 0.6197
# Epoch 235/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0031 - accuracy: 0.7646 - val_loss: 0.0125 - val_accuracy: 0.6228
# Epoch 236/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0031 - accuracy: 0.7685 - val_loss: 0.0118 - val_accuracy: 0.6203
# Epoch 237/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0031 - accuracy: 0.7667 - val_loss: 0.0124 - val_accuracy: 0.6178
# Epoch 238/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0030 - accuracy: 0.7683 - val_loss: 0.0121 - val_accuracy: 0.6180
# Epoch 239/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0030 - accuracy: 0.7693 - val_loss: 0.0117 - val_accuracy: 0.6220
# Epoch 240/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0030 - accuracy: 0.7701 - val_loss: 0.0127 - val_accuracy: 0.6215
# Epoch 241/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0030 - accuracy: 0.7711 - val_loss: 0.0116 - val_accuracy: 0.6205
# Epoch 242/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0030 - accuracy: 0.7715 - val_loss: 0.0125 - val_accuracy: 0.6213
# Epoch 243/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0029 - accuracy: 0.7723 - val_loss: 0.0121 - val_accuracy: 0.6198
# Epoch 244/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0029 - accuracy: 0.7740 - val_loss: 0.0118 - val_accuracy: 0.6188
# Epoch 245/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0029 - accuracy: 0.7735 - val_loss: 0.0127 - val_accuracy: 0.6201
# Epoch 246/500
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0029 - accuracy: 0.7750 - val_loss: 0.0116 - val_accuracy: 0.6194
# Epoch 247/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0029 - accuracy: 0.7750 - val_loss: 0.0123 - val_accuracy: 0.6179
# Epoch 248/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0029 - accuracy: 0.7752 - val_loss: 0.0126 - val_accuracy: 0.6220
# Epoch 249/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0029 - accuracy: 0.7782 - val_loss: 0.0113 - val_accuracy: 0.6148
# Epoch 250/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0029 - accuracy: 0.7738 - val_loss: 0.0131 - val_accuracy: 0.6193
# Epoch 251/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0029 - accuracy: 0.7778 - val_loss: 0.0115 - val_accuracy: 0.6215
# Epoch 252/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0029 - accuracy: 0.7764 - val_loss: 0.0120 - val_accuracy: 0.6156
# Epoch 253/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0030 - accuracy: 0.7721 - val_loss: 0.0131 - val_accuracy: 0.6170
# Epoch 254/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0029 - accuracy: 0.7792 - val_loss: 0.0111 - val_accuracy: 0.6147
# Epoch 255/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0029 - accuracy: 0.7758 - val_loss: 0.0135 - val_accuracy: 0.6191
# Epoch 256/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0029 - accuracy: 0.7792 - val_loss: 0.0112 - val_accuracy: 0.6209
# Epoch 257/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0029 - accuracy: 0.7790 - val_loss: 0.0125 - val_accuracy: 0.6192
# Epoch 258/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0028 - accuracy: 0.7779 - val_loss: 0.0123 - val_accuracy: 0.6192
# Epoch 259/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0028 - accuracy: 0.7816 - val_loss: 0.0115 - val_accuracy: 0.6175
# Epoch 260/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0028 - accuracy: 0.7798 - val_loss: 0.0133 - val_accuracy: 0.6231
# Epoch 261/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0028 - accuracy: 0.7844 - val_loss: 0.0114 - val_accuracy: 0.6153
# Epoch 262/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0028 - accuracy: 0.7767 - val_loss: 0.0128 - val_accuracy: 0.6189
# Epoch 263/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0028 - accuracy: 0.7821 - val_loss: 0.0118 - val_accuracy: 0.6193
# Epoch 264/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0028 - accuracy: 0.7831 - val_loss: 0.0120 - val_accuracy: 0.6140
# Epoch 265/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0029 - accuracy: 0.7795 - val_loss: 0.0127 - val_accuracy: 0.6169
# Epoch 266/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0028 - accuracy: 0.7836 - val_loss: 0.0116 - val_accuracy: 0.6181
# Epoch 267/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0028 - accuracy: 0.7820 - val_loss: 0.0129 - val_accuracy: 0.6162
# Epoch 268/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0028 - accuracy: 0.7810 - val_loss: 0.0121 - val_accuracy: 0.6243
# Epoch 269/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0028 - accuracy: 0.7833 - val_loss: 0.0119 - val_accuracy: 0.6188
# Epoch 270/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0028 - accuracy: 0.7795 - val_loss: 0.0127 - val_accuracy: 0.6158
# Epoch 271/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0028 - accuracy: 0.7814 - val_loss: 0.0121 - val_accuracy: 0.6198
# Epoch 272/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0027 - accuracy: 0.7831 - val_loss: 0.0126 - val_accuracy: 0.6146
# Epoch 273/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0027 - accuracy: 0.7836 - val_loss: 0.0119 - val_accuracy: 0.6184
# Epoch 274/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0027 - accuracy: 0.7860 - val_loss: 0.0127 - val_accuracy: 0.6172
# Epoch 275/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0027 - accuracy: 0.7839 - val_loss: 0.0123 - val_accuracy: 0.6180
# Epoch 276/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0027 - accuracy: 0.7870 - val_loss: 0.0122 - val_accuracy: 0.6156
# Epoch 277/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0027 - accuracy: 0.7860 - val_loss: 0.0124 - val_accuracy: 0.6228
# Epoch 278/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0026 - accuracy: 0.7871 - val_loss: 0.0119 - val_accuracy: 0.6210
# Epoch 279/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0026 - accuracy: 0.7872 - val_loss: 0.0127 - val_accuracy: 0.6212
# Epoch 280/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0026 - accuracy: 0.7883 - val_loss: 0.0119 - val_accuracy: 0.6190
# Epoch 281/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0026 - accuracy: 0.7885 - val_loss: 0.0126 - val_accuracy: 0.6196
# Epoch 282/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0026 - accuracy: 0.7884 - val_loss: 0.0121 - val_accuracy: 0.6154
# Epoch 283/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0026 - accuracy: 0.7903 - val_loss: 0.0122 - val_accuracy: 0.6241
# Epoch 284/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0026 - accuracy: 0.7892 - val_loss: 0.0125 - val_accuracy: 0.6173
# Epoch 285/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0026 - accuracy: 0.7913 - val_loss: 0.0123 - val_accuracy: 0.6174
# Epoch 286/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0026 - accuracy: 0.7897 - val_loss: 0.0120 - val_accuracy: 0.6178
# Epoch 287/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0026 - accuracy: 0.7881 - val_loss: 0.0128 - val_accuracy: 0.6195
# Epoch 288/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0026 - accuracy: 0.7907 - val_loss: 0.0124 - val_accuracy: 0.6208
# Epoch 289/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0026 - accuracy: 0.7919 - val_loss: 0.0117 - val_accuracy: 0.6188
# Epoch 290/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0026 - accuracy: 0.7877 - val_loss: 0.0130 - val_accuracy: 0.6190
# Epoch 291/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0027 - accuracy: 0.7923 - val_loss: 0.0118 - val_accuracy: 0.6105
# Epoch 292/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0027 - accuracy: 0.7897 - val_loss: 0.0118 - val_accuracy: 0.6150
# Epoch 293/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0027 - accuracy: 0.7868 - val_loss: 0.0129 - val_accuracy: 0.6191
# Epoch 294/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0027 - accuracy: 0.7899 - val_loss: 0.0119 - val_accuracy: 0.6124
# Epoch 295/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0026 - accuracy: 0.7873 - val_loss: 0.0124 - val_accuracy: 0.6212
# Epoch 296/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0026 - accuracy: 0.7881 - val_loss: 0.0126 - val_accuracy: 0.6193
# Epoch 297/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0027 - accuracy: 0.7896 - val_loss: 0.0124 - val_accuracy: 0.6093
# Epoch 298/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0027 - accuracy: 0.7854 - val_loss: 0.0123 - val_accuracy: 0.6079
# Epoch 299/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0027 - accuracy: 0.7894 - val_loss: 0.0124 - val_accuracy: 0.6114
# Epoch 300/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0026 - accuracy: 0.7902 - val_loss: 0.0121 - val_accuracy: 0.6140
# Epoch 301/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0026 - accuracy: 0.7874 - val_loss: 0.0133 - val_accuracy: 0.6109
# Epoch 302/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0026 - accuracy: 0.7934 - val_loss: 0.0118 - val_accuracy: 0.6074
# Epoch 303/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0026 - accuracy: 0.7931 - val_loss: 0.0125 - val_accuracy: 0.6187
# Epoch 304/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0025 - accuracy: 0.7906 - val_loss: 0.0126 - val_accuracy: 0.6156
# Epoch 305/500
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0025 - accuracy: 0.7959 - val_loss: 0.0118 - val_accuracy: 0.6067
# Epoch 306/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0025 - accuracy: 0.7945 - val_loss: 0.0131 - val_accuracy: 0.6221
# Epoch 307/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0024 - accuracy: 0.7974 - val_loss: 0.0119 - val_accuracy: 0.6120
# Epoch 308/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0024 - accuracy: 0.7971 - val_loss: 0.0125 - val_accuracy: 0.6157
# Epoch 309/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0024 - accuracy: 0.7973 - val_loss: 0.0125 - val_accuracy: 0.6140
# Epoch 310/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0024 - accuracy: 0.7985 - val_loss: 0.0122 - val_accuracy: 0.6191
# Epoch 311/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0024 - accuracy: 0.7996 - val_loss: 0.0126 - val_accuracy: 0.6127
# Epoch 312/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0024 - accuracy: 0.8001 - val_loss: 0.0123 - val_accuracy: 0.6190
# Epoch 313/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0024 - accuracy: 0.8011 - val_loss: 0.0121 - val_accuracy: 0.6137
# Epoch 314/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0024 - accuracy: 0.7995 - val_loss: 0.0129 - val_accuracy: 0.6200
# Epoch 315/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0024 - accuracy: 0.8025 - val_loss: 0.0119 - val_accuracy: 0.6128
# Epoch 316/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0024 - accuracy: 0.7993 - val_loss: 0.0122 - val_accuracy: 0.6211
# Epoch 317/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0024 - accuracy: 0.8016 - val_loss: 0.0128 - val_accuracy: 0.6142
# Epoch 318/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0024 - accuracy: 0.8030 - val_loss: 0.0119 - val_accuracy: 0.6179
# Epoch 319/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0024 - accuracy: 0.7995 - val_loss: 0.0124 - val_accuracy: 0.6114
# Epoch 320/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0024 - accuracy: 0.8018 - val_loss: 0.0127 - val_accuracy: 0.6204
# Epoch 321/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0024 - accuracy: 0.8021 - val_loss: 0.0118 - val_accuracy: 0.6154
# Epoch 322/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0024 - accuracy: 0.7975 - val_loss: 0.0131 - val_accuracy: 0.6162
# Epoch 323/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0024 - accuracy: 0.8017 - val_loss: 0.0118 - val_accuracy: 0.6122
# Epoch 324/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0024 - accuracy: 0.7997 - val_loss: 0.0121 - val_accuracy: 0.6116
# Epoch 325/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0024 - accuracy: 0.7964 - val_loss: 0.0131 - val_accuracy: 0.6146
# Epoch 326/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0024 - accuracy: 0.8045 - val_loss: 0.0116 - val_accuracy: 0.6120
# Epoch 327/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0024 - accuracy: 0.7967 - val_loss: 0.0133 - val_accuracy: 0.6217
# Epoch 328/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0024 - accuracy: 0.8010 - val_loss: 0.0117 - val_accuracy: 0.6117
# Epoch 329/500
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0024 - accuracy: 0.8012 - val_loss: 0.0122 - val_accuracy: 0.6231
# Epoch 330/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0024 - accuracy: 0.7985 - val_loss: 0.0130 - val_accuracy: 0.6117
# Epoch 331/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0023 - accuracy: 0.8044 - val_loss: 0.0116 - val_accuracy: 0.6144
# Epoch 332/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0023 - accuracy: 0.8031 - val_loss: 0.0129 - val_accuracy: 0.6188
# Epoch 333/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0023 - accuracy: 0.8032 - val_loss: 0.0120 - val_accuracy: 0.6151
# Epoch 334/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0023 - accuracy: 0.8063 - val_loss: 0.0124 - val_accuracy: 0.6140
# Epoch 335/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0023 - accuracy: 0.8036 - val_loss: 0.0125 - val_accuracy: 0.6200
# Epoch 336/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0023 - accuracy: 0.8061 - val_loss: 0.0123 - val_accuracy: 0.6160
# Epoch 337/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0023 - accuracy: 0.8045 - val_loss: 0.0123 - val_accuracy: 0.6250
# Epoch 338/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 0.8068 - val_loss: 0.0123 - val_accuracy: 0.6191
# Epoch 339/500
# ...
# Epoch 390/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0021 - accuracy: 0.8156 - val_loss: 0.0118 - val_accuracy: 0.6142
# Epoch 391/500
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0021 - accuracy: 0.8159 - val_loss: 0.0134 - val_accuracy: 0.6238
# Epoch 392/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0022 - accuracy: 0.8172 - val_loss: 0.0116 - val_accuracy: 0.6091
# Epoch 393/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 0.8113 - val_loss: 0.0126 - val_accuracy: 0.6120
# Epoch 394/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0022 - accuracy: 0.8128 - val_loss: 0.0125 - val_accuracy: 0.6169
# Epoch 395/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0022 - accuracy: 0.8129 - val_loss: 0.0118 - val_accuracy: 0.6085
# Epoch 396/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0022 - accuracy: 0.8105 - val_loss: 0.0128 - val_accuracy: 0.6173
# Epoch 397/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 0.8141 - val_loss: 0.0119 - val_accuracy: 0.6150
# Epoch 398/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0022 - accuracy: 0.8072 - val_loss: 0.0125 - val_accuracy: 0.6155
# Epoch 399/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0022 - accuracy: 0.8076 - val_loss: 0.0126 - val_accuracy: 0.6053
# Epoch 400/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0022 - accuracy: 0.8119 - val_loss: 0.0119 - val_accuracy: 0.6157
# Epoch 401/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0022 - accuracy: 0.8052 - val_loss: 0.0135 - val_accuracy: 0.6214
# Epoch 402/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0022 - accuracy: 0.8120 - val_loss: 0.0111 - val_accuracy: 0.6056
# Epoch 403/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0023 - accuracy: 0.8087 - val_loss: 0.0127 - val_accuracy: 0.6174
# Epoch 404/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0023 - accuracy: 0.8072 - val_loss: 0.0125 - val_accuracy: 0.6131
# Epoch 405/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0022 - accuracy: 0.8128 - val_loss: 0.0115 - val_accuracy: 0.6056
# Epoch 406/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0023 - accuracy: 0.8084 - val_loss: 0.0133 - val_accuracy: 0.6221
# Epoch 407/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 0.8143 - val_loss: 0.0113 - val_accuracy: 0.6096
# Epoch 408/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0022 - accuracy: 0.8111 - val_loss: 0.0125 - val_accuracy: 0.6260
# Epoch 409/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0022 - accuracy: 0.8115 - val_loss: 0.0124 - val_accuracy: 0.6212
# Epoch 410/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0021 - accuracy: 0.8140 - val_loss: 0.0117 - val_accuracy: 0.6153
# Epoch 411/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0021 - accuracy: 0.8125 - val_loss: 0.0127 - val_accuracy: 0.6166
# Epoch 412/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0021 - accuracy: 0.8170 - val_loss: 0.0119 - val_accuracy: 0.6122
# Epoch 413/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0021 - accuracy: 0.8119 - val_loss: 0.0127 - val_accuracy: 0.6225
# Epoch 414/500
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0021 - accuracy: 0.8192 - val_loss: 0.0115 - val_accuracy: 0.6154
# Epoch 415/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0021 - accuracy: 0.8125 - val_loss: 0.0127 - val_accuracy: 0.6003
# Epoch 416/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0021 - accuracy: 0.8108 - val_loss: 0.0121 - val_accuracy: 0.6205
# Epoch 417/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0021 - accuracy: 0.8181 - val_loss: 0.0119 - val_accuracy: 0.6067
# Epoch 418/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0021 - accuracy: 0.8115 - val_loss: 0.0131 - val_accuracy: 0.6195
# Epoch 419/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0021 - accuracy: 0.8154 - val_loss: 0.0114 - val_accuracy: 0.6038
# Epoch 420/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 0.8127 - val_loss: 0.0131 - val_accuracy: 0.6245
# Epoch 421/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0021 - accuracy: 0.8156 - val_loss: 0.0120 - val_accuracy: 0.6082
# Epoch 422/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0021 - accuracy: 0.8156 - val_loss: 0.0123 - val_accuracy: 0.6103
# Epoch 423/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0021 - accuracy: 0.8142 - val_loss: 0.0129 - val_accuracy: 0.6188
# Epoch 424/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 0.8211 - val_loss: 0.0115 - val_accuracy: 0.6161
# Epoch 425/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0020 - accuracy: 0.8183 - val_loss: 0.0131 - val_accuracy: 0.6209
# Epoch 426/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8183 - val_loss: 0.0119 - val_accuracy: 0.6119
# Epoch 427/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0020 - accuracy: 0.8197 - val_loss: 0.0122 - val_accuracy: 0.6193
# Epoch 428/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8201 - val_loss: 0.0126 - val_accuracy: 0.6200
# Epoch 429/500
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0020 - accuracy: 0.8216 - val_loss: 0.0119 - val_accuracy: 0.6154
# Epoch 430/500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0020 - accuracy: 0.8202 - val_loss: 0.0124 - val_accuracy: 0.6119
# Epoch 431/500
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0019 - accuracy: 0.8232 - val_loss: 0.0124 - val_accuracy: 0.6197
# Epoch 432/500
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0019 - accuracy: 0.8239 - val_loss: 0.0120 - val_accuracy: 0.6120
# Epoch 433/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0019 - accuracy: 0.8228 - val_loss: 0.0127 - val_accuracy: 0.6191
# Epoch 434/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0019 - accuracy: 0.8251 - val_loss: 0.0120 - val_accuracy: 0.6157
# Epoch 435/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 0.8247 - val_loss: 0.0122 - val_accuracy: 0.6147
# Epoch 436/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0019 - accuracy: 0.8231 - val_loss: 0.0128 - val_accuracy: 0.6211
# Epoch 437/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0019 - accuracy: 0.8271 - val_loss: 0.0118 - val_accuracy: 0.6124
# Epoch 438/500
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0019 - accuracy: 0.8239 - val_loss: 0.0126 - val_accuracy: 0.6188
# Epoch 439/500
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0019 - accuracy: 0.8248 - val_loss: 0.0125 - val_accuracy: 0.6170
# Epoch 440/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0019 - accuracy: 0.8263 - val_loss: 0.0116 - val_accuracy: 0.6112
# Epoch 441/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0019 - accuracy: 0.8225 - val_loss: 0.0131 - val_accuracy: 0.6249
# Epoch 442/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0019 - accuracy: 0.8263 - val_loss: 0.0119 - val_accuracy: 0.6129
# Epoch 443/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0020 - accuracy: 0.8222 - val_loss: 0.0117 - val_accuracy: 0.6139
# Epoch 444/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0020 - accuracy: 0.8210 - val_loss: 0.0135 - val_accuracy: 0.6274
# Epoch 445/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8252 - val_loss: 0.0112 - val_accuracy: 0.6086
# Epoch 446/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0020 - accuracy: 0.8168 - val_loss: 0.0129 - val_accuracy: 0.6254
# Epoch 447/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8208 - val_loss: 0.0123 - val_accuracy: 0.6160
# Epoch 448/500
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0021 - accuracy: 0.8195 - val_loss: 0.0116 - val_accuracy: 0.6127
# Epoch 449/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0022 - accuracy: 0.8148 - val_loss: 0.0131 - val_accuracy: 0.6222
# Epoch 450/500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0021 - accuracy: 0.8169 - val_loss: 0.0113 - val_accuracy: 0.6185
# Epoch 451/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0021 - accuracy: 0.8052 - val_loss: 0.0134 - val_accuracy: 0.6247
# Epoch 452/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 0.8142 - val_loss: 0.0120 - val_accuracy: 0.6056
# Epoch 453/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0020 - accuracy: 0.8175 - val_loss: 0.0122 - val_accuracy: 0.6139
# Epoch 454/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0021 - accuracy: 0.8140 - val_loss: 0.0127 - val_accuracy: 0.6140
# Epoch 455/500
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0021 - accuracy: 0.8199 - val_loss: 0.0120 - val_accuracy: 0.6180
# Epoch 456/500
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0020 - accuracy: 0.8148 - val_loss: 0.0123 - val_accuracy: 0.6027
# Epoch 457/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0021 - accuracy: 0.8136 - val_loss: 0.0126 - val_accuracy: 0.6319
# Epoch 458/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 0.8172 - val_loss: 0.0119 - val_accuracy: 0.6077
# Epoch 459/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0020 - accuracy: 0.8147 - val_loss: 0.0127 - val_accuracy: 0.6259
# Epoch 460/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8184 - val_loss: 0.0119 - val_accuracy: 0.6156
# Epoch 461/500
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0020 - accuracy: 0.8231 - val_loss: 0.0124 - val_accuracy: 0.6176
# Epoch 462/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8184 - val_loss: 0.0125 - val_accuracy: 0.6222
# Epoch 463/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0019 - accuracy: 0.8244 - val_loss: 0.0120 - val_accuracy: 0.6233
# Epoch 464/500
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0019 - accuracy: 0.8220 - val_loss: 0.0122 - val_accuracy: 0.6124
# Epoch 465/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 0.8203 - val_loss: 0.0123 - val_accuracy: 0.6211
# Epoch 466/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 0.8243 - val_loss: 0.0117 - val_accuracy: 0.6169
# Epoch 467/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0019 - accuracy: 0.8213 - val_loss: 0.0127 - val_accuracy: 0.6170
# Epoch 468/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0019 - accuracy: 0.8237 - val_loss: 0.0119 - val_accuracy: 0.6183
# Epoch 469/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0019 - accuracy: 0.8261 - val_loss: 0.0120 - val_accuracy: 0.6185
# Epoch 470/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0019 - accuracy: 0.8252 - val_loss: 0.0127 - val_accuracy: 0.6185
# Epoch 471/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0019 - accuracy: 0.8264 - val_loss: 0.0117 - val_accuracy: 0.6154
# Epoch 472/500
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0019 - accuracy: 0.8254 - val_loss: 0.0124 - val_accuracy: 0.6133
# Epoch 473/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0018 - accuracy: 0.8265 - val_loss: 0.0122 - val_accuracy: 0.6206
# Epoch 474/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0018 - accuracy: 0.8290 - val_loss: 0.0119 - val_accuracy: 0.6155
# Epoch 475/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0018 - accuracy: 0.8264 - val_loss: 0.0126 - val_accuracy: 0.6165
# Epoch 476/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0018 - accuracy: 0.8276 - val_loss: 0.0121 - val_accuracy: 0.6201
# Epoch 477/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0018 - accuracy: 0.8291 - val_loss: 0.0120 - val_accuracy: 0.6152
# Epoch 478/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0018 - accuracy: 0.8268 - val_loss: 0.0126 - val_accuracy: 0.6189
# Epoch 479/500
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0018 - accuracy: 0.8301 - val_loss: 0.0119 - val_accuracy: 0.6173
# Epoch 480/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0018 - accuracy: 0.8278 - val_loss: 0.0121 - val_accuracy: 0.6137
# Epoch 481/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0018 - accuracy: 0.8282 - val_loss: 0.0129 - val_accuracy: 0.6243
# Epoch 482/500
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0018 - accuracy: 0.8306 - val_loss: 0.0115 - val_accuracy: 0.6142
# Epoch 483/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0018 - accuracy: 0.8260 - val_loss: 0.0126 - val_accuracy: 0.6174
# Epoch 484/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0018 - accuracy: 0.8275 - val_loss: 0.0124 - val_accuracy: 0.6210
# Epoch 485/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0019 - accuracy: 0.8292 - val_loss: 0.0115 - val_accuracy: 0.6119
# Epoch 486/500
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0019 - accuracy: 0.8226 - val_loss: 0.0132 - val_accuracy: 0.6185
# Epoch 487/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 0.8273 - val_loss: 0.0117 - val_accuracy: 0.6208
# Epoch 488/500
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0019 - accuracy: 0.8256 - val_loss: 0.0117 - val_accuracy: 0.6065
# Epoch 489/500
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0020 - accuracy: 0.8180 - val_loss: 0.0133 - val_accuracy: 0.6184
# Epoch 490/500
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0020 - accuracy: 0.8274 - val_loss: 0.0113 - val_accuracy: 0.6199
# Epoch 491/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8172 - val_loss: 0.0127 - val_accuracy: 0.6157
# Epoch 492/500
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0020 - accuracy: 0.8236 - val_loss: 0.0122 - val_accuracy: 0.6211
# Epoch 493/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0020 - accuracy: 0.8254 - val_loss: 0.0117 - val_accuracy: 0.6234
# Epoch 494/500
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0021 - accuracy: 0.8174 - val_loss: 0.0132 - val_accuracy: 0.6139
# Epoch 495/500
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 0.8197 - val_loss: 0.0114 - val_accuracy: 0.6197
# Epoch 496/500
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0020 - accuracy: 0.8142 - val_loss: 0.0128 - val_accuracy: 0.6187
# Epoch 497/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0020 - accuracy: 0.8198 - val_loss: 0.0122 - val_accuracy: 0.6077
# Epoch 498/500
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0020 - accuracy: 0.8189 - val_loss: 0.0126 - val_accuracy: 0.6176
# Epoch 499/500
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0020 - accuracy: 0.8156 - val_loss: 0.0123 - val_accuracy: 0.6092
# Epoch 500/500
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0020 - accuracy: 0.8235 - val_loss: 0.0119 - val_accuracy: 0.6118
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Image Colorization/model-history/model/Ct_tfPyClass_xcept_GCData_100_500.model/assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %%
newModel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8, 8, 2048)]      0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         4718848
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         295040
#
#  up_sampling2d (UpSampling2D  (None, 16, 16, 128)      0
#  )
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 64)        73792
#
#  up_sampling2d_1 (UpSampling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        18464
#
#  up_sampling2d_2 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 16)        4624
#
#  up_sampling2d_3 (UpSampling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 2)       290
#
#  up_sampling2d_4 (UpSampling  (None, 256, 256, 2)      0
#  2D)
#
# =================================================================
# Total params: 5,111,058
# Trainable params: 5,111,058
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/1086.jpg'
# fileName = '/content/test8.jpeg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predLAB _l Shape : (256, 256, 1)
# _fn_predLAB _latent Shape : (8, 8, 2048)
# _latent re-Shape : (1, 8, 8, 2048)
# _fn_predRGB _l shape: (256, 256, 1)
# _fn_predRGB predAB shape: (1, 256, 256, 2)
# _fn_imgPostProcess_w
# _fn_imgPostProcess_h
# ab shape : (1, 256, 256, 2)
# l shape : (256, 256, 1)
# ok
# not ok
# _fn_imgPost result shape : (256, 256, 3)
# _fn_imgPost rgb shape : (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape)

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----

# %%
for x in test_ds:
    print(x)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1079.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/108.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1080.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1081.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1082.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1083.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1084.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1085.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1086.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1087.jpg', shape=(), dtype=string)
