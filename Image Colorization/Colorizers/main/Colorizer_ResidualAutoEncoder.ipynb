# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 1.7 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.24.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.24.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.24.0

# %%
# !nvidia-smi
# Out:
# Thu Apr  7 06:16:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
import tensorflow.keras.layers as L
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/ColorDataset/ColorDataset.zip'

# %%
# !mkdir colorDataset

# %%
# !unzip /content/drive/MyDrive/Datasets/ColorDataset/ColorDataset.zip -d /content/colorDataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/colorDataset/content/colorDataset/95.jpg
#   inflating: /content/colorDataset/content/colorDataset/4232.jpg
#   inflating: /content/colorDataset/content/colorDataset/1880.jpg
#   inflating: /content/colorDataset/content/colorDataset/4163.jpg
#   inflating: /content/colorDataset/content/colorDataset/177.jpg
#   inflating: /content/colorDataset/content/colorDataset/764.jpg
#   inflating: /content/colorDataset/content/colorDataset/684.jpg
#   inflating: /content/colorDataset/content/colorDataset/4051.jpg
#   inflating: /content/colorDataset/content/colorDataset/3924.jpg
#   inflating: /content/colorDataset/content/colorDataset/1077.jpg
#   inflating: /content/colorDataset/content/colorDataset/2311.jpg
#   inflating: /content/colorDataset/content/colorDataset/5336.jpg
#   inflating: /content/colorDataset/content/colorDataset/2479.jpg
#   inflating: /content/colorDataset/content/colorDataset/5152.jpg
#   inflating: /content/colorDataset/content/colorDataset/5869.jpg
#   inflating: /content/colorDataset/content/colorDataset/5794.jpg
#   inflating: /content/colorDataset/content/colorDataset/915.jpg
#   inflating: /content/colorDataset/content/colorDataset/1037.jpg
#   inflating: /content/colorDataset/content/colorDataset/1780.jpg
#   inflating: /content/colorDataset/content/colorDataset/1306.jpg
#   inflating: /content/colorDataset/content/colorDataset/4660.jpg
#   inflating: /content/colorDataset/content/colorDataset/4951.jpg
#   inflating: /content/colorDataset/content/colorDataset/4167.jpg
#   inflating: /content/colorDataset/content/colorDataset/2337.jpg
#   inflating: /content/colorDataset/content/colorDataset/526.jpg
#   inflating: /content/colorDataset/content/colorDataset/5392.jpg
#   inflating: /content/colorDataset/content/colorDataset/2420.jpg
#   inflating: /content/colorDataset/content/colorDataset/4162.jpg
#   inflating: /content/colorDataset/content/colorDataset/3907.jpg
#   inflating: /content/colorDataset/content/colorDataset/38.jpg
#   inflating: /content/colorDataset/content/colorDataset/1890.jpg
#   inflating: /content/colorDataset/content/colorDataset/5382.jpg
#   inflating: /content/colorDataset/content/colorDataset/4777.jpg
#   inflating: /content/colorDataset/content/colorDataset/5018.jpg
#   inflating: /content/colorDataset/content/colorDataset/5896.jpg
#   inflating: /content/colorDataset/content/colorDataset/2549.jpg
#   inflating: /content/colorDataset/content/colorDataset/367.jpg
#   inflating: /content/colorDataset/content/colorDataset/4105.jpg
#   inflating: /content/colorDataset/content/colorDataset/5898.jpg
#   inflating: /content/colorDataset/content/colorDataset/905.jpg
#   inflating: /content/colorDataset/content/colorDataset/1802.jpg
#   inflating: /content/colorDataset/content/colorDataset/2521.jpg
#   inflating: /content/colorDataset/content/colorDataset/3164.jpg
#   inflating: /content/colorDataset/content/colorDataset/3750.jpg
#   inflating: /content/colorDataset/content/colorDataset/2803.jpg
#   inflating: /content/colorDataset/content/colorDataset/2158.jpg
#   inflating: /content/colorDataset/content/colorDataset/4708.jpg
#   inflating: /content/colorDataset/content/colorDataset/2244.jpg
#   inflating: /content/colorDataset/content/colorDataset/4838.jpg
#   inflating: /content/colorDataset/content/colorDataset/5371.jpg
#   inflating: /content/colorDataset/content/colorDataset/2333.jpg
#   inflating: /content/colorDataset/content/colorDataset/1854.jpg
#   inflating: /content/colorDataset/content/colorDataset/4925.jpg
#   inflating: /content/colorDataset/content/colorDataset/5008.jpg
#   inflating: /content/colorDataset/content/colorDataset/5638.jpg
#   inflating: /content/colorDataset/content/colorDataset/5388.jpg
#   inflating: /content/colorDataset/content/colorDataset/1146.jpg
#   inflating: /content/colorDataset/content/colorDataset/3972.jpg
#   inflating: /content/colorDataset/content/colorDataset/2643.jpg
#   inflating: /content/colorDataset/content/colorDataset/5861.jpg
#   inflating: /content/colorDataset/content/colorDataset/1768.jpg
#   inflating: /content/colorDataset/content/colorDataset/5249.jpg
#   inflating: /content/colorDataset/content/colorDataset/3050.jpg
#   inflating: /content/colorDataset/content/colorDataset/3847.jpg
#   inflating: /content/colorDataset/content/colorDataset/962.jpg
#   inflating: /content/colorDataset/content/colorDataset/4282.jpg
#   inflating: /content/colorDataset/content/colorDataset/4239.jpg
#   inflating: /content/colorDataset/content/colorDataset/4798.jpg
#   inflating: /content/colorDataset/content/colorDataset/5845.jpg
#   inflating: /content/colorDataset/content/colorDataset/1921.jpg
#   inflating: /content/colorDataset/content/colorDataset/1206.jpg
#   inflating: /content/colorDataset/content/colorDataset/3127.jpg
#   inflating: /content/colorDataset/content/colorDataset/724.jpg
#   inflating: /content/colorDataset/content/colorDataset/3097.jpg
#   inflating: /content/colorDataset/content/colorDataset/3451.jpg
#   inflating: /content/colorDataset/content/colorDataset/3594.jpg
#   inflating: /content/colorDataset/content/colorDataset/4101.jpg
#   inflating: /content/colorDataset/content/colorDataset/5365.jpg
#   inflating: /content/colorDataset/content/colorDataset/716.jpg
#   inflating: /content/colorDataset/content/colorDataset/365.jpg
#   inflating: /content/colorDataset/content/colorDataset/3207.jpg
#   inflating: /content/colorDataset/content/colorDataset/4647.jpg
#   inflating: /content/colorDataset/content/colorDataset/1938.jpg
#   inflating: /content/colorDataset/content/colorDataset/5203.jpg

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/colorDataset'
imgDirPath = '/content/colorDataset/content/colorDataset'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# ##### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
            else:
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]

                if r.all() == g.all() == b.all():
                    isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])

        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages])

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                tf.Tensor 
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    def fixup_shape(_l, _ab, w, h):
        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, 2img_height56, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')
        _l = _l.numpy()
        _l = _l.reshape((1,) + _l.shape)
        print(f'_fn_predLAB _l re-Shape : {_l.shape}')
        _abPred = model.predict(_l)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        w = _ab.shape[1]
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))

        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[0,:,:,0] 
        result[:,:,1:] = _ab[0,:,:,:]


        result = result.astype('float32')
        # print(result)
        print(result.shape)

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        result = tf.convert_to_tensor(result)
        # print(result)

        rgb = tfio.experimental.color.lab_to_rgb(result)
        rgb = rgb.numpy()

        # ########
        
        print(rgb.shape)
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 
        print(_l.shape)
        print(predAB.shape)
        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 5900

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 0

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 5900

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/colorDataset/content/colorDataset/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/colorDataset/content/colorDataset/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset element_spec=TensorSpec(shape=<unknown>, dtype=tf.float32, name=None)>

# %%
train_lab_ds
# Out:
# <MapDataset element_spec=TensorSpec(shape=<unknown>, dtype=tf.float32, name=None)>

# %%
trainData
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(256, 256, 2), dtype=tf.float32, name=None))>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                    # no of epochs to train  the model

# optimizers for the model 
optimizerFn = tf.keras.optimizers.SGD()

# loss for model evaluation
lossFn = tf.keras.losses.CategoricalCrossentropy()

modelFileName = 'Colorizer_ResidualAutoEncoder_100_500'
#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/div-pascal-models/models/' + modelFileName + '.h5'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/div-pascal-models/history' + modelFileName + '.csv'

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def residualBlock(input, filterSize, kernelSize, stride, lname):

    # sending the l1 to the residual block

    r1 = L.Conv2D(filters=filterSize, kernel_size=kernelSize, strides=stride, activation='relu', padding='same', name=lname+'-r1')(input)
    r2 = L.Conv2D(filters=filterSize, kernel_size=kernelSize, strides=stride, activation='relu', padding='same', name=lname+'-r2')(r1)
    r3 = L.Conv2D(filters=filterSize, kernel_size=kernelSize, strides=stride, activation='relu', padding='same', name=lname+'-r3')(r2)

    # adding the skip connection 
    skip = L.concatenate([r1, r3], axis=3, name=lname+'-concat')

    x = L.Conv2D(filters=filterSize, kernel_size=kernelSize, strides=stride, activation='relu', padding='same', name=lname+'-x')(skip)
    
    # batch normalizaiton 
    bn = L.BatchNormalization(name=lname+'-norm')(x)

    return bn

# %%
def autoEncoder(inputShape=input_shape):

    # input layer
    input_L = L.Input(shape=inputShape, name='input_layer')
    
    # Encoder Blocks

    # encoding block 1
    e1 = L.Conv2D(filters=32, kernel_size=(3,3), strides=(2,2), activation='relu', padding='same', name='c-e1')(input_L)
    e_res1 = residualBlock(e1, 32, (3,3), (1,1), 'eb1')

    # encoding block 2 
    e2 = L.Conv2D(filters=64, kernel_size=(3,3), strides=(2,2), activation='relu', padding='same', name='c-e2')(e_res1)
    e_res2 = residualBlock(e2, 64, (3,3), (1,1), 'eb2')

    # encoding block 3 
    e3 = L.Conv2D(filters=128, kernel_size=(3,3), strides=(2,2), activation='relu', padding='same', name='c-e3')(e_res2)
    e_res3 = residualBlock(e3, 128, (3,3), (1,1), 'eb3')

    # encoding block 4 
    e4 = L.Conv2D(filters=256, kernel_size=(3,3), strides=(2,2), activation='relu', padding='same', name='c-e4')(e_res3)
    e_res4 = residualBlock(e4, 256, (3,3), (1,1), 'eb4')


    # Bottleneck
    latent = L.Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same', name='latent')(e_res4)
    e_res5 = residualBlock(latent, 512, (3,3), (1,1), 'res-latent')  


    # Decoding Blocks

    # decoding block 1
    d1 = L.Conv2DTranspose(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='ct-d1')(e_res5)
    d_res1 = residualBlock(d1, 256, (3,3), (1,1), 'db1')
    skip1 = L.concatenate([d_res1, e4], axis=3)

    # decoding block 2
    d2 = L.Conv2DTranspose(filters=128, kernel_size=(3,3), strides=(2,2), padding='same', activation='relu', name='ct-d2')(skip1)
    d_res2 = residualBlock(d2, 128, (3,3), (1,1), 'db2')
    skip2 = L.concatenate([d_res2, e3], axis=3)
    
    # decoding block 3
    d3 = L.Conv2DTranspose(filters=64, kernel_size=(3,3), strides=(2,2), padding='same', activation='relu', name='ct-d3')(skip2)
    d_res3 = residualBlock(d3, 64, (3,3), (1,1), 'db3')
    skip3 = L.concatenate([d_res3, e2], axis=3)
    
    # decoding block 4
    d4 = L.Conv2DTranspose(filters=32, kernel_size=(3,3), strides=(2,2), padding='same', activation='relu', name='ct-d4')(skip3)
    d_res4 = residualBlock(d4, 32, (3,3), (1,1), 'db4')
    skip4 = L.concatenate([d_res4, e1], axis=3)

    # output layer
    output_L = L.Conv2DTranspose(filters=2, kernel_size=(3,3), strides=(2,2), padding='same', activation='tanh', name='output_L')(skip4)
    

    return tf.keras.models.Model(inputs=input_L, outputs=output_L)

# %%
model = autoEncoder()

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 256, 256, 1  0           []
#                                 )]
#
#  c-e1 (Conv2D)                  (None, 128, 128, 32  320         ['input_layer[0][0]']
#                                 )
#
#  eb1-r1 (Conv2D)                (None, 128, 128, 32  9248        ['c-e1[0][0]']
#                                 )
#
#  eb1-r2 (Conv2D)                (None, 128, 128, 32  9248        ['eb1-r1[0][0]']
#                                 )
#
#  eb1-r3 (Conv2D)                (None, 128, 128, 32  9248        ['eb1-r2[0][0]']
#                                 )
#
#  eb1-concat (Concatenate)       (None, 128, 128, 64  0           ['eb1-r1[0][0]',
#                                 )                                 'eb1-r3[0][0]']
#
#  eb1-x (Conv2D)                 (None, 128, 128, 32  18464       ['eb1-concat[0][0]']
#                                 )
#
#  eb1-norm (BatchNormalization)  (None, 128, 128, 32  128         ['eb1-x[0][0]']
#                                 )
#
#  c-e2 (Conv2D)                  (None, 64, 64, 64)   18496       ['eb1-norm[0][0]']
#
#  eb2-r1 (Conv2D)                (None, 64, 64, 64)   36928       ['c-e2[0][0]']
#
#  eb2-r2 (Conv2D)                (None, 64, 64, 64)   36928       ['eb2-r1[0][0]']
#
#  eb2-r3 (Conv2D)                (None, 64, 64, 64)   36928       ['eb2-r2[0][0]']
#
#  eb2-concat (Concatenate)       (None, 64, 64, 128)  0           ['eb2-r1[0][0]',
#                                                                   'eb2-r3[0][0]']
#
#  eb2-x (Conv2D)                 (None, 64, 64, 64)   73792       ['eb2-concat[0][0]']
#
#  eb2-norm (BatchNormalization)  (None, 64, 64, 64)   256         ['eb2-x[0][0]']
#
#  c-e3 (Conv2D)                  (None, 32, 32, 128)  73856       ['eb2-norm[0][0]']
#
#  eb3-r1 (Conv2D)                (None, 32, 32, 128)  147584      ['c-e3[0][0]']
#
#  eb3-r2 (Conv2D)                (None, 32, 32, 128)  147584      ['eb3-r1[0][0]']
#
#  eb3-r3 (Conv2D)                (None, 32, 32, 128)  147584      ['eb3-r2[0][0]']
#
#  eb3-concat (Concatenate)       (None, 32, 32, 256)  0           ['eb3-r1[0][0]',
#                                                                   'eb3-r3[0][0]']
#
#  eb3-x (Conv2D)                 (None, 32, 32, 128)  295040      ['eb3-concat[0][0]']
#
#  eb3-norm (BatchNormalization)  (None, 32, 32, 128)  512         ['eb3-x[0][0]']
#
#  c-e4 (Conv2D)                  (None, 16, 16, 256)  295168      ['eb3-norm[0][0]']
#
#  eb4-r1 (Conv2D)                (None, 16, 16, 256)  590080      ['c-e4[0][0]']
#
#  eb4-r2 (Conv2D)                (None, 16, 16, 256)  590080      ['eb4-r1[0][0]']
#
#  eb4-r3 (Conv2D)                (None, 16, 16, 256)  590080      ['eb4-r2[0][0]']
#
#  eb4-concat (Concatenate)       (None, 16, 16, 512)  0           ['eb4-r1[0][0]',
#                                                                   'eb4-r3[0][0]']
#
#  eb4-x (Conv2D)                 (None, 16, 16, 256)  1179904     ['eb4-concat[0][0]']
#
#  eb4-norm (BatchNormalization)  (None, 16, 16, 256)  1024        ['eb4-x[0][0]']
#
#  latent (Conv2D)                (None, 16, 16, 512)  1180160     ['eb4-norm[0][0]']
#
#  res-latent-r1 (Conv2D)         (None, 16, 16, 512)  2359808     ['latent[0][0]']
#
#  res-latent-r2 (Conv2D)         (None, 16, 16, 512)  2359808     ['res-latent-r1[0][0]']
#
#  res-latent-r3 (Conv2D)         (None, 16, 16, 512)  2359808     ['res-latent-r2[0][0]']
#
#  res-latent-concat (Concatenate  (None, 16, 16, 1024  0          ['res-latent-r1[0][0]',
#  )                              )                                 'res-latent-r3[0][0]']
#
#  res-latent-x (Conv2D)          (None, 16, 16, 512)  4719104     ['res-latent-concat[0][0]']
#
#  res-latent-norm (BatchNormaliz  (None, 16, 16, 512)  2048       ['res-latent-x[0][0]']
#  ation)
#
#  ct-d1 (Conv2DTranspose)        (None, 16, 16, 256)  1179904     ['res-latent-norm[0][0]']
#
#  db1-r1 (Conv2D)                (None, 16, 16, 256)  590080      ['ct-d1[0][0]']
#
#  db1-r2 (Conv2D)                (None, 16, 16, 256)  590080      ['db1-r1[0][0]']
#
#  db1-r3 (Conv2D)                (None, 16, 16, 256)  590080      ['db1-r2[0][0]']
#
#  db1-concat (Concatenate)       (None, 16, 16, 512)  0           ['db1-r1[0][0]',
#                                                                   'db1-r3[0][0]']
#
#  db1-x (Conv2D)                 (None, 16, 16, 256)  1179904     ['db1-concat[0][0]']
#
#  db1-norm (BatchNormalization)  (None, 16, 16, 256)  1024        ['db1-x[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 512)  0           ['db1-norm[0][0]',
#                                                                   'c-e4[0][0]']
#
#  ct-d2 (Conv2DTranspose)        (None, 32, 32, 128)  589952      ['concatenate_4[0][0]']
#
#  db2-r1 (Conv2D)                (None, 32, 32, 128)  147584      ['ct-d2[0][0]']
#
#  db2-r2 (Conv2D)                (None, 32, 32, 128)  147584      ['db2-r1[0][0]']
#
#  db2-r3 (Conv2D)                (None, 32, 32, 128)  147584      ['db2-r2[0][0]']
#
#  db2-concat (Concatenate)       (None, 32, 32, 256)  0           ['db2-r1[0][0]',
#                                                                   'db2-r3[0][0]']
#
#  db2-x (Conv2D)                 (None, 32, 32, 128)  295040      ['db2-concat[0][0]']
#
#  db2-norm (BatchNormalization)  (None, 32, 32, 128)  512         ['db2-x[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 256)  0           ['db2-norm[0][0]',
#                                                                   'c-e3[0][0]']
#
#  ct-d3 (Conv2DTranspose)        (None, 64, 64, 64)   147520      ['concatenate_5[0][0]']
#
#  db3-r1 (Conv2D)                (None, 64, 64, 64)   36928       ['ct-d3[0][0]']
#
#  db3-r2 (Conv2D)                (None, 64, 64, 64)   36928       ['db3-r1[0][0]']
#
#  db3-r3 (Conv2D)                (None, 64, 64, 64)   36928       ['db3-r2[0][0]']
#
#  db3-concat (Concatenate)       (None, 64, 64, 128)  0           ['db3-r1[0][0]',
#                                                                   'db3-r3[0][0]']
#
#  db3-x (Conv2D)                 (None, 64, 64, 64)   73792       ['db3-concat[0][0]']
#
#  db3-norm (BatchNormalization)  (None, 64, 64, 64)   256         ['db3-x[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 128)  0           ['db3-norm[0][0]',
#                                                                   'c-e2[0][0]']
#
#  ct-d4 (Conv2DTranspose)        (None, 128, 128, 32  36896       ['concatenate_6[0][0]']
#                                 )
#
#  db4-r1 (Conv2D)                (None, 128, 128, 32  9248        ['ct-d4[0][0]']
#                                 )
#
#  db4-r2 (Conv2D)                (None, 128, 128, 32  9248        ['db4-r1[0][0]']
#                                 )
#
#  db4-r3 (Conv2D)                (None, 128, 128, 32  9248        ['db4-r2[0][0]']
#                                 )
#
#  db4-concat (Concatenate)       (None, 128, 128, 64  0           ['db4-r1[0][0]',
#                                 )                                 'db4-r3[0][0]']
#
#  db4-x (Conv2D)                 (None, 128, 128, 32  18464       ['db4-concat[0][0]']
#                                 )
#
#  db4-norm (BatchNormalization)  (None, 128, 128, 32  128         ['db4-x[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 64  0           ['db4-norm[0][0]',
#                                 )                                 'c-e1[0][0]']
#
#  output_L (Conv2DTranspose)     (None, 256, 256, 2)  1154        ['concatenate_7[0][0]']
#
# ==================================================================================================
# Total params: 23,165,282
# Trainable params: 23,162,338
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, show_shapes=True, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=False, dpi=64, show_layer_activations=True
)

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
# training the model

# timer
# starting the timer
start = time.time()

history = model.fit(trainData, validation_data=valData, epochs=num_epochs)

# ending the timer
end = time.time()

temp = end-start
print(f'Total Time in Seconds : {temp} sec')
hours = temp//3600
temp = temp - 3600*hours
minutes = temp//60
seconds = temp - 60*minutes
print('Total Time Taken : ')
print('HH:MM:SS => %d:%d:%d' %(hours,minutes,seconds))


model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 3/3 [==============================] -
500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0122 - accuracy: 0.6305 - val_loss: 0.0253 - val_accuracy: 0.5300
# Epoch 123/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0128 - accuracy: 0.6402 - val_loss: 0.0237 - val_accuracy: 0.5206
# Epoch 124/500
# 3/3 [==============================] - 2s 775ms/step - loss: 0.0124 - accuracy: 0.6220 - val_loss: 0.0236 - val_accuracy: 0.5205
# Epoch 125/500
# 3/3 [==============================] - 2s 777ms/step - loss: 0.0123 - accuracy: 0.6316 - val_loss: 0.0223 - val_accuracy: 0.5207
# Epoch 126/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.0120 - accuracy: 0.6418 - val_loss: 0.0244 - val_accuracy: 0.5201
# Epoch 127/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0118 - accuracy: 0.6357 - val_loss: 0.0271 - val_accuracy: 0.5263
# Epoch 128/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0119 - accuracy: 0.6303 - val_loss: 0.0241 - val_accuracy: 0.5141
# Epoch 129/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0117 - accuracy: 0.6353 - val_loss: 0.0246 - val_accuracy: 0.5257
# Epoch 130/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0115 - accuracy: 0.6488 - val_loss: 0.0261 - val_accuracy: 0.5280
# Epoch 131/500
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0115 - accuracy: 0.6378 - val_loss: 0.0267 - val_accuracy: 0.5305
# Epoch 132/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0114 - accuracy: 0.6481 - val_loss: 0.0269 - val_accuracy: 0.5251
# Epoch 133/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0112 - accuracy: 0.6449 - val_loss: 0.0271 - val_accuracy: 0.5309
# Epoch 134/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0109 - accuracy: 0.6473 - val_loss: 0.0290 - val_accuracy: 0.5297
# Epoch 135/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0108 - accuracy: 0.6597 - val_loss: 0.0297 - val_accuracy: 0.5348
# Epoch 136/500
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0109 - accuracy: 0.6598 - val_loss: 0.0293 - val_accuracy: 0.5351
# Epoch 137/500
# 3/3 [==============================] - 2s 775ms/step - loss: 0.0110 - accuracy: 0.6508 - val_loss: 0.0276 - val_accuracy: 0.5332
# Epoch 138/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0107 - accuracy: 0.6785 - val_loss: 0.0302 - val_accuracy: 0.5372
# Epoch 139/500
# 3/3 [==============================] - 2s 777ms/step - loss: 0.0105 - accuracy: 0.6681 - val_loss: 0.0303 - val_accuracy: 0.5360
# Epoch 140/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0105 - accuracy: 0.6686 - val_loss: 0.0304 - val_accuracy: 0.5361
# Epoch 141/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0104 - accuracy: 0.6730 - val_loss: 0.0304 - val_accuracy: 0.5354
# Epoch 142/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0105 - accuracy: 0.6631 - val_loss: 0.0276 - val_accuracy: 0.5347
# Epoch 143/500
# 3/3 [==============================] - 2s 777ms/step - loss: 0.0101 - accuracy: 0.6696 - val_loss: 0.0288 - val_accuracy: 0.5355
# Epoch 144/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0101 - accuracy: 0.6775 - val_loss: 0.0285 - val_accuracy: 0.5346
# Epoch 145/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.0101 - accuracy: 0.6736 - val_loss: 0.0313 - val_accuracy: 0.5360
# Epoch 146/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0102 - accuracy: 0.6669 - val_loss: 0.0279 - val_accuracy: 0.5346
# Epoch 147/500
# 3/3 [==============================] - 2s 773ms/step - loss: 0.0108 - accuracy: 0.6561 - val_loss: 0.0266 - val_accuracy: 0.5313
# Epoch 148/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.0103 - accuracy: 0.6659 - val_loss: 0.0284 - val_accuracy: 0.5345
# Epoch 149/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0104 - accuracy: 0.6597 - val_loss: 0.0267 - val_accuracy: 0.5273
# Epoch 150/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0109 - accuracy: 0.6524 - val_loss: 0.0307 - val_accuracy: 0.5297
# Epoch 151/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0112 - accuracy: 0.6491 - val_loss: 0.0242 - val_accuracy: 0.5173
# Epoch 152/500
# 3/3 [==============================] - 2s 775ms/step - loss: 0.0110 - accuracy: 0.6476 - val_loss: 0.0263 - val_accuracy: 0.5230
# Epoch 153/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0110 - accuracy: 0.6469 - val_loss: 0.0231 - val_accuracy: 0.5178
# Epoch 154/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.0111 - accuracy: 0.6419 - val_loss: 0.0271 - val_accuracy: 0.5229
# Epoch 155/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0110 - accuracy: 0.6550 - val_loss: 0.0236 - val_accuracy: 0.5244
# Epoch 156/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0110 - accuracy: 0.6427 - val_loss: 0.0244 - val_accuracy: 0.5215
# Epoch 157/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0108 - accuracy: 0.6488 - val_loss: 0.0211 - val_accuracy: 0.5218
# Epoch 158/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0100 - accuracy: 0.6293 - val_loss: 0.0226 - val_accuracy: 0.5341
# Epoch 159/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0094 - accuracy: 0.6499 - val_loss: 0.0247 - val_accuracy: 0.5302
# Epoch 160/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0090 - accuracy: 0.6599 - val_loss: 0.0251 - val_accuracy: 0.5281
# Epoch 161/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0090 - accuracy: 0.6786 - val_loss: 0.0255 - val_accuracy: 0.5346
# Epoch 162/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0089 - accuracy: 0.6871 - val_loss: 0.0251 - val_accuracy: 0.5309
# Epoch 163/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0085 - accuracy: 0.6919 - val_loss: 0.0284 - val_accuracy: 0.5372
# Epoch 164/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0086 - accuracy: 0.6614 - val_loss: 0.0308 - val_accuracy: 0.5415
# Epoch 165/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0086 - accuracy: 0.6715 - val_loss: 0.0329 - val_accuracy: 0.5374
# Epoch 166/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0092 - accuracy: 0.6899 - val_loss: 0.0310 - val_accuracy: 0.5375
# Epoch 167/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0098 - accuracy: 0.6660 - val_loss: 0.0324 - val_accuracy: 0.5399
# Epoch 168/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0098 - accuracy: 0.6855 - val_loss: 0.0285 - val_accuracy: 0.5383
# Epoch 169/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0098 - accuracy: 0.6565 - val_loss: 0.0296 - val_accuracy: 0.5376
# Epoch 170/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0091 - accuracy: 0.6854 - val_loss: 0.0260 - val_accuracy: 0.5378
# Epoch 171/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0087 - accuracy: 0.6822 - val_loss: 0.0266 - val_accuracy: 0.5375
# Epoch 172/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0089 - accuracy: 0.6642 - val_loss: 0.0243 - val_accuracy: 0.5427
# Epoch 173/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0087 - accuracy: 0.6752 - val_loss: 0.0264 - val_accuracy: 0.5275
# Epoch 174/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0095 - accuracy: 0.6496 - val_loss: 0.0249 - val_accuracy: 0.5243
# Epoch 175/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0096 - accuracy: 0.6419 - val_loss: 0.0308 - val_accuracy: 0.5151
# Epoch 176/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0104 - accuracy: 0.6506 - val_loss: 0.0263 - val_accuracy: 0.5216
# Epoch 177/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0105 - accuracy: 0.6564 - val_loss: 0.0274 - val_accuracy: 0.4989
# Epoch 178/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0100 - accuracy: 0.6685 - val_loss: 0.0210 - val_accuracy: 0.5209
# Epoch 179/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0085 - accuracy: 0.6624 - val_loss: 0.0219 - val_accuracy: 0.5268
# Epoch 180/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0075 - accuracy: 0.6780 - val_loss: 0.0229 - val_accuracy: 0.5280
# Epoch 181/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0071 - accuracy: 0.7007 - val_loss: 0.0225 - val_accuracy: 0.5339
# Epoch 182/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0072 - accuracy: 0.6792 - val_loss: 0.0277 - val_accuracy: 0.5348
# Epoch 183/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0073 - accuracy: 0.7049 - val_loss: 0.0260 - val_accuracy: 0.5411
# Epoch 184/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.0078 - accuracy: 0.6943 - val_loss: 0.0284 - val_accuracy: 0.5366
# Epoch 185/500
# 3/3 [==============================] - 2s 777ms/step - loss: 0.0082 - accuracy: 0.6882 - val_loss: 0.0319 - val_accuracy: 0.5400
# Epoch 186/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0086 - accuracy: 0.7058 - val_loss: 0.0326 - val_accuracy: 0.5397
# Epoch 187/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0086 - accuracy: 0.6938 - val_loss: 0.0263 - val_accuracy: 0.5361
# Epoch 188/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0083 - accuracy: 0.6996 - val_loss: 0.0210 - val_accuracy: 0.5311
# Epoch 189/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0081 - accuracy: 0.6720 - val_loss: 0.0200 - val_accuracy: 0.5297
# Epoch 190/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0079 - accuracy: 0.6727 - val_loss: 0.0208 - val_accuracy: 0.5271
# Epoch 191/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0080 - accuracy: 0.6863 - val_loss: 0.0246 - val_accuracy: 0.5214
# Epoch 192/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0083 - accuracy: 0.6821 - val_loss: 0.0240 - val_accuracy: 0.5237
# Epoch 193/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0081 - accuracy: 0.6904 - val_loss: 0.0208 - val_accuracy: 0.5202
# Epoch 194/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0072 - accuracy: 0.6882 - val_loss: 0.0230 - val_accuracy: 0.5355
# Epoch 195/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0066 - accuracy: 0.6909 - val_loss: 0.0223 - val_accuracy: 0.5362
# Epoch 196/500
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0064 - accuracy: 0.7222 - val_loss: 0.0299 - val_accuracy: 0.5393
# Epoch 197/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0071 - accuracy: 0.7030 - val_loss: 0.0300 - val_accuracy: 0.5399
# Epoch 198/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0077 - accuracy: 0.7026 - val_loss: 0.0292 - val_accuracy: 0.5390
# Epoch 199/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0084 - accuracy: 0.6976 - val_loss: 0.0285 - val_accuracy: 0.5396
# Epoch 200/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0083 - accuracy: 0.6975 - val_loss: 0.0231 - val_accuracy: 0.5413
# Epoch 201/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0073 - accuracy: 0.7096 - val_loss: 0.0229 - val_accuracy: 0.5368
# Epoch 202/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0071 - accuracy: 0.6976 - val_loss: 0.0214 - val_accuracy: 0.5365
# Epoch 203/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0072 - accuracy: 0.6893 - val_loss: 0.0219 - val_accuracy: 0.5300
# Epoch 204/500
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0077 - accuracy: 0.6827 - val_loss: 0.0222 - val_accuracy: 0.5247
# Epoch 205/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0077 - accuracy: 0.6715 - val_loss: 0.0258 - val_accuracy: 0.5208
# Epoch 206/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0076 - accuracy: 0.6900 - val_loss: 0.0250 - val_accuracy: 0.5267
# Epoch 207/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0071 - accuracy: 0.7055 - val_loss: 0.0233 - val_accuracy: 0.5348
# Epoch 208/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0065 - accuracy: 0.7159 - val_loss: 0.0250 - val_accuracy: 0.5370
# Epoch 209/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0062 - accuracy: 0.7394 - val_loss: 0.0247 - val_accuracy: 0.5387
# Epoch 210/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0067 - accuracy: 0.7068 - val_loss: 0.0274 - val_accuracy: 0.5387
# Epoch 211/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0071 - accuracy: 0.7106 - val_loss: 0.0272 - val_accuracy: 0.5385
# Epoch 212/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0073 - accuracy: 0.7081 - val_loss: 0.0233 - val_accuracy: 0.5380
# Epoch 213/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0072 - accuracy: 0.7022 - val_loss: 0.0198 - val_accuracy: 0.5372
# Epoch 214/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.
500
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0037 - accuracy: 0.7588 - val_loss: 0.0181 - val_accuracy: 0.5078
# Epoch 392/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0034 - accuracy: 0.7674 - val_loss: 0.0180 - val_accuracy: 0.5233
# Epoch 393/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0033 - accuracy: 0.7807 - val_loss: 0.0191 - val_accuracy: 0.5282
# Epoch 394/500
# 3/3 [==============================] - 2s 787ms/step - loss: 0.0036 - accuracy: 0.7846 - val_loss: 0.0184 - val_accuracy: 0.5248
# Epoch 395/500
# 3/3 [==============================] - 2s 788ms/step - loss: 0.0038 - accuracy: 0.7798 - val_loss: 0.0190 - val_accuracy: 0.5193
# Epoch 396/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0039 - accuracy: 0.7762 - val_loss: 0.0174 - val_accuracy: 0.5001
# Epoch 397/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0039 - accuracy: 0.7670 - val_loss: 0.0177 - val_accuracy: 0.5036
# Epoch 398/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0039 - accuracy: 0.7565 - val_loss: 0.0178 - val_accuracy: 0.4864
# Epoch 399/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0039 - accuracy: 0.7479 - val_loss: 0.0180 - val_accuracy: 0.5043
# Epoch 400/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0038 - accuracy: 0.7527 - val_loss: 0.0179 - val_accuracy: 0.4949
# Epoch 401/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0035 - accuracy: 0.7616 - val_loss: 0.0181 - val_accuracy: 0.5187
# Epoch 402/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0032 - accuracy: 0.7739 - val_loss: 0.0175 - val_accuracy: 0.5187
# Epoch 403/500
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0031 - accuracy: 0.7772 - val_loss: 0.0186 - val_accuracy: 0.5352
# Epoch 404/500
# 3/3 [==============================] - 2s 790ms/step - loss: 0.0031 - accuracy: 0.7933 - val_loss: 0.0178 - val_accuracy: 0.5289
# Epoch 405/500
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0033 - accuracy: 0.7898 - val_loss: 0.0192 - val_accuracy: 0.5308
# Epoch 406/500
# 3/3 [==============================] - 2s 787ms/step - loss: 0.0035 - accuracy: 0.7870 - val_loss: 0.0175 - val_accuracy: 0.5166
# Epoch 407/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0035 - accuracy: 0.7778 - val_loss: 0.0187 - val_accuracy: 0.5135
# Epoch 408/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0037 - accuracy: 0.7721 - val_loss: 0.0170 - val_accuracy: 0.4961
# Epoch 409/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0036 - accuracy: 0.7601 - val_loss: 0.0182 - val_accuracy: 0.5071
# Epoch 410/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0036 - accuracy: 0.7595 - val_loss: 0.0171 - val_accuracy: 0.4937
# Epoch 411/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0035 - accuracy: 0.7553 - val_loss: 0.0181 - val_accuracy: 0.5077
# Epoch 412/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0033 - accuracy: 0.7667 - val_loss: 0.0175 - val_accuracy: 0.5107
# Epoch 413/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0031 - accuracy: 0.7695 - val_loss: 0.0176 - val_accuracy: 0.5177
# Epoch 414/500
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0030 - accuracy: 0.7801 - val_loss: 0.0179 - val_accuracy: 0.5168
# Epoch 415/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0030 - accuracy: 0.7919 - val_loss: 0.0175 - val_accuracy: 0.5273
# Epoch 416/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0030 - accuracy: 0.7997 - val_loss: 0.0188 - val_accuracy: 0.5257
# Epoch 417/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0032 - accuracy: 0.8013 - val_loss: 0.0179 - val_accuracy: 0.5252
# Epoch 418/500
# 3/3 [==============================] - 2s 772ms/step - loss: 0.0034 - accuracy: 0.7954 - val_loss: 0.0193 - val_accuracy: 0.5183
# Epoch 419/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0036 - accuracy: 0.7876 - val_loss: 0.0179 - val_accuracy: 0.5122
# Epoch 420/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0037 - accuracy: 0.7769 - val_loss: 0.0188 - val_accuracy: 0.5065
# Epoch 421/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.
500
# 3/3 [==============================] - 2s 775ms/step - loss: 0.0061 - accuracy: 0.6978 - val_loss: 0.0208 - val_accuracy: 0.4594
# Epoch 483/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0060 - accuracy: 0.6989 - val_loss: 0.0216 - val_accuracy: 0.4923
# Epoch 484/500
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0062 - accuracy: 0.7042 - val_loss: 0.0234 - val_accuracy: 0.4772
# Epoch 485/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0057 - accuracy: 0.7236 - val_loss: 0.0202 - val_accuracy: 0.5144
# Epoch 486/500
# 3/3 [==============================] - 2s 778ms/step - loss: 0.0048 - accuracy: 0.7208 - val_loss: 0.0187 - val_accuracy: 0.5210
# Epoch 487/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0043 - accuracy: 0.7445 - val_loss: 0.0204 - val_accuracy: 0.5254
# Epoch 488/500
# 3/3 [==============================] - 2s 788ms/step - loss: 0.0044 - accuracy: 0.7389 - val_loss: 0.0250 - val_accuracy: 0.5499
# Epoch 489/500
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0051 - accuracy: 0.7383 - val_loss: 0.0250 - val_accuracy: 0.5485
# Epoch 490/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0059 - accuracy: 0.7315 - val_loss: 0.0201 - val_accuracy: 0.5256
# Epoch 491/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0059 - accuracy: 0.7381 - val_loss: 0.0183 - val_accuracy: 0.5305
# Epoch 492/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0059 - accuracy: 0.7132 - val_loss: 0.0178 - val_accuracy: 0.4728
# Epoch 493/500
# 3/3 [==============================] - 2s 782ms/step - loss: 0.0064 - accuracy: 0.7046 - val_loss: 0.0207 - val_accuracy: 0.4650
# Epoch 494/500
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0064 - accuracy: 0.6834 - val_loss: 0.0248 - val_accuracy: 0.4876
# Epoch 495/500
# 3/3 [==============================] - 2s 790ms/step - loss: 0.0065 - accuracy: 0.6915 - val_loss: 0.0245 - val_accuracy: 0.4725
# Epoch 496/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0053 - accuracy: 0.7120 - val_loss: 0.0209 - val_accuracy: 0.4818
# Epoch 497/500
# 3/3 [==============================] - 2s 785ms/step - loss: 0.0048 - accuracy: 0.7081 - val_loss: 0.0258 - val_accuracy: 0.5391
# Epoch 498/500
# 3/3 [==============================] - 2s 792ms/step - loss: 0.0048 - accuracy: 0.7312 - val_loss: 0.0268 - val_accuracy: 0.5231
# Epoch 499/500
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0057 - accuracy: 0.6918 - val_loss: 0.0211 - val_accuracy: 0.4905
# Epoch 500/500
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0059 - accuracy: 0.7118 - val_loss: 0.0213 - val_accuracy: 0.5386
# Total Time in Seconds : 1268.7467830181122 sec
# Total Time Taken :
# HH:MM:SS => 0:21:8
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %% [markdown]
# #### Predict

# %%
# fileName = '/content/colorDataset/content/colorDataset/2999.jpg'
fileName = '/content/test15.jpg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predLAB _l Shape : (256, 256, 1)
# _fn_predLAB _l re-Shape : (1, 256, 256, 1)
# (1, 256, 256, 1)
# (1, 256, 256, 2)
# (256, 256, 3)
# (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape )

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----
