# %% [markdown]
# ### Setup Libs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 8.6 MB/s
# Collecting tensorflow-io-gcs-filesystem==0.24.0
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 32.1 MB/s
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow-io
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.23.1
#     Uninstalling tensorflow-io-gcs-filesystem-0.23.1:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.23.1
# Successfully installed tensorflow-io-0.24.0 tensorflow-io-gcs-filesystem-0.24.0

# %%
# !nvidia-smi
# Out:
# Tue Feb  8 13:44:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import time
import glob
import sys
import random
import warnings

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
import skimage
from PIL import Image
from skimage.io import imread, imshow, imread_collection, concatenate_images,imsave
from skimage.transform import resize
from skimage.util import crop, pad
from skimage.morphology import label
from skimage.color import rgb2gray, gray2rgb, rgb2lab, lab2rgb
from sklearn.model_selection import train_test_split

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model, load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Dense, UpSampling2D, RepeatVector, Reshape
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.python.client import device_lib
from tensorflow.python.ops.numpy_ops import np_config
        

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Extracting the files from the zip to the folder

# %%
filePath = '/content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip'

# %%
# !mkdir gcImages

# %%
# !unzip /content/drive/MyDrive/Datasets/GCScrapped/gc-dataset.zip -d /content/gcImages

# %% [markdown]
# ### Global Var

# %%
dataset_path = '/content/gcImages/content/gc-dataset'
imgDirPath = '/content/gcImages/content/gc-dataset/train'
osSep = '/'
dataPath = imgDirPath + osSep + '*.jpg'

# %%
# image attr
img_w = 256
img_h = 256

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# ##### Method to set Configuration for the tf.data.Dataset

# %%
def config_ds(ds, batch_size):

    # setting up the cache 
    ds = ds.cache()
    # setting up the batch_size
    ds = ds.batch(batch_size)
    # setting up the prefectch freq
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %% [markdown]
# #### Class to Clean the Dataset

# %%
class DatasetCleaner:
    
    '''
    Description : Class to Clean the Datasets
    '''

    # Method to remove the grayscale images from the directroy
    @staticmethod
    def removeGrayScaleFromDir(dirPath, osSep='/', fileType='*.jpg'):
        '''
        Description : 
                Method to remove any grayScale images from the directroy
        Input : 
                dirPath => Path to the image directory (dType - String)
                osSep => OS File Separator (dType - String | Defualt : backslash)
                fileType => Types of Images to read from the directory(dType - String | Default : '*.jpg') 	
        Returns : 
                List (Details of the files removed from the directory)
        '''

        print('Removing any grayScale Images from the directory.........')
        removedFileNames = []
        for id, fileName in enumerate(glob.glob(dirPath + osSep + fileType)):

            image = tf.io.read_file(fileName)
            image = tf.image.decode_jpeg(image)

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False

            if isGrayScale:
                print(f'Removing ## ID : {id} ==== ImageShape : {image.shape} ==== FileName : {fileName}')
                removedFileNames.append([id, image.shape, fileName])
                os.remove(fileName)

        return removedFileNames

    # Method to remove the grayScale images from the numpy array
    @staticmethod
    def removeGrayScaleFromNumpy(numpyArr):
        '''
        Description : 
                Method to remove any grayScale images from the numpy.array
        Input : 
                numpyArr => numpy.array consisting of images
        Returns : 
                numpy.array (Consisting of only RGB images)
                List (Details of the images removed from the numpy)
        '''
        removedImages = []

        for id, image in enumerate(numpyArr):

            isGrayScale = True

            if len(image.shape) == 3 and image.shape[2] == 3:
                isGrayScale = False
            else:
                r = image[:,:,0]
                g = image[:,:,1]
                b = image[:,:,2]

                if r.all() == g.all() == b.all():
                    isGrayScale = True

            if isGrayScale:
                print(f'GrayScale Found ## ID : {id} ==== ImageShape : {image.shape}')
                removedImages.append([id, image.shape])

        print('Removing any grayScale Images from the numpy.array.........')
        numpyArr = np.delete(numpyArr, [dtl[0] for dtl in removedImages])

        return numpyArr, removedImages

# %% [markdown]
# #### Class to Load the Dataset

# %%
class DatasetLoader:
    '''
    Description : Class to load the Dataset
    '''

    # Method to load the dataset from the dir
    @staticmethod
    def loadDataSetFromDir(imageDataPath, isShuffle = False):
        '''
        Description : 
                Method to load the dataset from the directory
        Input :
                imageDataPath => Path to the directory where the images are located (dType - String)
                isShuffle => If the images in the dataset to be shuffled (Default - False)
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.list_files(imageDataPath, shuffle=isShuffle)
    
    # Method to load the dataset from the numpy.array
    @staticmethod
    def loadDataSetFromNumpy(numpyArr):
        '''
        Description : 
                Method to load the dataset from the numpy
        Input :
                numpyArr => numpy.array containing the data 
        Returns :
                TensorSliceDataset 
        '''
        return tf.data.Dataset.from_tensor_slices(numpyArr)

# %% [markdown]
# #### ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB

# %%
class ImageUtils:

    '''
    Description : ImageUtils class to get the RGB, LAB and to split the LAB channel into L and AB
    '''

    # Method to get the RGB images
    @staticmethod
    def getRGBData(filePath, img_width, img_height):
        '''
        Description : 
                Method to get the RGB image from the given path
        Input :
                filePath => File path to the image (dType - String)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor 
        '''
        filePath = filePath.numpy().decode('utf-8')
        image = imread(filePath)
        image = resize(image, output_shape=[img_width, img_height])         
        # resize method gives resized image along with normalization
        return image

    # Method to get the LAB images
    @staticmethod
    def getLABData(image):
        '''
        Description : 
                Method to get the LAB image from the given image
        Input :
                image => RGB Image 
        Returns :
                tf.Tensor 
        '''
        labImage = rgb2lab(image)
        return labImage


    # # Method to get the training data
    # def getTrainingData(filePath):

    #     image = tf.io.read_file(filePath)
    #     image = tf.io.decode_jpeg(image)
    #     image = tf.image.convert_image_dtype(image, tf.float32)

    #     labImage = tfio.experimental.color.rgb_to_lab(image)

    #     return tf.reshape(labImage[:,:,0], shape=[256,256,1]), labImage[:,:,1:]


    # Method to get the X(L) and Y(AB) data
    @staticmethod
    def getXYData(labImage, img_width, img_height):
        '''
        Description : 
                Method to split LAB image into L and AB channels as X and Y
        Input :
                labImage => LAB Image
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                tf.Tensor, tf.Tensor 
        '''
        _l = tf.reshape(labImage[:,:,0], shape=[img_width,img_height,1])
        _ab = tf.reshape(labImage[:,:,1:] / 128, shape=[img_width,img_height,2])
        return _l, _ab

    # to fix the shape
    def fixup_shape(_l, _ab, w, h):
        _l.set_shape([w, h, 1])
        _ab.set_shape([w, h, 2])
        return _l, _ab

# %% [markdown]
# #### Mapper class to Map the given Dataset

# %%
class DatasetMapper:

    '''
    Description : Mapper class to map the given dataset
    '''

    # Method to get the only RGB image Dataset from the give Image File Name Dataset
    @staticmethod
    def getRGBDataset(imgFileNames_ds, img_width, img_height):
        '''
        Description : 
                Method to get the only RGB image Dataset from the give Image File Name Dataset
        Input :
                imgFileNames_ds => TensorSliceDataset (consist of the image file names)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset Shapes: (img_width, img_height, None), types: tf.float32
        '''
        return imgFileNames_ds.map(lambda x : tf.py_function(ImageUtils.getRGBData, 
                                                             [x, img_width, img_height], 
                                                             tf.float32))

    # Method to get the only LAB images from the RGB image dataset
    @staticmethod
    def getLABDataset(rgbImg_ds):
        '''
        Description : 
                Method to get the only LAB images from the RGB image dataset
        Input :
                rgbImg_ds => MapDatset (consist of the RGB images)
            
        Returns :
                MapDataset Shapes: (rgbImg_width, rgbImg_height, None), types: tf.float32
        '''
        return rgbImg_ds.map(lambda x : tf.py_function(ImageUtils.getLABData,
                                                       [x],
                                                       tf.float32))

    # Method to split the LAB Image into L(X) and AB(Y) channels
    @staticmethod
    def getXYDataset(labImg_ds, img_width, img_height):
        '''
        Description : 
                Method to split the LAB Image into L(X) and AB(Y) channels
        Input :
                labImage => MapDatset (consist of the LAB images)
                img_width => Width of the Image 
                img_height => Height of the Image
        Returns :
                MapDataset shapes: ((img_width, img_height, 1), (img_width, 2img_height56, 2)), types: (tf.float32, tf.float32)
        '''

        ds = labImg_ds.map(lambda x : tf.py_function(ImageUtils.getXYData,
                                                       [x, img_width, img_height],
                                                       [tf.float32, tf.float32]))

        return ds.map(lambda x, y : ImageUtils.fixup_shape(x, y, img_width, img_height))

# %% [markdown]
# #### Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance

# %%
class ImageVisualizer:

    '''Description : Class contains nescessary methods to plot the RGB-LAB Images & to Visualize the Model Performance'''

    # function to plot the rgb/lab/grayScale images in given range from the dataset
    def plotImages(self, img_ds, img_count):

        '''
        Description :
                Method to plot the RGB/LAB/GrayScale images in given range from the given tf.data.dataset
        Input : 
                img_ds => RGB/LAB/GrayScale image dataset (tf.data.dataset )
                count => Count of images to show from the dataset
        Returns : 
                None
        '''

        # plt.figure(figsize=(100,60))
        imgs = []

        for rgb_img in img_ds.take(img_count):
            imgs.append(rgb_img)
        imgs = np.array(imgs)

        total_img = img_count

        if total_img == 1:
            plt.imshow(imgs[0])
        else:
        
            # if there are odd no of imgs
            if total_img & 1 == 1 and total_img != 1:
                total_img -= 1
                print("Only Showing", total_img)
        
            row = total_img // 3 + total_img % 3
            col = total_img // row
            # print(row, col)
            f, axs = plt.subplots(row, col)
            # print(len(axs))
            i = 0;

            if total_img == 2:        
                for ax in axs:
                    ax.imshow(imgs[i])
                    i += 1
            else:
                for r in range(row):
                    for c in range(col):
                        axs[r,c].imshow(imgs[i])
                        i += 1

        plt.tight_layout()
        plt.show()

    # to get the single channel out of img
    def getLABSingleChannel(self, img, channel):

        '''
        Description :
                Method to get the single channel out of the LAB Image
        Input : 
                img => lab image (w * h * 3)
                channel => idx of channel from the image to return 
        Returns : 
                numpy.array (w*h*3)
        '''

        z = np.zeros(img.shape)
        if channel != 0:
            # set sum lightness
            z[:,:,0] = 100 
        z[:,:,channel] = img[:,:,channel]
        z = lab2rgb(z)
        return(z)

    # function to plot the lab channel in gray map
    def plotLABSingleChannelGrayMap (self, ax, image):

        '''
        Description :
                Method to plot the individual channels of given LAB image in grayscale
        Input : 
                ax => matplotlib.pyplot.subplot axis to plot the given image
                image => LAB image
        Returns : 
                None
        '''

        ax[1].imshow(image[:,:,0], cmap='gray')
        ax[2].imshow(image[:,:,1], cmap='gray')
        ax[3].imshow(image[:,:,2], cmap='gray')
    
    # function to show the LAB image and its all the channels
    def plotLabChannels(self, labImg, label, cmap=None):

        '''
        Description :
                Method to show the LAB image and its all the channels
        Input : 
                labImg => Single LAB Image in np.array format
                label => Label for the Image (dType : Stirng)
                cmap => To plot image in grayScale or not. By default 'None'
        Returns : 
                None
        '''

        print('LAB Image - {}'.format(label))
        fig, axes = plt.subplots(nrows=1,ncols=4)
        axes[0].imshow(labImg)
        if cmap is None:
            axes[1].imshow(self.getLABSingleChannel(labImg, 0))
            axes[2].imshow(self.getLABSingleChannel(labImg, 1))
            axes[3].imshow(self.getLABSingleChannel(labImg, 2))
        else:
            self.plotLABSingleChannelGrayMap(axes, labImg)
            
        plt.tight_layout()
        plt.show()

    # function to plot the lab images in the given range
    def plotLABImages(self, lab_ds, count_img, cmap=None):

        '''
        Description :
                Method to plot the LAB images as separate channels from the given tf.data.dataset in a given range 
        Input : 
                lab_ds => LAB image dataset (tf.data.Dataset)
                count_img => Count of images to show from the dataset
                cmap => To plot image in grayScale or not. By default 'None'
                        Values : [None,'gray']
        Returns : 
                None
        '''

        if count_img <= 0:
            print('Please given the valid img count')
        for i, lab in zip(range(count_img), lab_ds.take(count_img)):
            if cmap is None:
                self.plotLabChannels(lab.numpy(), i)
            else:
                self.plotLabChannels(lab.numpy(), i, 'gray')
            print('----------------------------------------------------')

    # Function to visualize the Model Performance and Loss
    def visualizeModelHistory(self, history):

        '''
        Description :
                Method to visualize the Model Performance and Loss
        Input : 
                history => History of Model (dict)
        Returns : 
                None
        '''

        # list all data in history
        print(history.history.keys())

        # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %% [markdown]
# #### Class to Colorize the Images

# %%
class Colorizer:
    '''Description : Class to Colorize the images'''

    # To predict the lab channels of given image
    def __predictLAB(self, model, imgPath):

        '''
        Description :
                Method to takes RGB Image filepath, then convert it to LAB to extract the L channel and 
                predict the remaining two channels (A` & B`)
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
                imgPath => RGB image file path
        Returns : 
                Tuple (L channel and Predicted AB channels)

        '''
        image = ImageUtils.getRGBData(imgPath, img_w, img_h)

        labImage = ImageUtils.getLABData(image)

        _l, _ab = ImageUtils.getXYData(labImage, img_w, img_h)
        print(f'_fn_predLAB _l Shape : {_l.numpy().shape}')
        _l = _l.numpy()
        _l = _l.reshape((1,) + _l.shape)
        print(f'_fn_predLAB _l re-Shape : {_l.shape}')
        _abPred = model.predict(_l)
        return _l, _abPred


    # To Postprocess the L and AB channel
    # i.e. merge the L and AB channel and convert them into RGB image
    def __imgPostProcess(self, _l, _ab):

        '''
        Description : 
                Method to perform the processing on the predicted images
        Input : 
                _l => L channel of the Image
                _ab => Predicted AB channel of Image
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        w = _ab.shape[1]
        h = _ab.shape[2]
        result = np.zeros((w, h, 3))

        # de normalizing the values
        # _l *= 100
        _ab *= 128
        # merging all the channels
        result[:,:,0] = _l[0,:,:,0] 
        result[:,:,1:] = _ab[0,:,:,:]


        result = result.astype('float32')
        # print(result)
        print(result.shape)

        # converting the colorspace into rgb using opencv
        # rgb = cv2.cvtColor(result, cv2.COLOR_LAB2RGB)

        # converting the colorspace into rgb using skimage
        # rgb = lab2rgb(result)

        # chaning down
        
        result = tf.convert_to_tensor(result)
        # print(result)

        rgb = tfio.experimental.color.lab_to_rgb(result)
        rgb = rgb.numpy()

        # ########
        
        print(rgb.shape)
        return np.array(rgb)

    # To predict the RGB Images from given images
    def predictRGB(self, model, img):
        
        '''
        Description : 
                Method to predict the RGB Image 
        Input : 
                model => Pretrained NN model to predict the A` and B` channels
		        img => RGB image (w * h * 3)
        Returns : 
                np.array (RGB Image - w * h* 3)
        '''
        _l, predAB = self.__predictLAB(model,img) 
        print(_l.shape)
        print(predAB.shape)
        rgbImage = self.__imgPostProcess(_l, predAB)
        return np.array(rgbImage)

# %% [markdown]
# ### File Count of the gcDataset

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files : {total_files}')
# Out:
# Total JPG Files : 8800

# %% [markdown]
# ### Removing the any Grayscale Images from the dir

# %%
rmFileList = DatasetCleaner.removeGrayScaleFromDir(imgDirPath)
print('-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-')
print(f'Total Count of the removed grayScale images : {len(rmFileList)}')
# Out:
# Removing any grayScale Images from the directory.........
# Removing ## ID : 244 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4423.jpg
# Removing ## ID : 717 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2897.jpg
# Removing ## ID : 2504 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6849.jpg
# Removing ## ID : 2608 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5410.jpg
# Removing ## ID : 3130 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/4705.jpg
# Removing ## ID : 3587 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8689.jpg
# Removing ## ID : 3860 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8679.jpg
# Removing ## ID : 4867 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5367.jpg
# Removing ## ID : 5392 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/5710.jpg
# Removing ## ID : 5668 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/7462.jpg
# Removing ## ID : 5763 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1204.jpg
# Removing ## ID : 6022 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/8215.jpg
# Removing ## ID : 6590 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/1658.jpg
# Removing ## ID : 8452 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/6725.jpg
# Removing ## ID : 8517 ==== ImageShape : (256, 256, 1) ==== FileName : /content/gcImages/content/gc-dataset/train/2661.jpg
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Total Count of the removed grayScale images : 15

# %%
total_files = len(glob.glob(imgDirPath + osSep + '*.jpg'))
print(f'Total JPG Files in the Directroy : {total_files}')
# Out:
# Total JPG Files in the Directroy : 8785

# %% [markdown]
# ### Creating the tf Data Pipeline

# %% [markdown]
# #### Using the tf.data.Dataset for data pipelining

# %%
# reading the all images from the folder
image_ds = DatasetLoader.loadDataSetFromDir(dataPath).take(100)

# %%
# displaying the first three data Tensors
for data in image_ds.take(2):
    print(data)
# Out:
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/0.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/gcImages/content/gc-dataset/train/1.jpg', shape=(), dtype=string)

# %% [markdown]
# #### No of Images in the Dataset

# %%
total_imgs = len(image_ds)
print(f'Size of image_ds : {total_imgs}')
# Out:
# Size of image_ds : 100

# %% [markdown]
# #### Setting the train-test-validation dataset size

# %%
train_size = int(total_imgs * 0.8)
val_size = int(total_imgs * 0.1)
test_size = int(total_imgs - train_size - val_size)
print(f'Train Size : {train_size}')
print(f'Test Size : {test_size}')
print(f'Val Size : {val_size}')
# Out:
# Train Size : 80
# Test Size : 10
# Val Size : 10

# %% [markdown]
# #### Splitting into train-test-validation

# %%
# taking the train-test-val data
train_ds = image_ds.take(train_size)
val_ds = image_ds.skip(train_size).take(val_size)
test_ds = image_ds.skip(train_size + val_size)

# %%
print(f'train_ds Size : {len(train_ds)}')
print(f'val_ds Size : {len(val_ds)}')
print(f'test_ds Size : {len(test_ds)}')
# Out:
# train_ds Size : 80
# val_ds Size : 10
# test_ds Size : 10

# %% [markdown]
# #### Setting up the Data Pipeline for the train-test-val

# %% [markdown]
# ##### Mapping the datasets for training

# %%
# getting the RGB Images dataset from the Original Dataset
train_rgb_ds = DatasetMapper.getRGBDataset(train_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected RGB Dataset
train_lab_ds = DatasetMapper.getLABDataset(train_rgb_ds)

# %%
# getting the data to train model i.e L(X) & AB(Y) channels from the collected LAB Dataset
trainData = DatasetMapper.getXYDataset(train_lab_ds, img_w, img_h)

# %%
train_rgb_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
train_lab_ds
# Out:
# <MapDataset shapes: <unknown>, types: tf.float32>

# %%
trainData
# Out:
# <MapDataset shapes: ((256, 256, 1), (256, 256, 2)), types: (tf.float32, tf.float32)>

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in train_rgb_ds.take(1):
    print(f'RGB Image Shape : {rgb.shape}')
# Out:
# RGB Image Shape : (256, 256, 3)

# %%
for lab in train_lab_ds.take(1):
    print(f'Lab Image Shape : {lab.shape}')
# Out:
# Lab Image Shape : (256, 256, 3)

# %%
for _l, _ab in trainData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Training Dataset

# %%
visual = ImageVisualizer()

# %%
visual.plotImages(train_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(train_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for testing

# %%
# getting the RGB Images dataset from the testing Dataset
test_rgb_ds = DatasetMapper.getRGBDataset(test_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected testing RGB Dataset
test_lab_ds = DatasetMapper.getLABDataset(test_rgb_ds)

# %%
# getting the data to test model i.e L(X) & AB(Y) channels from the collected LAB Dataset
testData = DatasetMapper.getXYDataset(test_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in test_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in test_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in testData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(test_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(test_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# ##### Mapping the datasets for validation

# %%
# getting the RGB Images dataset from the Original Validation Dataset
val_rgb_ds = DatasetMapper.getRGBDataset(val_ds, img_w, img_h)

# %%
# getting the LAB Images dataset from the collected Validation RGB Dataset
val_lab_ds = DatasetMapper.getLABDataset(val_rgb_ds)

# %%
# getting the data to validate model i.e L(X) & AB(Y) channels from the collected LAB Dataset
valData = DatasetMapper.getXYDataset(val_lab_ds, img_w, img_h)

# %% [markdown]
# Checking the each Dataset Image shapes

# %%
for rgb in val_rgb_ds.take(1):
    print('RGB Images Shape :', rgb.shape)
# Out:
# RGB Images Shape : (256, 256, 3)

# %%
for lab in val_lab_ds.take(2):
    print('LAB Images Shape :', lab.shape)
# Out:
# LAB Images Shape : (256, 256, 3)
# LAB Images Shape : (256, 256, 3)

# %%
for _l, _ab in valData.take(1):
    print('L Shape : ',_l.numpy().shape)
    print('AB Shape : ',_ab.numpy().shape)
# Out:
# L Shape :  (256, 256, 1)
# AB Shape :  (256, 256, 2)

# %% [markdown]
# Visualization of Testing Dataset

# %%
visual.plotImages(val_rgb_ds, 2)

# %% [markdown]
# Plotting the LAB Images

# %%
visual.plotLABImages(val_lab_ds, 2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# LAB Image - 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------
# LAB Image - 1
# ----------------------------------------------------

# %% [markdown]
# #### Setting up the configuration for train-test-val dataset

# %%
# setting the batch size of the input dataset
batchSize = 32

# %%
trainData = config_ds(trainData, batchSize)
testData = config_ds(testData, batchSize)
valData = config_ds(valData, batchSize)

# %% [markdown]
# ### Creating the Autoencoder Model

# %% [markdown]
# #### Model Variables

# %%
# model variables
input_shape = (256,256,1)           # input shape of the nn
num_epochs = 500                     # no of epochs to train  the model

# instantiate the optimizers function
optimizer_fn = keras.optimizers.adam_v2.Adam()

# instantiate the loss function
loss_fn = keras.losses.MeanSquaredError()   

# metrices for train and val accuracy 

train_acc_metric = keras.metrics.MeanSquaredError()
val_acc_metric = keras.metrics.MeanSquaredError()

# var for recording the losses and the accuracy while training and validating
train_loss = []
val_loss = []
train_acc = []
val_acc = []

lrelu = lambda x: tf.keras.activations.relu(x, alpha=0.1) 

#  defining the model save / load path 
model_path = '/content/drive/MyDrive/Image Colorization/model-history/model/CtfPy_tfGTClass_AE2_GCData_100_500.model'

# defining the history of model save / load path
history_path = '/content/drive/MyDrive/Image Colorization/model-history/model/CtfPy_tfGTClass_AE2_GCData_100_500.csv'

# %% [markdown]
# #### AutoEncoder NN Architecture

# %%
def autoEncoder(inputShape = input_shape):

    # input layer
    input_L = Input(shape = inputShape)

    # encoder

    # l1 
    l1 = Conv2D(filters=64, kernel_size=(3,3), activation=lrelu, padding='same',strides=2)(input_L)

    # l2
    l2 = Conv2D(filters=128, kernel_size=(3,3), activation=lrelu, padding='same')(l1)
    
    # l3
    l3 = Conv2D(filters=128, kernel_size=(3,3), activation=lrelu, padding='same', strides=2)(l2)

    # l4
    l4 = Conv2D(filters=256, kernel_size=(3,3), activation=lrelu, padding='same')(l3)

    # l5
    l5 = Conv2D(filters=256, kernel_size=(3,3), activation=lrelu, padding='same', strides=2)(l4)

    # l6
    l6 = Conv2D(filters=512, kernel_size=(3,3), activation=lrelu, padding='same')(l5)

    # l7
    l7 = Conv2D(filters=512, kernel_size=(3,3), activation=lrelu, padding='same')(l6)

    # l8
    l8 = Conv2D(filters=256, kernel_size=(3,3), activation=lrelu, padding='same')(l7)


    # decoder

    # l9
    l9 = Conv2DTranspose(filters=128, kernel_size=3, strides=(2,2), padding='same', activation=lrelu)(l8)

    # l10
    l10 = Conv2DTranspose(filters=64, kernel_size=3, strides=(2,2), padding='same', activation=lrelu)(l9)

    # l11
    l11 = Conv2DTranspose(filters=2, kernel_size=3, strides=(2,2), padding='same', activation='tanh')(l10)



    return Model(inputs=input_L, outputs=l11)

# %%
model = autoEncoder()

# %%
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 256, 256, 1)]     0
#
#  conv2d_98 (Conv2D)          (None, 128, 128, 64)      640
#
#  conv2d_99 (Conv2D)          (None, 128, 128, 128)     73856
#
#  conv2d_100 (Conv2D)         (None, 64, 64, 128)       147584
#
#  conv2d_101 (Conv2D)         (None, 64, 64, 256)       295168
#
#  conv2d_102 (Conv2D)         (None, 32, 32, 256)       590080
#
#  conv2d_103 (Conv2D)         (None, 32, 32, 512)       1180160
#
#  conv2d_104 (Conv2D)         (None, 32, 32, 512)       2359808
#
#  conv2d_105 (Conv2D)         (None, 32, 32, 256)       1179904
#
#  conv2d_transpose_39 (Conv2D  (None, 64, 64, 128)      295040
#  Transpose)
#
#  conv2d_transpose_40 (Conv2D  (None, 128, 128, 64)     73792
#  Transpose)
#
#  conv2d_transpose_41 (Conv2D  (None, 256, 256, 2)      1154
#  Transpose)
#
# =================================================================
# Total params: 6,197,186
# Trainable params: 6,197,186
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
# training the model
history = model.fit(trainData, validation_data=valData, epochs=num_epochs)
model.save(model_path)          # saving the model

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)
visual.visualizeModelHistory(history)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 5s 1s/step - loss: 0.0144 - accuracy: 0.5567 - val_loss: 0.0148 - val_accuracy: 0.5707
# Epoch 2/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0138 - accuracy: 0.6133 - val_loss: 0.0130 - val_accuracy: 0.5846
# Epoch 3/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0137 - accuracy: 0.6442 - val_loss: 0.0109 - val_accuracy: 0.5711
# Epoch 4/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0121 - accuracy: 0.6380 - val_loss: 0.0120 - val_accuracy: 0.5931
# Epoch 5/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0128 - accuracy: 0.6327 - val_loss: 0.0108 - val_accuracy: 0.5853
# Epoch 6/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.0120 - accuracy: 0.6570 - val_loss: 0.0104 - val_accuracy: 0.5953
# Epoch 7/500
# 3/3 [==============================] - 2s 567ms/step - loss: 0.0116 - accuracy: 0.6698 - val_loss: 0.0112 - val_accuracy: 0.5935
# Epoch 8/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0116 - accuracy: 0.6703 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 9/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0113 - val_accuracy: 0.5935
# Epoch 10/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0115 - accuracy: 0.6703 - val_loss: 0.0112 - val_accuracy: 0.5935
# Epoch 11/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0112 - val_accuracy: 0.5935
# Epoch 12/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 13/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0116 - val_accuracy: 0.5935
# Epoch 14/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 15/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0113 - val_accuracy: 0.5935
# Epoch 16/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 17/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0113 - val_accuracy: 0.5935
# Epoch 18/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0112 - val_accuracy: 0.5935
# Epoch 19/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0116 - val_accuracy: 0.5935
# Epoch 20/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0111 - val_accuracy: 0.5935
# Epoch 21/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0114 - val_accuracy: 0.5935
# Epoch 22/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0115 - val_accuracy: 0.5935
# Epoch 23/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0111 - val_accuracy: 0.5935
# Epoch 24/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0111 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5948
# Epoch 25/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0122 - accuracy: 0.6657 - val_loss: 0.0251 - val_accuracy: 0.5935
# Epoch 26/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.0158 - accuracy: 0.6469 - val_loss: 0.0103 - val_accuracy: 0.5916
# Epoch 27/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0157 - accuracy: 0.6081 - val_loss: 0.0493 - val_accuracy: 0.5150
# Epoch 28/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0325 - accuracy: 0.5617 - val_loss: 0.0212 - val_accuracy: 0.5301
# Epoch 29/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0279 - accuracy: 0.5581 - val_loss: 0.2137 - val_accuracy: 0.5191
# Epoch 30/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.1063 - accuracy: 0.5521 - val_loss: 0.0801 - val_accuracy: 0.5266
# Epoch 31/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0606 - accuracy: 0.5274 - val_loss: 0.7254 - val_accuracy: 0.4961
# Epoch 32/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.3048 - accuracy: 0.5052 - val_loss: 0.4556 - val_accuracy: 0.4970
# Epoch 33/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.2507 - accuracy: 0.5147 - val_loss: 0.0516 - val_accuracy: 0.5474
# Epoch 34/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0953 - accuracy: 0.5540 - val_loss: 0.1347 - val_accuracy: 0.5243
# Epoch 35/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.1254 - accuracy: 0.5241 - val_loss: 0.1696 - val_accuracy: 0.4862
# Epoch 36/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.3070 - accuracy: 0.4833 - val_loss: 0.2187 - val_accuracy: 0.5289
# Epoch 37/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.1944 - accuracy: 0.5407 - val_loss: 0.1525 - val_accuracy: 0.5214
# Epoch 38/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0868 - accuracy: 0.5278 - val_loss: 0.0173 - val_accuracy: 0.5321
# Epoch 39/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0192 - accuracy: 0.5391 - val_loss: 0.0220 - val_accuracy: 0.5162
# Epoch 40/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0222 - accuracy: 0.5284 - val_loss: 0.0144 - val_accuracy: 0.5436
# Epoch 41/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0142 - accuracy: 0.5886 - val_loss: 0.0119 - val_accuracy: 0.5736
# Epoch 42/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0123 - accuracy: 0.6279 - val_loss: 0.0109 - val_accuracy: 0.5854
# Epoch 43/500
# 3/3 [==============================] - 2s 588ms/step - loss: 0.0117 - accuracy: 0.6461 - val_loss: 0.0106 - val_accuracy: 0.5946
# Epoch 44/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0120 - accuracy: 0.6542 - val_loss: 0.0437 - val_accuracy: 0.5464
# Epoch 45/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0481 - accuracy: 0.5801 - val_loss: 0.0193 - val_accuracy: 0.5269
# Epoch 46/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0225 - accuracy: 0.5213 - val_loss: 0.0198 - val_accuracy: 0.5395
# Epoch 47/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0197 - accuracy: 0.5657 - val_loss: 0.0150 - val_accuracy: 0.5627
# Epoch 48/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0148 - accuracy: 0.5984 - val_loss: 0.0126 - val_accuracy: 0.5716
# Epoch 49/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0130 - accuracy: 0.6180 - val_loss: 0.0117 - val_accuracy: 0.5839
# Epoch 50/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0121 - accuracy: 0.6410 - val_loss: 0.0114 - val_accuracy: 0.5902
# Epoch 51/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0118 - accuracy: 0.6524 - val_loss: 0.0114 - val_accuracy: 0.5945
# Epoch 52/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.0117 - accuracy: 0.6637 - val_loss: 0.0114 - val_accuracy: 0.5947
# Epoch 53/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0116 - accuracy: 0.6695 - val_loss: 0.0113 - val_accuracy: 0.5936
# Epoch 54/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0115 - accuracy: 0.6700 - val_loss: 0.0112 - val_accuracy: 0.5937
# Epoch 55/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0111 - val_accuracy: 0.5936
# Epoch 56/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 57/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 58/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 59/500
# 3/3 [==============================] - 2s 627ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 60/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 61/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 62/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 63/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 64/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 65/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 66/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 67/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 68/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 69/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 70/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 71/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 72/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 73/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 74/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 75/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 76/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 77/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 78/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 79/500
# 3/3 [==============================] - 2s 568ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 80/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 81/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 82/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 83/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 84/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5937
# Epoch 85/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5937
# Epoch 86/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5937
# Epoch 87/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5938
# Epoch 88/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0110 - val_accuracy: 0.5938
# Epoch 89/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0111 - val_accuracy: 0.5936
# Epoch 90/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0111 - val_accuracy: 0.5937
# Epoch 91/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0112 - accuracy: 0.6701 - val_loss: 0.0112 - val_accuracy: 0.5935
# Epoch 92/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5940
# Epoch 93/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6706 - val_loss: 0.0113 - val_accuracy: 0.5936
# Epoch 94/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0111 - val_accuracy: 0.5936
# Epoch 95/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0113 - accuracy: 0.6701 - val_loss: 0.0109 - val_accuracy: 0.5939
# Epoch 96/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0110 - val_accuracy: 0.5938
# Epoch 97/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5939
# Epoch 98/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5940
# Epoch 99/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5940
# Epoch 100/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0110 - val_accuracy: 0.5940
# Epoch 101/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0108 - val_accuracy: 0.5944
# Epoch 102/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6705 - val_loss: 0.0110 - val_accuracy: 0.5940
# Epoch 103/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5940
# Epoch 104/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6704 - val_loss: 0.0111 - val_accuracy: 0.5938
# Epoch 105/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6701 - val_loss: 0.0108 - val_accuracy: 0.5954
# Epoch 106/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0111 - accuracy: 0.6710 - val_loss: 0.0110 - val_accuracy: 0.5941
# Epoch 107/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6708 - val_loss: 0.0118 - val_accuracy: 0.5936
# Epoch 108/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0115 - val_accuracy: 0.5936
# Epoch 109/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6701 - val_loss: 0.0107 - val_accuracy: 0.5959
# Epoch 110/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6710 - val_loss: 0.0109 - val_accuracy: 0.5939
# Epoch 111/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0112 - accuracy: 0.6700 - val_loss: 0.0109 - val_accuracy: 0.5942
# Epoch 112/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0112 - accuracy: 0.6701 - val_loss: 0.0107 - val_accuracy: 0.5949
# Epoch 113/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0112 - accuracy: 0.6706 - val_loss: 0.0110 - val_accuracy: 0.5940
# Epoch 114/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0107 - val_accuracy: 0.5961
# Epoch 115/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0111 - accuracy: 0.6710 - val_loss: 0.0111 - val_accuracy: 0.5941
# Epoch 116/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0112 - accuracy: 0.6699 - val_loss: 0.0109 - val_accuracy: 0.5947
# Epoch 117/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0111 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5963
# Epoch 118/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0111 - accuracy: 0.6713 - val_loss: 0.0111 - val_accuracy: 0.5944
# Epoch 119/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0111 - accuracy: 0.6699 - val_loss: 0.0116 - val_accuracy: 0.5937
# Epoch 120/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0116 - val_accuracy: 0.5937
# Epoch 121/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0113 - accuracy: 0.6677 - val_loss: 0.0119 - val_accuracy: 0.5936
# Epoch 122/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0116 - accuracy: 0.6702 - val_loss: 0.0133 - val_accuracy: 0.5936
# Epoch 123/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0119 - accuracy: 0.6700 - val_loss: 0.0117 - val_accuracy: 0.5936
# Epoch 124/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0115 - accuracy: 0.6702 - val_loss: 0.0108 - val_accuracy: 0.5936
# Epoch 125/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0104 - val_accuracy: 0.5940
# Epoch 126/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0114 - accuracy: 0.6702 - val_loss: 0.0104 - val_accuracy: 0.5942
# Epoch 127/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0104 - val_accuracy: 0.5935
# Epoch 128/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0114 - accuracy: 0.6703 - val_loss: 0.0105 - val_accuracy: 0.5935
# Epoch 129/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5935
# Epoch 130/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0108 - val_accuracy: 0.5935
# Epoch 131/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5935
# Epoch 132/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 133/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0111 - val_accuracy: 0.5935
# Epoch 134/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 135/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 136/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 137/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 138/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 139/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 140/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 141/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 142/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 143/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0113 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 144/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 145/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 146/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5936
# Epoch 147/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 148/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 149/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 150/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5936
# Epoch 151/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5937
# Epoch 152/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5938
# Epoch 153/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0109 - val_accuracy: 0.5939
# Epoch 154/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0108 - val_accuracy: 0.5940
# Epoch 155/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0108 - val_accuracy: 0.5941
# Epoch 156/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0112 - accuracy: 0.6702 - val_loss: 0.0108 - val_accuracy: 0.5943
# Epoch 157/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0111 - accuracy: 0.6701 - val_loss: 0.0108 - val_accuracy: 0.5943
# Epoch 158/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0111 - accuracy: 0.6701 - val_loss: 0.0108 - val_accuracy: 0.5945
# Epoch 159/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0111 - accuracy: 0.6701 - val_loss: 0.0108 - val_accuracy: 0.5951
# Epoch 160/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0111 - accuracy: 0.6701 - val_loss: 0.0108 - val_accuracy: 0.5953
# Epoch 161/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0111 - accuracy: 0.6703 - val_loss: 0.0109 - val_accuracy: 0.5953
# Epoch 162/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0110 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5955
# Epoch 163/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0110 - accuracy: 0.6708 - val_loss: 0.0109 - val_accuracy: 0.5956
# Epoch 164/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0110 - accuracy: 0.6708 - val_loss: 0.0109 - val_accuracy: 0.5956
# Epoch 165/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0110 - accuracy: 0.6709 - val_loss: 0.0109 - val_accuracy: 0.5957
# Epoch 166/500
# 3/3 [==============================] - 2s 591ms/step - loss: 0.0110 - accuracy: 0.6713 - val_loss: 0.0110 - val_accuracy: 0.5953
# Epoch 167/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0110 - accuracy: 0.6708 - val_loss: 0.0110 - val_accuracy: 0.5954
# Epoch 168/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0110 - accuracy: 0.6703 - val_loss: 0.0107 - val_accuracy: 0.5971
# Epoch 169/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0109 - accuracy: 0.6719 - val_loss: 0.0108 - val_accuracy: 0.5961
# Epoch 170/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0109 - accuracy: 0.6722 - val_loss: 0.0114 - val_accuracy: 0.5945
# Epoch 171/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0110 - accuracy: 0.6710 - val_loss: 0.0115 - val_accuracy: 0.5944
# Epoch 172/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0110 - accuracy: 0.6696 - val_loss: 0.0105 - val_accuracy: 0.5964
# Epoch 173/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0109 - accuracy: 0.6709 - val_loss: 0.0108 - val_accuracy: 0.5956
# Epoch 174/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0109 - accuracy: 0.6708 - val_loss: 0.0114 - val_accuracy: 0.5946
# Epoch 175/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0109 - accuracy: 0.6698 - val_loss: 0.0118 - val_accuracy: 0.5944
# Epoch 176/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0110 - accuracy: 0.6688 - val_loss: 0.0107 - val_accuracy: 0.5963
# Epoch 177/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0108 - accuracy: 0.6709 - val_loss: 0.0105 - val_accuracy: 0.5996
# Epoch 178/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0107 - accuracy: 0.6732 - val_loss: 0.0111 - val_accuracy: 0.5957
# Epoch 179/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0110 - accuracy: 0.6694 - val_loss: 0.0130 - val_accuracy: 0.5939
# Epoch 180/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0113 - accuracy: 0.6670 - val_loss: 0.0112 - val_accuracy: 0.5943
# Epoch 181/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0111 - accuracy: 0.6702 - val_loss: 0.0124 - val_accuracy: 0.5936
# Epoch 182/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0113 - accuracy: 0.6702 - val_loss: 0.0107 - val_accuracy: 0.5947
# Epoch 183/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0112 - accuracy: 0.6694 - val_loss: 0.0102 - val_accuracy: 0.5961
# Epoch 184/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0111 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.5940
# Epoch 185/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0110 - accuracy: 0.6702 - val_loss: 0.0116 - val_accuracy: 0.5938
# Epoch 186/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0110 - accuracy: 0.6701 - val_loss: 0.0103 - val_accuracy: 0.5975
# Epoch 187/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0108 - accuracy: 0.6714 - val_loss: 0.0111 - val_accuracy: 0.5954
# Epoch 188/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0107 - accuracy: 0.6700 - val_loss: 0.0105 - val_accuracy: 0.6064
# Epoch 189/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0106 - accuracy: 0.6749 - val_loss: 0.0107 - val_accuracy: 0.6064
# Epoch 190/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0106 - accuracy: 0.6740 - val_loss: 0.0113 - val_accuracy: 0.5979
# Epoch 191/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0107 - accuracy: 0.6696 - val_loss: 0.0119 - val_accuracy: 0.5951
# Epoch 192/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0109 - accuracy: 0.6680 - val_loss: 0.0119 - val_accuracy: 0.5946
# Epoch 193/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0107 - accuracy: 0.6697 - val_loss: 0.0102 - val_accuracy: 0.6028
# Epoch 194/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0106 - accuracy: 0.6728 - val_loss: 0.0118 - val_accuracy: 0.5946
# Epoch 195/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0106 - accuracy: 0.6695 - val_loss: 0.0111 - val_accuracy: 0.5997
# Epoch 196/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0105 - accuracy: 0.6704 - val_loss: 0.0103 - val_accuracy: 0.6175
# Epoch 197/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0104 - accuracy: 0.6761 - val_loss: 0.0100 - val_accuracy: 0.6205
# Epoch 198/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0104 - accuracy: 0.6766 - val_loss: 0.0101 - val_accuracy: 0.6182
# Epoch 199/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0104 - accuracy: 0.6757 - val_loss: 0.0104 - val_accuracy: 0.6137
# Epoch 200/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0104 - accuracy: 0.6744 - val_loss: 0.0109 - val_accuracy: 0.6051
# Epoch 201/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0104 - accuracy: 0.6708 - val_loss: 0.0119 - val_accuracy: 0.5982
# Epoch 202/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0106 - accuracy: 0.6665 - val_loss: 0.0131 - val_accuracy: 0.5953
# Epoch 203/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0108 - accuracy: 0.6687 - val_loss: 0.0104 - val_accuracy: 0.5995
# Epoch 204/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0104 - accuracy: 0.6711 - val_loss: 0.0107 - val_accuracy: 0.5981
# Epoch 205/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0105 - accuracy: 0.6700 - val_loss: 0.0116 - val_accuracy: 0.5976
# Epoch 206/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0105 - accuracy: 0.6688 - val_loss: 0.0101 - val_accuracy: 0.6185
# Epoch 207/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0103 - accuracy: 0.6767 - val_loss: 0.0099 - val_accuracy: 0.6239
# Epoch 208/500
# 3/3 [==============================] - 2s 603ms/step - loss: 0.0103 - accuracy: 0.6778 - val_loss: 0.0106 - val_accuracy: 0.6118
# Epoch 209/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0103 - accuracy: 0.6724 - val_loss: 0.0116 - val_accuracy: 0.6008
# Epoch 210/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0105 - accuracy: 0.6642 - val_loss: 0.0130 - val_accuracy: 0.5962
# Epoch 211/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0108 - accuracy: 0.6663 - val_loss: 0.0107 - val_accuracy: 0.5982
# Epoch 212/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0105 - accuracy: 0.6706 - val_loss: 0.0105 - val_accuracy: 0.5966
# Epoch 213/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0106 - accuracy: 0.6697 - val_loss: 0.0108 - val_accuracy: 0.5964
# Epoch 214/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0104 - accuracy: 0.6702 - val_loss: 0.0103 - val_accuracy: 0.6008
# Epoch 215/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0104 - accuracy: 0.6710 - val_loss: 0.0120 - val_accuracy: 0.5977
# Epoch 216/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0104 - accuracy: 0.6690 - val_loss: 0.0102 - val_accuracy: 0.6163
# Epoch 217/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0103 - accuracy: 0.6757 - val_loss: 0.0100 - val_accuracy: 0.6184
# Epoch 218/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0103 - accuracy: 0.6740 - val_loss: 0.0113 - val_accuracy: 0.6000
# Epoch 219/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0103 - accuracy: 0.6675 - val_loss: 0.0114 - val_accuracy: 0.6036
# Epoch 220/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0103 - accuracy: 0.6703 - val_loss: 0.0101 - val_accuracy: 0.6219
# Epoch 221/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0102 - accuracy: 0.6768 - val_loss: 0.0100 - val_accuracy: 0.6200
# Epoch 222/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0102 - accuracy: 0.6762 - val_loss: 0.0110 - val_accuracy: 0.6023
# Epoch 223/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0102 - accuracy: 0.6715 - val_loss: 0.0115 - val_accuracy: 0.6000
# Epoch 224/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0102 - accuracy: 0.6702 - val_loss: 0.0115 - val_accuracy: 0.6059
# Epoch 225/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0102 - accuracy: 0.6714 - val_loss: 0.0114 - val_accuracy: 0.6080
# Epoch 226/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0101 - accuracy: 0.6721 - val_loss: 0.0112 - val_accuracy: 0.6091
# Epoch 227/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0101 - accuracy: 0.6724 - val_loss: 0.0110 - val_accuracy: 0.6138
# Epoch 228/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0101 - accuracy: 0.6736 - val_loss: 0.0108 - val_accuracy: 0.6186
# Epoch 229/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0100 - accuracy: 0.6755 - val_loss: 0.0106 - val_accuracy: 0.6209
# Epoch 230/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0100 - accuracy: 0.6767 - val_loss: 0.0103 - val_accuracy: 0.6237
# Epoch 231/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0100 - accuracy: 0.6786 - val_loss: 0.0097 - val_accuracy: 0.6302
# Epoch 232/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0101 - accuracy: 0.6800 - val_loss: 0.0090 - val_accuracy: 0.6232
# Epoch 233/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0106 - accuracy: 0.6704 - val_loss: 0.0134 - val_accuracy: 0.5942
# Epoch 234/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0109 - accuracy: 0.6697 - val_loss: 0.0098 - val_accuracy: 0.5988
# Epoch 235/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0107 - accuracy: 0.6702 - val_loss: 0.0123 - val_accuracy: 0.5949
# Epoch 236/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0105 - accuracy: 0.6699 - val_loss: 0.0097 - val_accuracy: 0.6161
# Epoch 237/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0102 - accuracy: 0.6772 - val_loss: 0.0114 - val_accuracy: 0.6073
# Epoch 238/500
# 3/3 [==============================] - 2s 569ms/step - loss: 0.0103 - accuracy: 0.6675 - val_loss: 0.0133 - val_accuracy: 0.5964
# Epoch 239/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0108 - accuracy: 0.6631 - val_loss: 0.0101 - val_accuracy: 0.5996
# Epoch 240/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0104 - accuracy: 0.6708 - val_loss: 0.0120 - val_accuracy: 0.5946
# Epoch 241/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0107 - accuracy: 0.6697 - val_loss: 0.0101 - val_accuracy: 0.5960
# Epoch 242/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0104 - accuracy: 0.6695 - val_loss: 0.0127 - val_accuracy: 0.5953
# Epoch 243/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0106 - accuracy: 0.6679 - val_loss: 0.0098 - val_accuracy: 0.6095
# Epoch 244/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0103 - accuracy: 0.6738 - val_loss: 0.0105 - val_accuracy: 0.6085
# Epoch 245/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0102 - accuracy: 0.6728 - val_loss: 0.0113 - val_accuracy: 0.6044
# Epoch 246/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0102 - accuracy: 0.6710 - val_loss: 0.0103 - val_accuracy: 0.6178
# Epoch 247/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0101 - accuracy: 0.6750 - val_loss: 0.0101 - val_accuracy: 0.6214
# Epoch 248/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0100 - accuracy: 0.6752 - val_loss: 0.0109 - val_accuracy: 0.6147
# Epoch 249/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0100 - accuracy: 0.6734 - val_loss: 0.0115 - val_accuracy: 0.6087
# Epoch 250/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0101 - accuracy: 0.6705 - val_loss: 0.0124 - val_accuracy: 0.6011
# Epoch 251/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0104 - accuracy: 0.6672 - val_loss: 0.0123 - val_accuracy: 0.5978
# Epoch 252/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0102 - accuracy: 0.6696 - val_loss: 0.0100 - val_accuracy: 0.6054
# Epoch 253/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0100 - accuracy: 0.6720 - val_loss: 0.0106 - val_accuracy: 0.6062
# Epoch 254/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0100 - accuracy: 0.6724 - val_loss: 0.0117 - val_accuracy: 0.6080
# Epoch 255/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0101 - accuracy: 0.6718 - val_loss: 0.0113 - val_accuracy: 0.6147
# Epoch 256/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0100 - accuracy: 0.6757 - val_loss: 0.0102 - val_accuracy: 0.6173
# Epoch 257/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0099 - accuracy: 0.6762 - val_loss: 0.0101 - val_accuracy: 0.6167
# Epoch 258/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0100 - accuracy: 0.6760 - val_loss: 0.0106 - val_accuracy: 0.6180
# Epoch 259/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0099 - accuracy: 0.6757 - val_loss: 0.0112 - val_accuracy: 0.6200
# Epoch 260/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0100 - accuracy: 0.6745 - val_loss: 0.0120 - val_accuracy: 0.6068
# Epoch 261/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0103 - accuracy: 0.6674 - val_loss: 0.0132 - val_accuracy: 0.5979
# Epoch 262/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0105 - accuracy: 0.6686 - val_loss: 0.0109 - val_accuracy: 0.5990
# Epoch 263/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.0101 - accuracy: 0.6704 - val_loss: 0.0098 - val_accuracy: 0.6151
# Epoch 264/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0101 - accuracy: 0.6761 - val_loss: 0.0119 - val_accuracy: 0.6008
# Epoch 265/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0101 - accuracy: 0.6704 - val_loss: 0.0109 - val_accuracy: 0.6169
# Epoch 266/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0100 - accuracy: 0.6764 - val_loss: 0.0097 - val_accuracy: 0.6267
# Epoch 267/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0100 - accuracy: 0.6807 - val_loss: 0.0112 - val_accuracy: 0.6033
# Epoch 268/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0100 - accuracy: 0.6716 - val_loss: 0.0108 - val_accuracy: 0.6180
# Epoch 269/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0099 - accuracy: 0.6767 - val_loss: 0.0100 - val_accuracy: 0.6329
# Epoch 270/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0099 - accuracy: 0.6814 - val_loss: 0.0100 - val_accuracy: 0.6210
# Epoch 271/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0099 - accuracy: 0.6775 - val_loss: 0.0107 - val_accuracy: 0.6088
# Epoch 272/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0099 - accuracy: 0.6736 - val_loss: 0.0120 - val_accuracy: 0.6090
# Epoch 273/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0103 - accuracy: 0.6608 - val_loss: 0.0143 - val_accuracy: 0.5970
# Epoch 274/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0109 - accuracy: 0.6658 - val_loss: 0.0100 - val_accuracy: 0.5961
# Epoch 275/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0104 - accuracy: 0.6698 - val_loss: 0.0136 - val_accuracy: 0.5937
# Epoch 276/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0107 - accuracy: 0.6702 - val_loss: 0.0101 - val_accuracy: 0.5985
# Epoch 277/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0102 - accuracy: 0.6688 - val_loss: 0.0118 - val_accuracy: 0.6026
# Epoch 278/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0103 - accuracy: 0.6714 - val_loss: 0.0099 - val_accuracy: 0.6263
# Epoch 279/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0101 - accuracy: 0.6809 - val_loss: 0.0103 - val_accuracy: 0.6130
# Epoch 280/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0100 - accuracy: 0.6745 - val_loss: 0.0106 - val_accuracy: 0.6124
# Epoch 281/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0100 - accuracy: 0.6748 - val_loss: 0.0101 - val_accuracy: 0.6256
# Epoch 282/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0099 - accuracy: 0.6752 - val_loss: 0.0111 - val_accuracy: 0.6178
# Epoch 283/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0099 - accuracy: 0.6744 - val_loss: 0.0106 - val_accuracy: 0.6168
# Epoch 284/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0099 - accuracy: 0.6744 - val_loss: 0.0103 - val_accuracy: 0.6161
# Epoch 285/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0098 - accuracy: 0.6737 - val_loss: 0.0103 - val_accuracy: 0.6174
# Epoch 286/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0098 - accuracy: 0.6748 - val_loss: 0.0104 - val_accuracy: 0.6247
# Epoch 287/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0098 - accuracy: 0.6779 - val_loss: 0.0106 - val_accuracy: 0.6243
# Epoch 288/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0099 - accuracy: 0.6776 - val_loss: 0.0115 - val_accuracy: 0.6060
# Epoch 289/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0102 - accuracy: 0.6637 - val_loss: 0.0150 - val_accuracy: 0.5963
# Epoch 290/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0118 - accuracy: 0.6293 - val_loss: 0.0101 - val_accuracy: 0.5950
# Epoch 291/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0110 - accuracy: 0.6698 - val_loss: 0.0130 - val_accuracy: 0.5935
# Epoch 292/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0116 - accuracy: 0.6702 - val_loss: 0.0120 - val_accuracy: 0.5935
# Epoch 293/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6703 - val_loss: 0.0110 - val_accuracy: 0.5935
# Epoch 294/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0108 - accuracy: 0.6702 - val_loss: 0.0115 - val_accuracy: 0.5935
# Epoch 295/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0107 - accuracy: 0.6702 - val_loss: 0.0113 - val_accuracy: 0.5936
# Epoch 296/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0105 - accuracy: 0.6712 - val_loss: 0.0122 - val_accuracy: 0.5936
# Epoch 297/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0106 - accuracy: 0.6703 - val_loss: 0.0108 - val_accuracy: 0.5937
# Epoch 298/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0105 - accuracy: 0.6694 - val_loss: 0.0110 - val_accuracy: 0.5937
# Epoch 299/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0104 - accuracy: 0.6691 - val_loss: 0.0116 - val_accuracy: 0.5940
# Epoch 300/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0104 - accuracy: 0.6686 - val_loss: 0.0107 - val_accuracy: 0.5957
# Epoch 301/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0102 - accuracy: 0.6682 - val_loss: 0.0113 - val_accuracy: 0.5973
# Epoch 302/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0102 - accuracy: 0.6685 - val_loss: 0.0107 - val_accuracy: 0.6121
# Epoch 303/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0101 - accuracy: 0.6700 - val_loss: 0.0107 - val_accuracy: 0.6060
# Epoch 304/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0101 - accuracy: 0.6660 - val_loss: 0.0112 - val_accuracy: 0.5997
# Epoch 305/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0100 - accuracy: 0.6655 - val_loss: 0.0108 - val_accuracy: 0.6098
# Epoch 306/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0100 - accuracy: 0.6686 - val_loss: 0.0108 - val_accuracy: 0.6122
# Epoch 307/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0100 - accuracy: 0.6690 - val_loss: 0.0111 - val_accuracy: 0.6081
# Epoch 308/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0099 - accuracy: 0.6681 - val_loss: 0.0114 - val_accuracy: 0.6074
# Epoch 309/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0099 - accuracy: 0.6688 - val_loss: 0.0118 - val_accuracy: 0.6063
# Epoch 310/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0100 - accuracy: 0.6688 - val_loss: 0.0120 - val_accuracy: 0.6027
# Epoch 311/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0100 - accuracy: 0.6683 - val_loss: 0.0119 - val_accuracy: 0.6066
# Epoch 312/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0099 - accuracy: 0.6695 - val_loss: 0.0113 - val_accuracy: 0.6165
# Epoch 313/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0098 - accuracy: 0.6718 - val_loss: 0.0108 - val_accuracy: 0.6255
# Epoch 314/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0098 - accuracy: 0.6742 - val_loss: 0.0105 - val_accuracy: 0.6297
# Epoch 315/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0098 - accuracy: 0.6749 - val_loss: 0.0103 - val_accuracy: 0.6315
# Epoch 316/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0097 - accuracy: 0.6756 - val_loss: 0.0100 - val_accuracy: 0.6307
# Epoch 317/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0097 - accuracy: 0.6753 - val_loss: 0.0098 - val_accuracy: 0.6290
# Epoch 318/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0098 - accuracy: 0.6761 - val_loss: 0.0090 - val_accuracy: 0.6185
# Epoch 319/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0102 - accuracy: 0.6680 - val_loss: 0.0102 - val_accuracy: 0.5917
# Epoch 320/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.0110 - accuracy: 0.6595 - val_loss: 0.0100 - val_accuracy: 0.5882
# Epoch 321/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0111 - accuracy: 0.6614 - val_loss: 0.0114 - val_accuracy: 0.5917
# Epoch 322/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0112 - accuracy: 0.6657 - val_loss: 0.0116 - val_accuracy: 0.5923
# Epoch 323/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0111 - accuracy: 0.6651 - val_loss: 0.0102 - val_accuracy: 0.5906
# Epoch 324/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0109 - accuracy: 0.6622 - val_loss: 0.0112 - val_accuracy: 0.5927
# Epoch 325/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0108 - accuracy: 0.6649 - val_loss: 0.0104 - val_accuracy: 0.5976
# Epoch 326/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0106 - accuracy: 0.6651 - val_loss: 0.0111 - val_accuracy: 0.5977
# Epoch 327/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0105 - accuracy: 0.6669 - val_loss: 0.0106 - val_accuracy: 0.6084
# Epoch 328/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0104 - accuracy: 0.6732 - val_loss: 0.0109 - val_accuracy: 0.6008
# Epoch 329/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0104 - accuracy: 0.6692 - val_loss: 0.0114 - val_accuracy: 0.5963
# Epoch 330/500
# 3/3 [==============================] - 2s 584ms/step - loss: 0.0104 - accuracy: 0.6681 - val_loss: 0.0118 - val_accuracy: 0.5966
# Epoch 331/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0103 - accuracy: 0.6684 - val_loss: 0.0109 - val_accuracy: 0.6051
# Epoch 332/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0100 - accuracy: 0.6693 - val_loss: 0.0104 - val_accuracy: 0.6196
# Epoch 333/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0100 - accuracy: 0.6722 - val_loss: 0.0110 - val_accuracy: 0.6081
# Epoch 334/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0103 - accuracy: 0.6619 - val_loss: 0.0125 - val_accuracy: 0.5965
# Epoch 335/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0105 - accuracy: 0.6657 - val_loss: 0.0098 - val_accuracy: 0.6030
# Epoch 336/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0103 - accuracy: 0.6684 - val_loss: 0.0128 - val_accuracy: 0.5947
# Epoch 337/500
# ...
# Epoch 391/500
# 3/3 [==============================] - 2s 585ms/step - loss: 0.0097 - accuracy: 0.6873 - val_loss: 0.0096 - val_accuracy: 0.6390
# Epoch 392/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0097 - accuracy: 0.6844 - val_loss: 0.0098 - val_accuracy: 0.6358
# Epoch 393/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0099 - accuracy: 0.6744 - val_loss: 0.0118 - val_accuracy: 0.6066
# Epoch 394/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0098 - accuracy: 0.6707 - val_loss: 0.0095 - val_accuracy: 0.6249
# Epoch 395/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0098 - accuracy: 0.6752 - val_loss: 0.0120 - val_accuracy: 0.6080
# Epoch 396/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0097 - accuracy: 0.6728 - val_loss: 0.0103 - val_accuracy: 0.6319
# Epoch 397/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0096 - accuracy: 0.6823 - val_loss: 0.0101 - val_accuracy: 0.6384
# Epoch 398/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0096 - accuracy: 0.6721 - val_loss: 0.0117 - val_accuracy: 0.6350
# Epoch 399/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0096 - accuracy: 0.6824 - val_loss: 0.0101 - val_accuracy: 0.6365
# Epoch 400/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0095 - accuracy: 0.6810 - val_loss: 0.0102 - val_accuracy: 0.6403
# Epoch 401/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0095 - accuracy: 0.6773 - val_loss: 0.0117 - val_accuracy: 0.6299
# Epoch 402/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0095 - accuracy: 0.6799 - val_loss: 0.0106 - val_accuracy: 0.6416
# Epoch 403/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0095 - accuracy: 0.6833 - val_loss: 0.0100 - val_accuracy: 0.6402
# Epoch 404/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0095 - accuracy: 0.6815 - val_loss: 0.0107 - val_accuracy: 0.6355
# Epoch 405/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0094 - accuracy: 0.6800 - val_loss: 0.0116 - val_accuracy: 0.6417
# Epoch 406/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0095 - accuracy: 0.6829 - val_loss: 0.0109 - val_accuracy: 0.6458
# Epoch 407/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0095 - accuracy: 0.6840 - val_loss: 0.0101 - val_accuracy: 0.6410
# Epoch 408/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0095 - accuracy: 0.6827 - val_loss: 0.0096 - val_accuracy: 0.6331
# Epoch 409/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0099 - accuracy: 0.6658 - val_loss: 0.0145 - val_accuracy: 0.6041
# Epoch 410/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0101 - accuracy: 0.6675 - val_loss: 0.0098 - val_accuracy: 0.6337
# Epoch 411/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0097 - accuracy: 0.6833 - val_loss: 0.0105 - val_accuracy: 0.6145
# Epoch 412/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0098 - accuracy: 0.6712 - val_loss: 0.0104 - val_accuracy: 0.6390
# Epoch 413/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0097 - accuracy: 0.6826 - val_loss: 0.0099 - val_accuracy: 0.6355
# Epoch 414/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0098 - accuracy: 0.6738 - val_loss: 0.0110 - val_accuracy: 0.6279
# Epoch 415/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0097 - accuracy: 0.6830 - val_loss: 0.0098 - val_accuracy: 0.6345
# Epoch 416/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0097 - accuracy: 0.6699 - val_loss: 0.0114 - val_accuracy: 0.6227
# Epoch 417/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0096 - accuracy: 0.6774 - val_loss: 0.0099 - val_accuracy: 0.6387
# Epoch 418/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0097 - accuracy: 0.6733 - val_loss: 0.0117 - val_accuracy: 0.6371
# Epoch 419/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.0096 - accuracy: 0.6853 - val_loss: 0.0098 - val_accuracy: 0.6360
# Epoch 420/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0096 - accuracy: 0.6762 - val_loss: 0.0119 - val_accuracy: 0.6332
# Epoch 421/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.0096 - accuracy: 0.6851 - val_loss: 0.0098 - val_accuracy: 0.6369
# Epoch 422/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0096 - accuracy: 0.6776 - val_loss: 0.0113 - val_accuracy: 0.6346
# Epoch 423/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0094 - accuracy: 0.6847 - val_loss: 0.0105 - val_accuracy: 0.6394
# Epoch 424/500
# 3/3 [==============================] - 2s 585ms/step - loss: 0.0094 - accuracy: 0.6841 - val_loss: 0.0099 - val_accuracy: 0.6374
# Epoch 425/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0095 - accuracy: 0.6811 - val_loss: 0.0123 - val_accuracy: 0.6229
# Epoch 426/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0095 - accuracy: 0.6787 - val_loss: 0.0105 - val_accuracy: 0.6469
# Epoch 427/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0096 - accuracy: 0.6811 - val_loss: 0.0099 - val_accuracy: 0.6361
# Epoch 428/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0095 - accuracy: 0.6789 - val_loss: 0.0106 - val_accuracy: 0.6332
# Epoch 429/500
# 3/3 [==============================] - 2s 585ms/step - loss: 0.0094 - accuracy: 0.6766 - val_loss: 0.0117 - val_accuracy: 0.6416
# Epoch 430/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0095 - accuracy: 0.6886 - val_loss: 0.0099 - val_accuracy: 0.6391
# Epoch 431/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0095 - accuracy: 0.6847 - val_loss: 0.0106 - val_accuracy: 0.6365
# Epoch 432/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0094 - accuracy: 0.6823 - val_loss: 0.0109 - val_accuracy: 0.6444
# Epoch 433/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0094 - accuracy: 0.6873 - val_loss: 0.0102 - val_accuracy: 0.6404
# Epoch 434/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0094 - accuracy: 0.6840 - val_loss: 0.0104 - val_accuracy: 0.6395
# Epoch 435/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0093 - accuracy: 0.6806 - val_loss: 0.0105 - val_accuracy: 0.6436
# Epoch 436/500
# 3/3 [==============================] - 2s 586ms/step - loss: 0.0093 - accuracy: 0.6848 - val_loss: 0.0106 - val_accuracy: 0.6406
# Epoch 437/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0093 - accuracy: 0.6862 - val_loss: 0.0106 - val_accuracy: 0.6435
# Epoch 438/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0094 - accuracy: 0.6870 - val_loss: 0.0105 - val_accuracy: 0.6440
# Epoch 439/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0094 - accuracy: 0.6862 - val_loss: 0.0102 - val_accuracy: 0.6426
# Epoch 440/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0094 - accuracy: 0.6860 - val_loss: 0.0097 - val_accuracy: 0.6350
# Epoch 441/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0095 - accuracy: 0.6776 - val_loss: 0.0111 - val_accuracy: 0.6356
# Epoch 442/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0094 - accuracy: 0.6807 - val_loss: 0.0112 - val_accuracy: 0.6439
# Epoch 443/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0094 - accuracy: 0.6911 - val_loss: 0.0101 - val_accuracy: 0.6410
# Epoch 444/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0095 - accuracy: 0.6755 - val_loss: 0.0094 - val_accuracy: 0.6345
# Epoch 445/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0101 - accuracy: 0.6655 - val_loss: 0.0131 - val_accuracy: 0.5999
# Epoch 446/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0099 - accuracy: 0.6707 - val_loss: 0.0099 - val_accuracy: 0.6379
# Epoch 447/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0097 - accuracy: 0.6834 - val_loss: 0.0111 - val_accuracy: 0.6019
# Epoch 448/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0097 - accuracy: 0.6665 - val_loss: 0.0107 - val_accuracy: 0.6339
# Epoch 449/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0096 - accuracy: 0.6753 - val_loss: 0.0096 - val_accuracy: 0.6219
# Epoch 450/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0100 - accuracy: 0.6445 - val_loss: 0.0117 - val_accuracy: 0.6056
# Epoch 451/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0098 - accuracy: 0.6734 - val_loss: 0.0100 - val_accuracy: 0.6314
# Epoch 452/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0099 - accuracy: 0.6584 - val_loss: 0.0103 - val_accuracy: 0.6395
# Epoch 453/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0097 - accuracy: 0.6865 - val_loss: 0.0101 - val_accuracy: 0.6322
# Epoch 454/500
# 3/3 [==============================] - 2s 586ms/step - loss: 0.0099 - accuracy: 0.6792 - val_loss: 0.0093 - val_accuracy: 0.6338
# Epoch 455/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0097 - accuracy: 0.6840 - val_loss: 0.0126 - val_accuracy: 0.6128
# Epoch 456/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0097 - accuracy: 0.6789 - val_loss: 0.0099 - val_accuracy: 0.6333
# Epoch 457/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0096 - accuracy: 0.6835 - val_loss: 0.0111 - val_accuracy: 0.6358
# Epoch 458/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0095 - accuracy: 0.6895 - val_loss: 0.0099 - val_accuracy: 0.6441
# Epoch 459/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0097 - accuracy: 0.6733 - val_loss: 0.0105 - val_accuracy: 0.6400
# Epoch 460/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0095 - accuracy: 0.6894 - val_loss: 0.0100 - val_accuracy: 0.6409
# Epoch 461/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0098 - accuracy: 0.6740 - val_loss: 0.0099 - val_accuracy: 0.6325
# Epoch 462/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0095 - accuracy: 0.6866 - val_loss: 0.0116 - val_accuracy: 0.6193
# Epoch 463/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0096 - accuracy: 0.6786 - val_loss: 0.0099 - val_accuracy: 0.6384
# Epoch 464/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0094 - accuracy: 0.6925 - val_loss: 0.0115 - val_accuracy: 0.6204
# Epoch 465/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0094 - accuracy: 0.6801 - val_loss: 0.0100 - val_accuracy: 0.6453
# Epoch 466/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0094 - accuracy: 0.6713 - val_loss: 0.0107 - val_accuracy: 0.6423
# Epoch 467/500
# 3/3 [==============================] - 2s 592ms/step - loss: 0.0093 - accuracy: 0.6856 - val_loss: 0.0109 - val_accuracy: 0.6319
# Epoch 468/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0093 - accuracy: 0.6830 - val_loss: 0.0100 - val_accuracy: 0.6377
# Epoch 469/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0094 - accuracy: 0.6781 - val_loss: 0.0113 - val_accuracy: 0.6429
# Epoch 470/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0093 - accuracy: 0.6883 - val_loss: 0.0101 - val_accuracy: 0.6390
# Epoch 471/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0093 - accuracy: 0.6811 - val_loss: 0.0103 - val_accuracy: 0.6411
# Epoch 472/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0092 - accuracy: 0.6804 - val_loss: 0.0112 - val_accuracy: 0.6423
# Epoch 473/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0093 - accuracy: 0.6874 - val_loss: 0.0102 - val_accuracy: 0.6439
# Epoch 474/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0093 - accuracy: 0.6831 - val_loss: 0.0097 - val_accuracy: 0.6441
# Epoch 475/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0096 - accuracy: 0.6776 - val_loss: 0.0137 - val_accuracy: 0.6419
# Epoch 476/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0097 - accuracy: 0.6841 - val_loss: 0.0096 - val_accuracy: 0.6383
# Epoch 477/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0095 - accuracy: 0.6861 - val_loss: 0.0106 - val_accuracy: 0.6239
# Epoch 478/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0094 - accuracy: 0.6790 - val_loss: 0.0109 - val_accuracy: 0.6492
# Epoch 479/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0094 - accuracy: 0.6876 - val_loss: 0.0099 - val_accuracy: 0.6361
# Epoch 480/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0096 - accuracy: 0.6756 - val_loss: 0.0116 - val_accuracy: 0.6269
# Epoch 481/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0096 - accuracy: 0.6834 - val_loss: 0.0093 - val_accuracy: 0.6352
# Epoch 482/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0099 - accuracy: 0.6544 - val_loss: 0.0110 - val_accuracy: 0.6099
# Epoch 483/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.0097 - accuracy: 0.6742 - val_loss: 0.0101 - val_accuracy: 0.6291
# Epoch 484/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0099 - accuracy: 0.6693 - val_loss: 0.0095 - val_accuracy: 0.6285
# Epoch 485/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.0097 - accuracy: 0.6848 - val_loss: 0.0126 - val_accuracy: 0.5997
# Epoch 486/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0097 - accuracy: 0.6721 - val_loss: 0.0098 - val_accuracy: 0.6383
# Epoch 487/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.0098 - accuracy: 0.6647 - val_loss: 0.0107 - val_accuracy: 0.6197
# Epoch 488/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.0096 - accuracy: 0.6783 - val_loss: 0.0109 - val_accuracy: 0.6058
# Epoch 489/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0096 - accuracy: 0.6698 - val_loss: 0.0100 - val_accuracy: 0.6328
# Epoch 490/500
# 3/3 [==============================] - 2s 579ms/step - loss: 0.0094 - accuracy: 0.6789 - val_loss: 0.0113 - val_accuracy: 0.6408
# Epoch 491/500
# 3/3 [==============================] - 2s 578ms/step - loss: 0.0094 - accuracy: 0.6832 - val_loss: 0.0102 - val_accuracy: 0.6407
# Epoch 492/500
# 3/3 [==============================] - 2s 580ms/step - loss: 0.0093 - accuracy: 0.6887 - val_loss: 0.0111 - val_accuracy: 0.6334
# Epoch 493/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0093 - accuracy: 0.6813 - val_loss: 0.0102 - val_accuracy: 0.6478
# Epoch 494/500
# 3/3 [==============================] - 2s 574ms/step - loss: 0.0093 - accuracy: 0.6756 - val_loss: 0.0107 - val_accuracy: 0.6450
# Epoch 495/500
# 3/3 [==============================] - 2s 576ms/step - loss: 0.0092 - accuracy: 0.6866 - val_loss: 0.0107 - val_accuracy: 0.6386
# Epoch 496/500
# 3/3 [==============================] - 2s 573ms/step - loss: 0.0092 - accuracy: 0.6856 - val_loss: 0.0100 - val_accuracy: 0.6428
# Epoch 497/500
# 3/3 [==============================] - 2s 584ms/step - loss: 0.0092 - accuracy: 0.6780 - val_loss: 0.0108 - val_accuracy: 0.6448
# Epoch 498/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.0091 - accuracy: 0.6884 - val_loss: 0.0103 - val_accuracy: 0.6434
# Epoch 499/500
# 3/3 [==============================] - 2s 575ms/step - loss: 0.0091 - accuracy: 0.6855 - val_loss: 0.0102 - val_accuracy: 0.6435
# Epoch 500/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.0092 - accuracy: 0.6829 - val_loss: 0.0109 - val_accuracy: 0.6431
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Image Colorization/model-history/model/CtfPy_tfGTClass_AE2_GCData_100_500.model/assets
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Trying to Predict the Results

# %% [markdown]
# #### Loading the Model

# %%
# loading the model
newModel = keras.models.load_model(model_path)

# %% [markdown]
# #### Predict

# %%
fileName = '/content/gcImages/content/gc-dataset/train/450.jpg'

# %%
imgFile = tf.convert_to_tensor(fileName)

# %%
Ximg = ImageUtils.getRGBData(imgFile, img_w, img_h)

# %%
rgbResult = Colorizer().predictRGB(newModel, imgFile)
# Out:
# _fn_predLAB _l Shape : (256, 256, 1)
# _fn_predLAB _l re-Shape : (1, 256, 256, 1)
# (1, 256, 256, 1)
# (1, 256, 256, 2)
# (256, 256, 3)
# (256, 256, 3)

# %%
rgbResult = rgbResult.reshape((1,) + rgbResult.shape )

# %%
print('---- original -----')
plt.imshow(Ximg)
# Out:
# ---- original -----

# %%
print('---- predict -----')
plt.imshow(rgbResult[0])
# Out:
# ---- predict -----

# %%
print('---- grayScale -----')
imshow(gray2rgb(rgb2gray(imread(fileName))))
# Out:
# ---- grayScale -----
